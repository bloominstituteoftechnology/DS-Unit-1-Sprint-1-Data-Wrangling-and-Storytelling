# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Petrus/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Lucas_Petrus_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-06-02 19:43:10--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 52.89.160.109, 44.228.179.66, 35.163.140.110
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|52.89.160.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [           <=>      ]  22.10M  2.00MB/s    in 12s
#
# 2020-06-02 19:43:23 (1.89 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23170772]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)
df.shape
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                           2
# mo_sin_old_rev_tl_op             2
# delinq_amnt                      2
# chargeoff_within_12_mths         2
# acc_open_past_24mths             2
#                              ...
# settlement_percentage       127563
# id                          128412
# desc                        128414
# url                         128414
# member_id                   128414
# Length: 144, dtype: int64

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')
df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                           0
# mo_sin_old_rev_tl_op             0
# delinq_amnt                      0
# chargeoff_within_12_mths         0
# acc_open_past_24mths             0
#                              ...
# settlement_percentage       127561
# desc                        128412
# url                         128412
# member_id                   128412
# id                          128412
# Length: 144, dtype: int64

# %%
df.drop(['desc','url','member_id','id'], axis=1)
df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.dtypes
# Out:
# id                       float64
# member_id                float64
# loan_amnt                  int64
# funded_amnt                int64
# funded_amnt_inv          float64
#                           ...
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 144, dtype: object

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     14.47%
# 2     27.27%
# 3     12.98%
# 4     26.31%
# 5     17.97%
# 6     11.80%
# 7     10.72%
# 8     16.14%
# 9     12.98%
# Name: int_rate, dtype: object

# %%
df['int_rate'][3]
# Out:
# ' 12.98%'

# %%
int_rate = ' 12.98%'
int_rate.strip().strip('%')
# Out:
# '12.98'

# %%
type(int_rate.strip().strip('%'))
# Out:
# str

# %%
float(int_rate.strip().strip('%'))
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
int_rate_to_float(int_rate)
# Out:
# 12.98

# %%
type(int_rate_to_float(int_rate))
# Out:
# float

# %%
cleaned = []

for int_rate in df['int_rate']:
  cleaned.append(int_rate_to_float(int_rate))

df['int_rate_cleaned'] = pd.Series(cleaned)

# %%
df.head()
# Out:
#    id  member_id  ...  settlement_term  int_rate_cleaned
# 0 NaN        NaN  ...              NaN             14.47
# 1 NaN        NaN  ...              NaN             14.47
# 2 NaN        NaN  ...              NaN             27.27
# 3 NaN        NaN  ...              NaN             12.98
# 4 NaN        NaN  ...              NaN             26.31
#
# [5 rows x 145 columns]

# %%
df.dtypes['int_rate_cleaned']
# Out:
# dtype('float64')

# %%
int_rates = [' 16.57%',' 16.52%',' 16.58%',' 16.41%']

[int_rate_to_float(item)for item in int_rates]
# Out:
# [16.57, 16.52, 16.58, 16.41]

# %%
df['int_rate'] =df['int_rate'].apply(int_rate_to_float)
df.head()
# Out:
#    id  member_id  ...  settlement_term  int_rate_cleaned
# 0 NaN        NaN  ...              NaN             14.47
# 1 NaN        NaN  ...              NaN             14.47
# 2 NaN        NaN  ...              NaN             27.27
# 3 NaN        NaN  ...              NaN             12.98
# 4 NaN        NaN  ...              NaN             26.31
#
# [5 rows x 145 columns]

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
examples = ['owner', 'Supervisor',' Project Manager', np.NaN]

# %%
def clean_emp_title(title):
  if isinstance(title,str):
    return title.strip().title()
  else:
    return "Unknown"

for example in examples:
  print(clean_emp_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
df['new_column'] = [clean_emp_title(title) for title in examples]

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()
# Out:
#    id  member_id  ...  settlement_term  int_rate_cleaned
# 0 NaN        NaN  ...              NaN             14.47
# 1 NaN        NaN  ...              NaN             14.47
# 2 NaN        NaN  ...              NaN             27.27
# 3 NaN        NaN  ...              NaN             12.98
# 4 NaN        NaN  ...              NaN             26.31
#
# [5 rows x 145 columns]

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 34902

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'].tail()
# Out:
# 128407    Oct-2018
# 128408    Oct-2018
# 128409    Oct-2018
# 128410    Oct-2018
# 128411    Oct-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d'].head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    id  member_id  loan_amnt  ...  int_rate_cleaned  issue_year issue_month
# 0 NaN        NaN      20000  ...             14.47        2018          12
# 1 NaN        NaN      16000  ...             14.47        2018          12
# 2 NaN        NaN       8425  ...             27.27        2018          12
# 3 NaN        NaN      10000  ...             12.98        2018          12
# 4 NaN        NaN      30000  ...             26.31        2018          12
#
# [5 rows x 147 columns]

# %%
df.dtypes
# Out:
# id                       float64
# member_id                float64
# loan_amnt                  int64
# funded_amnt                int64
# funded_amnt_inv          float64
#                           ...
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# issue_year                 int64
# issue_month                int64
# Length: 147, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['earliest_cr_line'].head()
# Out:
# 0   1979-06-01
# 1   2001-11-01
# 2   1997-10-01
# 3   2007-05-01
# 4   2007-10-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days / 365
# Out:
# 0         39.528767
# 1         17.093151
# 2         21.180822
# 3         11.594521
# 4         11.175342
#             ...
# 128407    33.189041
# 128408    36.276712
# 128409    12.342466
# 128410    10.005479
# 128411    12.090411
# Length: 128412, dtype: float64

# %%
df['length_of_credit_history'] = (df['issue_d'] - df['earliest_cr_line']).dt.days / 365

df.head()
# Out:
#    id  member_id  loan_amnt  ...  issue_year  issue_month length_of_credit_history
# 0 NaN        NaN      20000  ...        2018           12                39.528767
# 1 NaN        NaN      16000  ...        2018           12                17.093151
# 2 NaN        NaN       8425  ...        2018           12                21.180822
# 3 NaN        NaN      10000  ...        2018           12                11.594521
# 4 NaN        NaN      30000  ...        2018           12                11.175342
#
# [5 rows x 148 columns]

# %%
df['length_of_credit_history'].describe()
# Out:
# count    128412.000000
# mean         16.054497
# std           7.908317
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: length_of_credit_history, dtype: float64

# %%
df['term']
# Out:
# 0          36 months
# 1          36 months
# 2          36 months
# 3          60 months
# 4          60 months
#              ...
# 128407     36 months
# 128408     36 months
# 128409     36 months
# 128410     36 months
# 128411     36 months
# Name: term, Length: 128412, dtype: object

# %%
#Convert the term column from string to integer.

def term_to_int(cell_contents):
  return int(cell_contents.strip(' months'))

df['new_term'] = df['term'].apply(term_to_int)

# %%
type(df['new_term'][0])
# Out:
# numpy.int64

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  ...  issue_month  length_of_credit_history new_term
# 0 NaN        NaN      20000  ...           12                 39.528767       36
# 1 NaN        NaN      16000  ...           12                 17.093151       36
# 2 NaN        NaN       8425  ...           12                 21.180822       36
# 3 NaN        NaN      10000  ...           12                 11.594521       60
# 4 NaN        NaN      30000  ...           12                 11.175342       60
#
# [5 rows x 149 columns]

# %%
#Make a column named loan_status_is_great. 
#It should contain the integer 1 if loan_status is "Current" 
#or "Fully Paid." Else it should contain the integer 0
def clean_loan_status(loan_status):
  if isinstance (loan_status, obj):
    return 1
  else:
    return 0

df['loan_status_is_great']= df['loan_status_is_great'].apply(clean_loan_status)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loan_status_is_great'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-0ed4a8612764> in <module>()
#       8     return 0
# ...

# %%
#Make last_pymnt_d_month and last_pymnt_d_year columns

[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
