# %% [markdown]
# <a href="https://colab.research.google.com/github/james-caldwell1981/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/LS_DS_111_Exploratory_Data_Analysis_Assignment_Caldwell_James_TL_Hadi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice Loading and Exploring Datasets
#
# This assignment is purposely open-ended. You will be asked to load datasets from the [UC-Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php).
#
# Even though you maybe using different datasets than your fellow classmates, try and be supportive and assist each other in the challenges that you are facing. You will only deepend your understanding of these topics as you work to assist one another. Many popular UCI datasets face similar data loading challenges.
#
# Remember that the UCI datasets do not necessarily have a file type of `.csv` so it's important that you learn as much as you can about the dataset before you try and load it. See if you can look at the raw text of the file either locally or using the `!curl` shell command -or in some other way before you try and read it in as a dataframe. This will help you catch what would otherwise be unforseen problems.
#
# Feel free to embellish this notebook with additional markdown cells,code cells, comments, graphs, etc. Whatever you think helps adequately address the questions.

# %% [markdown]
# ## 1) Load a dataset from UCI (via its URL)
#
# Please navigate to the home page and choose a dataset (other than the Adult dataset) from the "Most Popular" section on the right-hand side of the home page. Load the dataset via its URL and check the following (show your work):
#
# - Are the headers showing up properly?
# - Look at the first 5 and the last 5 rows, do they seem to be in order?
# - Does the dataset have the correct number of rows and columns as described in the UCI page?
#  - Remember, that UCI does not count the y variable (column of values that we might want to predict via a machine learning model) as an "attribute" but rather as a "class attribute" so you may end up seeing a number of columns that is one greater than the number listed on the UCI website.
# - Does UCI list this dataset as having missing values? Check for missing values and see if your analysis corroborates what UCI reports?
# - if `NaN` values or other missing value indicators are not being detected by `df.isnull().sum()` find a way to replace whatever is indicating the missing values with `np.NaN`.
# - Use the .describe() function in order to see the summary statistics of both the numeric and non-numeric columns.

# %%
import pandas as pd
import numpy as np

fire_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/forest-fires/forestfires.csv'
fire_headers = ['X', 'Y', 'Month', 'Day', 'FFMC', 'DMC', 'DC', 'ISI', 'Temp',
                'RH', 'Wind', 'Rain', 'Area']

df = pd.read_csv(fire_url, names=fire_headers, skiprows=1)

df.head()
# Out:
#    X  Y Month  Day  FFMC   DMC     DC  ISI  Temp  RH  Wind  Rain  Area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
#Print last 5 rows. All information seems to be in order
df.tail(5)
# Out:
#      X  Y Month  Day  FFMC    DMC     DC   ISI  Temp  RH  Wind  Rain   Area
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00

# %%
#No null or erroneous values found
df.isnull().sum()
# Out:
# X        0
# Y        0
# Month    0
# Day      0
# FFMC     0
# DMC      0
# DC       0
# ISI      0
# Temp     0
# RH       0
# Wind     0
# Rain     0
# Area     0
# dtype: int64

# %%
#Dataset has same number of rows as in documentation
print(df.describe())
# Out:
#                 X           Y        FFMC  ...        Wind        Rain         Area
# count  517.000000  517.000000  517.000000  ...  517.000000  517.000000   517.000000
# mean     4.669246    4.299807   90.644681  ...    4.017602    0.021663    12.847292
# std      2.313778    1.229900    5.520111  ...    1.791653    0.295959    63.655818
# min      1.000000    2.000000   18.700000  ...    0.400000    0.000000     0.000000
# 25%      3.000000    4.000000   90.200000  ...    2.700000    0.000000     0.000000
# 50%      4.000000    4.000000   91.600000  ...    4.000000    0.000000     0.520000
# 75%      7.000000    5.000000   92.900000  ...    4.900000    0.000000     6.570000
# max      9.000000    9.000000   96.200000  ...    9.400000    6.400000  1090.840000
#
# [8 rows x 11 columns]

# %% [markdown]
# ## 2) Load a dataset from your local machine.
# Choose a second dataset from the "Popular Datasets" listing on UCI, but this time download it to your local machine instead of reading it in via the URL. Upload the file to Google Colab using the files tab in the left-hand sidebar or by importing `files` from `google.colab` The following link will be a useful resource if you can't remember the syntax: <https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92>
#
# - Answer all of the same bullet point questions from part 1 again on this new dataset.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-051322a6-e1e0-4eb7-8e04-e5fac7881253" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-051322a6-e1e0-4eb7-8e04-e5fac7881253">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
adult_headers = ('age',
                'workclass',
                'fnlwgt',
                'education',
                'education-num',
                'marital-status',
                'occupation',
                'relationship',
                'race',
                'sex',
                'capital-gain',
                'capital-loss',
                'hours-per-week',
                'native-country',
                )

# %%
df = pd.read_csv('adult.data', index_col=False, names=adult_headers)
df.head()
# Out:
#    age          workclass  fnlwgt  ... capital-loss  hours-per-week  native-country
# 0   39          State-gov   77516  ...            0              40   United-States
# 1   50   Self-emp-not-inc   83311  ...            0              13   United-States
# 2   38            Private  215646  ...            0              40   United-States
# 3   53            Private  234721  ...            0              40   United-States
# 4   28            Private  338409  ...            0              40            Cuba
#
# [5 rows x 14 columns]

# %%
#data seems to be in order
df.tail()
# Out:
#        age      workclass  fnlwgt  ... capital-loss  hours-per-week  native-country
# 32556   27        Private  257302  ...            0              38   United-States
# 32557   40        Private  154374  ...            0              40   United-States
# 32558   58        Private  151910  ...            0              40   United-States
# 32559   22        Private  201490  ...            0              20   United-States
# 32560   52   Self-emp-inc  287927  ...            0              40   United-States
#
# [5 rows x 14 columns]

# %%
#No null values nor erroneous entries detected
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# dtype: int64

# %%
#correct number of headers listed including one output column 'area'
df.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# ## 3) Make Crosstabs of the Categorical Variables
#
# Take whichever of the above datasets has more categorical variables and use crosstabs to tabulate the different instances of the categorical variables.

# %%
print(adult_headers)
# Out:
# ('age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country')

# %%
crosstab1 = pd.crosstab(df['education'], df['native-country'])
crosstab1
# Out:
# native-country    ?   Cambodia   Canada  ...   United-States   Vietnam   Yugoslavia
# education                                ...
#  10th            12          0        2  ...             848         3            1
#  11th             8          0        5  ...            1067         3            0
#  12th            16          1        2  ...             365         1            0
#  1st-4th          5          1        0  ...              46         2            0
#  5th-6th         15          0        1  ...              97         2            0
#  7th-8th         19          1        2  ...             499         1            1
#  9th              8          0        3  ...             395         1            1
#  Assoc-acdm      12          0        1  ...             982         1            2
#  Assoc-voc       16          0        7  ...            1289         2            1
#  Bachelors      145          3       24  ...            4766        14            4
#  Doctorate       23          0        8  ...             328         1            0
#  HS-grad        133          7       31  ...            9702        16            3
#  Masters         49          0        8  ...            1527         0            0
#  Preschool        1          1        0  ...              17         0            0
#  Prof-school     17          0        2  ...             502         1            0
#  Some-college   104          5       25  ...            6740        19            3
#
# [16 rows x 42 columns]

# %%
crosstab2 = pd.crosstab(df['race'], df['native-country'])
crosstab2
# Out:
# native-country         ?   Cambodia  ...   Vietnam   Yugoslavia
# race                                 ...
#  Amer-Indian-Eskimo    0          0  ...         0            0
#  Asian-Pac-Islander   83         18  ...        65            0
#  Black                96          1  ...         0            0
#  Other                18          0  ...         0            0
#  White               386          0  ...         2           16
#
# [5 rows x 42 columns]

# %% [markdown]
# ## 4) Explore the distributions of the variables of the dataset using:
# - Histograms
# - Scatterplots
# - Density Plots

# %%
df['age'].hist();

# %%
df.plot.scatter(x='capital-gain', y='hours-per-week');

# %%
df['age'].plot(kind='density');

# %%
df[['education-num','age']].plot();

# %% [markdown]
# ## 5) Create at least one visualization from a crosstab:
#
# Remember that a crosstab is just a dataframe and can be manipulated in the same way by row index, column, index, or column/row/cell position.

# %%
crosstab = pd.crosstab(df['age'], df['education'])
crosstab.head()
# Out:
# education   10th   11th   12th  ...   Preschool   Prof-school   Some-college
# age                             ...
# 17           138    180     37  ...           0             0              3
# 18            38    166     60  ...           0             0            116
# 19            16     45     29  ...           1             0            329
# 20            15     27     14  ...           1             0            413
# 21            17     16      8  ...           2             0            372
#
# [5 rows x 16 columns]

# %%
crosstab.plot(kind='line', figsize=(8,6));

# %% [markdown]
# ## Stretch Goals
#
# The following additional study tasks are optional, they are intended to give you an opportunity to stretch yourself beyond the main requirements of the assignment. You can pick and choose from the below, you do not need to complete them in any particular order.
#
# ### - Practice Exploring other Datasets
#
# ### -  Try using the Seaborn plotting library's "Pairplot" functionality in order to explore all of the possible histograms and scatterplots of your dataset all at once:
#
# [Seaborn Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)
#
# ### - Turn some of the continuous variables into categorical variables by binning the values using:
# - [pd.cut()](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.cut.html)
# - [pd.qcut()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html)
# - <https://stackoverflow.com/questions/30211923/what-is-the-difference-between-pandas-qcut-and-pandas-cut>
#
# And then use crosstabs to compare/visualize these binned variables against the other variables.
#
#
# ### - Other types and sources of data
# Not all data comes in a nice single file - for example, image classification involves handling lots of image files. You still will probably want labels for them, so you may have tabular data in addition to the image blobs - and the images may be reduced in resolution and even fit in a regular csv as a bunch of numbers.
#
# If you're interested in natural language processing and analyzing text, that is another example where, while it can be put in a csv, you may end up loading much larger raw data and generating features that can then be thought of in a more standard tabular fashion.
#
# Overall you will in the course of learning data science deal with loading data in a variety of ways. Another common way to get data is from a database - most modern applications are backed by one or more databases, which you can query to get data to analyze. We'll cover this more in our data engineering unit.
#
# How does data get in the database? Most applications generate logs - text files with lots and lots of records of each use of the application. Databases are often populated based on these files, but in some situations you may directly analyze log files. The usual way to do this is with command line (Unix) tools - command lines are intimidating, so don't expect to learn them all at once, but depending on your interests it can be useful to practice.
#
# One last major source of data is APIs: https://github.com/toddmotto/public-apis
#
# API stands for Application Programming Interface, and while originally meant e.g. the way an application interfaced with the GUI or other aspects of an operating system, now it largely refers to online services that let you query and retrieve data. You can essentially think of most of them as "somebody else's database" - you have (usually limited) access.
#
# *Stretch goal* - research one of the above extended forms of data/data loading. See if you can get a basic example working in a notebook. Image, text, or (public) APIs are probably more tractable - databases are interesting, but there aren't many publicly accessible and they require a great deal of setup.

# %%
import seaborn as sns

# %%
heart = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/00519/heart_failure_clinical_records_dataset.csv')
heart.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
sns.pairplot(heart)

# %%
age_bins = pd.cut(heart['age'], bins=5)
platelet_bins = pd.cut(heart['platelets'], bins=10)

# %%
sodium_bins = pd.qcut(heart['serum_sodium'], q=4)
time_bins = pd.qcut(heart['time'], q=4)

# %%
import requests as req
import getpass as gp
import random as rand

# %%
base_url = 'https://cat-fact.herokuapp.com'
endp_facts = '/facts'

cat_fact_res = req.get(base_url+endp_facts)

cat_facts = cat_fact_res.json()
print(cat_facts)
# Out:
# {'all': [{'_id': '588e746706ac2b00110e59ff', 'text': 'Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.', 'type': 'cat', 'user': {'_id': '588e6e8806ac2b00110e59c3', 'name': {'first': 'Thomas', 'last': 'Lockwood'}}, 'upvotes': 13, 'userUpvoted': None}, {'_id': '5b1b40d4841d9700146158d8', 'text': 'Koko the gorilla got a pet cat for her birthday in 1985 after she requested to have one as a birthday present.', 'type': 'cat', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 13, 'userUpvoted': None}, {'_id': '58e007f50aac31001185ecf8', 'text': 'A group of cats is called a clowder.', 'type': 'cat', 'user': {'_id': '58e007480aac31001185ecef', 'name': {'first': 'Kasimir', 'last': 'Schulz'}}, 'upvotes': 12, 'userUpvoted': None}, {'_id': '58e008b80aac31001185ed0d', 'text': 'Adult cats only meow to communicate with humans.', 'type': 'cat', 'user': {'_id': '58e007480aac31001185ecef', 'name': {'first': 'Kasimir', 'last': 'Schulz'}}, 'upvotes': 12, 'userUpvoted': None}, {'_id': '5887e1d85c873e0011036889', 'text': 'Cats make about 100 different sounds. Dogs make only about 10.', 'type': 'cat', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 11, 'userUpvoted': None}, {'_id': '58e009420aac31001185ed11', 'text': 'Basically all cartoon cats lied to us: Raw fish is off the table for cats as well.', 'type': 'cat', 'user': {'_id': '58e007480aac31001185ecef', 'name': {'first': 'Kasimir', 'last': 'Schulz'}}, 'upvotes': 11, 'userUpvoted': None}, {'_id': '5b4910ae0508220014ccfe90', 'text': 'Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.', 'type': 'cat', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 11, 'userUpvoted': None}, {'_id': '58f8d7b98098c80011c50a42', 'text': 'A man named Ernest Misko gave marijuana tinctures to his 24-year-old cat, Borzo. In a couple of days, he was walking normally again, pain-free. Veterinarians in many states are still not legally allowed to prescribe cannabis to cats, even in states that have legalized medicinal marijuana for humans.', 'type': 'cat', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 10, 'userUpvoted': None}, {'_id': '58e00b970aac31001185edf9', 'text': 'A house cat is faster than Usain Bolt.', 'type': 'cat', 'user': {'_id': '58e007480aac31001185ecef', 'name': {'first': 'Kasimir', 'last': 'Schulz'}}, 'upvotes': 10, 'userUpvoted': None}, {'_id': '58e00b450aac31001185ed21', 'text': "There are 45 Hemingway cats living at the author's former home in Key West, Fla.", 'type': 'cat', 'user': {'_id': '58e007480aac31001185ecef', 'name': {'first': 'Kasimir', 'last': 'Schulz'}}, 'upvotes': 9, 'userUpvoted': None}, {'_id': '5b4911940508220014ccfe94', 'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.', 'type': 'cat', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 9, 'userUpvoted': None}, {'_id': '58e00af60aac31001185ed1d', 'text': 'It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.', 'type': 'cat', 'user': {'_id': '58e007480aac31001185ecef', 'name': {'first': 'Kasimir', 'last': 'Schulz'}}, 'upvotes': 8, 'userUpvoted': None}, {'_id': '5e236d6bdc76630015d4c51f', 'type': 'cat', 'text': 'gato loves grace', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 8, 'userUpvoted': None}, {'_id': '5b4912c60508220014ccfe99', 'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.', 'type': 'cat', 'user': {'_id': '5a9ac18c7478810ea6c06381', 'name': {'first': 'Alex', 'last': 'Wohlbruck'}}, 'upvotes': 8, 'userUpvoted': None}, {'_id': '58e009650aac310 ...

# %%
for i in range(len(cat_facts['all'])):
    fact = cat_facts['all'][i]
    print('Fact ', i, ': ', fact['text'],"\n \n")
# Out:
# Fact  0 :  Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.
#
#
# Fact  1 :  Koko the gorilla got a pet cat for her birthday in 1985 after she requested to have one as a birthday present.
#
#
# Fact  2 :  A group of cats is called a clowder.
#
#
# Fact  3 :  Adult cats only meow to communicate with humans.
#
#
# Fact  4 :  Cats make about 100 different sounds. Dogs make only about 10.
#
#
# Fact  5 :  Basically all cartoon cats lied to us: Raw fish is off the table for cats as well.
#
#
# Fact  6 :  Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.
#
#
# Fact  7 :  A man named Ernest Misko gave marijuana tinctures to his 24-year-old cat, Borzo. In a couple of days, he was walking normally again, pain-free. Veterinarians in many states are still not legally allowed to prescribe cannabis to cats, even in states that have legalized medicinal marijuana for humans.
#
#
# Fact  8 :  A house cat is faster than Usain Bolt.
#
#
# Fact  9 :  There are 45 Hemingway cats living at the author's former home in Key West, Fla.
#
#
# Fact  10 :  By the time a cat is 9 years old, it will only have been awake for three years of its life.
#
#
# Fact  11 :  It was illegal to slay cats in ancient Egypt, in large part because they provided the great service of controlling the rat population.
#
#
# Fact  12 :  gato loves grace
#
#
# Fact  13 :  Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.
#
#
# Fact  14 :  In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.
#
#
# Fact  15 :  The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.
#
#
# Fact  16 :  Cat owners are 17% more likely to have a graduate degree than non cat owners.
#
#
# Fact  17 :  Cats can distinguish different flavors in water.
#
#
# Fact  18 :  The oldest cat video on YouTube dates back to 1894.
#
#
# Fact  19 :  Cats sleep 70% of their lives.
#
#
# Fact  20 :  The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.
#
#
# Fact  21 :  The technical term for a cat’s hairball is a bezoar.
#
#
# Fact  22 :  People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.
#
#
# Fact  23 :  Female cats are typically right-pawed while male cats are typically left-pawed.
#
#
# Fact  24 :  Cats and humans have nearly identical sections of the brain that control emotion.
#
#
# Fact  25 :  The world's largest cat measured 48.5 inches long.
#
#
# Fact  26 :  Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.
#
#
# Fact  27 :  A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.
#
#
# Fact  28 :  In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.
#
#
# Fact  29 :  The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.
#
#
# Fact  30 :  Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.
#
#
# Fact  31 :  A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.
#
#
# Fact  32 :  Cats use their whiskers to detect if they can fit through a space.
#
#
# Fact  33 :  Cats love to eat olives or for that matter anything preserved in brine.
#
#
# Fact  34 :  Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk
#
#
# Fact  35 :  Cats "knead" because of seperation from their mothers
#
#
# Fact  36 :  Kangaroos can't hop backwards
#
#
# Fact  37 :  America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.
#
#
# Fact  38 :  Wikipedia has a recording of a cat meowing, because why not?
#
#
# Fact  39 :  The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare's Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."
#
#
# Fact  40 :  Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.
#
#
# Fact  41 :  There are cats who have survived falls from over 32 stories (320 meters) onto concrete.
#
#
# Fact  42 :  Most cats don't like water because their coats do not insulate them well enough.
#
#
# Fact  43 :  A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.
#
#
# Fact  44 :  The technical term for "hairball" is "bezoar."
#
#
# Fact  45 :  Cats make more than 100 different sounds whereas dogs make around 10.
#
#
# Fact  46 :  A cat's brain is 90% similar to a human's — more similar than to a dog's.
#
#
# Fact  47 :  Cats can survive falls from up to 65 feet or more.
#
#
# Fact  48 :  In 1879, Belgium unsuccessfully tried to use cats to deliver mail.
#
#
# Fact  49 :  Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.
#
#
# Fact  50 :  Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux
#
#
# Fact  51 :  Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.
#
#
# Fact  52 :  I don't know anything about cats.
#
#
# Fact  53 :  Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.
#
#
# Fact  54 :  Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.
#
#
# Fact  55 :  In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.
#
#
# Fact  56 :  The world's richest cat is worth $13 million after his human passed away and left her fortune to him.
#
#
# Fact  57 :  When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.
#
#
# Fact  58 :  A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.
#
#
# Fact  59 :  Your cat recognizes your voice but just acts too cool to care (probably because they are).
#
#
# Fact  60 :  Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.
#
#
# Fact  61 :  Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.
#
#
# Fact  62 :  When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."
#
#
# Fact  63 :  Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.
#
#
# Fact  64 :  One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.
#
#
# Fact  65 :  In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.
#
#
# Fact  66 :  When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.
#
#
# Fact  67 :  Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.
#
#
# Fact  68 :  A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.
#
#
# Fact  69 :  Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.
#
#
# Fact  70 :  The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.
#
#
# Fact  71 :  Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.
#
#
# Fact  72 :  Owning a cat can reduce the risk of stroke and heart attack by a third.
#
#
# Fact  73 :  The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.
#
#
# Fact  74 :  In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".
#
#
# Fact  75 :  A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.
#
#
# Fact  76 :  Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.
#
#
# Fact  77 :  A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.
#
#
# Fact  78 :  Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.
#
#
# Fact  79 :  Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.
#
#
# Fact  80 :  When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.
#
#
# Fact  81 :  In most US states, declawing cats is legal but in the European Union it is not.
#
#
# Fact  82 :  Kittens sleep so much because the growth hormone is only released when they sleep.
#
#
# Fact  83 :  It has been estimated that a cat yawns on the average of 109,500 times in his life.
#
#
# Fact  84 :  A cat can jump up to six times its length.
#
#
# Fact  85 :  Cats only sweat through their foot pads.
#
#
# Fact  86 :  A female cat is called a “molly” or a “queen”.
#
#
# Fact  87 :  Black cats are less likely to be adopted because of their "appearance".
#
#
# Fact  88 :  Cats were mythic symbols of divinity in ancient Egypt.
#
#
# Fact  89 :  Cats have 38 chromosomes in each zygote cell.
#
#
# Fact  90 :  If they have ample water, cats can tolerate temperatures up to 133 °F.
#
#
# Fact  91 :  The collective noun for kittens is a "kindle".
#
#
# Fact  92 :  Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!
#
#
# Fact  93 :  For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.
#
#
# Fact  94 :  Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.
#
#
# Fact  95 :  Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.
#
#
# Fact  96 :  A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.
#
#
# Fact  97 :  Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.
#
#
# Fact  98 :  The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".
#
#
# Fact  99 :  The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.
#
#
# Fact  100 :  Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.
#
#
# Fact  101 :  A cat can die from essential oils
#
#
# Fact  102 :  Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.
#
#
# Fact  103 :  Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.
#
#
# Fact  104 :  Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).
#
#
# Fact  105 :  Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).
#
#
# Fact  106 :  The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.
#
#
# Fact  107 :  A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.
#
#
# Fact  108 :  The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.
#
#
# Fact  109 :  The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.
#
#
# Fact  110 :  The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).
#
#
# Fact  111 :  The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."
#
#
# Fact  112 :  The Australian Wildlife Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who kill about a million native birds every night across Australia and have caused the extinction of 20 native species.
#
#
# Fact  113 :  Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.
#
#
# Fact  114 :  The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.
#
#
# Fact  115 :  Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.
#
#
# Fact  116 :  The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.
#
#
# Fact  117 :  A male cat is called a tom.
#
#
# Fact  118 :  Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.
#
#
# Fact  119 :  A cats whiskers are the exact width of their body.
#
#
# Fact  120 :  At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.
#
#
# Fact  121 :  Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.
#
#
# Fact  122 :  Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.
#
#
# Fact  123 :  When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.
#
#
# Fact  124 :  Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.
#
#
# Fact  125 :  The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.
#
#
# Fact  126 :  Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)
#
#
# Fact  127 :  Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.
#
#
# Fact  128 :  Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.
#
#
# Fact  129 :  In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.
#
#
# Fact  130 :  A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.
#
#
# Fact  131 :  Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.
#
#
# Fact  132 :  The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).
#
#
# Fact  133 :  Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.
#
#
# Fact  134 :  Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.
#
#
# Fact  135 :  The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.
#
#
# Fact  136 :  The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.
#
#
# Fact  137 :  Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.
#
#
# Fact  138 :  The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.
#
#
# Fact  139 :  While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.
#
#
# Fact  140 :  Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.
#
#
# Fact  141 :  All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.
#
#
# Fact  142 :  Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.
#
#
# Fact  143 :  If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.
#
#
# Fact  144 :  Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.
#
#
# Fact  145 :  The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.
#
#
# Fact  146 :  A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.
#
#
# Fact  147 :  Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.
#
#
# Fact  148 :  The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.
#
#
# Fact  149 :  In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.
#
#
# Fact  150 :  Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.
#
#
# Fact  151 :  The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.
#
#
# Fact  152 :  A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.
#
#
# Fact  153 :  Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry's duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".
#
#
# Fact  154 :  The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.
#
#
# Fact  155 :  The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.
#
#
# Fact  156 :  Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.
#
#
# Fact  157 :  The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.
#
#
# Fact  158 :  While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.
#
#
# Fact  159 :  The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.
#
#
# Fact  160 :  Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.
#
#
# Fact  161 :  The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.
#
#
# Fact  162 :  GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.
#
#
# Fact  163 :  About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.
#
#
# Fact  164 :  Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.
#
#
# Fact  165 :  The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.
#
#
# Fact  166 :  The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.
#
#
# Fact  167 :  Blackie became the richest cat in history when he inherited 15 million British Pounds.
#
#
# Fact  168 :  Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).
#
#
# Fact  169 :  Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.
#
#
# Fact  170 :  Approximately 1/3 of cat owners think their pets are able to read their minds.
#
#
# Fact  171 :  The average female housecat could give birth to ove 100 kittens in her lifetime.
#
#
# Fact  172 :  Cats don't go through menopause, so they can continue to breed into their senior years.
#
#
# Fact  173 :  Cats like being brushed by their owners, because it reminds them of their mother.
#
#
# Fact  174 :  Loyal, playful, and alert, Manx are considered to be more "doglike" than other cats.
#
#
# Fact  175 :  According to the American Society for the Prevention of Cruelty of Animals, newborn kittens get all the nutrition they need duing the first four weeks of life fom their mother's milk. If you are taking care of a kitten without its mother, or if the mother isn't producing enough milk, you can feed the kitten a commercial milk substitute.
#
#
# Fact  176 :  When kittens ages to weeks five and six, they should start making the transition to dry food.
#
#
# Fact  177 :  Legend holds that the Chartreux once lived alongside the Carthusian monks of France.
#
#
# Fact  178 :  Bobtail cats owe their shortened tails to a natural genetic mutation that has appeared in cats across time and in various regions of the world. The American Bobtail can be traced back to Yodi, a cat with the mutation that was found in Arizona in the 1960s. Yodi passed the genetic quirk on to his kittens, thus creating a new breed.
#
#
# Fact  179 :  Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.
#
#
# Fact  180 :  A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.
#
#
# Fact  181 :  The fear of cats is called "Ailurophobia"
#
#
# Fact  182 :  Cat owners are 25% likely to pick George Harrison as their favorite Beatle.
#
#
# Fact  183 :  Only 11.5% of people consider themselves "cat people".
#
#
# Fact  184 :  "Cat people" are 11% more likely to be introverted than others.
#
#
# Fact  185 :  The place where Julius Caesar was murdered is now a cat sanctuary.
#
#
# Fact  186 :  The Bombay cat breed was developed to resemble a miniature panther.
#
#
# Fact  187 :  Cats use their whiskers to judge whether they’ll fit through a space.
#
#
# Fact  188 :  Among domestic cats, males are more likely to fight than females.
#
#
# Fact  189 :  The softest part of a cat is most definitely its cheek area.
#
#
# Fact  190 :  When a cat yawns, it's mouth opens so wide that you can count every tooth.
#
#
# Fact  191 :  Cats can move their ears 180 degrees.
#
#
# Fact  192 :  Like humans, cats tend to favor one paw over another.
#
#
# Fact  193 :  Approximately 40,000 people are bitten by cats in the U.S. annually.
#
#
# Fact  194 :  Kittens start to dream when they’re about a week old.
#
#
# Fact  195 :  Approximately 40% of cats have a dominant paw. The rest are ambidextrous.
#
#
# Fact  196 :  Cats can have three litters a year, or approximately 12 kittens.
#
#
# Fact  197 :  If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!
#
#
# Fact  198 :  Approximately 80% of orange tabbies are male.
#
#
# Fact  199 :  If you need to trim a cat's nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you're using a pair of clippers specifically for cat's nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat's nail, which is full of blood vessels and nerves.
#
#
# Fact  200 :  Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.
#
#
# Fact  201 :  The cheetah is the only cat that doesn't have retractable claws.
#
#
# Fact  202 :  There are only two escalators in the state of Wyoming.
#
#
# Fact  203 :  When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn't been spayed, "elevator butt" could be a sign that she's ready to mate. The proper name for this stance is lordosis, and cats adopt it when they're in heat.
#
#
# Fact  204 :  On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".
#
#
# Fact  205 :  Cats can sense distress from a human being.
#
#
# Fact  206 :  Norwegian Forest Cats are usually very people friendly.
#
#
# Fact  207 :  During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.
#
#
# Fact  208 :  Courgars are the largest wild cats that can purr.
#
#
# Fact  209 :  Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.
#
#
# Fact  210 :  While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.
#
#
# Fact  211 :  It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.
#
#
# Fact  212 :  Dr. Seuss wrote The Cat in the Hat using only 236 words.
#
#
# Fact  213 :  Cats conserve energy by sleeping for an average of 13 to 14 hours a day.
#
#
# Fact  214 :  Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.
#
#
# Fact  215 :  Some cats do not eat fish.
#
#
# Fact  216 :  Cats can climb on trees faster than squirels.
#
#
# Fact  217 :  "Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".
#
#
# Fact  218 :  "A house cat is faster than Usain Bolt.".
#
#
# Fact  219 :  Yjyyu.
#
#
# Fact  220 :  Cats are fat, sometimes.
#
#
# Fact  221 :  Sss.
#
#
# Fact  222 :  In a sense, cats can see in the dark.
#
#
# Fact  223 :  Cats are the best pets.
#
#
# Fact  224 :  Hello cats.
#
#
# Fact  225 :  Cats love womans, dog loves mans.
#
#
# Fact  226 :  Cat is cat.
#
#
# Fact  227 :  Z.
#
#
# Fact  228 :  Los gatos tienen más huesos que los seres humanos, nos ganan por 24.
#
#
# Fact  229 :  Take a try.
#
#
# Fact  230 :  Cats are cats.
#
#
# Fact  231 :  Lucy, the oldest cat ever, lived to be 39 years old which is equivalent to 172 cat years.
#
#
# Fact  232 :  Fdfd.
#
#
# Fact  233 :  Cxcbc.
#
#
# Fact  234 :  Jfhfhf.
#
#
# Fact  235 :  The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.
#
#
# Fact  236 :  In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.
#
#
# Fact  237 :  American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.
#
#
# Fact  238 :  If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.
#
#
# Fact  239 :  Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.
#
#
# Fact  240 :  The pink substance inside a cat's nail is called the "quick" or the "dermis". When trimming your cat's nails, be sure to only cut the upper white part of the nail, not the quick.
#
#
# Fact  241 :  The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.
#
#
# Fact  242 :  Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.
#
#
# Fact  243 :  While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.
#
#
# Fact  244 :  Kittens typically begin to engage in playful behavior at around four weeks of age.
#
#
# Fact  245 :  Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship's cat as cats would eat the rats that have always plagued ships. The ship's cat would often be given a rank and sailors would generally take excessively good care of their cats.
#
#
# Fact  246 :  Cats sleep most of the time.
