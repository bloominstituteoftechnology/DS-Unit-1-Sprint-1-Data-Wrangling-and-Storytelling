# %% [markdown]
# <a href="https://colab.research.google.com/github/manic2man/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/MarshallShoots_Unit1_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# At one point the website went down, but I had downloaded the dataset already
# I just wanted to use the url because it meant someone else could run this.
#df = pd.read_csv('/content/BCHI-dataset_2019-03-04.csv')
url = 'https://bchi.bigcitieshealth.org/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBPUT09IiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--d420076690399fd28de697fa5a876e8b1d3188ac/BCHI-dataset_2019-03-04.csv?disposition=attachment'
df = pd.read_csv(url)
df.head()
# Out:
#                   Indicator Category  ... 95% Confidence Level - High
# 0  Behavioral Health/Substance Abuse  ...                         NaN
# 1  Behavioral Health/Substance Abuse  ...                         3.0
# 2  Behavioral Health/Substance Abuse  ...                         3.2
# 3  Behavioral Health/Substance Abuse  ...                         3.9
# 4  Behavioral Health/Substance Abuse  ...                         4.5
#
# [5 rows x 15 columns]

# %%
# I may change my mind later, but I want observations I can compare against each other,
# while camparing across different sexes and races may twist results
df1 = df[(df['Sex'] == 'Both') & (df['Race/Ethnicity'] == 'All')]
df1
# Out:
#                       Indicator Category  ... 95% Confidence Level - High
# 0      Behavioral Health/Substance Abuse  ...                         NaN
# 1      Behavioral Health/Substance Abuse  ...                         3.0
# 2      Behavioral Health/Substance Abuse  ...                         3.2
# 3      Behavioral Health/Substance Abuse  ...                         3.9
# 4      Behavioral Health/Substance Abuse  ...                         4.5
# ...                                  ...  ...                         ...
# 34313        Social and Economic Factors  ...                         NaN
# 34314        Social and Economic Factors  ...                         NaN
# 34315        Social and Economic Factors  ...                         NaN
# 34316        Social and Economic Factors  ...                         NaN
# 34317        Social and Economic Factors  ...                         NaN
#
# [6164 rows x 15 columns]

# %%
#Don't need the methodologies for visualization
df_slim = df1[['Place', 'Year', 'Indicator', 'Value']]
df_slim
# Out:
#                                  Place  ...  Value
# 0                       Washington, DC  ...    1.7
# 1      Fort Worth (Tarrant County), TX  ...    2.2
# 2         Oakland (Alameda County), CA  ...    2.3
# 3                      San Antonio, TX  ...    3.0
# 4               U.S. Total, U.S. Total  ...    4.4
# ...                                ...  ...    ...
# 34313                      Chicago, Il  ...   10.9
# 34314                    Baltimore, MD  ...   11.8
# 34315                 Philadelphia, PA  ...   12.8
# 34316                    Cleveland, OH  ...   18.4
# 34317                      Detroit, MI  ...   21.6
#
# [6164 rows x 4 columns]

# %%
# Just picking out my variables
# Heart Disease Mortality Rate (Age-Adjusted; Per 100,000 people)
# Diabetes Mortality Rate (Age-Adjusted; Per 100,000 people)
# All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)
# Suicide Rate (Age-Adjusted; Per 100,000 people)
# Percent of Population Uninsured
# Percent of Adults Who Meet CDC-Recommended Physical Activity Levels
df_slim.Indicator.value_counts()
# Out:
# Percent of Households Whose Housing Costs Exceed 35% of Income                                         165
# Persons Living with HIV/AIDS Rate (Per 100,000 people)                                                 145
# Total Population (People)                                                                              145
# Percent Who Only Speak English at Home                                                                 145
# Heart Disease Mortality Rate (Age-Adjusted; Per 100,000 people)                                        143
# Percent of Population Under 18                                                                         143
# Percent of 3 and 4 Year Olds Currently Enrolled in Preschool                                           142
# Percent of Population with a Disability                                                                142
# Percent Who Speak Spanish at Home                                                                      142
# Diabetes Mortality Rate (Age-Adjusted; Per 100,000 people)                                             142
# Percent of Population 65 and Over                                                                      140
# All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)                                  140
# HIV Diagnoses Rate (Per 100,000 people)                                                                140
# Percent Foreign Born                                                                                   138
# Median Household Income (Dollars)                                                                      138
# AIDS Diagnoses Rate (Per 100,000 people)                                                               138
# Lung Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)                                          136
# Percent of High School Graduates (Over Age 18)                                                         134
# Pneumonia and Influenza Mortality Rate (Age-Adjusted; Per 100,000 people)                              134
# Tuberculosis Incidence Rate (Per 100,000 people)                                                       133
# HIV-Related Mortality Rate (Age-Adjusted; Per 100,000 people)                                          132
# Gonorrhea Rate (Per 100,000 People)                                                                    131
# Percent of Low Birth Weight Babies Born                                                                131
# Motor Vehicle Mortality Rate (Age-Adjusted; Per 100,000 people)                                        131
# Percent of Population Uninsured                                                                        131
# Homicide Rate (Age-Adjusted; Per 100,000 people)                                                       130
# Infant Mortality Rate (Per 1,000 live births)                                                          129
# Suicide Rate (Age-Adjusted; Per 100,000 people)                                                        126
# Chlamydia Rate (Per 100,000 People)                                                                    126
# Rate of Laboratory Confirmed Infections Caused by Shiga Toxin-Producing E-Coli (Per 100,000 people)    125
# Firearm-Related Mortality Rate (Age-Adjusted; Per 100,000 people)                                      124
# Rate of Laboratory Confirmed Infections Caused by Salmonella (Per 100,000 people)                      124
# All-Cause Mortality Rate (Age-Adjusted; Per 100,000 people)                                            123
# Primary and Secondary Syphilis Rate (Per 100,000 People)                                               120
# Percent of Children Living in Poverty                                                                  112
# Percent Living Below 200% Poverty Level                                                                107
# Percent of Adults Who Are Obese                                                                        107
# Percent of Adults Who Binge Drank                                                                      101
# Percent of Adults Who Currently Smoke                                                                   98
# Congenital Syphilis Rate (Per 100,000 Live Births)                                                      94
# Opioid-Related Unintentional Drug Overdose Mortality Rate (Age-Adjusted; Per 100,000 people)            91
# Percent of Adults 65 and Over Who Received Pneumonia Vaccine                                            89
# Percent of Adults Who Received Seasonal Flu Shot                                                        81
# Percent of Children (Tested) Under Age 6 with Elevated Blood Lead Levels                                81
# Life Expectancy at Birth (Years)                                                                        78
# Percent Unemployed                                                                                      70
# Percent of Adults Who Meet CDC-Recommended Physical Activity Levels                                     60
# Percent of High School Students Who Are Obese                                                           51
# Asthma Emergency Department Visit Rate (Age-Adjusted; Per 10,000)                                       50
# Firearm-Related Emergency Department Visit Rate (Age-Adjusted; Per 10,000 people)                       50
# Percent of High School Students Who Meet CDC-Recommended Physical Activity Levels                       46
# Percent of High School Students Who Binge Drank                                                         44
# Percent of High School Students Who Currently Smoke                                                     43
# Percent of Children Who Received Seasonal Flu Shot                                                      36
# Transit Score                                                                                           21
# Bike Score                                                                                              21
# Walkability                                                                                             19
# Percent of Mothers Under Age 20                                                                          6
# Name: Indicator, dtype: int64

# %%
df_small = df_slim[df_slim['Indicator'].isin(['Heart Disease Mortality Rate (Age-Adjusted; Per 100,000 people)',
                                              'Diabetes Mortality Rate (Age-Adjusted; Per 100,000 people)',
                                              'All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)',
                                              'Suicide Rate (Age-Adjusted; Per 100,000 people)',
                                              'Percent of Population Uninsured',
                                              'Percent of Adults Who Meet CDC-Recommended Physical Activity Levels'])]
df_small['Indicator'].value_counts()
# Out:
# Heart Disease Mortality Rate (Age-Adjusted; Per 100,000 people)          143
# Diabetes Mortality Rate (Age-Adjusted; Per 100,000 people)               142
# All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)    140
# Percent of Population Uninsured                                          131
# Suicide Rate (Age-Adjusted; Per 100,000 people)                          126
# Percent of Adults Who Meet CDC-Recommended Physical Activity Levels       60
# Name: Indicator, dtype: int64

# %%
df_small.head()
# Out:
#                               Place  ...  Value
# 1465                Los Angeles, CA  ...   88.5
# 1466                    Phoenix, AZ  ...   98.0
# 1467  Miami (Miami-Dade County), FL  ...  140.1
# 1468              San Francisco, CA  ...  149.9
# 1469                    Seattle, WA  ...  156.7
#
# [5 rows x 4 columns]

# %%
df_small.shape
# Out:
# (742, 4)

# %%
# Setting that option was useful for seeing full datasets, but it just makes the
#notebook cumbersome to read at this point
#pd.options.display.max_rows = 999
df_wide = df_small.pivot_table(index=['Place', 'Year'], columns='Indicator', values='Value').reset_index()
df_wide
# Out:
# Indicator           Place  ...  Suicide Rate (Age-Adjusted; Per 100,000 people)
# 0              Austin, TX  ...                                              NaN
# 1              Austin, TX  ...                                              NaN
# 2           Baltimore, MD  ...                                              NaN
# 3           Baltimore, MD  ...                                              NaN
# 4           Baltimore, MD  ...                                              NaN
# ..                    ...  ...                                              ...
# 196        Washington, DC  ...                                              5.5
# 197        Washington, DC  ...                                              NaN
# 198        Washington, DC  ...                                              NaN
# 199        Washington, DC  ...                                              NaN
# 200        Washington, DC  ...                                              NaN
#
# [201 rows x 8 columns]

# %%
# Its about to get a little weird, but I kinda want to fill in some exercise data
# Good news, these numbers are very consistent year to year, so a simple mean will suffice
# Bad news, they differ wildly from one city to the next.

# %%
df_wide = df_wide.set_index('Place')
df_wide.head()
# Out:
# Indicator      Year  ...  Suicide Rate (Age-Adjusted; Per 100,000 people)
# Place                ...
# Austin, TX     2015  ...                                              NaN
# Austin, TX     2016  ...                                              NaN
# Baltimore, MD  2010  ...                                              NaN
# Baltimore, MD  2011  ...                                              NaN
# Baltimore, MD  2012  ...                                              NaN
#
# [5 rows x 7 columns]

# %%
for city in (df_wide.index.unique()):
  if len(df_wide.loc[city, 'Percent of Adults Who Meet CDC-Recommended Physical Activity Levels'].dropna()) > 0:
    df_wide.loc[city,'Percent of Adults Who Meet CDC-Recommended Physical Activity Levels'] = df_wide.loc[city,'Percent of Adults Who Meet CDC-Recommended Physical Activity Levels'].fillna(np.nanmean(df_wide.loc[city,'Percent of Adults Who Meet CDC-Recommended Physical Activity Levels']))

# %%
df_wide = df_wide.reset_index()
df_wide
# Out:
# Indicator           Place  ...  Suicide Rate (Age-Adjusted; Per 100,000 people)
# 0              Austin, TX  ...                                              NaN
# 1              Austin, TX  ...                                              NaN
# 2           Baltimore, MD  ...                                              NaN
# 3           Baltimore, MD  ...                                              NaN
# 4           Baltimore, MD  ...                                              NaN
# ..                    ...  ...                                              ...
# 196        Washington, DC  ...                                              5.5
# 197        Washington, DC  ...                                              NaN
# 198        Washington, DC  ...                                              NaN
# 199        Washington, DC  ...                                              NaN
# 200        Washington, DC  ...                                              NaN
#
# [201 rows x 8 columns]

# %%
# I no longer need the location or year for cleaning, just the raw data for graphing
df_clean = df_wide.copy()
df_clean['Cancer'] = df_clean['All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)']
df_clean['Diabetes'] = df_clean['Diabetes Mortality Rate (Age-Adjusted; Per 100,000 people)']
df_clean['Heart Disease'] = df_clean['Heart Disease Mortality Rate (Age-Adjusted; Per 100,000 people)']
df_clean['Suicide'] = df_clean['Suicide Rate (Age-Adjusted; Per 100,000 people)']
df_clean = df_clean[['Percent of Adults Who Meet CDC-Recommended Physical Activity Levels',
                     'Percent of Population Uninsured',
                     'Cancer','Diabetes','Heart Disease', 'Suicide']]
df_clean.head()
# Out:
# Indicator  Percent of Adults Who Meet CDC-Recommended Physical Activity Levels  ...  Suicide
# 0                                                        NaN                    ...      NaN
# 1                                                        NaN                    ...      NaN
# 2                                                       68.4                    ...      NaN
# 3                                                       68.4                    ...      NaN
# 4                                                       68.6                    ...      NaN
#
# [5 rows x 6 columns]

# %%
# Seaborn likes tidy format, so making a dataframe for each comparison
df_exercise = pd.melt(df_clean, id_vars='Percent of Adults Who Meet CDC-Recommended Physical Activity Levels', value_vars=['Cancer',	'Diabetes',	'Heart Disease',	'Suicide']).dropna()
df_exercise = df_exercise.rename(columns={'Indicator':'Cause', 'value': 'Deaths per 100,000 people'})
df_exercise
# Out:
#      Percent of Adults Who Meet CDC-Recommended Physical Activity Levels  ... Deaths per 100,000 people
# 4                                                 68.6                    ...                     213.9
# 9                                                 21.5                    ...                     184.1
# 10                                                21.5                    ...                     171.5
# 11                                                21.5                    ...                     187.3
# 12                                                24.2                    ...                     175.7
# ..                                                 ...                    ...                       ...
# 788                                               27.0                    ...                      12.0
# 791                                               48.8                    ...                      12.3
# 792                                               50.0                    ...                      12.6
# 793                                               49.9                    ...                      12.6
# 794                                               28.5                    ...                      13.0
#
# [460 rows x 3 columns]

# %%
df_uninsured = pd.melt(df_clean, id_vars='Percent of Population Uninsured', value_vars=['Cancer',	'Diabetes',	'Heart Disease',	'Suicide']).dropna()
df_uninsured = df_uninsured.rename(columns={'Indicator':'Cause', 'value': 'Deaths per 100,000 people'})
df_uninsured
# Out:
#      Percent of Population Uninsured    Cause  Deaths per 100,000 people
# 4                               12.3   Cancer                      213.9
# 13                               5.1   Cancer                      153.1
# 22                              19.2   Cancer                      186.1
# 23                              19.7   Cancer                      187.2
# 31                              11.8   Cancer                      218.3
# ..                               ...      ...                        ...
# 787                              6.5  Suicide                       10.4
# 788                              4.4  Suicide                       12.0
# 792                             14.8  Suicide                       12.6
# 793                             14.5  Suicide                       12.6
# 794                             11.7  Suicide                       13.0
#
# [296 rows x 3 columns]

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from matplotlib import pyplot
fig, ax = pyplot.subplots(figsize=(12,6))
ax = sns.scatterplot(x="Percent of Adults Who Meet CDC-Recommended Physical Activity Levels",
                     y="Deaths per 100,000 people",
                     hue="Cause",
                     data=df_exercise)
ax.set_title("Influence of Exercise on Various Cause of Death in US Cities")
# Out:
# Text(0.5, 1.0, 'Influence of Exercise on Various Cause of Death in US Cities')

# %%
# With the huge disparity in values, Ill break these each into two smaller graphs
df_e1 = df_exercise[(df_exercise['Cause'] == 'Cancer') | (df_exercise['Cause'] == 'Heart Disease')]
df_e2 = df_exercise[(df_exercise['Cause'] == 'Diabetes') | (df_exercise['Cause'] == 'Suicide')]

# %%
fig, ax = pyplot.subplots(figsize=(12,6))
ax = sns.scatterplot(x="Percent of Adults Who Meet CDC-Recommended Physical Activity Levels",
                     y="Deaths per 100,000 people",
                     hue="Cause",
                     data=df_e1)
ax.set_title("Influence of Exercise on Cancer and Heart Disease Deaths in US Cities")
# Out:
# Text(0.5, 1.0, 'Influence of Exercise on Cancer and Heart Disease Deaths in US Cities')

# %%
fig, ax = pyplot.subplots(figsize=(12,6))
ax = sns.scatterplot(x="Percent of Adults Who Meet CDC-Recommended Physical Activity Levels",
                     y="Deaths per 100,000 people",
                     hue="Cause",
                     data=df_e2)
ax.set_title("Influence of Exercise on Diabetes and Suicide Deaths in US Cities")
# Out:
# Text(0.5, 1.0, 'Influence of Exercise on Diabetes and Suicide Deaths in US Cities')

# %%
fig, ax = pyplot.subplots(figsize=(12,6))
ax = sns.scatterplot(x="Percent of Population Uninsured",
                     y="Deaths per 100,000 people",
                     hue="Cause",
                     data=df_uninsured)
ax.set_title("Effects of Lack of Insurance on Various Cause of Death in US Cities")
# Out:
# Text(0.5, 1.0, 'Effects of Lack of Insurance on Various Cause of Death in US Cities')

# %%
#Now to break this one in half too
df_i1 = df_uninsured[(df_uninsured['Cause'] == 'Cancer') | (df_uninsured['Cause'] == 'Heart Disease')]
df_i2 = df_uninsured[(df_uninsured['Cause'] == 'Diabetes') | (df_uninsured['Cause'] == 'Suicide')]

# %%
fig, ax = pyplot.subplots(figsize=(12,6))
ax = sns.scatterplot(x="Percent of Population Uninsured",
                     y="Deaths per 100,000 people",
                     hue="Cause",
                     data=df_i1)
ax.set_title("Effects of Lack of Insurance on Cancer and Heart Disease Deaths in US Cities")
# Out:
# Text(0.5, 1.0, 'Effects of Lack of Insurance on Cancer and Heart Disease Deaths in US Cities')

# %%
fig, ax = pyplot.subplots(figsize=(12,6))
ax = sns.scatterplot(x="Percent of Population Uninsured",
                     y="Deaths per 100,000 people",
                     hue="Cause",
                     data=df_i2)
ax.set_title("Effects of Lack of Insurance on Diabetes and Suicide Deaths in US Cities")
# Out:
# Text(0.5, 1.0, 'Effects of Lack of Insurance on Diabetes and Suicide Deaths in US Cities')
