# %% [markdown]
# <a href="https://colab.research.google.com/github/ttped/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module4-make-explanatory-visualizations/Trevor_Pedersen_LS_DS_114_Make_Explanatory_Visualizations_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 1, Sprint 1, Module 4*
#
# ---
#
# # ASSIGNMENT
#
# ### 1) Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# Get caught up to where we got our example in class and then try and take things further. How close to "pixel perfect" can you make the lecture graph?
#
# Once you have something that you're proud of, share your graph in the cohort channel and move on to the second exercise.
#
# ### 2) Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
# **WARNING**: There are a lot of very custom graphs and tables at the above link. I **highly** recommend not trying to reproduce any that look like a table of values or something really different from the graph types that we are already familiar with. Search through the posts until you find a graph type that you are more or less familiar with: histogram, bar chart, stacked bar chart, line chart, [seaborn relplot](https://seaborn.pydata.org/generated/seaborn.relplot.html), etc. Recreating some of the graphics that 538 uses would be a lot easier in Adobe photoshop/illustrator than with matplotlib.
#
# - If you put in some time to find a graph that looks "easy" to replicate you'll probably find that it's not as easy as you thought.
#
# - If you start with a graph that looks hard to replicate you'll probably run up against a brick wall and be disappointed with your afternoon.

# %%
import pandas as pd

df = pd.DataFrame({'a': [1,3,2,4,3,5], 'b': [3,5,4,6,5,7]})

df.head()
# Out:
#    a  b
# 0  1  3
# 1  3  5
# 2  2  4
# 3  4  6
# 4  3  5

# %%
fig, ax = plt.subplots()
## Everything in the middle is done on the figure or the axes

fig.patch.set_facecolor('green')

ax.plot(df['a'])
ax.set_facecolor('yellow')
ax.set_title('Graph Title', color='white')
ax.set_xlabel('x axis', color='white')

plt.show()

# %%
from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
# Your Work Here
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots()

fig.set_facecolor('white')

#put bars on the plot
ax.bar(x=range(1,11,1),  height=fake, color='#ED713A', width=.91)

# white axes background
ax.set_facecolor('white')

# x axis ticks and tick labels
ax.set_xticks(range(1,11,1))
ax.set_xticklabels(range(1,11,1))

# y axis ticks and tick labels
ax.set_yticks(range(0, 41, 10))
ax.set_yticklabels([0, 10, 20, 30, "40%"])

# Axis Titles
ax.set_xlabel('Rating', fontsize=10, fontweight='bold')
ax.set_ylabel('Percent of total votes', fontsize=10, fontweight='bold')

# Title
# x and y refer to the size of the graph
ax.set_title("'An Inconvenient Sequel: Truth to Power' is divisive", fontsize=12, fontweight='bold', x=.35, y=1.15)

# Subtitle (All pieces of text on a graph, are just custom text objects)
# x and y refer to axis positions only for text objects
ax.text(x=-1.1, y=44, s='IMDb ratings for the film as of Aug. 29')

# Silly Text
# ax.text(x=9, y=36, s="Loved the Movie")
# ax.text(x=.5, y=39, s="Haters")

# Turn off some of the spines

ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# show the graph
plt.show()

# %%
#Part 2 of assignment

# %%
# !wget https://projects.fivethirtyeight.com/data-webpage-data/datasets/bob-ross.zip
# Out:
# --2020-08-06 20:50:06--  https://projects.fivethirtyeight.com/data-webpage-data/datasets/bob-ross.zip
# Resolving projects.fivethirtyeight.com (projects.fivethirtyeight.com)... 151.101.2.109, 151.101.66.109, 151.101.130.109, ...
# Connecting to projects.fivethirtyeight.com (projects.fivethirtyeight.com)|151.101.2.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9569 (9.3K) [application/zip]
# Saving to: ‘bob-ross.zip’
#
# bob-ross.zip        100%[===================>]   9.34K  --.-KB/s    in 0s
#
# 2020-08-06 20:50:07 (101 MB/s) - ‘bob-ross.zip’ saved [9569/9569]

# %%
# !unzip 'bob-ross.zip'
# Out:
# Archive:  bob-ross.zip
#    creating: bob-ross/
#   inflating: bob-ross/cluster-paintings.py
#   inflating: bob-ross/README.md
#   inflating: bob-ross/elements-by-episode.csv

# %%
# !wget https://fivethirtyeight.com/wp-content/uploads/2014/04/hickey-ross-tags-1.png?w=575
# Out:
# --2020-08-06 21:15:57--  https://fivethirtyeight.com/wp-content/uploads/2014/04/hickey-ross-tags-1.png?w=575
# Resolving fivethirtyeight.com (fivethirtyeight.com)... 192.0.66.2
# Connecting to fivethirtyeight.com (fivethirtyeight.com)|192.0.66.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85450 (83K) [image/png]
# Saving to: ‘hickey-ross-tags-1.png?w=575’
#
# hickey-ross-tags-1. 100%[===================>]  83.45K  --.-KB/s    in 0.03s
#
# 2020-08-06 21:15:58 (3.07 MB/s) - ‘hickey-ross-tags-1.png?w=575’ saved [85450/85450]

# %%
from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2014/04/hickey-ross-tags-1.png?w=575'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2014/04/hickey-ross-tags-1.png?w=575" width="400"/>

# %%
df2 = pd.read_csv('bob-ross/elements-by-episode.csv')
df2
# Out:
#     EPISODE                     TITLE  ...  WINTER  WOOD_FRAMED
# 0    S01E01     "A WALK IN THE WOODS"  ...       0            0
# 1    S01E02            "MT. MCKINLEY"  ...       1            0
# 2    S01E03            "EBONY SUNSET"  ...       1            0
# 3    S01E04             "WINTER MIST"  ...       0            0
# 4    S01E05            "QUIET STREAM"  ...       0            0
# ..      ...                       ...  ...     ...          ...
# 398  S31E09        "EVERGREEN VALLEY"  ...       0            0
# 399  S31E10             "BALMY BEACH"  ...       0            0
# 400  S31E11       "LAKE AT THE RIDGE"  ...       0            0
# 401  S31E12  "IN THE MIDST OF WINTER"  ...       1            0
# 402  S31E13          "WILDERNESS DAY"  ...       0            0
#
# [403 rows x 69 columns]

# %%
temp = df2.copy()
temp = temp.drop(['EPISODE', 'TITLE'], axis=1)
sum = temp.sum()
sum = sum.sort_values(ascending=True)
sum.plot(kind='barh', figsize=(8, 16))
plt.plot()
# Out:
# []

# %%
#A good start, but lets drop some tables that aren't included in original graph
#It seems they dropped everything with very small values so we'll start dropping those rows
#anything less than 4 seems to be a good start
mask = sum > 4
copy = sum[mask]
copy = copy.drop('GUEST')
copy = copy.drop('STEVE_ROSS')
copy.plot(kind='barh', figsize=(8, 16))
plt.plot()
# Out:
# []

# %%
#Closer, but still many things off
#Need to increase width of bars and change them to a lighter color
#Need to add title
#Need to add subtitle
#The Y-axis titles need to be changed
#Some of the rows have been combined into 1
#

# %%
display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2014/04/hickey-ross-tags-1.png?w=575" width="400"/>

# %% [markdown]
# # STRETCH OPTIONS
#
# ### 1) Reproduce one of the following using the matplotlib or seaborn libraries:
#
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/)
# - or another example of your choice!
#
# ### 2) Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!
