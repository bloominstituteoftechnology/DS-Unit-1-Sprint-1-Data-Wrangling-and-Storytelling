# %% [markdown]
# <a href="https://colab.research.google.com/github/Mike-Xie/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module4-make-explanatory-visualizations/Mike_Xie_LS_DS_114_Make_Explanatory_Visualizations_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 1, Sprint 1, Module 4*
#
# ---
#
# # ASSIGNMENT
#
# ### 1) Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# Get caught up to where we got our example in class and then try and take thing`s further. How close to "pixel perfect" can you make the lecture graph?
#
# Once you have something that you're proud of, share your graph in the cohort channel and move on to the second exercise.
#
# ### 2) Reproduce another example from [FiveThityEight's shared data repository](https://data.fivethirtyeight.com/).
#
# **WARNING**: There are a lot of very custom graphs and tables at the above link. I **highly** recommend not trying to reproduce any that look like a table of values or something really different from the graph types that we are already familiar with. Search through the posts until you find a graph type that you are more or less familiar with: histogram, bar chart, stacked bar chart, line chart, [seaborn relplot](https://seaborn.pydata.org/generated/seaborn.relplot.html), etc. Recreating some of the graphics that 538 uses would be a lot easier in Adobe photoshop/illustrator than with matplotlib.
#
# - If you put in some time to find a graph that looks "easy" to replicate you'll probably find that it's not as easy as you thought.
#
# - If you start with a graph that looks hard to replicate you'll probably run up against a brick wall and be disappointed with your afternoon.

# %% [markdown]
# # Part 1 Replicate Lesson Code

# %%
# start with imports as always
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter

# %%
# what we want to replicate
from IPython.display import display, Image

url = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png'
example = Image(url=url, width=400)

display(example)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>

# %%
# data for our version

ratings = [38,3,2,1,2,4,6,5,5,5,33]
data = pd.Series(ratings, index=range(1,12))
plt.style.use('fivethirtyeight')

data.plot.bar(color='#ED703A', width=0.8);

# %%
# use fig, axe style

fig, ax = plt.subplots()

#bars on axis
data.plot.bar(width=0.9, color='#ED703A')

# color outside of graph
fig.patch.set(facecolor='white')
# bg color inside of graph
ax.set_facecolor('white')

ax.set_title("'An Inconvenient Sequel: Truth To Power' is divisive", 
             fontsize=13, fontweight='bold', x=.35, y=1.1)

#set plot sub title
ax.text(s="IMDb ratings for the film as of Aug. 29", y=41.8, x=-2.35, fontsize=11)

# set plot y and x label
ax.set_ylabel("Percent of Total Votes", fontsize=11, fontweight='medium')
ax.set_xlabel("Rating", fontsize=9, fontweight='medium')

# y tick, ha = left does left align
ax.set_yticklabels(labels=['0','10','20','30','40%'], color='gray', fontsize=9, ha = 'left')
ax.set_yticks(range(0,50,10))

# y tick pad since otherwise stuck in left most bar
pad = 15
yax = ax.get_yaxis()
yax.set_tick_params(pad=pad)

# x tick
ax.set_xticklabels(labels=range(0,11,1), rotation='horizontal', color='gray',
                   fontsize=9)
ax.set_xticks(range(0,11,1))

# hide left & right spine
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

fig.set_size_inches(4.8,3)
fig.show();

print('The Original')
display(example)

print('My Graph')
fig.show()
# Out:
# The Original
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/mehtahickey-inconvenient-0830-1.png" width="400"/>
# My Graph

# %% [markdown]
# # Part 2 Reproduce another example from FiveThityEight's shared data repository.

# %%
# what we want to replicate (just the left side)
from IPython.display import display, Image

url2 = 'https://fivethirtyeight.com/wp-content/uploads/2017/09/ajr-worldrespect-1.png'
example2 = Image(url=url2, width=400)

# fig axes style, I find this is more clear than unbundling subplot

fig, ax = plt.figure(), plt.axes()

ax.set_title("... has a favorable view of the United States", 
             fontsize=11, fontweight='medium', x=.35, y=1.1, loc='center')

# graph lines, only did one since it's just busy work making more
plt.plot([2015, 2016, 2017], [81, 81, 81], 'm', label='Israel')

# y tick, ha = left does left align
ax.set_yticklabels(labels=range(0,110,10), color='gray', fontsize=9, ha = 'right')
ax.set_yticks(range(0,110,10))

# y tick pad since otherwise stuck in left most bar
pad = 15
yax = ax.get_yaxis()
yax.set_tick_params(pad=pad)

# color outside of graph
fig.patch.set(facecolor='white')
# bg color inside of graph
ax.set_facecolor('white')

# x tick
ax.set_xticklabels(labels=range(2015,2018,1), rotation='horizontal', color='black',
                   fontsize=9, fontweight='bold')
ax.set_xticks(range(2015,2018,1))
ax.xaxis.tick_top()
# hid axes ticks


# hide left & right spine
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# hide grid lines
plt.grid(b=None)


display(example2)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2017/09/ajr-worldrespect-1.png" width="400"/>

# %% [markdown]
# To do:
# Couldn't figure out what to google to find labeling beginning point of graph on LHS, only how to make legends.
# Making circles for discrete points on the line plots
#
# Thxgiving 2015 on weekend

# %%
# skeleton for doing side by side later
# fig, (ax1, ax2) = plt.subplots(1, 2)
# fig.suptitle('Horizontally stacked subplots')
# ax1.plot(x, y)
# ax2.plot(x, -y)

# %% [markdown]
# # STRETCH OPTIONS
#
# ### 1) Reproduce one of the following using the matplotlib or seaborn libraries:
#
# - [thanksgiving-2015](https://fivethirtyeight.com/features/heres-what-your-part-of-america-eats-on-thanksgiving/)
# - [candy-power-ranking](https://fivethirtyeight.com/features/the-ultimate-halloween-candy-power-ranking/)
# - or another example of your choice!
#
# ### 2) Make more charts!
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
# More Work Here
