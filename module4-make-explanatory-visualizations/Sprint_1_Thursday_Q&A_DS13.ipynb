# %% [markdown]
# <a href="https://colab.research.google.com/github/masonnystrom/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module4-make-explanatory-visualizations/Sprint_1_Thursday_Q%26A_DS13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !head ncaa-womens-basketball-tournament-history.csv
# Out:
# ﻿Year,School,Seed,Conference,Conf. W,Conf. L,Conf. %,Conf. place,Reg. W,Reg. L,Reg. %,How qual,1st game at home?,Tourney W,Tourney L,Tourney finish,Full W,Full L,Full %
# 1982,Arizona St.,4,Western Collegiate,-,-,-,-,23,6,79.3,at-large,Y,1,1,RSF,24,7,77.4
# 1982,Auburn,7,Southeastern,-,-,-,-,24,4,85.7,at-large,N,0,1,1st,24,5,82.8
# 1982,Cheyney,2,Independent,-,-,-,-,24,2,92.3,at-large,Y,4,1,N2nd,28,3,90.3
# 1982,Clemson,5,Atlantic Coast,6,3,66.7,4th,20,11,64.5,at-large,N,0,1,1st,20,12,62.5
# 1982,Drake,4,Missouri Valley,-,-,-,-,26,6,81.3,auto,Y,2,1,RF,28,7,80
# 1982,East Carolina,6,Independent,-,-,-,-,19,7,73.1,at-large,N,0,1,1st,19,8,70.4
# 1982,Georgia,5,Southeastern,-,-,-,-,21,8,72.4,at-large,N,0,1,1st,21,9,70
# 1982,Howard,8,Mid-Eastern,-,-,-,-,14,10,58.3,auto,N,0,1,1st,14,11,56
# 1982,Illinois,7,Big Ten,-,-,-,-,21,8,72.4,at-large,N,0,1,1st,21,9,70

# %%
# !tail ncaa-womens-basketball-tournament-history.csv
# Out:
# 2018,Stanford,4,Pac-12,14,3,82.4,2nd,22,10,68.8,at-large,Y,2,1,RSF,24,11,68.6
# 2018,Syracuse,8,Atlantic Coast,10,6,62.5,T4th,22,8,73.3,at-large,N,0,1,1st,22,9,71
# 2018,Tennessee,3,Southeastern,11,5,68.8,T4th,24,7,77.4,at-large,Y,1,1,2nd,25,8,75.8
# 2018,Texas,2,Big 12,15,3,83.3,2nd,26,6,81.3,at-large,Y,2,1,RSF,28,7,80
# 2018,Texas A&M,4,Southeastern,11,5,68.8,T4th,24,9,72.7,at-large,Y,2,1,RSF,26,10,72.2
# 2018,UCLA,3,Pac-12,14,4,77.8,3rd,24,8,75,at-large,Y,2,1,RF,27,8,77.1
# 2018,UConn,1,American Athletic,16,0,100,1st,32,0,100,auto,Y,4,1,NSF,36,1,97.3
# 2018,Villanova,9,Big East,12,6,66.7,3rd,22,8,73.3,at-large,N,1,1,2nd,23,9,71.9
# 2018,Virginia,10,Atlantic Coast,10,6,62.5,6th,10,6,62.5,at-large,N,1,1,2nd,19,14,57.6
# 2018,Western Ky.,11,Conference USA,12,4,75,2nd,24,8,75,auto,N,0,1,1st,24,9,72.7

# %%
df = pd.read_csv('ncaa-womens-basketball-tournament-history.csv')

print(df.shape)
df.head()
# Out:
# (2092, 19)
#    Year       School Seed  ... Full W Full L Full %
# 0  1982  Arizona St.    4  ...     24      7   77.4
# 1  1982       Auburn    7  ...     24      5   82.8
# 2  1982      Cheyney    2  ...     28      3   90.3
# 3  1982      Clemson    5  ...     20     12   62.5
# 4  1982        Drake    4  ...     28      7     80
#
# [5 rows x 19 columns]

# %%
df['Year'].value_counts()
# Out:
# 2017    64
# 2015    64
# 1994    64
# 1996    64
# 1998    64
# 2000    64
# 2002    64
# 2004    64
# 2006    64
# 2008    64
# 2010    64
# 2012    64
# 2014    64
# 2016    64
# 2018    64
# 2005    64
# 2001    64
# 2013    64
# 2011    64
# 2009    64
# 2007    64
# 2003    64
# 1999    64
# 1997    64
# 1995    64
# 1990    48
# 1993    48
# 1991    48
# 1989    48
# 1992    48
# 1988    40
# 1986    40
# 1987    40
# 1983    36
# 1985    32
# 1984    32
# 1982    32
# Name: Year, dtype: int64

# %%
Louisiana = df[df['School'] == 'Louisiana Tech']

Louisiana.head()
# Out:
#      Year          School Seed  ... Full W Full L Full %
# 14   1982  Louisiana Tech    1  ...     35      1   97.2
# 47   1983  Louisiana Tech    1  ...     31      2   93.9
# 77   1984  Louisiana Tech    1  ...     30      3   90.9
# 108  1985  Louisiana Tech    1  ...     29      4   87.9
# 142  1986  Louisiana Tech    2  ...     27      5   84.4
#
# [5 rows x 19 columns]

# %%
Louisiana['Year'].value_counts().sort_index()
# Out:
# 1982    1
# 1983    1
# 1984    1
# 1985    1
# 1986    1
# 1987    1
# 1988    1
# 1989    1
# 1990    1
# 1991    1
# 1992    1
# 1993    1
# 1994    1
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# 2000    1
# 2001    1
# 2002    1
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2010    1
# 2011    1
# Name: Year, dtype: int64

# %%
Louisiana = Louisiana.reset_index()

Louisiana.head()
# Out:
#    index  Year          School Seed  ... Tourney finish Full W Full L Full %
# 0     14  1982  Louisiana Tech    1  ...          Champ     35      1   97.2
# 1     47  1983  Louisiana Tech    1  ...           N2nd     31      2   93.9
# 2     77  1984  Louisiana Tech    1  ...            NSF     30      3   90.9
# 3    108  1985  Louisiana Tech    1  ...             RF     29      4   87.9
# 4    142  1986  Louisiana Tech    2  ...             RF     27      5   84.4
#
# [5 rows x 20 columns]

# %%
Louisiana['Year']
# Out:
# 0     1982
# 1     1983
# 2     1984
# 3     1985
# 4     1986
# 5     1987
# 6     1988
# 7     1989
# 8     1990
# 9     1991
# 10    1992
# 11    1993
# 12    1994
# 13    1995
# 14    1996
# 15    1997
# 16    1998
# 17    1999
# 18    2000
# 19    2001
# 20    2002
# 21    2003
# 22    2004
# 23    2005
# 24    2006
# 25    2010
# 26    2011
# Name: Year, dtype: int64

# %%
Louisiana['Seed']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2
# 5      1
# 6      2
# 7      1
# 8      1
# 9     10
# 10     6
# 11     6
# 12     4
# 13     2
# 14     1
# 15     2
# 16     3
# 17     1
# 18     1
# 19     3
# 20     5
# 21     5
# 22     5
# 23    11
# 24    11
# 25    14
# 26    10
# Name: Seed, dtype: object

# %%
plt.scatter(Louisiana['Year'], Louisiana['Seed'])
plt.plot(Louisiana['Year'], Louisiana['Seed'])

plt.show()

# %%
Louisiana.dtypes
# Out:
# index                  int64
# Year                   int64
# School                object
# Seed                  object
# Conference            object
# Conf. W               object
# Conf. L               object
# Conf. %               object
# Conf. place           object
# Reg. W                 int64
# Reg. L                 int64
# Reg. %               float64
# How qual              object
# 1st game at home?     object
# Tourney W              int64
# Tourney L              int64
# Tourney finish        object
# Full W                 int64
# Full L                 int64
# Full %                object
# dtype: object

# %%
Louisiana['Seed'][0]
# Out:
# '1'

# %%
Louisiana['Seed'] = Louisiana['Seed'].astype('int')


Louisiana.dtypes
# Out:
# index                  int64
# Year                   int64
# School                object
# Seed                   int64
# Conference            object
# Conf. W               object
# Conf. L               object
# Conf. %               object
# Conf. place           object
# Reg. W                 int64
# Reg. L                 int64
# Reg. %               float64
# How qual              object
# 1st game at home?     object
# Tourney W              int64
# Tourney L              int64
# Tourney finish        object
# Full W                 int64
# Full L                 int64
# Full %                object
# dtype: object

# %%
def one_hundred_minus_seed(cell_contents):
  return 101 - cell_contents

Louisiana['100_minus_seed'] = Louisiana['Seed'].apply(one_hundred_minus_seed)

Louisiana.head(15)
# Out:
#     index  Year          School  Seed  ... Full W Full L Full % 100_minus_seed
# 0      14  1982  Louisiana Tech     1  ...     35      1   97.2            100
# 1      47  1983  Louisiana Tech     1  ...     31      2   93.9            100
# 2      77  1984  Louisiana Tech     1  ...     30      3   90.9            100
# 3     108  1985  Louisiana Tech     1  ...     29      4   87.9            100
# 4     142  1986  Louisiana Tech     2  ...     27      5   84.4             99
# 5     183  1987  Louisiana Tech     1  ...     30      3   90.9            100
# 6     226  1988  Louisiana Tech     2  ...     32      2   94.1             99
# 7     268  1989  Louisiana Tech     1  ...     32      4   88.9            100
# 8     312  1990  Louisiana Tech     1  ...     32      1     97            100
# 9     364  1991  Louisiana Tech    10  ...     18     12     60             91
# 10    409  1992  Louisiana Tech     6  ...     20     10   66.7             95
# ...

# %%
# plt.scatter(Louisiana['Year'], Louisiana['100_minus_seed'])
plt.plot(Louisiana['Year'], Louisiana['100_minus_seed'])

plt.show()

# %%
import scipy

fig, ax = plt.subplots()

# Line PLot
ax.plot(Louisiana['Year'], Louisiana['100_minus_seed'])

# Set the title
ax.set_title("The fall of yesterday's women's basketball powerhouses", fontsize=14, fontweight='bold', y=1.1)

# Set a subtitle
ax.text(s="Seed points by year for Louisiana Tech", x=1975 , y=110, fontsize=12)

ax.set_xlabel("Year", fontsize=12, fontweight='bold')

ax.set_ylim(80,102)

# Fill in below the line
d = scipy.zeros(len(Louisiana['100_minus_seed']))
ax.fill_between(Louisiana['Year'], Louisiana['100_minus_seed'], where=Louisiana['100_minus_seed']>=d, interpolate=True, color='blue')

# ax.fill_between(xs, ys, where=ys<=d, interpolate=True, color='red')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   app.launch_new_instance()
