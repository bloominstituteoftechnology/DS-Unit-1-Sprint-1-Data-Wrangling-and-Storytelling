# %% [markdown]
# <a href="https://colab.research.google.com/github/JulieMew/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Julie_Chandler_Make_Features_Assignment_ipynb_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
pd.set_option('max_rows', 120)
pd.set_option('max_columns', 100)

# %%
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df['LotFrontage'].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 82.0      12
# 40.0      12
# 43.0      12
# 67.0      12
# 57.0      12
# 69.0      11
# 76.0      11
# 86.0      10
# 53.0      10
# 34.0      10
# 92.0      10
# 88.0      10
# 62.0       9
# 44.0       9
# 84.0       9
# 77.0       9
# 35.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 120.0      7
# 95.0       7
# 58.0       7
# 41.0       6
# 30.0       6
# 81.0       6
# 89.0       6
# 105.0      6
# 48.0       6
# 110.0      6
# 94.0       6
# 54.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 37.0       5
# 83.0       5
# 56.0       5
# 87.0       5
# ...

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
import numpy as np
np.NaN
# Out:
# nan

# %%
type(np.NaN)
# Out:
# float

# %%
df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
df_small.TotalBsmtSF
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_small['TotalBsmtSF']
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_small['TotalSquareFootage'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF'] 

df_small['TotalSquareFootage'].head()
# Out:
# 0    2566
# 1    2524
# 2    2706
# 3    2473
# 4    3343
# Name: TotalSquareFootage, dtype: int64

# %%
df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSquareFootage']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage  \
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343
#
#    PricePerSqFt
# 0     81.254871
# 1     71.909667
# 2     82.594235
# 3     56.611403
# 4     74.783129

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-04-08 06:06:34--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 50.112.132.61, 52.32.57.66, 54.69.167.66
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|50.112.132.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [              <=>   ]  21.77M  2.00MB/s    in 11s
#
# 2020-04-08 06:06:46 (1.96 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22826918]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3235.65","3235.65","3223.02","3223.02","2364.35","858.67","0.0","0.0","0.0","Mar-2020","190.21","Apr-2020","Mar-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# !curl LoanStats_2018Q4.csv
# Out:
# curl: (6) Could not resolve host: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)
df.shape
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 1  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 2  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 3  NaN        NaN    17100.0      17100.0          17100.0   36 months
# 4  NaN        NaN     4000.0       4000.0           4000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   14.47%      1204.23     C        C2       Staff Physician    8 years
# 1   22.35%       191.86     D        D5     Director of Sales  10+ years
# 2   23.40%       284.21     E        E1                   NaN   < 1 year
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# Id                  0
# TotalBsmtSF         0
# Heating             0
# SaleCondition       0
# CentralAir          0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# SaleType            0
# YrSold              0
# MoSold              0
# MiscVal             0
# PoolArea            0
# ScreenPorch         0
# BsmtUnfSF           0
# 3SsnPorch           0
# OpenPorchSF         0
# WoodDeckSF          0
# PavedDrive          0
# GarageArea          0
# GarageCars          0
# Fireplaces          0
# EnclosedPorch       0
# BsmtFinSF2          0
# HeatingQC           0
# SalePrice           0
# LandSlope           0
# LandContour         0
# LotShape            0
# Neighborhood        0
# Condition1          0
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df = df.drop('url', 'member_id' , 'id' , 'desc' ], axis=1)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-298-a96fa0bc4830> in <module>()
# ----> 1 df = df.drop(['url'], axis=1)
#       2
#       3 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df['int_rate'].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'int_rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-299-950423bb9636> in <module>()
# ----> 1 df['int_rate'].head(10)
#
# ...

# %%
df['int_rate'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'int_rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-300-537eb723fd5e> in <module>()
# ----> 1 df['int_rate'][0]
#
# ...

# %%
int_rate = ' 16.57%'

ny_num = 5

# %%
int_rate.strip()
# Out:
# '16.57%'

# %%
int_rate.strip('%')
# Out:
# ' 16.57'

# %%
int_rate.strip().strip('%')
# Out:
# '16.57'

# %%
float(int_rate.strip().strip('%'))
# Out:
# 16.57

# %%
def int_rate_to_float(dirty_int_rate):
  return float(int_rate.strip().strip('%'))

# %%
int_rate_to_float(int_rate)
# Out:
# 16.57

# %%
int_rates = [' 16.47%', ' 14.88%', ' 13.67%', ' 14.11%', ' 14.47%']

# %%
df['int_rates'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'int_rates'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-311-d28d0adb1808> in <module>()
# ----> 1 df['int_rates'].head()
#
# ...

# %%
clean_int_rates = []
for int_rate in int_rates:
  clean_int_rates.append(int_rate_to_float(int_rate))

clean_int_rates = pd.Series(clean_int_rates)

clean_int_rates
# Out:
# 0    16.47
# 1    14.88
# 2    13.67
# 3    14.11
# 4    14.47
# dtype: float64

# %%
df['int_rate'].apply(int_rate_to_float)
# Out:
# 0         14.47
# 1         14.47
# 2         14.47
# 3         14.47
# 4         14.47
#           ...
# 128409    14.47
# 128410    14.47
# 128411    14.47
# 128412    14.47
# 128413    14.47
# Name: int_rate, Length: 128414, dtype: float64

# %%
df['int_rate_cleaned'] = df['int_rate'].apply(int_rate_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0    35000.0      35000.0          35000.0   36 months   14.47%      1204.23
# 1     5000.0       5000.0           5000.0   36 months   22.35%       191.86
# 2    10000.0      10000.0          10000.0   60 months   23.40%       284.21
# 3    17100.0      17100.0          17100.0   36 months   18.94%       626.30
# 4     4000.0       4000.0           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2       Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5     Director of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1                   NaN   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist   10+ years           RENT     38000.0
# 4     B        B2  Extrusion assistant   10+ years       MORTGAGE     56000.0
#
# ...

# %%
df.dtypes.tail()
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# dtype: object

# %%
int_rate_to_float(' 15.69%')
# Out:
# 14.47

# %%
my_int_rate_var = ' 15.69%'
int_rate_to_float((my_int_rate_var))
# Out:
# 14.47

# %%
type(int_rate_to_float(int_rate))
# Out:
# float

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20949
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
df['emp_title'].isnull().sum()
# Out:
# 20949

# %%
examples = [ "owner", 'Supervisor', ' Project Manager', np.NaN]
import numpy as np

# %%
def clean_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "unknown"

for example in examples:
  print(clean_emp_title(examples))
# Out:
# unknown
# unknown
# unknown
# unknown

# %%
df['emp_title'].apply(clean_emp_title).head(10)
# Out:
# 0                        Staff Physician
# 1                      Director Of Sales
# 2                                unknown
# 3                           Receptionist
# 4                    Extrusion Assistant
# 5                                Teacher
# 6                             Supervisor
# 7                                Analyst
# 8    Corporate Communications Strategist
# 9                        Project Manager
# Name: emp_title, dtype: object

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0    35000.0      35000.0          35000.0   36 months   14.47%      1204.23
# 1     5000.0       5000.0           5000.0   36 months   22.35%       191.86
# 2    10000.0      10000.0          10000.0   60 months   23.40%       284.21
# 3    17100.0      17100.0          17100.0   36 months   18.94%       626.30
# 4     4000.0       4000.0           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
df['emp_title'].value_counts().head(20)
# Out:
# unknown               20949
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 34902

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
[col for col in df if col.endswith(' d')]
# Out:
# []

# %%
df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'],infer_datetime_format=True)

# %%
df['issue_d'].head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df.dtypes[:15]
# Out:
# loan_amnt                     float64
# funded_amnt                   float64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df['issue_d'].dt.year
# Out:
# 0         2018.0
# 1         2018.0
# 2         2018.0
# 3         2018.0
# 4         2018.0
#            ...
# 128409    2018.0
# 128410    2018.0
# 128411    2018.0
# 128412       NaN
# 128413       NaN
# Name: issue_d, Length: 128414, dtype: float64

# %%
df['issue_d'].dt.year
# Out:
# 0         2018.0
# 1         2018.0
# 2         2018.0
# 3         2018.0
# 4         2018.0
#            ...
# 128409    2018.0
# 128410    2018.0
# 128411    2018.0
# 128412       NaN
# 128413       NaN
# Name: issue_d, Length: 128414, dtype: float64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0    35000.0      35000.0          35000.0   36 months   14.47%      1204.23
# 1     5000.0       5000.0           5000.0   36 months   22.35%       191.86
# 2    10000.0      10000.0          10000.0   60 months   23.40%       284.21
# 3    17100.0      17100.0          17100.0   36 months   18.94%       626.30
# 4     4000.0       4000.0           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
df.dtypes[-5:]
# Out:
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# issue_year               float64
# issue_month              float64
# dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['earliest_cr_line'].head()
# Out:
# 0   1995-04-01
# 1   2010-03-01
# 2   2007-04-01
# 3   1998-03-01
# 4   2006-09-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days
# Out:
# 0         8645.0
# 1         3197.0
# 2         4262.0
# 3         7580.0
# 4         4474.0
#            ...
# 128409    4505.0
# 128410    3652.0
# 128411    4413.0
# 128412       NaN
# 128413       NaN
# Length: 128414, dtype: float64

# %%
df['years_from_earliest_credit_to_issue'] = (df['issue_d'])-df['earliest_cr_line']).dt.days / 365

df.head()
# Out:
#   File "<ipython-input-104-0bb2783f2669>", line 1
#     df['years_from_earliest_credit_to_issue'] = (df['issue_d'])-df['earliest_cr_line']).dt.days / 365
#                                                                                       ^
# SyntaxError: invalid syntax

# %%
df['years_from_earliest_credit_to_issue].describe()
# Out:
#   File "<ipython-input-104-05c90afc3b07>", line 1
#     df['years_from_earliest_credit_to_issue].describe()
#                                                        ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
 # !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-04-08 14:03:46--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.16.179
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.16.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  16.3MB/s    in 13s
#
# 2020-04-08 14:04:00 (14.5 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
#There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.

df['revol_util'].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'revol_util'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-314-3d6c8ec28b98> in <module>()
#       1
# ...

# %%
df['revol_util'][0]
# Out:
# '43.2%'

# %%
revol_util = '43.2%'

# %%
revol_util.strip('%')
# Out:
# '43.2'

# %%
float(revol_util.strip('%'))
# Out:
# 43.2

# %%
def revol_util_to_float(dirty_revol_util):
  return float(revol_util.strip('%'))

# %%
revol_util_to_float(revol_util)
# Out:
# 43.2

# %%
revol_util = ['43.2%', '41.6%', '46.2%', '48.2%', '43.1%']

# %%
df['revol_util'].head()
# Out:
# 0    43.2%
# 1    47.1%
# 2    53.9%
# 3      53%
# 4    28.6%
# Name: revol_util, dtype: object

# %%
clean_revol_util = []
for revol_util in revol_util:
  clean_revol_util.append(revol_util_to_float(revol_util))

clean_revol_util = pd.Series(clean_revol_util)

clean_revol_util
# Out:
# 0    43.2
# 1    41.6
# 2    46.2
# 3    48.2
# 4    43.1
# dtype: float64

# %%
df['revol_util'].apply(revol_util_to_float)
# Out:
# 0         43.1
# 1         43.1
# 2         43.1
# 3         43.1
# 4         43.1
#           ...
# 128409    43.1
# 128410    43.1
# 128411    43.1
# 128412    43.1
# 128413    43.1
# Name: revol_util, Length: 128414, dtype: float64

# %%
df['revol_util'] = df['revol_util'].apply(revol_util_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0    35000.0      35000.0          35000.0   36 months   14.47%      1204.23
# 1     5000.0       5000.0           5000.0   36 months   22.35%       191.86
# 2    10000.0      10000.0          10000.0   60 months   23.40%       284.21
# 3    17100.0      17100.0          17100.0   36 months   18.94%       626.30
# 4     4000.0       4000.0           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
df.dtypes.tail()
# Out:
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# issue_year               float64
# issue_month              float64
# dtype: object

# %%
revol_util_to_float('42.1%')
# Out:
# 43.1

# %%
my_revol_util_var = '42.1%'
revol_util_to_float((my_revol_util_var))
# Out:
# 43.1

# %%
type(revol_util_to_float(revol_util))
# Out:
# float

# %%
#Modify the emp_title column to replace titles with 'Other' if the title is not in the top 20.

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# Unknown               20949
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 34902

# %%
len(df['emp_title'].value_counts())
# Out:
# 34902

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
examples = [ "owner", 'Supervisor', ' Project Manager', np.NaN]

# %%
def clean_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "unknown"

for example in examples:
  print(clean_emp_title(examples))
# Out:
# unknown
# unknown
# unknown
# unknown

# %%
df['emp_title'].apply(clean_emp_title).head(10)
# Out:
# 0                        Staff Physician
# 1                      Director Of Sales
# 2                                Unknown
# 3                           Receptionist
# 4                    Extrusion Assistant
# 5                                Teacher
# 6                             Supervisor
# 7                                Analyst
# 8    Corporate Communications Strategist
# 9                        Project Manager
# Name: emp_title, dtype: object

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0    35000.0      35000.0          35000.0   36 months   14.47%      1204.23
# 1     5000.0       5000.0           5000.0   36 months   22.35%       191.86
# 2    10000.0      10000.0          10000.0   60 months   23.40%       284.21
# 3    17100.0      17100.0          17100.0   36 months   18.94%       626.30
# 4     4000.0       4000.0           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              Unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
df['emp_title'].value_counts().head(20)
# Out:
# Unknown               20949
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].value_counts().head(20)
# Out:
# Unknown               20949
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
#Modify the emp_title column to replace titles with 'Other' if the title is not in the top 20.

# %%
top_20 = (df['emp_title'].value_counts().nlargest(20)).index.tolist()
df['emp_title_test'] = df['emp_title'][df['emp_title'].isin(Top_20)

emp_title_test
# Out:
#   File "<ipython-input-270-3d6f123628d2>", line 4
#     emp_title_test
#                  ^
# SyntaxError: invalid syntax

# %%
#Take initiatve and work on your own ideas!

# %%
def loan_int():
  df['loan_amnt']*df['int_rate_cleaned']

loan_int
# Out:
# <function __main__.loan_int>

# %%
#Read Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera, especially the Feature Engineering section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
#How often the user reordered items

# %%
#Read and replicate parts of Simple Exploration Notebook - Instacart. (It's the Python Notebook with the most upvotes for this Kaggle competition.)

# %%
library(data.table)
library(dplyr)
library(tidyr)

# %%
#Take initiative and work on your own ideas!

# %%
instacart = pd.read_csv()
