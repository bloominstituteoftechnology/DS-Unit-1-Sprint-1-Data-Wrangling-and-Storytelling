# %% [markdown]
# <a href="https://colab.research.google.com/github/Tunde1010/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Tunde_Akinsawe_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd

# %%
# Ames Iowa Housing Dataset:
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
pd.set_option('display.max_rows', 400)

df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df['BedroomAbvGr'].head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# 5    1
# 6    3
# 7    3
# 8    2
# 9    2
# Name: BedroomAbvGr, dtype: int64

# %%
# Looking at the first ten rows of the `BedroomAbvGr` column.
df['LotFrontage'].head(10)
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# 5    85.0
# 6    75.0
# 7     NaN
# 8    51.0
# 9    50.0
# Name: LotFrontage, dtype: float64

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
# NaN Not a number
df["LotFrontage"].value_counts(dropna=False).head()
# Out:
# NaN     259
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# Name: LotFrontage, dtype: int64

# %%
import numpy as np

# %%
type(np.NaN)
# Out:
# float

# %%
# let make a smaller dataframe
small_df = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
# new column 'last_pymnt_d_month'

small_df['last_pymnt_d_month']  = small_df['TotalBsmtSF'] + small_df['1stFlrSF'] + small_df['2ndFlrSF']

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  last_pymnt_d_month
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343

# %%
# adding additional column last_pymnt_d_year
small_df['last_pymnt_d_year'] = (small_df['SalePrice'] / small_df['last_pymnt_d_month'])

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  ...  last_pymnt_d_month  last_pymnt_d_year
# 0          856       856  ...                2566          81.254871
# 1         1262      1262  ...                2524          71.909667
# 2          920       920  ...                2706          82.594235
# 3          756       961  ...                2473          56.611403
# 4         1145      1145  ...                3343          74.783129
#
# [5 rows x 6 columns]

# %%
import pandas as pd

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-22 03:41:24--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [         <=>        ]  21.72M   359KB/s    in 64s
#
# 2020-01-22 03:42:29 (348 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22776791]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
df.shape
df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
# source of answer slack overflow
df['loan_status'].isin(['Current','Fully Paid']).astype(int)
df.head(5)
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.dtypes
# Out:
# id                       float64
# member_id                float64
# loan_amnt                  int64
# funded_amnt                int64
# funded_amnt_inv          float64
#                           ...
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 144, dtype: object

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
#!wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-01-17 20:17:05--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.179.133
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.179.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  35.2MB/s    in 6.1s
#
# 2020-01-17 20:17:11 (31.9 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-17 23:29:26--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [            <=>     ]  21.72M   401KB/s    in 56s
#
# 2020-01-17 23:30:23 (395 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22776791]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
df.shape
# Out:
# (128397, 144)

# %%
df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
pd.set_option('display.max_rows', 200)
df.isnull().sum()
# Out:
# id                                            128397
# member_id                                     128397
# loan_amnt                                          0
# funded_amnt                                        0
# funded_amnt_inv                                    0
# term                                               0
# int_rate                                           0
# installment                                        0
# grade                                              0
# sub_grade                                          0
# emp_title                                      20942
# emp_length                                     11701
# home_ownership                                     0
# annual_inc                                         0
# verification_status                                0
# issue_d                                            0
# loan_status                                        0
# pymnt_plan                                         0
# ...

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     10.33%
# 2     15.02%
# 3     12.98%
# 4     16.14%
# 5     12.98%
# 6     15.02%
# 7     16.14%
# 8     14.47%
# 9     13.56%
# Name: int_rate, dtype: object

# %%
df['int_rate'][3]
# Out:
# ' 12.98%'

# %%
type(df['int_rate'][3])
# Out:
# str

# %%
int_rate = ' 12.98%'

# %%
int_rate.strip()
# Out:
# '12.98%'

# %%
int_rate.strip('%')
# Out:
# ' 12.98'

# %%
int_rate.strip().strip('%')
# Out:
# '12.98'

# %%
float(int_rate.strip().strip('%'))
# Out:
# 12.98

# %%
float('12.98')
# Out:
# 12.98

# %%
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
def myfunc(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
myfunc(int_rate)
# Out:
# 12.98

# %%
type(myfunc(int_rate))
# Out:
# float

# %%
new_list = []

# %%
# for loop
for cell in df['int_rate']:
  new_list.append(myfunc(cell))

# %%
# 10 value of new list
new_list[:10]
# Out:
# [14.47, 10.33, 15.02, 12.98, 16.14, 12.98, 15.02, 16.14, 14.47, 13.56]

# %%
# convert the list to new column
small_df['int_rate_clean'] = pd.Series(new_list)
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  ...  last_pymnt_d_year  int_rate_clean
# 0          856       856  ...          81.254871           14.47
# 1         1262      1262  ...          71.909667           10.33
# 2          920       920  ...          82.594235           15.02
# 3          756       961  ...          56.611403           12.98
# 4         1145      1145  ...          74.783129           16.14
#
# [5 rows x 7 columns]

# %%
small_df.dtypes
# Out:
# TotalBsmtSF             int64
# 1stFlrSF                int64
# 2ndFlrSF                int64
# SalePrice               int64
# last_pymnt_d_month      int64
# last_pymnt_d_year     float64
# int_rate_clean        float64
# dtype: object

# %%
# .apply function
small_df['int_rate_cleaned2'] = df['int_rate'].apply(myfunc)
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  ...  int_rate_clean  int_rate_cleaned2
# 0          856       856  ...           14.47              14.47
# 1         1262      1262  ...           10.33              10.33
# 2          920       920  ...           15.02              15.02
# 3          756       961  ...           12.98              12.98
# 4         1145      1145  ...           16.14              16.14
#
# [5 rows x 8 columns]

# %%
#!tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# tar (child): instacart_online_grocery_shopping_2017_05_01.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
 #%cd instacart_2017_05_01
# Out:
# [Errno 2] No such file or directory: 'instacart_2017_05_01'
# /content
