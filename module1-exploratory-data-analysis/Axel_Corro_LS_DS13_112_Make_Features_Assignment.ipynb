# %% [markdown]
# <a href="https://colab.research.google.com/github/axefx/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module1-exploratory-data-analysis/Axel_Corro_LS_DS13_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_rows', 100)
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df['BedroomAbvGr'].head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# 5    1
# 6    3
# 7    3
# 8    2
# 9    2
# Name: BedroomAbvGr, dtype: int64

# %%
pd.set_option('display.max_rows', 150)
df['LotFrontage'].value_counts(dropna=False)

# %%
type(np.NaN)
# Out:
# float

# %%
df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
df_small['TotalSF'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF']
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSF']
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqFt
# 0          856       856       854     208500     2566     81.254871
# 1         1262      1262         0     181500     2524     71.909667
# 2          920       920       866     223500     2706     82.594235
# 3          756       961       756     140000     2473     56.611403
# 4         1145      1145      1053     250000     3343     74.783129

# %%
# Loan Dataset
# !head /content/LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail /content/LoanStats_2018Q4.csv
# Out:
# "","","5000","5000","5000"," 36 months"," 12.98%","168.43","B","B5","Machine operator","< 1 year","RENT","57000","Not Verified","Dec-2018","Current","n","","","major_purchase","Major purchase","601xx","IL","15.05","0","Jun-2008","0","","","7","0","21075","80.1%","13","w","3413.09","3413.09","2185.98","2185.98","1586.91","599.07","0.0","0.0","0.0","Jan-2020","168.43","Feb-2020","Jan-2020","0","","1","Individual","","","","0","0","109601","0","1","0","0","32","901","18","0","0","11190","70","26300","0","0","0","0","18267","3725","85","0","0","126","119","27","27","1","27","","23","","0","2","2","4","8","2","5","9","2","7","0","0","0","0","100","66.7","0","0","144420","21976","24800","5000","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# Read in the CSV
df = pd.read_csv('LoanStats_2018Q4.csv',skiprows=1,skipfooter=2)
print(df.shape)
df.isnull().sum().sort_values()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# (28420, 144)
# inq_fi                                            0
# delinq_amnt                                       0
# chargeoff_within_12_mths                          0
# acc_open_past_24mths                              0
# inq_last_12m                                      0
# total_cu_tl                                       0
# total_rev_hi_lim                                  0
# max_bal_bc                                        0
# open_rv_24m                                       0
# open_rv_12m                                       0
# total_bal_il                                      0
# open_il_24m                                       0
# hardship_flag                                     0
# ...

# %%
df = df.drop(['url','member_id','desc','id'], axis=1)

# %%
df.head(10)
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      35000        35000  ...                    NaN             NaN
# 1       5000         5000  ...                    NaN             NaN
# 2      10000        10000  ...                    NaN             NaN
# 3      17100        17100  ...                    NaN             NaN
# 4       4000         4000  ...                    NaN             NaN
# 5      10475        10475  ...                    NaN             NaN
# 6       7500         7500  ...                    NaN             NaN
# 7       3600         3600  ...                    NaN             NaN
# 8      22000        22000  ...                    NaN             NaN
# 9      10450        10450  ...                    NaN             NaN
#
# [10 rows x 140 columns]

# %%
# int_rate
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
# create function - start with single fix
int_rate = '  7.49%'

# %%
int_rate.strip()
# Out:
# '7.49%'

# %%
int_rate.strip().strip('%')
# Out:
# '7.49'

# %%
float(int_rate.strip().strip('%'))
# Out:
# 7.49

# %%
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      35000        35000  ...              NaN          14.47
# 1       5000         5000  ...              NaN          22.35
# 2      10000        10000  ...              NaN          23.40
# 3      17100        17100  ...              NaN          18.94
# 4       4000         4000  ...              NaN          10.72
#
# [5 rows x 141 columns]

# %%
# improvements to 'emp_title'
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   4803
# Teacher                465
# Manager                392
# Driver                 199
# Registered Nurse       183
# Supervisor             164
# RN                     144
# General Manager        133
# Sales                  122
# Project Manager        119
# Director               102
# Owner                   93
# Truck Driver            84
# Vice President          80
# Office Manager          80
# Operations Manager      72
# Nurse                   71
# manager                 68
# Mechanic                68
# Engineer                66
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 12570

# %%
df['emp_title'].isnull().sum()
# Out:
# 4803

# %%
examples = ['owner', 'Supervisor', 'Project Manager', np.NaN]

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

# %%
[clean_title(example) for example in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      35000        35000  ...              NaN          14.47
# 1       5000         5000  ...              NaN          22.35
# 2      10000        10000  ...              NaN          23.40
# 3      17100        17100  ...              NaN          18.94
# 4       4000         4000  ...              NaN          10.72
#
# [5 rows x 141 columns]

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# Unknown               4803
# Teacher                579
# Manager                536
# Registered Nurse       288
# Supervisor             275
# Driver                 273
# Truck Driver           221
# General Manager        199
# Sales                  172
# Rn                     170
# Project Manager        165
# Owner                  146
# Office Manager         138
# Director               131
# Sales Manager          108
# Vice President         105
# Operations Manager     102
# Nurse                   99
# Mechanic                99
# Technician              93
# Name: emp_title, dtype: int64

# %%
len(df['emp_title'].value_counts())
# Out:
# 10281

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
# Work with Dates
df['issue_d'].value_counts()
# Out:
# Dec-2018    28420
# Name: issue_d, dtype: int64

# %%
df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv                 int64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['issue_d'].dt.year
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 28415    2018
# 28416    2018
# 28417    2018
# 28418    2018
# 28419    2018
# Name: issue_d, Length: 28420, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 28415    12
# 28416    12
# 28417    12
# 28418    12
# 28419    12
# Name: issue_d, Length: 28420, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      35000        35000  ...        2018          12
# 1       5000         5000  ...        2018          12
# 2      10000        10000  ...        2018          12
# 3      17100        17100  ...        2018          12
# 4       4000         4000  ...        2018          12
#
# [5 rows x 143 columns]

# %%
# days_from_credit_to_issue feature
## improve earliest_cr_line
df['earliest_cr_line'].head()
# Out:
# 0    Apr-1995
# 1    Mar-2010
# 2    Apr-2007
# 3    Mar-1998
# 4    Sep-2006
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days
# Out:
# 0         8645
# 1         3197
# 2         4262
# 3         7580
# 4         4474
#          ...
# 28415     3590
# 28416     4597
# 28417     5601
# 28418    11688
# 28419     9284
# Length: 28420, dtype: int64

# %%
df['days_from_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df['days_from_credit_to_issue'].describe()
# Out:
# count    28420.000000
# mean      5866.650106
# std       2882.622525
# min       1126.000000
# 25%       4079.000000
# 50%       5266.000000
# 75%       7243.000000
# max      25171.000000
# Name: days_from_credit_to_issue, dtype: float64

# %%
# Convert the term column from string to integer.
df['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     60 months
# 3     36 months
# 4     36 months
# Name: term, dtype: object

# %%
df['term'].value_counts()
# Out:
#  36 months    19485
#  60 months     8935
# Name: term, dtype: int64

# %%
df['term'].isnull().sum()
# Out:
# 0

# %%
df['term'][0]
# Out:
# ' 36 months'

# %%
[char.strip() for char in ' 36 months' if not char.isalpha()]
# Out:
# ['', '3', '6', '']

# %%
def term_to_int(cell_contents):
  cell_contents = ''.join([char for char in cell_contents if not char.isalpha()])
  return int(cell_contents.strip(' '))

# %%
df['term'] = df['term'].astype('int')
df['term'].head()
# Out:
# 0    36
# 1    36
# 2    60
# 3    36
# 4    36
# Name: term, dtype: int64

# %%
# Make a column named loan_status_is_great. It should contain the integer 1
# if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.
df['loan_status'].value_counts()
# Out:
# Current               21547
# Fully Paid             4817
# Charged Off            1146
# Late (31-120 days)      583
# In Grace Period         243
# Late (16-30 days)        84
# Name: loan_status, dtype: int64

# %%
df['loan_status'].head()
# Out:
# 0    Fully Paid
# 1    Fully Paid
# 2       Current
# 3       Current
# 4       Current
# Name: loan_status, dtype: object

# %%
print(df['loan_status'][0])
# Out:
# Fully Paid

# %%
print(df['loan_status'][3])
# Out:
# Current

# %%
def status_to_int(cell_contents):
  if cell_contents == 'Current' or cell_contents == 'Fully Paid':
    return 1
  else:
    return 0

# %%
status_to_int(df['loan_status'][0])
# Out:
# 1

# %%
df['loan_status_is_great'] = df['loan_status'].apply(status_to_int)

# %%
df['loan_status_is_great'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: loan_status_is_great, dtype: int64

# %%
df['loan_status_is_great'].value_counts()
# Out:
# 1    26364
# 0     2056
# Name: loan_status_is_great, dtype: int64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  days_from_credit_to_issue  loan_status_is_great
# 0      35000        35000  ...                       8645                     1
# 1       5000         5000  ...                       3197                     1
# 2      10000        10000  ...                       4262                     1
# 3      17100        17100  ...                       7580                     1
# 4       4000         4000  ...                       4474                     1
#
# [5 rows x 145 columns]

# %%
# Make last_pymnt_d_month and last_pymnt_d_year columns
df.columns.sort_values().values
# Out:
# array(['acc_now_delinq', 'acc_open_past_24mths', 'addr_state', 'all_util',
#        'annual_inc', 'annual_inc_joint', 'application_type',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'collection_recovery_fee',
#        'collections_12_mths_ex_med', 'days_from_credit_to_issue',
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'deferral_term', 'delinq_2yrs', 'delinq_amnt', 'dti', 'dti_joint',
#        'earliest_cr_line', 'emp_length', 'emp_title', 'funded_amnt',
#        'funded_amnt_inv', 'grade', 'hardship_amount', 'hardship_dpd',
#        'hardship_end_date', 'hardship_flag',
#        'hardship_last_payment_amount', 'hardship_length',
#        'hardship_loan_status', 'hardship_payoff_balance_amount',
#        'hardship_reason', 'hardship_start_date', 'hardship_status',
#        'hardship_type', 'home_ownership', 'il_util',
#        'initial_list_status', 'inq_fi', 'inq_last_12m', 'inq_last_6mths',
# ...

# %%
pd.set_option('display.max_rows',300)
df[:][df['last_pymnt_d'].isnull()]
# Out:
#        loan_amnt  funded_amnt  ...  days_from_credit_to_issue  loan_status_is_great
# 1588       20975        20975  ...                       7731                     0
# 2930       14000        14000  ...                       7305                     0
# 3225       20000        20000  ...                       5601                     0
# 3289       32000        32000  ...                       3409                     0
# 3439        9100         9100  ...                       5509                     0
# 3852       36000        36000  ...                       4079                     0
# 4430        3525         3525  ...                       1795                     0
# 4943       11500        11500  ...                       3348                     0
# 5550        8000         8000  ...                       6058                     0
# 7360       30000        30000  ...                       6423                     0
# ...

# %%
df['last_pymnt_d'].value_counts(dropna=False)
# Out:
# Jan-2020    21793
# Dec-2019      804
# Sep-2019      652
# Jul-2019      641
# Oct-2019      610
# Aug-2019      582
# Nov-2019      538
# May-2019      510
# Jun-2019      485
# Apr-2019      477
# Mar-2019      407
# Jan-2019      400
# Feb-2019      371
# Dec-2018      116
# NaN            34
# Name: last_pymnt_d, dtype: int64

# %%
df['last_pymnt_d'].isnull().sum()
# Out:
# 34

# %%
df['last_pymnt_d'][0]
# Out:
# 'Aug-2019'

# %%
import math
def clean_pymnt_d(date):
  da

# %%
df['last_pymnt_d'].dropna()
# Out:
# 0       2019-08-01
# 1       2019-07-01
# 2       2020-01-01
# 3       2020-01-01
# 4       2020-01-01
#            ...
# 28415   2020-01-01
# 28416   2020-01-01
# 28417   2020-01-01
# 28418   2019-01-01
# 28419   2020-01-01
# Name: last_pymnt_d, Length: 28386, dtype: datetime64[ns]

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

# %%
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month
#pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)


print(df['last_pymnt_d_year'][0])
print(df['last_pymnt_d_month'][0])
# Out:
# 2019.0
# 8.0

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
