# %% [markdown]
# <a href="https://colab.research.google.com/github/MehdiKhiatiDS/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/module2-make-features/mk_of_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-10-30 03:17:28--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [  <=>               ]  21.62M   646KB/s    in 34s
#
# 2019-10-30 03:18:08 (642 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22667400]

# %%
# !unzip LoanStats_2018Q4.csv.zip

# i kept gettin an error after trying to unzip it the second time when i was trying to get full lenght of dtypes of df.. added pd.options.display.max_row = 900 but then i get getting an error in both...🤯
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4122.15","4122.15","2081.76","2081.76","1477.85","603.91","0.0","0.0","0.0","Sep-2019","190.21","Oct-2019","Sep-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 144



df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine = 'python')

print(df.shape)

df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      25000        25000          25000.0   60 months
# 2 NaN        NaN      26500        26500          26500.0   60 months
# 3 NaN        NaN      10400        10400          10400.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   60 months
#
#   int_rate  installment grade sub_grade                         emp_title  \
# 0   14.47%       688.13     C        C2                        bus driver
# 1   16.14%       609.82     C        C4                Production Manager
# 2   11.31%       580.28     B        B3               Compliance Director
# 3   12.98%       350.32     B        B5        Program Support Assistant
# 4   12.98%       796.00     B        B5  Sr. Vice President -Risk Manager
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
df.describe()
# Out:
#         id  member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  128412.000000  128412.000000    128412.000000
# mean   NaN        NaN   15971.321021   15971.321021     15968.498166
# std    NaN        NaN   10150.384233   10150.384233     10152.168970
# min    NaN        NaN    1000.000000    1000.000000       725.000000
# 25%    NaN        NaN    8000.000000    8000.000000      8000.000000
# 50%    NaN        NaN   14000.000000   14000.000000     14000.000000
# 75%    NaN        NaN   21600.000000   21600.000000     21600.000000
# max    NaN        NaN   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc  url  desc            dti    delinq_2yrs  \
# count  128412.000000  1.284120e+05  0.0   0.0  128175.000000  128412.000000
# mean      463.253654  8.279733e+04  NaN   NaN      19.933178       0.227837
# std       285.718934  1.082985e+05  NaN   NaN      20.143542       0.733793
# ...

# %%
df.dtypes
# this where pd.options.display.max_row (and max_column gave me an error!)
# Out:
# id                                            float64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
# Out:
#         loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0           20000        20000  ...                    NaN             NaN
# 1           25000        25000  ...                    NaN             NaN
# 2           26500        26500  ...                    NaN             NaN
# 3           10400        10400  ...                    NaN             NaN
# 4           35000        35000  ...                    NaN             NaN
# ...           ...          ...  ...                    ...             ...
# 128407      23000        23000  ...                    NaN             NaN
# 128408      10000        10000  ...                    NaN             NaN
# 128409       5000         5000  ...                    NaN             NaN
# 128410      10000        10000  ...                    NaN             NaN
# 128411      10000        10000  ...                    NaN             NaN
#
# [128412 rows x 140 columns]

# %%
df_mod1 = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)

df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      25000        25000          25000.0   60 months   16.14%       609.82
# 2      26500        26500          26500.0   60 months   11.31%       580.28
# 3      10400        10400          10400.0   36 months   12.98%       350.32
# 4      35000        35000          35000.0   60 months   12.98%       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        bus driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5        Program Support Assistant   10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
# starting the process of changing int_rate to float..
df_mod1['int_rate'][5]
# Out:
# '  7.56%'

# %%
int_rate = '  7.56%'

# %%
in_rate = int_rate.strip().strip('%')
print(int_rate)
x = ' 233.56%'
# Out:
#   7.56%

# %%
#  int_rate=int_rate.replace(' ', '').replace('%', '')

def int_rate_to_float(int_rate):
  return float((int_rate.strip().strip('%')))


int_rate_to_float(int_rate)
# Out:
# 7.56

# %%
d = '  71.57%'

int_rate_to_float(d)

# trying if my function works!
# Out:
# 71.57

# %%
print(type(d))
type(int_rate_to_float(d))
# Out:
# <class 'str'>
# float

# %%
# adding changes to df_mod1

df_mod1['int_rate'] = df_mod1['int_rate'].apply(int_rate_to_float)

df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        bus driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5        Program Support Assistant   10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
# cleaning emp_title as much as could retain...

print(df_mod1.shape)
df_mod1['emp_title']
# Out:
# (128412, 140)
# 0                               bus driver
# 1                       Production Manager
# 2                      Compliance Director
# 3               Program Support Assistant
# 4         Sr. Vice President -Risk Manager
#                         ...
# 128407                      Tax Consultant
# 128408                      security guard
# 128409                        Payoff Clerk
# 128410                                 NaN
# 128411                Key Accounts Manager
# Name: emp_title, Length: 128412, dtype: object

# %%
df_mod1['emp_title'].value_counts(dropna=False)[:20]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
len(df_mod1['emp_title'].value_counts())
# Out:
# 43892

# %%
df_mod1['emp_title'].isnull().sum()
# Out:
# 20947

# %%
import numpy as np

examples = ["owner", 'Supervisor', ' Project Manager', np.NaN]

def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

[clean_title(i) for i in examples]

# examples = ["owner", 'Supervisor', ' Project Manager', np.NaN]

# def clean_title(title):
#   if isinstance(title, str):
#     return title.strip().title()
#   else:
#     return "Unknown"

# [clean_title(item) for item in examples]  , i need to go over this with you! its a bit weird to me!
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df_mod1['emp_title'] = df_mod1['emp_title'].apply(clean_title)

df_mod1.tail()

# there is an example of it working at the second row from the end..
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 128407      23000        23000          23000.0   36 months     15.02
# 128408      10000        10000          10000.0   36 months     15.02
# 128409       5000         5000           5000.0   36 months     13.56
# 128410      10000        10000           9750.0   36 months     11.06
# 128411      10000        10000          10000.0   36 months     16.91
#
#         installment grade sub_grade             emp_title emp_length  \
# 128407       797.53     C        C3        Tax Consultant  10+ years
# 128408       346.76     C        C3        Security Guard    5 years
# 128409       169.83     C        C1          Payoff Clerk  10+ years
# 128410       327.68     B        B3               Unknown        NaN
# 128411       356.08     C        C5  Key Accounts Manager    2 years
#
#        home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
len(df_mod1['emp_title'].value_counts())
# Out:
# 34902

# %%
df_mod1['emp_title'].isnull().sum()
# Out:
# 0

# %%
# working on filtering dataframe 

df_mod1['emp_title_manager'] = df_mod1['emp_title'].str.contains('Manager')
df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term  emp_title_manager
# 0      20000        20000  ...              NaN              False
# 1      25000        25000  ...              NaN               True
# 2      26500        26500  ...              NaN              False
# 3      10400        10400  ...              NaN              False
# 4      35000        35000  ...              NaN               True
#
# [5 rows x 141 columns]

# %%
condition =  (df_mod1['emp_title_manager'] == True)
condition
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 128407    False
# 128408    False
# 128409    False
# 128410    False
# 128411     True
# Name: emp_title_manager, Length: 128412, dtype: bool

# %%
managers = df_mod1[condition]

managers.head()
# Out:
#     loan_amnt  funded_amnt  ...  settlement_term  emp_title_manager
# 1       25000        25000  ...              NaN               True
# 4       35000        35000  ...              NaN               True
# 8       12000        12000  ...              NaN               True
# 16      12000        12000  ...              NaN               True
# 18      20400        20400  ...              NaN               True
#
# [5 rows x 141 columns]

# %%
df_mod1['employed_more_than_10years'] = df_mod1['emp_length'].str.contains('10')
df_mod1.head()

# added a column of worked more than 10 years!
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
employed_more_than_10years = df_mod1['emp_length'].str.contains('10')

employed_more_than_10years.describe()
# Out:
# count     116708
# unique         2
# top        False
# freq       77882
# Name: emp_length, dtype: object

# %%
df_mod1['settlement_date'].isnull().sum()
# Out:
# 128244

# %%
df_mod1['settlement_date'].dtypes
# Out:
# dtype('O')

# %%
condition = df_mod1['settlement_date'].str.contains('')
condition
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 128407    NaN
# 128408    NaN
# 128409    NaN
# 128410    NaN
# 128411    NaN
# Name: settlement_date, Length: 128412, dtype: object

# %%
employed_more_than_2years = df_mod1[condition]
employed_more_than_2years.head()

# this would work for me wehen i tried setting a new dataframe based on that condition..

# %%
df_mod1['employed_more_than_2years'] = df_mod1['emp_length'].str.contains('2')
df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        Bus Driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5         Program Support Assistant  10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_mod1['employed_more_than_2years'].describe()
# Out:
# count     116708
# unique         2
# top        False
# freq      105851
# Name: employed_more_than_2years, dtype: object

# %%
df_mod1['employed_more_than_2years'].isnull().sum()
# Out:
# 11704

# %%
# working on it Converting term column from string to intege slowly

print(df_mod1['term'])

strings =  '36 months'

strings = strings.replace('months', '').replace(' ', '')

print(strings)

test = '45 months'
# Out:
# 0          36 months
# 1          60 months
# 2          60 months
# 3          36 months
# 4          60 months
#              ...
# 128407     36 months
# 128408     36 months
# 128409     36 months
# 128410     36 months
# 128411     36 months
# Name: term, Length: 128412, dtype: object
# 36

# %%
def term_to_int(strings):
  return int(strings.strip('months').strip())

# %%
# test, test

term_to_int(test)
# Out:
# 45

# %%
df_mod1['term'] = df_mod1['term'].apply(term_to_int)

df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_mod1['loan_status']
# Out:
# 0             Current
# 1          Fully Paid
# 2             Current
# 3             Current
# 4          Fully Paid
#              ...
# 128407    Charged Off
# 128408        Current
# 128409        Current
# 128410        Current
# 128411        Current
# Name: loan_status, Length: 128412, dtype: object

# %%
type(df_mod1['term'][0])
# Out:
# numpy.int64

# %%
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.


df_mod1['loan_status_is_great'] = df_mod1['loan_status'].str.contains("Current" or "Fully Paid")
df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
condition = (df_mod1['loan_status_is_great'] == True)
condition
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 128407    False
# 128408     True
# 128409     True
# 128410     True
# 128411     True
# Name: loan_status_is_great, Length: 128412, dtype: bool

# %%
loan_status_is_great = df_mod1[condition]
loan_status_is_great.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 6      13000        13000          13000.0    36     17.97       469.79     D
# 8      12000        12000          12000.0    36     11.80       397.43     B
#
#   sub_grade                  emp_title emp_length home_ownership  annual_inc  \
# 0        C2                 Bus Driver    4 years            OWN     52000.0
# 2        B3        Compliance Director  10+ years       MORTGAGE    134000.0
# 3        B5  Program Support Assistant  10+ years       MORTGAGE     56099.0
# 6        D1       Help Tech Supervisor  10+ years       MORTGAGE     92360.0
# 8        B4     Transportation Manager  10+ years           RENT     79365.0
#
# ...

# %%
loan_status_is_great = df_mod1[~condition]    
# (df_mod1['loan_status_is_great'] == False) or/
loan_status_is_great.head()
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 1       25000        25000          25000.0    60     16.14       609.82
# 4       35000        35000          35000.0    60     12.98       796.00
# 5       20000        20000          20000.0    36      7.56       622.68
# 7       12000        12000          12000.0    60     14.47       282.16
# 10      35000        35000          35000.0    60     18.94       906.77
#
#    grade sub_grade                                 emp_title emp_length  \
# 1      C        C4                        Production Manager    5 years
# 4      B        B5          Sr. Vice President -Risk Manager    7 years
# 5      A        A3                                   Teacher  10+ years
# 7      C        C2  Assistant Athletic Director Of Marketing     1 year
# 10     D        D2                         Financial Advisor  10+ years
#
#    home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
loan_status_is_great.dtypes
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                            int64
# int_rate                      float64
#                                ...
# emp_title_manager                bool
# test                           object
# employed_more_than_10years     object
# employed_more_than_2years      object
# loan_status_is_great          float64
# Length: 145, dtype: object

# %%
df.loan_status_is_great = df.loan_status_is_great.astype(int)
df.loan_status_is_great.head() 
# shoulda showed them becoming ints but since I messed up before and just replaced True by 1 and False by 2 then by 0 things got a bit confusing but I understoond the concept ( the hard way but none the less)

# %%
df_mod1['employed_more_than_2years'][6]
# Out:
# False

# %%
df_mod1['loan_status_is_great'] = df_mod1['loan_status_is_great'].replace(True, 1).replace(False, 0)

df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_mod1['loan_status_is_great'][87655]
# Out:
# 1.0

# %%
i-it = 

def loan_status_is_great_to_int(loan_status_bool):
  if True:
   return int(loan_status_is_great.replace(True, 1))
  else:
     return int(loan_status_is_great.replace(False, 0))


  loan_status_is_great_to_int(i-it)
# Out:
#   File "<ipython-input-69-00dabadf5cb2>", line 1
#     i-it =
#            ^
# SyntaxError: invalid syntax

# %%
# Make last_pymnt_d_month and last_pymnt_d_year columns.


print(df_mod1.columns)


list(df_mod1.columns)
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'employed_more_than_2years',
#        'loan_status_is_great', 'employed_more_than_10years'],
#       dtype='object', length=143)
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
# ...

# %%
# Make last_pymnt_d_month and last_pymnt_d_year columns.

df_mod1['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

type(df_mod1['last_pymnt_d'])
# Out:
# pandas.core.series.Series

# %%
df_mod1['last_pymnt_d']
# Out:
# 0        2019-09-01
# 1        2019-04-01
# 2        2019-09-01
# 3        2019-09-01
# 4        2019-04-01
#             ...
# 128407   2018-12-01
# 128408   2019-09-01
# 128409   2019-09-01
# 128410   2019-09-01
# 128411   2019-09-01
# Name: last_pymnt_d, Length: 128412, dtype: datetime64[ns]

# %%
df_mod1['last_pymnt_d_month'] =  pd.DatetimeIndex(df_mod1['last_pymnt_d']).month


df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df_mod1['last_pymnt_d_month'] = pd.to_datetime(df['last_pymnt_d_month'], infer_datetime_format=True)

# %%
[col for col in df_mod1 if col.endswith('_d')]

# %%
df_mod1['last_pymnt_d_year'] = df_mod1['last_pymnt_d'].dt.year

df_mod1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2019-10-30 04:33:50--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.36.198
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.36.198|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  45.6MB/s    in 4.2s
#
# 2019-10-30 04:33:55 (46.3 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
df = pd.read_csv('instacart_2017_05_01')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-102-b00c02bdc865> in <module>()
# ----> 1 df = pd.read_csv('instacart_2017_05_01')
#       2
#       3 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...
