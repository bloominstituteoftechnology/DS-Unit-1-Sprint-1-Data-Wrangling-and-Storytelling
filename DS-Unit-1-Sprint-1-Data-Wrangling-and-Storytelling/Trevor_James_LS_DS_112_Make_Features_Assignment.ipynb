# %% [markdown]
# <a href="https://colab.research.google.com/github/trevorwjames/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/Trevor_James_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd

pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 100)

df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
import numpy as np

type(np.NaN)
# Out:
# float

# %%
df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']]
# Out:
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0             856       856       854     208500
# 1            1262      1262         0     181500
# 2             920       920       866     223500
# 3             756       961       756     140000
# 4            1145      1145      1053     250000
# ...           ...       ...       ...        ...
# 1455          953       953       694     175000
# 1456         1542      2073         0     210000
# 1457         1152      1188      1152     266500
# 1458         1078      1078         0     142125
# 1459         1256      1256         0     147500
#
# [1460 rows x 4 columns]

# %%
# creating a smaller data set to engineer a new feature
df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
# create a new column 'TotalSqFt'

df_small['TotalSqFt'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSqFt
# 0          856       856       854     208500       2566
# 1         1262      1262         0     181500       2524
# 2          920       920       866     223500       2706
# 3          756       961       756     140000       2473
# 4         1145      1145      1053     250000       3343

# %%
df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSqFt']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSqFt  PricePerSqFt
# 0          856       856       854     208500       2566     81.254871
# 1         1262      1262         0     181500       2524     71.909667
# 2          920       920       866     223500       2706     82.594235
# 3          756       961       756     140000       2473     56.611403
# 4         1145      1145      1053     250000       3343     74.783129

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-06-02 22:32:44--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 44.228.179.66, 52.89.160.109, 35.163.140.110
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|44.228.179.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [         <=>        ]  22.10M  1.98MB/s    in 12s
#
# 2020-06-02 22:32:57 (1.86 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23170772]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    20000.0      20000.0          20000.0   36 months
# 1  NaN        NaN    16000.0      16000.0          16000.0   36 months
# 2  NaN        NaN     8425.0       8425.0           8425.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 4  NaN        NaN    30000.0      30000.0          30000.0   60 months
#
#   int_rate  installment grade sub_grade                        emp_title  \
# 0   14.47%       688.13     C        C2                       bus driver
# 1   14.47%       550.51     C        C2                        Carpenter
# 2   27.27%       345.18     E        E5  Senior Director Risk Management
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')

print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      16000        16000          16000.0   36 months
# 2 NaN        NaN       8425         8425           8425.0   36 months
# 3 NaN        NaN      10000        10000          10000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade                        emp_title  \
# 0   14.47%       688.13     C        C2                       bus driver
# 1   14.47%       550.51     C        C2                        Carpenter
# 2   27.27%       345.18     E        E5  Senior Director Risk Management
# 3   12.98%       227.43     B        B5                          Printer
# 4   26.31%       903.73     E        E4                      Casino Host
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# mo_sin_old_rev_tl_op                               0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# open_il_12m                                        0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df = df.drop(['desc', 'url', 'member_id', 'id'], axis=1)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      16000        16000          16000.0   36 months   14.47%       550.51
# 2       8425         8425           8425.0   36 months   27.27%       345.18
# 3      10000        10000          10000.0   60 months   12.98%       227.43
# 4      30000        30000          30000.0   60 months   26.31%       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       bus driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     14.47%
# 2     27.27%
# 3     12.98%
# 4     26.31%
# 5     17.97%
# 6     11.80%
# 7     10.72%
# 8     16.14%
# 9     12.98%
# Name: int_rate, dtype: object

# %%
df['int_rate'][3]
# Out:
# ' 12.98%'

# %%
df.iloc[0:10, 0:2]
# Out:
#    loan_amnt  funded_amnt
# 0      20000        20000
# 1      16000        16000
# 2       8425         8425
# 3      10000        10000
# 4      30000        30000
# 5      13000        13000
# 6       6500         6500
# 7       7500         7500
# 8      14000        14000
# 9      25000        25000

# %%
# need to make the number into a float
int_rate = ' 12.98%'

int_rate.strip().strip('%')
# Out:
# '12.98'

# %%
float(int_rate.strip().strip('%'))
# Out:
# 12.98

# %%
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
int_rate_to_float(int_rate)
# Out:
# 12.98

# %%
cleaned = []

for int_rate in df['int_rate']:
  cleaned.append(int_rate_to_float(int_rate))

df['int_rate_cleaned'] = pd.Series(cleaned)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      16000        16000          16000.0   36 months   14.47%       550.51
# 2       8425         8425           8425.0   36 months   27.27%       345.18
# 3      10000        10000          10000.0   60 months   12.98%       227.43
# 4      30000        30000          30000.0   60 months   26.31%       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       bus driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
# Employment Title time! 

df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
import numpy as np

examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
def clean_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

for example in exmaples:
  print(clean_emp_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
# list comprehensions are still a little confusing to me. 

df['new_column'] = [clean_emp_title(title) for title in examples]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-d1ae848053be> in <module>()
#       1 # list comprehensions are still a little confusing to me.
#       2
# ----> 3 df['new_column'] = [clean_emp_title(title) for title in examples]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()

# %%
df['emp_title'].value_counts(dropna=False).head(20)

# %%
df['emp_title'].isnull().sum()

# %%
# Work with dates and times

[col for col in df if col.endswith('_d')]

# %%
print(df['issue_d'].head())
df['issue_d'].tail()

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d'].head()

# %%
df['issue_d'].dt.year

# %%
df['issue_d'].dt.month

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()

# %%
df.dtypes

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

df['earliest_cr_line'].head()

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days / 365

# %%
df['length_of_credit_history'] = (df['issue_d'] - df['earliest_cr_line']).dt.days / 365

df.head()

# %%
df['length_of_credit_history'].describe()

#Thats an old credit line

# %%
df['term']

# %% [markdown]
# Convert the term column from string to integer.
#
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.
#
# Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      16000        16000          16000.0   36 months
# 2 NaN        NaN       8425         8425           8425.0   36 months
# 3 NaN        NaN      10000        10000          10000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade                        emp_title  \
# 0   14.47%       688.13     C        C2                       bus driver
# 1   14.47%       550.51     C        C2                        Carpenter
# 2   27.27%       345.18     E        E5  Senior Director Risk Management
# 3   12.98%       227.43     B        B5                          Printer
# 4   26.31%       903.73     E        E4                      Casino Host
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df = df.drop(['desc', 'url', 'member_id', 'id'], axis=1)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      16000        16000          16000.0   36 months   14.47%       550.51
# 2       8425         8425           8425.0   36 months   27.27%       345.18
# 3      10000        10000          10000.0   60 months   12.98%       227.43
# 4      30000        30000          30000.0   60 months   26.31%       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       bus driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
df['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     60 months
# Name: term, dtype: object

# %%
def term_to_float(cell_contents):
  return(float(cell_contents.strip('months')))

# %%
df['term'] = df['term'].apply(term_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0  36.0   14.47%       688.13     C
# 1      16000        16000          16000.0  36.0   14.47%       550.51     C
# 2       8425         8425           8425.0  36.0   27.27%       345.18     E
# 3      10000        10000          10000.0  60.0   12.98%       227.43     B
# 4      30000        30000          30000.0  60.0   26.31%       903.73     E
#
#   sub_grade                        emp_title emp_length home_ownership  \
# 0        C2                       bus driver    4 years            OWN
# 1        C2                        Carpenter  10+ years           RENT
# 2        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3        B5                          Printer    9 years           RENT
# 4        E4                      Casino Host  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
examples1 = ['Fully Paid', 'Current']


def clean_loan_status(loan_status):
  if loan_status in ('Current', 'Fully Paid'):
    return 1
  else:
    return 0

for example in examples1:
  print(clean_loan_status(example))
# Out:
# 1
# 1

# %%
df['Loan_status_is_great'] = df['loan_status'].apply(clean_loan_status)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0  36.0   14.47%       688.13     C
# 1      16000        16000          16000.0  36.0   14.47%       550.51     C
# 2       8425         8425           8425.0  36.0   27.27%       345.18     E
# 3      10000        10000          10000.0  60.0   12.98%       227.43     B
# 4      30000        30000          30000.0  60.0   26.31%       903.73     E
#
#   sub_grade                        emp_title emp_length home_ownership  \
# 0        C2                       bus driver    4 years            OWN
# 1        C2                        Carpenter  10+ years           RENT
# 2        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3        B5                          Printer    9 years           RENT
# 4        E4                      Casino Host  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
# Make last_pymnt_d_month and last_pymnt_d_year columns.

df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

df['last_pymnt_d'].head()
# Out:
# 0   1970-01-01 00:00:00.000002020
# 1   1970-01-01 00:00:00.000002020
# 2   1970-01-01 00:00:00.000002019
# 3   1970-01-01 00:00:00.000002020
# 4   1970-01-01 00:00:00.000002019
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df['last_pymnt_d'].dt.year
# Out:
# 0         1970.0
# 1         1970.0
# 2         1970.0
# 3         1970.0
# 4         1970.0
#            ...
# 128407    1970.0
# 128408    1970.0
# 128409    1970.0
# 128410    1970.0
# 128411    1970.0
# Name: last_pymnt_d, Length: 128412, dtype: float64

# %%
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0  36.0   14.47%       688.13     C
# 1      16000        16000          16000.0  36.0   14.47%       550.51     C
# 2       8425         8425           8425.0  36.0   27.27%       345.18     E
# 3      10000        10000          10000.0  60.0   12.98%       227.43     B
# 4      30000        30000          30000.0  60.0   26.31%       903.73     E
#
#   sub_grade                        emp_title emp_length home_ownership  \
# 0        C2                       bus driver    4 years            OWN
# 1        C2                        Carpenter  10+ years           RENT
# 2        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3        B5                          Printer    9 years           RENT
# 4        E4                      Casino Host  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
df.tail()3
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment  \
# 128407      23000        23000          23000.0  36.0   15.02%       797.53
# 128408      10000        10000          10000.0  36.0   15.02%       346.76
# 128409       5000         5000           5000.0  36.0   13.56%       169.83
# 128410      10000        10000           9750.0  36.0   11.06%       327.68
# 128411      10000        10000          10000.0  36.0   16.91%       356.08
#
#        grade sub_grade             emp_title emp_length home_ownership  \
# 128407     C        C3        Tax Consultant  10+ years       MORTGAGE
# 128408     C        C3        security guard    5 years       MORTGAGE
# 128409     C        C1          Payoff Clerk  10+ years       MORTGAGE
# 128410     B        B3                   NaN        NaN           RENT
# 128411     C        C5  Key Accounts Manager    2 years           RENT
#
#         annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01

# %%
df = pd.read_csv('aisles.csv')

# %%
df.head()

# %%
df.dtypes

# %%
df.describe

# %%
df = pd.read_csv('orders.csv')

# %%
df.head()

# %%
df.isnull().sum().sort_values()

# %%
df.tail()

# %%
df['order_number'].max()

# %%
df['order_hour_of_day'].mean()

# %%
df['order_dow'].describe()

# %%
df1 = pd.read_csv('products.csv')
df1.head()

# %%
df1['aisle_id']

# %%
df1['department_id'].head()

# %%
df1.head()
