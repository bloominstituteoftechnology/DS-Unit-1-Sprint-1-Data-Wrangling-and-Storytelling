# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# > - Objective 1 - Load a CSV dataset from a URL
# > - Objective 2 - Load a CSV dataset from a local file
# > - Objective 3 - Use basic Pandas functions for Exploratory Data Analysis-EDA
# > - Objective 4 - Understand how to do basic Feature Engineering
# > - Objective 5 - Work with Strings in Pandas

# %% [markdown]
# # Load a dataset (CSV) via its URL

# %% [markdown]
# ## Overview
#
# In order to practice loading datasets into Google Colab, we're going to use the [Flags Dataset](https://archive.ics.uci.edu/ml/datasets/Flags) from UCI to load datasets via URL and from a local file.
#
#
# When loading a dataset:
#
# 1) Learn as much as you can about the dataset:
#  - Number of rows
#  - Number of columns
#  - Column headers (Is there a "data dictionary"?)
#  - Is there missing data?
#  - Open the raw file and look at it - it may not be formatted the way you expect.
#
# 2) Try loading the dataset using `pandas.read_csv()` and if things aren't acting the way that you expect, investigate until you can get it loading correctly.
#
# 3) Keep in mind that functions like `pandas.read_csv()` have a lot of optional parameters that might help us change the way that data is read in. If you get stuck, google, read the documentation, and try things out.
#
# 4) You might need to type out column headers if they are not provided in the original dataset.

# %% [markdown]
# ## Follow Along
#
# ### Learn about the dataset and look at the raw file.

# %%
flag_data_url = 'https://raw.githubusercontent.com/bloominstituteoftechnology/data-science-practice-datasets/main/unit_1/Flags/Flags.csv'

# %% [markdown]
# <details>
#     <summary style="display:list-item"> <b> What is a csv? </b></summary>
#
# A comma separated value.
# </details>

# %% [markdown]
# ### Attempt to load it via its URL

# %%
# Load the flags dataset from its URL:



#Print the first 5 rows:

# %% [markdown]
# <details>
#     <summary style="display:list-item"> <b> What went wrong?</b></summary>
#
# The columns are supposed to be the first row of the dataset, not the names.
# </details>

# %%
# Googling is great! Studying the documentation is even better!
#https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
column_headers = ['name', 'landmass', 'zone', 'area', 'population', 'language', 
                  'religion', 'bars', 'stripes', 'colours', 'red', 'green', 
                  'blue', 'gold', 'white', 'black', 'orange', 'mainhue', 
                  'circles', 'crosses', 'saltires', 'quarters', 'sunstars', 
                  'crescent', 'triangle', 'icon', 'animate', 'text', 'topleft', 
                  'botright']

# %% [markdown]
# <details>
#     <summary style="display:list-item"> <b> What kind of object is the item above? </b></summary>
#
# A list.
# </details>

# %%
## Include the column headers in the import statebment


#Print the dimensions


#Print the first 5 observations:

# %% [markdown]
# ### Load a dataset (CSV) from a local file

# %% [markdown]
# ## Overview
#
# Many of our csv documents for this class will be stored online. For files that are downloaded to your **local computer**, you will need to upload files to Google Colab's Drive.
#
# *Note: There are different ways you can accomplish this.*

# %% [markdown]
# Go to the website http://users.stat.ufl.edu/~winner/datasets.html and scroll down to **Disney World Marathon Times and Miles/Hour - 1-12-2020**
#
#
# **Download it to your personal computer.**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-21dc3c638f66> in <module>
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
#Read in the dataset using read_csv

#Print the dimensions of the dataset


#Print the first 15 observations

# %% [markdown]
# ## Use basic Pandas functions for Exploratory Data Analysis (EDA)

# %% [markdown]
# ![Workflow.png](data:image/png;base64,...)

# %% [markdown]
# ## Overview
#
# > Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns, to spot anomalies, to develop hypotheses and check assumptions with the help of summary statistics and graphical representations.
#
#
# Exploratory Data Analysis is often the first thing to do with a new dataset. The discoveries made during this stage of the process will determine which model to choose, the analysis approach, and how to approach a data science methodology.

# %% [markdown]
# ## Follow Along

# %%
#Determine the dimensions of the dataset

# %%
#Learn more about the variables in the dataset

# %% [markdown]
# ## Learn more about each variable

# %%
#Determine the data types

# %%
# Summary Statistics

# %% [markdown]
# <details>
#     <summary style="display:list-item"> <b> What is the problem with this output?</b></summary>
#
# We are missing the results for our non-numeric columns.
# </details>

# %%
# Display the non-numeric columns

# %%
# Access a specific column of the dataframe

# %%
# Sort by a specific column

# %%
#How many individuals are in each group?

# %%
# Check for missing values

# %%
# Total number of missing cells in the entire dataset

# %%
# Drop rows from the dataset

# %%
# Drop rows using the inplace method

# %%
# Use axis=1 to iterate through column headers


# Using inplace

# %%
# Another argument you can use to drop columns

# %%
#Never do this when using inplace

# %% [markdown]
# # Feature Engineering and Cleaning

# %% [markdown]
# ![Workflow.png](data:image/png;base64,...)

# %%
house = pd.read_csv('https://raw.githubusercontent.com/bloominstituteoftechnology/data-science-practice-datasets/main/unit_1/Housing/Ames%20Iowa%20Housing%20Data.csv')

# %% [markdown]
# Let's look a little more closely at `BedroomAbvGr`
#
# `BedroomAbvGr` which stands for "Bedrooms Above Ground." This is the number of non-basement bedrooms in the home.
# <br>
# <br>
# <details>
#     <summary style= "display:list-item">  <b> 'What type of variable is BedroomAbvGr?  Is it categorical or quantitative?</b> </summary>
#
#     Quantitative
# </details>

# %%
#BedroomAbvGr

# %% [markdown]
# ___
# Now lets take a closer look at `LotFrontage`.

# %%
#LotFrontage

# %% [markdown]
# <details>
#     <summary style= "display:list-item">  <b> Do the values look like floats to you?</b> </summary>
#
# They all have `.0`, they are stored as floats. This might not have been the intention originally.
# </details>

# %% [markdown]
# <br>
# <details>
#     <summary style= "display:list-item">  <b> Does every house have a lot frontage?</b> </summary>
#
# Not in some apartments, condos, or building properties.
# </details>

# %% [markdown]
# ## NaN
#
# `NaN` stands stands for "Not a Number" and is the default missing value indicator with Pandas. This means there were cells in this column that did not have a `LotFrontage` value recorded for those properties.
#
# This is where domain knowledge starts to come in. Think about the context we're working with here: houses. What might a null or blank cell representing "Linear feet of street connected to property" mean in the context of a housing dataset?
#
# Perhaps some of this data is truly missing or unrecorded data, but sometimes `NaNs` are more likely to indicate something that was "NA" or "Not Applicable" to a particular observation. There could be multiple reasons why there was no value recorded for a particular feature
#
# Remember - Pandas tries to maintain a single datatype for all values in a column. Is there a better value to use?

# %%
#import numpy



# What is the datatype of NaN?

# %% [markdown]
# ## Making new Features
#
# Lets slim down the dataset and consider just a few specific columns:
#
# - `TotalBsmtSF`
# - `1stFlrSF`
# - `2ndFlrSF`
# - `SalePrice1`

# %% [markdown]
# Use a single square bracket to select only one column.

# %% [markdown]
# Make a smaller dataframe with a few specific columns by passing a list of column headers inside two square brackets.

# %% [markdown]
# ###.copy()
# In the following example we are copying a set to another set using = operator.  With this method, any changes made to either dataframe is modified, and will reflect in both objects. If you do not want this kind of behavior and only want the set where you are making changes to be changed then use .copy() method.
#
# For more on the differences between shallow and deep copies: <br>https://medium.com/better-programming/assignment-vs-shallow-copy-vs-deep-copy-in-python-246ea4d36b3c

# %%
#Check the data types.

# %% [markdown]
# ## Creating new columns

# %%
### Creating a new column by doing arithmetic on other columns

# %%
# Lets add up all of the square footage values to get a single square footage amount for the entire dataset

# %%
# Lets make another new column that is 'PricePerSqFt' by
# dividing the price by the square footage

# %% [markdown]
# <br>
# <details>
#     <summary style= "display:list-item">  <b> Why might you want to have the total square footage or price per square foot variables?</b> </summary>
#
# Significant method of measuring the value of a property.
# </details>

# %% [markdown]
# ### Creating a Boolean or Conditional Variable (Column)
#
#
# Say we want to categorize houses as having a high price per square foot (greater than or equal to 80 dollars per square foot) or a low price per square foot (less than 80 dollars per square foot).

# %% [markdown]
# ### Using .loc[ ]

# %%
#We can identify high price per square foot properties that have basements.

# %% [markdown]
# <br>
# <details>
#     <summary style= "display:list-item">  <b> Why might we want to have categories for high and low cost per square foot?</b> </summary>
#
# To develop additional categorical values.
# </details>

# %%
house.new_col.value_counts()

# %% [markdown]
# # Work with Strings in Pandas

# %%
import pandas as pd
loans_data = 'https://raw.githubusercontent.com/bloominstituteoftechnology/data-science-practice-datasets/main/unit_1/LendingClub/LoanStats_2018Q4_sm.csv'
loans = pd.read_csv(loans_data)

# %%
#check for missing data in loans


#drop columns where everything is missing

# %% [markdown]
# ### Cleaning the `int_rate` column
#
# Many machine learning models only work on numerical values, and require a different process when accounting for string values. Math will not work on words.

# %%
#Note that there is a leading blank space in the values for the int_column
loans.loc[1, 'int_rate']
# Out:
# ' 10.08%'

# %%
#Use .str.strip to remove both the leading space and the % sign
loans
# Out:
#        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     NaN        NaN       5525         5525           5525.0   36 months
# 1     NaN        NaN      10000        10000          10000.0   36 months
# 2     NaN        NaN      12000        12000          12000.0   60 months
# 3     NaN        NaN      20000        20000          20000.0   36 months
# 4     NaN        NaN      12000        12000          12000.0   36 months
# ...    ..        ...        ...          ...              ...         ...
# 29995 NaN        NaN      20000        20000          20000.0   36 months
# 29996 NaN        NaN      35000        35000          35000.0   60 months
# 29997 NaN        NaN      10000        10000           9975.0   60 months
# 29998 NaN        NaN      16000        16000          16000.0   60 months
# 29999 NaN        NaN       6400         6400           6400.0   36 months
#
#       int_rate  installment grade sub_grade  ...  \
# ...

# %% [markdown]
# ### Using .str

# %%
#Cast the value as a float

# %% [markdown]
# ### Using functions and .apply()

# %% [markdown]
# ### Write a function to make our solution reusable!

# %% [markdown]
# Every function has these parts:
#
# * def statement
# * name
# * parameter name(s)
# * body
# * a return statement
# * a return value
#
# ![Function+parts+Argument(sent+in)+radius+is+called+a.+parameter.+def+vol_of_sphere(radius)_+header+vol+=+4_3.0_math.pi_radius__3+return+vol.jpg](data:image/jpeg;base64,...)

# %%
# Create a function that will take a single string, strip off the space and %
def remover(col_name):
    return float(col_name.strip().strip('%'))

# %%
loans['int_rate'].apply(remover)
# Out:
# 0        10.72
# 1        10.08
# 2        10.08
# 3         6.46
# 4         7.02
#          ...
# 29995    10.33
# 29996     6.11
# 29997    25.34
# 29998     7.84
# 29999    13.56
# Name: int_rate, Length: 30000, dtype: float64
