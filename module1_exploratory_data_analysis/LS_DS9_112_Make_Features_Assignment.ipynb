# %% [markdown]
# <a href="https://colab.research.google.com/github/maiormarso/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module1_exploratory_data_analysis/LS_DS9_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here ###lendingclub.com/LoanStats_2018Q4.csv.zip
#!wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip

# %% [markdown]
# Load Lending Club data
#
# pandas documentation
# - rea
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html

# %%
#!unzip LoanStats_2018Q4.csv.zip

# %%
import pandas as pd
df=pd.read_csv('LoanStats_2018Q4.csv',skiprows=1, skipfooter=2, engine='python')

# %%
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      25000        25000          25000.0   60 months
# 2 NaN        NaN      26500        26500          26500.0   60 months
# 3 NaN        NaN      10400        10400          10400.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   60 months
#
#   int_rate  installment grade sub_grade                         emp_title  \
# 0   14.47%       688.13     C        C2                        bus driver
# 1   16.14%       609.82     C        C4                Production Manager
# 2   11.31%       580.28     B        B3               Compliance Director
# 3   12.98%       350.32     B        B5        Program Support Assistant
# 4   12.98%       796.00     B        B5  Sr. Vice President -Risk Manager
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
pd.options.display.max_columns =999
pd.options.display.max_rows = 999

# %%
df.isnull().sum().sort_values()[:10]# chaining

# %%
df = df.drop(['url','member_id','desc','id'], axis=1)

# %%
df.head(1)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
#
#   grade sub_grade   emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2  bus driver    4 years            OWN     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan             purpose  \
# 0     Source Verified  Dec-2018     Current          n  debt_consolidation
#
#                 title zip_code addr_state    dti  delinq_2yrs  \
# 0  Debt consolidation    681xx         NE  30.65            1
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Jun-1979               2                    15.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         6        0      15048        73%         22
#
#   initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# ...

# %%
#Convert term column from string to integer

# %%
def remove_months(string):
 return (string.strip('months'))

# %%
df['term'] = df['term'].apply(remove_months)

# %%
df['term'] = df['term'].astype('int64')

# %%
df.dtypes

# %%
df.head(10)

# %%
df.dtypes[:10]
# Out:
# loan_amnt            int64
# funded_amnt          int64
# funded_amnt_inv    float64
# term                 int64
# int_rate            object
# installment        float64
# grade               object
# sub_grade           object
# emp_title           object
# emp_length          object
# dtype: object

# %% [markdown]
# #Make a column named loan_status_is_great.
#
# It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
df['loan_status_is_great'] = df['loan_status'].str.contains('Current','Fully Paid')

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0    36   14.47%       688.13     C
# 1      25000        25000          25000.0    60   16.14%       609.82     C
# 2      26500        26500          26500.0    60   11.31%       580.28     B
# 3      10400        10400          10400.0    36   12.98%       350.32     B
# 4      35000        35000          35000.0    60   12.98%       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        bus driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5        Program Support Assistant   10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %% [markdown]
# #Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
df['last_pymnt_d_month']= 1

# %%
df['last_pymnt_d_year']= 1

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0    36   14.47%       688.13     C
# 1      25000        25000          25000.0    60   16.14%       609.82     C
# 2      26500        26500          26500.0    60   11.31%       580.28     B
# 3      10400        10400          10400.0    36   12.98%       350.32     B
# 4      35000        35000          35000.0    60   12.98%       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        bus driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5        Program Support Assistant   10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                            int64
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0    36   14.47%       688.13     C
# 1      25000        25000          25000.0    60   16.14%       609.82     C
# 2      26500        26500          26500.0    60   11.31%       580.28     B
# 3      10400        10400          10400.0    36   12.98%       350.32     B
# 4      35000        35000          35000.0    60   12.98%       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        bus driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5        Program Support Assistant   10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %% [markdown]
# Work with strings
#
# for machine learning we usually want to replace strings with numbers.
#
# We can get info about which columns have a datatype of 'object' (strings)

# %%
df['int_rate'][:1]

# %%
int_rate = ' 15.02%'
int_rate

# %%
# 'Cast' from a string to a float
int_rate.strip().strip('%')

# %%
type(float(int_rate.strip().strip('%')))

# %% [markdown]
# ##Convert int_rate
#
# Define a functionto remove percent signs fromstrings and conver to floats

# %%
def int_rate_to_float(mystring): # second int_rate is a parameter and can be any name
  return float(mystring.strip().strip('%')) # chaining left to right .strip().strip('%')
 # return float(mystring.strip().strip('%')) #/100
int_rate_to_float(int_rate) # second int_rate is the argument)

# %% [markdown]
# Apply the function to the int_rate column

# %%
# just in case df['int_rate_decimal'].apply(int_rate_to_float)[:10]
df['int_rate'].apply(int_rate_to_float)[:10] # bracket notation

# %%
df['int_rate'].apply(int_rate_to_float)[:10] # bracket notation

# %%
#df['int_rate']= df['int_rate'].apply(int_rate_to_float)

# %%
df['int_rate_decimal']= df['int_rate'].apply(int_rate_to_float)

# %%
df['int_rate_float']= df['int_rate'].apply(int_rate_to_float)

# %%
df.head()

# %%
df.dtypes[:10]

# %% [markdown]
# ###Clean emp_title

# %%
df['emp_title'].value_counts(ascending=False)[:20]

# %% [markdown]
# # How often is emp_title null?

# %%
df['emp_title'].isnull().sum()

# %%
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]

# %% [markdown]
# How many unique job titles do we currently have?

# %%
# of unique job titles
len(df['emp_title'].value_counts())

# %%
df['emp_title'].value_counts().reset_index()[:4]

# %%
df['emp_title'].value_counts().reset_index().shape

# %% [markdown]
# How often is emp_title null?

# %%
# NaNs
df['emp_title'].isnull().sum()

# %% [markdown]
# ###Write a function to clean up our titles and check if it works using a 'List Comprehension'

# %% [markdown]
# Clean the title and handle missing values

# %%
import numpy as np
type(np.NaN)

# %%
examples = ['owner','Supervisor','Project Manager', np.NaN]
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'
[clean_title(item) for item in examples]

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

# %%
## From here one must go up to  the heading
# How Often Is a emp_title Null? then two lines down run code
#df['emp_title'].value_counts(dropna=False, ascending=False)[:20]

# %%
df.head()

# %%
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]

# %%
len(df['emp_title'].value_counts())

# %% [markdown]
# ###Create emp_title_manager
# pandas documentation str.contains

# %%
df['emp_title_manager'] = df['emp_title'].str.contains('Manager')

# %%
df.head()

# %% [markdown]
# ### Dataframe Filtering Example
# (Get a subset of a dataframe based on certain conditions)

# %%
condition = (df['emp_title_manager'] == True) 
managers =  df[df['emp_title_manager']== True]
  
print(managers.shape)
managers.head()

# %%
plebians = df[(df['emp_title_manager'] == False) & (df['home_ownership']=='OWN')]
#plebians = df[(df['emp_title_manager'] == False) & (df['home_ownership']== 'MORTGAGE')]
plebians.shape

# %%
plebians.head()

# %%
managers['int_rate_float'].mean()

# %%
plebians['int_rate_float'].mean()

# %% [markdown]
# We can make exploratory visualizations based on the two subsetted dataframes,that would be harder to make if we hadn't done the filtering

# %%
import seaborn as sns

sns.kdeplot(plebians['int_rate_float']);
sns.kdeplot(managers['int_rate_float']);

# %%
import seaborn as sns
sns.distplot(plebians['int_rate_float']);
sns.distplot(managers['int_rate_float']);

# %%
managers['int_rate_float'].mean()

# %%
plebians['int_rate_float'].mean()

# %%
managers['int_rate_float'].mean()

# %% [markdown]
# ##Work with dates
# Time/Date with underscore '_d'

# %%
list(df.columns)

# %%
[col for col in df if col.endswith('_d')]

# %%
['issue_d', 'last_payment_d','next_paymnt_d', 'last_credit_pull_d']

# %%
df.dtypes

# %%
df.dtypes[:12]

# %%
df.dtypes['issue_d']

# %%
df.dtypes[:15]

# %%
df['issue_d'][:10]

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df.head(1)

# %%
df['issue_d'][:10]

# %%
df.dtypes[:15]

# %%
df['issue_d'].head().values

# %%
df['issue_d'].dt.year

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

# %%
df.head()

# %%
df['earliest_cr_line'].head()

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'],
                                       infer_datetime_format=True)

# %%
df['days_from_earliest_credit_to_issue']  = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df.head(1)

# %%
df['days_from_earliest_credit_to_issue'].describe()

# %%
25171/365

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
