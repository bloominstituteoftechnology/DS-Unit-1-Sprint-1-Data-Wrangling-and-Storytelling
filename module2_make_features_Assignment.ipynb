# %% [markdown]
# <a href="https://colab.research.google.com/github/kylerhellyer/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2_make_features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
pd.set_option('display.max_rows', 120)
pd.set_option('display.max_columns', 100)

df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df['LotFrontage'].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 82.0      12
# 40.0      12
# 43.0      12
# 67.0      12
# 57.0      12
# 69.0      11
# 76.0      11
# 86.0      10
# 53.0      10
# 34.0      10
# 92.0      10
# 88.0      10
# 62.0       9
# 44.0       9
# 84.0       9
# 77.0       9
# 35.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 120.0      7
# 95.0       7
# 58.0       7
# 41.0       6
# 30.0       6
# 81.0       6
# 89.0       6
# 105.0      6
# 48.0       6
# 110.0      6
# 94.0       6
# 54.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 37.0       5
# 83.0       5
# 56.0       5
# 87.0       5
# ...

# %%
import numpy as np

type(np.NaN)
# Out:
# float

# %%
df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
column_header_variable = 'TotalBsmtSF'

# %%
df_small[column_header_variable]
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
df_small['TotalSF'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSF']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqFt
# 0          856       856       854     208500     2566     81.254871
# 1         1262      1262         0     181500     2524     71.909667
# 2          920       920       866     223500     2706     82.594235
# 3          756       961       756     140000     2473     56.611403
# 4         1145      1145      1053     250000     3343     74.783129

# %%
# Convert the term column from string to integer.

# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is 
# "Current" or "Fully Paid." Else it should contain the integer 0.

# Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-03-10 20:29:23--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [         <=>        ]  21.71M   430KB/s    in 54s
#
# 2020-03-10 20:30:18 (410 KB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22763850]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3387.58","3387.58","3032.81","3032.81","2212.42","820.39","0.0","0.0","0.0","Feb-2020","190.21","Mar-2020","Jan-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# ?pd.read_csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv')

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128287, 1)
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)

print(df.shape)
df.tail()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128286, 144)
#                                                       id  member_id  \
# 128281                                               NaN        NaN
# 128282                                               NaN        NaN
# 128283                                               NaN        NaN
# 128284  Total amount funded in policy code 1: 2048833825        NaN
# 128285   Total amount funded in policy code 2: 819375497        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128281     5000.0       5000.0           5000.0   36 months   13.56%
# 128282    10000.0      10000.0           9750.0   36 months   11.06%
# 128283    10000.0      10000.0          10000.0   36 months   16.91%
# ...

# %%
pd.set_option('display.max_rows', 150)

df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# max_bal_bc                                         2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# hardship_flag                                      2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')

print(df.shape)
df.head()
# Out:
# (128284, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   60 months
# 1 NaN        NaN       6500         6500           6500.0   36 months
# 2 NaN        NaN       4500         4500           4500.0   36 months
# 3 NaN        NaN      25000        25000          25000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   16.14%       243.93     C        C4        Sale Consultant    2 years
# 1   11.80%       215.28     B        B4              Educator     2 years
# 2   11.31%       147.99     B        B3  Accounts Examiner III  10+ years
# 3   14.47%       587.82     C        C2                teacher  10+ years
# 4   27.27%       920.91     E        E5         Claims Analyst     1 year
#
#   home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   60 months   16.14%       243.93
# 1       6500         6500           6500.0   36 months   11.80%       215.28
# 2       4500         4500           4500.0   36 months   11.31%       147.99
# 3      25000        25000          25000.0   60 months   14.47%       587.82
# 4      30000        30000          30000.0   60 months   27.27%       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
# Convert the term column from string to integer.

# %%
df['term'].head(10)
# Out:
# 0     60 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     60 months
# 5     36 months
# 6     60 months
# 7     36 months
# 8     36 months
# 9     36 months
# Name: term, dtype: object

# %%
df['term'][0]
# Out:
# ' 60 months'

# %%
term = '36 months'

# %%
term.strip()
# Out:
# '36 months'

# %%
term.strip(' months')
# Out:
# '36'

# %%
float(term.strip().strip(' months'))
# Out:
# 36.0

# %%
def term_to_float(cell_contents):
  return float(cell_contents.strip().strip(' months'))

term_to_float(term)
# Out:
# 36.0

# %%
term_list = []

for cell in df['term']:
  term_list.append(term_to_float(cell))

term_list[0:10]

df['term_cleaned'] = pd.Series(term_list)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   60 months   16.14%       243.93
# 1       6500         6500           6500.0   36 months   11.80%       215.28
# 2       4500         4500           4500.0   36 months   11.31%       147.99
# 3      25000        25000          25000.0   60 months   14.47%       587.82
# 4      30000        30000          30000.0   60 months   27.27%       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
df['term'] = df['term'].apply(term_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      10000        10000          10000.0  60.0   16.14%       243.93     C
# 1       6500         6500           6500.0  36.0   11.80%       215.28     B
# 2       4500         4500           4500.0  36.0   11.31%       147.99     B
# 3      25000        25000          25000.0  60.0   14.47%       587.82     C
# 4      30000        30000          30000.0  60.0   27.27%       920.91     E
#
#   sub_grade              emp_title emp_length home_ownership  annual_inc  \
# 0        C4        Sale Consultant    2 years           RENT     90000.0
# 1        B4              Educator     2 years           RENT     46500.0
# 2        B3  Accounts Examiner III  10+ years           RENT     38500.0
# 3        C2                teacher  10+ years            OWN    110000.0
# 4        E5         Claims Analyst     1 year           RENT     50000.0
#
# ...

# %%
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is 
# "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
df['loan_status'].value_counts(dropna=False).head(20)
# Out:
# Current               92485
# Fully Paid            24821
# Charged Off            6766
# Late (31-120 days)     2210
# In Grace Period        1405
# Late (16-30 days)       486
# Default                 111
# Name: loan_status, dtype: int64

# %%
def loan_status_is_great(): 
  if isinstance('Current','Fully Paid'):
    return '1'
  else:
    return '0'

# %%
df['loan_status_is_great'] = df['loan_status']

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      10000        10000          10000.0  60.0   16.14%       243.93     C
# 1       6500         6500           6500.0  36.0   11.80%       215.28     B
# 2       4500         4500           4500.0  36.0   11.31%       147.99     B
# 3      25000        25000          25000.0  60.0   14.47%       587.82     C
# 4      30000        30000          30000.0  60.0   27.27%       920.91     E
#
#   sub_grade              emp_title emp_length home_ownership  annual_inc  \
# 0        C4        Sale Consultant    2 years           RENT     90000.0
# 1        B4              Educator     2 years           RENT     46500.0
# 2        B3  Accounts Examiner III  10+ years           RENT     38500.0
# 3        C2                teacher  10+ years            OWN    110000.0
# 4        E5         Claims Analyst     1 year           RENT     50000.0
#
# ...

# %%
# Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['last_pymnt_d']
# Out:
# 0        2019-05-01
# 1        2020-02-01
# 2        2019-02-01
# 3        2019-10-01
# 4        2020-02-01
#             ...
# 128279   2018-12-01
# 128280   2020-02-01
# 128281   2020-02-01
# 128282   2020-02-01
# 128283   2020-02-01
# Name: last_pymnt_d, Length: 128284, dtype: datetime64[ns]

# %%
df['last_pymnt_d'].value_counts()
# Out:
# 2020-02-01    93927
# 2019-07-01     3141
# 2020-01-01     3028
# 2019-12-01     2789
# 2019-09-01     2755
# 2019-10-01     2741
# 2019-08-01     2712
# 2019-05-01     2547
# 2019-11-01     2430
# 2019-04-01     2352
# 2019-06-01     2284
# 2019-03-01     1980
# 2019-02-01     1915
# 2019-01-01     1561
# 2018-12-01     1052
# 2018-11-01      678
# 2018-10-01      233
# Name: last_pymnt_d, dtype: int64

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

df.dtypes[20]
# Out:
# dtype('float64')

# %%
df['last_pymnt_d'][0]
# Out:
# Timestamp('2019-05-01 00:00:00')

# %%
df['last_pymnt_d'].head().values
# Out:
# array(['2019-05-01T00:00:00.000000000', '2020-02-01T00:00:00.000000000',
#        '2019-02-01T00:00:00.000000000', '2019-10-01T00:00:00.000000000',
#        '2020-02-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['last_pymnt_d'].dt.year
# Out:
# 0         2019.0
# 1         2020.0
# 2         2019.0
# 3         2019.0
# 4         2020.0
#            ...
# 128279    2018.0
# 128280    2020.0
# 128281    2020.0
# 128282    2020.0
# 128283    2020.0
# Name: last_pymnt_d, Length: 128284, dtype: float64

# %%
df['last_pymnt_d'].dt.month
# Out:
# 0          5.0
# 1          2.0
# 2          2.0
# 3         10.0
# 4          2.0
#           ...
# 128279    12.0
# 128280     2.0
# 128281     2.0
# 128282     2.0
# 128283     2.0
# Name: last_pymnt_d, Length: 128284, dtype: float64

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      10000        10000          10000.0  60.0   16.14%       243.93     C
# 1       6500         6500           6500.0  36.0   11.80%       215.28     B
# 2       4500         4500           4500.0  36.0   11.31%       147.99     B
# 3      25000        25000          25000.0  60.0   14.47%       587.82     C
# 4      30000        30000          30000.0  60.0   27.27%       920.91     E
#
#   sub_grade              emp_title emp_length home_ownership  annual_inc  \
# 0        C4        Sale Consultant    2 years           RENT     90000.0
# 1        B4              Educator     2 years           RENT     46500.0
# 2        B3  Accounts Examiner III  10+ years           RENT     38500.0
# 3        C2                teacher  10+ years            OWN    110000.0
# 4        E5         Claims Analyst     1 year           RENT     50000.0
#
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
