# %% [markdown]
# <a href="https://colab.research.google.com/github/edwinapalmer/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Make_Features_Edwina_Palmer_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd

# %%
#Pandas Display Options
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 100)

# %%
#Lets take a look at the Ames Iowa Housing Dataset
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#specific columns hold specific kinds of data

df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
#Look at the first ten rows of the 'BedroomAbvGr' columns.
# Looks like integers to me!
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
# Look at the first ten rows of the 'LotFrontage' column.
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df['LotFrontage'].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 82.0      12
# 40.0      12
# 43.0      12
# 67.0      12
# 57.0      12
# 69.0      11
# 76.0      11
# 86.0      10
# 53.0      10
# 34.0      10
# 92.0      10
# 88.0      10
# 62.0       9
# 44.0       9
# 84.0       9
# 77.0       9
# 35.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 120.0      7
# 95.0       7
# 58.0       7
# 41.0       6
# 30.0       6
# 81.0       6
# 89.0       6
# 105.0      6
# 48.0       6
# 110.0      6
# 94.0       6
# 54.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 37.0       5
# 83.0       5
# 56.0       5
# 87.0       5
# ...

# %%
#NaN is the most common value in this column. What is NaN
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
import numpy as np

# What is the datatype of NaN?

type(np.NaN)
# Out:
# float

# %%
 # I can make smaller dataframe with a few specific column headers
 #by passing a list of column headers inside of the square brackets
 df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

 df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
# Creating new columns on a dataframe

df_small.TotalBsmtSF
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_small['TotalBsmtSF']
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
# Lets add up all of the square footage to get a single square footage
# column for the entire dataset

#Using bracket syntax to make a new 'TotalSquareFootage' column
df_small['TotalSquareFootage'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343

# %%
# Lets make another new column that is 'PricePerSqFt' by
# dividing the price by the square footage

df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSquareFootage']

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage  \
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343
#
#    PricePerSqFt
# 0     81.254871
# 1     71.909667
# 2     82.594235
# 3     56.611403
# 4     74.783129

# %%
 # Load a new dataset to work with strings with pandas

# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-04-07 21:47:42--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 50.112.132.61, 52.32.57.66, 54.69.167.66
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|50.112.132.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [            <=>     ]  21.77M  1.98MB/s    in 11s
#
# 2020-04-07 21:47:54 (1.91 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22826918]

# %%
 # to unzip csv from zipped folder

# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3235.65","3235.65","3223.02","3223.02","2364.35","858.67","0.0","0.0","0.0","Mar-2020","190.21","Apr-2020","Mar-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# Read in the CSV

df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 1  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 2  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 3  NaN        NaN    17100.0      17100.0          17100.0   36 months
# 4  NaN        NaN     4000.0       4000.0           4000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   14.47%      1204.23     C        C2       Staff Physician    8 years
# 1   22.35%       191.86     D        D5     Director of Sales  10+ years
# ...

# %%
# We can fix the header problem by using the 'skiprows parameter

df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      35000        35000          35000.0   36 months
# 1 NaN        NaN       5000         5000           5000.0   36 months
# 2 NaN        NaN      10000        10000          10000.0   60 months
# 3 NaN        NaN      17100        17100          17100.0   36 months
# 4 NaN        NaN       4000         4000           4000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   14.47%      1204.23     C        C2       Staff Physician    8 years
# 1   22.35%       191.86     D        D5     Director of Sales  10+ years
# 2   23.40%       284.21     E        E1                   NaN   < 1 year
# ...

# %%
# Sum null values by column and sort from least to greatest
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
# drop columns made up NaN values

df = df.drop(['url', 'member_id', 'id', 'desc'], axis=1)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      35000        35000          35000.0   36 months   14.47%      1204.23
# 1       5000         5000           5000.0   36 months   22.35%       191.86
# 2      10000        10000          10000.0   60 months   23.40%       284.21
# 3      17100        17100          17100.0   36 months   18.94%       626.30
# 4       4000         4000           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              Unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
# Clean up int_rate column
# Look at the first 10 values of the int_rate column
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
# Look at a specific value from the int_rate column

df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
# Lets start with just fixing a single string.
# If we can fix one, we can usually fix all of them

int_rate = " 16.57%"

# %%
# .strip() by default removes leading or trailing whitespace from a string
int_rate.strip()
# Out:
# '16.57%'

# %%
int_rate.strip("%")
# Out:
# ' 16.57'

# %%
# Chaining: when I call two functions back to back

int_rate.strip().strip("%")
# Out:
# '16.57'

# %%
# "Casting" from a string to a float

float(int_rate.strip().strip("%"))
# Out:
# 16.57

# %%
# Write a function that can do what we have written above to any
# String that is passed to it.

# Works for any value/cell in a dataframe column
def int_rate_to_float(dirty_int_rate):
  return float(dirty_int_rate.strip().strip("%"))

# %%
# Test out our function by calling it on our example
int_rate_to_float(int_rate)
# Out:
# 16.57

# %%
int_rate_to_float(' 15.69%')
# Out:
# 15.69

# %%
# is the data type correct?

type(int_rate_to_float(int_rate))
# Out:
# float

# %%
# To apply solution to every cell in a column

df['int_rate'].head()
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# Name: int_rate, dtype: object

# %%
int_rates = [' 16.57%', ' 16.52%', ' 16.58%', ' 16.41%', ' 15.47%']

# %%
clean_int_rates = []
for int_rate in int_rates:
  clean_int_rates.append(int_rate_to_float(int_rate))

#Taking the list and turning it into a dataframe column

clean_int_rates
# Out:
# [16.57, 16.52, 16.58, 16.41, 15.47]

# %%
# The technical name for a column of a dataframe is a "Series"
clean_int_rates = pd.Series(clean_int_rates)

clean_int_rates
# Out:
# 0    16.57
# 1    16.52
# 2    16.58
# 3    16.41
# 4    15.47
# dtype: float64

# %%
# The .apply() function

# You pass the apply function, another function - int_rate_to_float
df['int_rate_cleaned'] = df['int_rate'].apply(int_rate_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      35000        35000          35000.0   36 months   14.47%      1204.23
# 1       5000         5000           5000.0   36 months   22.35%       191.86
# 2      10000        10000          10000.0   60 months   23.40%       284.21
# 3      17100        17100          17100.0   36 months   18.94%       626.30
# 4       4000         4000           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              Unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
# What type of data is held in our new column?

# Look at the datatypes of the last 5 columns
df.dtypes.tail()
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# dtype: object

# %%
# Modify and Create Columns using .apply()
# Let's try and diagnose the problem and see what improvements can be made

#Look at the top 20 employment titles
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
df['emp_title'].nunique()
# Out:
# 43892

# %%
len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
# How often is the employment_title null?
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
# Reasons why employment title not provided
# Create some examples that represent the cases that we want to clean up
import numpy as np

examples = ['Owner', 'Supervisor', 'Project Manager', np.NaN]

# %%
# Write a function to clean up these use cases and increase uniformity.

def clean_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

for example in examples:
  print(clean_emp_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
# list comprehensions can combine function calls and for loops over lists
# into one succinct and fairly readable single line of code.

[clean_emp_title(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df['emp_title'].head(10)
# Out:
# 0                        Staff Physician
# 1                      Director of Sales
# 2                                    NaN
# 3                          Receptionist
# 4                   Extrusion assistant
# 5                                Teacher
# 6                             Supervisor
# 7                                Analyst
# 8    Corporate Communications Strategist
# 9                        Project Manager
# Name: emp_title, dtype: object

# %%
# We have a function that works as expected. Lets apply it to our column.
# This time we'll overwrite the original column

df['emp_title'].apply(clean_emp_title).head(10)
# Out:
# 0                        Staff Physician
# 1                      Director Of Sales
# 2                                Unknown
# 3                           Receptionist
# 4                    Extrusion Assistant
# 5                                Teacher
# 6                             Supervisor
# 7                                Analyst
# 8    Corporate Communications Strategist
# 9                        Project Manager
# Name: emp_title, dtype: object

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      35000        35000          35000.0   36 months   14.47%      1204.23
# 1       5000         5000           5000.0   36 months   22.35%       191.86
# 2      10000        10000          10000.0   60 months   23.40%       284.21
# 3      17100        17100          17100.0   36 months   18.94%       626.30
# 4       4000         4000           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              Unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
# Look at the top 20 employment titles

df['emp_title'].value_counts().head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
df['emp_title'].nunique()
# Out:
# 34902

# %%
# How often is the employment_title null (NaN)?
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
# Work with Dates and Times with Pandas
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
# Lets look at the string format of the issue_d column
df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'].value_counts()
# Out:
# Oct-2018    46305
# Nov-2018    41973
# Dec-2018    40134
# Name: issue_d, dtype: int64

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
# See what a datetime object looks like:

df['issue_d'].head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
# Look at the first 15 datatypes
df.dtypes[:15]
# Out:
# id                     float64
# member_id              float64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate                object
# installment            float64
# grade                   object
# sub_grade               object
# emp_title               object
# emp_length              object
# home_ownership          object
# annual_inc             float64
# verification_status     object
# dtype: object

# %%
# Grab just the year from all the cells in the issue_d
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
# Now the month

df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
# Add year and month values as new columns on dataframe

df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      35000        35000          35000.0   36 months   14.47%      1204.23
# 1       5000         5000           5000.0   36 months   22.35%       191.86
# 2      10000        10000          10000.0   60 months   23.40%       284.21
# 3      17100        17100          17100.0   36 months   18.94%       626.30
# 4       4000         4000           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              Unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
df.dtypes[-5:]
# Out:
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# issue_year                 int64
# issue_month                int64
# dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['earliest_cr_line'].head()
# Out:
# 0   1995-04-01
# 1   2010-03-01
# 2   2007-04-01
# 3   1998-03-01
# 4   2006-09-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days
# Out:
# 0          8645
# 1          3197
# 2          4262
# 3          7580
# 4          4474
#           ...
# 128407    12114
# 128408    13241
# 128409     4505
# 128410     3652
# 128411     4413
# Length: 128412, dtype: int64

# %%
df['years_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days / 365

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      35000        35000          35000.0   36 months   14.47%      1204.23
# 1       5000         5000           5000.0   36 months   22.35%       191.86
# 2      10000        10000          10000.0   60 months   23.40%       284.21
# 3      17100        17100          17100.0   36 months   18.94%       626.30
# 4       4000         4000           4000.0   36 months   10.72%       130.43
#
#   grade sub_grade            emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2      Staff Physician    8 years       MORTGAGE    360000.0
# 1     D        D5    Director Of Sales  10+ years       MORTGAGE     72000.0
# 2     E        E1              Unknown   < 1 year           RENT     55000.0
# 3     D        D2         Receptionist  10+ years           RENT     38000.0
# 4     B        B2  Extrusion Assistant  10+ years       MORTGAGE     56000.0
#
# ...

# %%
# What's oldest credit history that was involved in Q4 2018?

df['years_from_earliest_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean         16.054497
# std           7.908317
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: years_from_earliest_credit_to_issue, dtype: float64

# %%
# To convert the term column from string to integer.

df['term']
df['term'] = df['term'].astype(int)

df.term.dtype
# Out:
# dtype('int64')

# %%
df['term'] = df['term'].str.extract('(\d+)', expand=False)
df['term'] = df['term'].astype(int)

# %%
def loan_status_is_great(loan_status):
  if loan_status=='Current' or loan_status=='Fully Paid':
    df['loan_status_is_great'] = 1
  else: df['loan_status_is_great'] = 0

# %%
df['loan_status_is_great'] = df['loan_status'].apply(loan_status_is_great)
df.column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-3cf59f8ae6bc> in <module>()
# ----> 1 df['loan_status_is_great'] = df['loan_status'].apply(loan_status_is_great)
#       2 df.column
#
# NameError: name 'df' is not defined

# %%
# To make last_pymnt_d_month and last_pymnt_d_year columns.

df[last_pymnt_d].dt.month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-828af9a2eded> in <module>()
#       1
# ----> 2 df[last_pymnt_d].dt.month
#
# NameError: name 'df' is not defined

# %%
df['last_pymnt_d'].dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-7c7f1bb2f2a2> in <module>()
# ----> 1 df['last_pymnt_d'].dt.year
#
# NameError: name 'df' is not defined

# %%
df['last_pymnt_month'] = df['last_pymnt_d'].dt.month
df['last_pymnt_year'] = df['last_pymnt_d'].dt.year


# I keep getting the NameError message, and I've spent a long time at it and could still not figure out how to fix it. I have used google and tried some suggestions but nothing have been of help. I'm taking a break for now, and will get back to solving them.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-5704bbae7f96> in <module>()
# ----> 1 df['last_pymnt_month'] = df['last_pymnt_d'].dt.month
#       2 df['last_pymnt_year'] = df['last_pymnt_d'].dt.year
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
