# %% [markdown]
# <a href="https://colab.research.google.com/github/JulieMew/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Copy_of_Ideas_for_data_storytelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment!
#
# Fill out the template *twice*, for two different ideas.
#
# Then compare and contrast and select one as the idea you're leaning towards
# working on for your project week.
#
#
# # Ideas for data storytelling - Idea 1
#
# ## You
#
# What do you care about?
#
# UFC, Fencing, bioengineering, robotics, philosophy, art, 3d modeling, HEMA, neural network, social sciences
#
# What do you know about?
#
# UFC, Fencing, HEMA, art, social sciences
#
# What decisions do you face?
#
# Which ones have the most data relating to them.
#
# ## Seven templates
#
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# 1. Geographic Variation
#
# Do fighters from different areas overuse specific techniques, prefer certain martial arts, or have different tactics from a cultural basis? Do fighters from higher altitudes have an advantage?
#
# 2. Trend related to the news
#
# Recent fights have been suspended due to corona virus.
#
# 3. Who does that?
#
# usually 30-32 year old, fit people.
#
# 4. Answering a question people care about
#
# What technique is used the most by winners the most times in a single match?
#
# 5. Valuable to businesses
#
# Preferred products by UFC's target demographic.
#
# 6. What's the most popular?
#
# Most popular weight range this year and ten years back, what's the trend?
#
# 7. Cost/Money rankings
#
# Cost of training a UFC fighter compared to income on average.
#
# ## Misconceptions
#
# What misconceptions do people have about your topic?
#
# UFC is a monopoly
#
# ## Examples
#
# What data storytelling example inspires you?
#
# "Which is the best/most quotable Simpsons episode?"
#
# Could you do a new hypothesis, for the same question?
#
# I would assume that an aggregate of reddit and facebook groups would give me a better guess, since reddit is used less by some older users that are more likely to use facebook exclusively.
#
# Could you do a new question, for the same topic?
#
# Which Simpsons side characters has the greatest life expectancy?
#
# Could you do a new topic, with the same "style"?
#
# Absolutely. The writer is really similar to how I write casually, which is a huge relief.
#
# ## Data
#
# Where could you search for data about your topic?
#
# reddit and kaggle already have data on the topic.
# ---
#
# # Ideas for data storytelling - Idea 2
#
# ## You
#
# What do you care about?
#
# aesthetic philosophy
#
# What do you know about?
#
# aesthetic philosophy
#
# What decisions do you face?
#
# How much of beauty is culturally determined, how much is biological, and how much of the things that are culturally determined are still unique to an individual, and to what degree?
#
# ## Seven templates
#
# Training Kit (https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r) explains the seven templates from Priceonomics.
#
# Can you apply the templates to your topics?
#
# 1. Geographic Variation
#
# How are beauty standards different by culture or country?
#
# 2. Trend related to the news
#
# What are the most common cosmetic surgeries at the moment?
#
# 3. Who does that?
#
# How are surgeons assessed?
#
# 4. Answering a question people care about
#
# How can I get the best cosmetic surgery possible?
#
# 5. Valuable to businesses
#
# What factors cause surgery malpractice the most often?
#
# 6. What's the most popular?
#
# What does the perfect face look like to people from around the world?
#
# 7. Cost/Money rankings
#
# What surgeries cost the most? Who gets those surgeries, and what clinics make the most?
#
# ## Misconceptions
#
# What misconceptions do people have about your topic?
#
# Not all surgeons who do plastic surgery are board certified specifically to do so.
#
# ## Examples
#
# What data storytelling example inspires you?
#
#
# Could you do a new hypothesis, for the same question?
#
#
# Could you do a new question, for the same topic?
#
#
# Could you do a new topic, with the same "style"?
#
#
# ## Data
#
# https://www.rcophth.ac.uk/standards-publications-research/audit-and-data/clinical-data-sets/cosmetic-surgery-clinical-quality-and-outcomes-updates/
