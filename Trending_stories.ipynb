# %% [markdown]
# <a href="https://colab.research.google.com/github/raklives/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Trending_stories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT

# %%
 # libraries
import numpy as np 
import pandas as pd 
import json
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from datetime import datetime
import seaborn as sns

# %%
# csv files for United States, Canada, Great Britain
US = pd.read_csv('/content/USvideos.csv')
CA = pd.read_csv('/content/CAvideos.csv')
GB = pd.read_csv('/content/GBvideos.csv')

# %%
# check US data set
US.head(2)
# Out:
#       video_id  ...                                        description
# 0  2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  1ZAPwfrtAFY  ...  One year after the presidential election, John...
#
# [2 rows x 16 columns]

# %%
CA.head(1)
# Out:
#       video_id  ...                                        description
# 0  n1WpP7iowLc  ...  Eminem's new track Walk on Water ft. Beyoncé i...
#
# [1 rows x 16 columns]

# %%
# add column hold country name
CA['country'] = 'CA'
#check
CA.head()
# Out:
#       video_id  ... country
# 0  n1WpP7iowLc  ...      CA
# 1  0dBIkQ4Mz1M  ...      CA
# 2  5qpjK5DgCt4  ...      CA
# 3  d380meD0W0M  ...      CA
# 4  2Vv-BfVoq4g  ...      CA
#
# [5 rows x 17 columns]

# %%
# checkGB head
GB.head(2)
# Out:
#       video_id  ...                                        description
# 0  Jw1Y-zhQURU  ...  Click here to continue the story and make your...
# 1  3s1rvMFUweQ  ...  Musical guest Taylor Swift performs …Ready for...
#
# [2 rows x 16 columns]

# %%
GB['country'] = 'GB'
# check 
GB.head()
# Out:
#       video_id  ... country
# 0  Jw1Y-zhQURU  ...      GB
# 1  3s1rvMFUweQ  ...      GB
# 2  n1WpP7iowLc  ...      GB
# 3  PUTEiSjKwJU  ...      GB
# 4  rHwDegptbI4  ...      GB
#
# [5 rows x 17 columns]

# %%
# check the columns it has
print(US.columns)
print(US.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (40949, 17)

# %%
US['country'] = 'US'

# %%
# check columns for CA
print(CA.columns)
print(CA.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (23326, 17)

# %%
# check columns for GB
print(GB.columns)
print(GB.shape)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'country'],
#       dtype='object')
# (23371, 17)

# %% [markdown]
# ### US has more observations compare to GB and CA.
# > So we'll create a new dataframe from a sample of the original data frame

# %%
# sample of US data
US = US.sample(n=23371, replace=False, axis=0)
US.shape
print('we now have a sample of ')
# Out:
# (23371, 17)

# %% [markdown]
# ### The 3 countries share the same columns. This will make it easier to combine them.
# > now let's combine all three into a single data frames

# %%
# combine in single data fram
countries = pd.concat([CA, GB, US], axis=0)
print(countries.shape)
# Out:
# (70068, 17)

# %%
# check 
countries.head(40)
# Out:
#        video_id  ... country
# 0   n1WpP7iowLc  ...      CA
# 1   0dBIkQ4Mz1M  ...      CA
# 2   5qpjK5DgCt4  ...      CA
# 3   d380meD0W0M  ...      CA
# 4   2Vv-BfVoq4g  ...      CA
# 5   0yIWz1XEeyc  ...      CA
# 6   _uM5kFfkhB8  ...      CA
# 7   2kyS6SvSYSE  ...      CA
# 8   JzCsM1vtn78  ...      CA
# 9   43sm-QwLcx4  ...      CA
# 10  H1KBHFXm2Bg  ...      CA
# 11  U3xLOo-CNwo  ...      CA
# 12  FyZMnhUtLfE  ...      CA
# 13  7MxiQ4v0EnE  ...      CA
# 14  LUzsOyWp9lw  ...      CA
# 15  AS9-ITLhQxo  ...      CA
# 16  gifPYwArCVQ  ...      CA
# 17  8NHA23f7LvU  ...      CA
# 18  fy-CuCzaPp8  ...      CA
# 19  kzwfHumJyYc  ...      CA
# 20  nc99ccSXST0  ...      CA
# 21  puqaWrEC7tY  ...      CA
# 22  6H3wVsceoS0  ...      CA
# 23  PRlmRnU9qts  ...      CA
# 24  ZhhXLMbZ1rQ  ...      CA
# 25  wuf2KinLxZ8  ...      CA
# 26  aVTAU_4i9AY  ...      CA
# 27  7779JdxVAg0  ...      CA
# 28  jVpp2BUtMoY  ...      CA
# 29  j67FgNEvyh8  ...      CA
# 30  oQH_rtoHsdQ  ...      CA
# ...

# %%
# make sure all countries are represented
countries['country'].unique()
# Out:
# array(['CA', 'GB', 'US'], dtype=object)

# %%
# check for missing values
print(countries.isnull().sum())
print('description is missing alot of data')
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1434
# country                      0
# dtype: int64
# description is missing alot of data

# %%
# info on the dataset
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70068 entries, 0 to 36544
# Data columns (total 17 columns):
# video_id                  70068 non-null object
# trending_date             70068 non-null object
# title                     70068 non-null object
# channel_title             70068 non-null object
# category_id               70068 non-null int64
# publish_time              70068 non-null object
# tags                      70068 non-null object
# views                     70068 non-null int64
# likes                     70068 non-null int64
# dislikes                  70068 non-null int64
# comment_count             70068 non-null int64
# thumbnail_link            70068 non-null object
# comments_disabled         70068 non-null bool
# ratings_disabled          70068 non-null bool
# video_error_or_removed    70068 non-null bool
# description               68634 non-null object
# country                   70068 non-null object
# dtypes: bool(3), int64(5), object(9)
# ...

# %%
# replace null values in the description column
countries['description'] = countries['description'].fillna(value="")

# check
print(countries.info())
print('looks like we have no missing values')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70068 entries, 0 to 36544
# Data columns (total 17 columns):
# video_id                  70068 non-null object
# trending_date             70068 non-null object
# title                     70068 non-null object
# channel_title             70068 non-null object
# category_id               70068 non-null int64
# publish_time              70068 non-null object
# tags                      70068 non-null object
# views                     70068 non-null int64
# likes                     70068 non-null int64
# dislikes                  70068 non-null int64
# comment_count             70068 non-null int64
# thumbnail_link            70068 non-null object
# comments_disabled         70068 non-null bool
# ratings_disabled          70068 non-null bool
# video_error_or_removed    70068 non-null bool
# description               70068 non-null object
# country                   70068 non-null object
# dtypes: bool(3), int64(5), object(9)
# ...

# %% [markdown]
# ### The Category Column is currently just a bunch of numbers. We need to convert to numbers to their actual meaning

# %%
# list all the unique categories we have
countries['category_id'].unique()
# Out:
# array([10, 23, 24, 25, 22, 26,  1, 28, 20, 17, 29, 15, 19,  2, 27, 43])
