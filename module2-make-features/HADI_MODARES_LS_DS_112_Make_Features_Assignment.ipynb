# %% [markdown]
# <a href="https://colab.research.google.com/github/hadi-M/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/HADI_MODARES_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

# %%
# Part 1

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

display(df)
display(df.shape)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pd.set_option("display.max_columns", 120)
pd.set_option("display.max_rows", 100)

df.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave   NaN      Reg
# 1     2          20       RL         80.0     9600   Pave   NaN      Reg
# 2     3          60       RL         68.0    11250   Pave   NaN      IR1
# 3     4          70       RL         60.0     9550   Pave   NaN      IR1
# 4     5          60       RL         84.0    14260   Pave   NaN      IR1
# 5     6          50       RL         85.0    14115   Pave   NaN      IR1
# 6     7          20       RL         75.0    10084   Pave   NaN      Reg
# 7     8          60       RL          NaN    10382   Pave   NaN      IR1
# 8     9          50       RM         51.0     6120   Pave   NaN      Reg
# 9    10         190       RL         50.0     7420   Pave   NaN      Reg
# 10   11          20       RL         70.0    11200   Pave   NaN      Reg
# 11   12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df["LotFrontage"].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
df_small = df[["TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "SalePrice"]].copy()

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
df_small["TotalSF"] = df_small["TotalBsmtSF"] + df_small["1stFlrSF"] + df_small["2ndFlrSF"]

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
df_small["PricePerSqFt"] = df_small["SalePrice"] / df_small["TotalSF"] 

df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqFt
# 0          856       856       854     208500     2566     81.254871
# 1         1262      1262         0     181500     2524     71.909667
# 2          920       920       866     223500     2706     82.594235
# 3          756       961       756     140000     2473     56.611403
# 4         1145      1145      1053     250000     3343     74.783129

# %%
# Part 2

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# !ls
# Out:
# --2020-03-10 22:01:35--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [            <=>     ]  21.71M   412KB/s    in 54s
#
# 2020-03-10 22:02:30 (411 KB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22763850]
#
# LoanStats_2018Q4.csv	  LoanStats_2018Q4.csv.zip.1
# LoanStats_2018Q4.csv.zip  sample_data

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# !ls
# Out:
# LoanStats_2018Q4.csv	  LoanStats_2018Q4.csv.zip.1
# LoanStats_2018Q4.csv.zip  sample_data

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3387.58","3387.58","3032.81","3032.81","2212.42","820.39","0.0","0.0","0.0","Feb-2020","190.21","Mar-2020","Jan-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
df = pd.read_csv("LoanStats_2018Q4.csv")
display(df.shape)
display(df.head())
display(df.tail())
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128287, 1)
# ...

# %%
df = pd.read_csv("LoanStats_2018Q4.csv", skiprows=1, skipfooter=2)
display(df.shape)
display(df.head())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# (128284, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   60 months
# 1 NaN        NaN       6500         6500           6500.0   36 months
# 2 NaN        NaN       4500         4500           4500.0   36 months
# 3 NaN        NaN      25000        25000          25000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   16.14%       243.93     C        C4        Sale Consultant    2 years
# 1   11.80%       215.28     B        B4              Educator     2 years
# ...

# %%
pd.set_option("display.max_rows", 150)
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df = df.drop(["url", "member_id", "desc", "id"], axis=1)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   60 months   16.14%       243.93
# 1       6500         6500           6500.0   36 months   11.80%       215.28
# 2       4500         4500           4500.0   36 months   11.31%       147.99
# 3      25000        25000          25000.0   60 months   14.47%       587.82
# 4      30000        30000          30000.0   60 months   27.27%       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
display(df['int_rate'].head(10))
display(df['int_rate'][0])
# Out:
# 0     16.14%
# 1     11.80%
# 2     11.31%
# 3     14.47%
# 4     27.27%
# 5     16.14%
# 6     12.98%
# 7     10.33%
# 8     23.40%
# 9     10.72%
# Name: int_rate, dtype: object
# ' 16.14%'

# %%
df["int_rate"] = df["int_rate"].apply(lambda x: float(x.strip().strip("%")))
display(df.head())
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   60 months     16.14       243.93
# 1       6500         6500           6500.0   36 months     11.80       215.28
# 2       4500         4500           4500.0   36 months     11.31       147.99
# 3      25000        25000          25000.0   60 months     14.47       587.82
# 4      30000        30000          30000.0   60 months     27.27       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d         loan_status pymnt_plan  \
# ...

# %%
# Or this would work too:

# df["int_rate"] = df["int_rate"].str.strip().str.strip("%").astype("float")

# %%
df["emp_title"].value_counts(dropna=False).head(20)
# Out:
# NaN                   20922
# Teacher                2088
# Manager                1771
# Registered Nurse        950
# Driver                  924
# RN                      724
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          520
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
import numpy as np

examples = ["owner", "Supervisor", " Project Manager", np.NaN]

def clean_title(cell_contents):
  if isinstance(cell_contents, str):
    return cell_contents.strip().title()
  else:
    return "Unknown"

title_list = []

for title in examples:
  title_list.append(clean_title(title))

title_list
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
# df["emp_title"] = df["emp_title"].apply(clean_title)

# Or we could do:

df["emp_title"] = df["emp_title"].apply(
    lambda x: x.strip().title() if isinstance(x, str) else "Unknown"
)


df["emp_title"].value_counts(dropna=False).head(20)
# Out:
# Unknown               20922
# Teacher                2553
# Manager                2393
# Registered Nurse       1416
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      832
# Office Manager          804
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   623
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   424
# Technician              420
# Engineer                411
# Name: emp_title, dtype: int64

# %%
display(len(df["emp_title"].value_counts()))
display(df["emp_title"].isnull().sum())
# Out:
# 34877
# 0

# %%
# Part 3

# %%
[col for col in df if col.endswith("_d")]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df["issue_d"]
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
#             ...
# 128279    Oct-2018
# 128280    Oct-2018
# 128281    Oct-2018
# 128282    Oct-2018
# 128283    Oct-2018
# Name: issue_d, Length: 128284, dtype: object

# %%
df["issue_d"].value_counts()
# Out:
# Oct-2018    46257
# Nov-2018    41938
# Dec-2018    40089
# Name: issue_d, dtype: int64

# %%
df["issue_d"] = pd.to_datetime(df["issue_d"], infer_datetime_format=True)
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                      float64
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df["issue_d"][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df["issue_d"].iloc[:5].values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
display(df["issue_d"].dt.year)
display(df["issue_d"].dt.month)
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128279    2018
# 128280    2018
# 128281    2018
# 128282    2018
# 128283    2018
# Name: issue_d, Length: 128284, dtype: int64
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128279    10
# 128280    10
# 128281    10
# 128282    10
# 128283    10
# Name: issue_d, Length: 128284, dtype: int64

# %%
df["issue_year"] = df["issue_d"].dt.year
df["issue_month"] = df["issue_d"].dt.month

# %% [markdown]
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
# converting term to int
df["term"] = df["term"].apply(lambda x: int(x.split(" ")[1]))

# %%
# creating 'loan_status_is_great' column
df["loan_status_is_great"] = df["loan_status"].apply(lambda status: 1 if (status=="Current" or status=="Fully Paid") else 0)

# %%
last_pymnt_datetime = pd.to_datetime(df["last_pymnt_d"], infer_datetime_format=True)
# last_pymnt_datetime[last_pymnt_datetime.isnull()]
df["last_pymnt_d_month"] = last_pymnt_datetime.dt.month
df["last_pymnt_d_year"] = last_pymnt_datetime.dt.year
# Out:
# 0          5.0
# 1          2.0
# 2          2.0
# 3         10.0
# 4          2.0
#           ...
# 128279    12.0
# 128280     2.0
# 128281     2.0
# 128282     2.0
# 128283     2.0
# Name: last_pymnt_d_month, Length: 128284, dtype: float64

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!

# %%
# removing '%' sign
df["revol_util"] = df["revol_util"].str.strip("%").astype("float")
df["revol_util"].head()
# Out:
# 0    58.5
# 1    41.6
# 2    15.3
# 3    45.7
# 4    10.7
# Name: revol_util, dtype: float64

# %%
# display(df["emp_title"])
top_20_titles = df["emp_title"].value_counts()[0:21]
# the reason I chose the top 21 titles is that,
# the 'Unknown' title (the title with highest value_count),
# is basically just np.NaN and is not a title

df["emp_title"] = df["emp_title"].apply(
    lambda title: title if title in top_20_titles else "Other"
)
df["emp_title"].value_counts()
# top_20_titles
# print(1)
# Out:
# Other                       89445
# Unknown                     20922
# Teacher                      2553
# Manager                      2393
# Registered Nurse             1416
# Driver                       1258
# Supervisor                   1160
# Truck Driver                  920
# Rn                            832
# Office Manager                804
# Sales                         803
# General Manager               791
# Project Manager               720
# Owner                         623
# Director                      523
# Operations Manager            518
# Sales Manager                 500
# Police Officer                440
# Nurse                         424
# Technician                    420
# Engineer                      411
# Administrative Assistant      408
# Name: emp_title, dtype: int64

# %% [markdown]
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-03-10 22:12:09--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.134.213
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.134.213|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  16.9MB/s    in 13s
#
# 2020-03-10 22:12:23 (15.0 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01
