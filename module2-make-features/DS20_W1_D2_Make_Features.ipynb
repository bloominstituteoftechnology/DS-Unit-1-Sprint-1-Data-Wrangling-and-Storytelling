# %% [markdown]
# <a href="https://colab.research.google.com/github/spasatel13/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/DS20_W1_D2_Make_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 1, Sprint 1, Module 2*
#
# ---

# %% [markdown]
# # Learning Objectives
#
# - Objective 01 - understand the purpose of feature engineering
# - Objective 02 - demonstrate how to work with strings in pandas
# - Objective 03 - modify or create dataframe columns using the `apply()` function
# - Objective 04 - work with dates and times in pandas
#
#
# Helpful Links:
# - [Minimally Sufficient Pandas](https://medium.com/dunder-data/minimally-sufficient-pandas-a8e67f2a2428)
# - [Feature Engineering](https://en.wikipedia.org/wiki/Feature_engineering)
# - Python Data Science Handbook
#   - [Chapter 3.10](https://jakevdp.github.io/PythonDataScienceHandbook/03.10-working-with-strings.html), Vectorized String Operations
#   - [Chapter 3.11](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html), Working with Time Series
# - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)

# %%
#df.column_header

#this one always works
#df['column_header']

# %% [markdown]
# # [Objective 01](#feature-engineering) - The Purpose of Feature Engineering

# %% [markdown]
# ## Overview
#
# Feature Engineering is the process of using a combination of domain knowledge, creativity, and the pre-existing columns of a dataset to create completely new columns.
#
#  Machine Learning models try to detect patterns in the data and then associate those patterns with certain predictions. The hope is that by creating new columns on our dataset that we can expose our model to new patterns in the data so that it can make better and better predictions.
#
# This is largely a matter of understanding how to work with individual columns of a dataframe with Pandas --which is what we'll be practicing today!

# %% [markdown]
# ## Follow Along
#
# Columns of a dataframe each hold a specific type of data. Lets inspect some of the common datatypes found in datasets and then we'll make a new feature on a dataset using pre-existing columns.

# %%
import pandas as pd

#Pandas Display Options:
pd.set_option('display.max_rows',150)
pd.set_option('display.max_columns',180)

# %%
# Lets take a look at the Ames Iowa Housing Dataset:
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

# %% [markdown]
# ### Specific Columns hold specific kinds of data

# %%
print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
df.dtypes

# %% [markdown]
# Some columns hold integer values like the `BedroomAbvGr` which stands for "Bedrooms Above Grade." This is the number of non-basement bedrooms in the home.
#
# For more information on specific column meanings view the [data dictionary](https://github.com/ryanleeallred/datasets/blob/master/Ames%20Housing%20Data/data_description.txt).

# %%
# Look at a few rows of the `BedroomAbvGr` column.
# Looks like integers to me!
df.BedroomAbvGr.head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# 5    1
# 6    3
# 7    3
# 8    2
# 9    2
# Name: BedroomAbvGr, dtype: int64

# %% [markdown]
# What type of variable is BedroomAbvGr?  Is it categorical or quantitative?  If you answered "categorical", is it ordinal, nominal or an identifier?  If you answered "quantitative", is it continuous or discrete?

# %% [markdown]
# It is quantitative and discrete.

# %% [markdown]
# Some columns hold float values like the `LotFrontage` column.

# %%
# Look at a few rows of the `LotFrontage` column.
df.LotFrontage.head(10)
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# 5    85.0
# 6    75.0
# 7     NaN
# 8    51.0
# 9    50.0
# Name: LotFrontage, dtype: float64

# %% [markdown]
# Hmmm, do the values above look like floats to you?
#
# They all have .0 on them so technically they're being stored as floats, but *should* they be stored as floats?
#
# Lets see what all of the possible values for this column are.

# %%
df.LotFrontage.value_counts()

#for bfiefness
df.LotFrontage.value_counts().head(10)
# Out:
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# 75.0     53
# 65.0     44
# 85.0     40
# 78.0     25
# 21.0     23
# 90.0     23
# Name: LotFrontage, dtype: int64

# %%
print(type(df.LotFrontage.value_counts()))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Looks to me like the `LotFrontage` column originally held integer values but was cast to a `float` meaning that each original integer values was converted to its corresponding float representation.
#
# Any guesses as to why that would have happened?
#
#
# HINT: What's the most common `LotFrontage` value for this column?

# %%
# NaN is the most common value in this column. What is a NaN
df.LotFrontage.value_counts(dropna=False)

#for briefness
df.LotFrontage.value_counts(dropna=False).head(10)

# %% [markdown]
# `NaN` stands stands for "Not a Number" and is the default missing value indicator with Pandas. This means there were cells in this column that didn't have a LotFrontage value recorded for those homes.
#
# This is where domain knowledge starts to come in. Think about the context we're working with here: houses. What might a null or blank cell representing "Linear feet of street connected to property" mean in the context of a housing dataset?
#
# Ok, so maybe it makes sense to have some NaNs in this column. What is the datatype of a NaN value?
#
# Perhaps some of this data is truly missing or unrecorded data, but sometimes `NaNs` are more likely to indicate something that was "NA" or "Not Applicable" to a particular observation. There could be multiple reasons why there was no value recorded for a particular feature.
#
# Remember - Pandas tries to maintain a single datatype for all values in a column, and therefore...

# %%
import numpy as np

# What is the datatype of NaN?
print(type(np.nan))
# Out:
# <class 'float'>

# %% [markdown]
# The datatype of a NaN is float!  This means that if we have a column of integer values, but the column has even a single `NaN` that column will not be treated with the integer datatype but all of the integers will be converted to floats in order to try and preserve the same datatype throughout the entire column.
#
# You can see already how understanding column datatypes is crucial to understanding how Pandas help us manage our data.

# %% [markdown]
# Making new Features
#
# Lets slim down the dataset and consider just a few specific columns:
#
# - `TotalBsmtSF`
# - `1stFlrSF`
# - `2ndFlrSF`
# - `SalePrice1`

# %%
# I can make a smaller dataframe with a few specific column headers
# by passing a list of column headers inside of the square brackets

small_df=df[['TotalBsmtSF','1stFlrSF','2ndFlrSF','SalePrice']]
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
small_df.dtypes

# %% [markdown]
# ### Syntax for creating new columns
#
# When making a new column on a dataframe, we have to use the square bracket syntax of accessing a column. We can't use "dot syntax" here.

# %%
# Lets add up all of the square footage to get a single square footage 
# column for the entire dataset

# Using bracket syntax to make a new 'TotalSquareFootage' column

small_df['TotalSF']=small_df.TotalBsmtSF+small_df['1stFlrSF']+small_df['2ndFlrSF']
small_df.head()

# %%
# Lets make  another new column that is 'PricePerSqFt' by
# dividing the price by the square footage

small_df['TotalBsmtSF'][0]=2
small_df.head()
#df.head()
#the warning is useless since only the small_df is being edited, even though it's being passed by reference
#but to avoid the warning just use .copy() at the end.

# %%
small_df=df[['TotalBsmtSF','1stFlrSF','2ndFlrSF','SalePrice']].copy()
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
small_df['TotalSF']=small_df.TotalBsmtSF+small_df['1stFlrSF']+small_df['2ndFlrSF']
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
#Reasigning row index
small_df.index=small_df['TotalSF']
small_df.head()
# Out:
#          TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# TotalSF
# 2566             856       856       854     208500     2566
# 2524            1262      1262         0     181500     2524
# 2706             920       920       866     223500     2706
# 2473             756       961       756     140000     2473
# 3343            1145      1145      1053     250000     3343

# %% [markdown]
# ###We can also use if-then statements to create new variables.
#
# Say we want to categorize houses as having a high price per square foot (greater than or equal to 80 dollars per square foot) or a low price per square foot (less than 80 dollars per square foot).

# %%
small_df['PricePerSF']=small_df['SalePrice']/small_df['TotalSF']
small_df.head()
# Out:
#          TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSF
# TotalSF
# 2566             856       856       854     208500     2566   81.254871
# 2524            1262      1262         0     181500     2524   71.909667
# 2706             920       920       866     223500     2706   82.594235
# 2473             756       961       756     140000     2473   56.611403
# 3343            1145      1145      1053     250000     3343   74.783129

# %%
small_df=small_df.round(2)
small_df.head()

# %%
#pd.crosstab(small_df['High_ppsqft'],columns='count')

# %% [markdown]
# Now we have added several new columns on our small dataset.
#
# - What does a **high** `PricePerSqFt` say about a home that the square footage and price alone don't capture as directly?
#
# - What does a **low** `PricePerSqFt` say about a home that the square footage and price alone don't directly capture?

# %% [markdown]
# ### Let's include "and" and "or" conditions in the if-then statements.
#
# Let's identify the 2-story duplex houses.

# %% [markdown]
# ## Challenge
#
# I hope you can see how we have used existing columns to create a new column on a dataset that say something new about our unit of observation. This is what making new features (columns) on a dataset is all about and why it's so essential to data science --particularly predictive modeling "Machine Learning."
#
# We'll spend the rest of the lecture and assignment today trying to get as good as we can at manipulating (cleaning) and creating new columns on datasets.

# %% [markdown]
# # [Objective 02](#work-with-strings) - Work with Strings with Pandas

# %% [markdown]
# ## Overview
#
# So far we have worked with numeric datatypes (ints and floats) but we haven't worked with any columns containing string values. We can't simply use arithmetic to manipulate string values, so we'll need to learn some more techniques in order to work with this datatype.

# %% [markdown]
# ## Follow Along
#
# We're going to import a new dataset here to work with. This dataset is from LendingClub and holds information about loans issued in Q4 of 2018. This dataset is a bit messy so it will give us plenty of opportunities to clean up existing columns as well as create new ones.
#
# The `!wget` shell command being used here does exactly the same thing that your browser does when you type a URL in the address. It makes a request or "gets" the file at that address. However, in our case the file isn't a webpage, it's a compressed CSV file.
#
# Try copying and pasting the URL from below into your browser, did it start an automatic download? Any URLs like this that start automatic downloads when navigated to can be used along with the `!wget` command to bring files directly into your notebook's memory.

# %% [markdown]
# ### Load a new dataset

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-10-01 19:03:56--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 44.235.65.250, 44.224.91.33, 54.213.174.123
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|44.235.65.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.4’
#
# LoanStats_2018Q4.cs     [                 <=>]  22.30M  2.15MB/s    in 11s
#
# 2020-10-01 19:04:07 (2.11 MB/s) - ‘LoanStats_2018Q4.csv.zip.4’ saved [23387713]

# %% [markdown]
# We need to use the `!unzip` command to extract the csv from the zipped folder.

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %% [markdown]
# We can also use bash/shell commands to look at the raw file using the `!head` and `!tail` commands

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# "id","member_id","loan_amnt","funded_amnt","funded_amnt_inv","term","int_rate","installment","grade","sub_grade","emp_title","emp_length","home_ownership","annual_inc","verification_status","issue_d","loan_status","pymnt_plan","url","desc","purpose","title","zip_code","addr_state","dti","delinq_2yrs","earliest_cr_line","inq_last_6mths","mths_since_last_delinq","mths_since_last_record","open_acc","pub_rec","revol_bal","revol_util","total_acc","initial_list_status","out_prncp","out_prncp_inv","total_pymnt","total_pymnt_inv","total_rec_prncp","total_rec_int","total_rec_late_fee","recoveries","collection_recovery_fee","last_pymnt_d","last_pymnt_amnt","next_pymnt_d","last_credit_pull_d","collections_12_mths_ex_med","mths_since_last_major_derog","policy_code","application_type","annual_inc_joint","dti_joint","verification_status_joint","acc_now_delinq","tot_coll_amt","tot_cur_bal","open_acc_6m","open_act_il","open_il_12m","open_il_24m","mths_since_rcnt_il","total_bal_il","il_util","open_rv_12m","open_rv_24m","max_bal_bc","all_util","total_rev_hi_lim","inq_fi","total_cu_tl","inq_last_12m","acc_open_past_24mths","avg_cur_bal","bc_open_to_buy","bc_util","chargeoff_within_12_mths","delinq_amnt","mo_sin_old_il_acct","mo_sin_old_rev_tl_op","mo_sin_rcnt_rev_tl_op","mo_sin_rcnt_tl","mort_acc","mths_since_recent_bc","mths_since_recent_bc_dlq","mths_since_recent_inq","mths_since_recent_revol_delinq","num_accts_ever
","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","5000","5000","5000"," 36 months"," 13.56%","169.83","C","C1","Payoff Clerk","10+ years","MORTGAGE","35360","Not Verified","Oct-2018","Current","n","","","debt_consolidation","Debt consolidation","381xx","TN","11.3","1","Jun-2006","0","21","","9","0","2597","27.3%","15","f","2042.26","2042.26","3902.32","3902.32","2957.74","944.58","0.0","0.0","0.0","Sep-2020","169.83","Oct-2020","Sep-2020","0","","1","Individual","","","","0","1413","69785","0","2","0","1","16","2379","40","3","4","1826","32","9500","0","0","1","5","8723","1174","60.9","0","0","147","85","9","9","2","10","21","9","21","0","1","3","2","2","6","6","7","3","9","0","0","0","3","92.9","50","0","0","93908","4976","3000","6028","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","10000","10000","9750"," 36 months"," 11.06%","327.68","B","B3","","n/a","RENT","44400","Source Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","980xx","WA","11.78","0","Oct-2008","2","40","","15","0","6269","13.1%","25","f","3996.89","3896.97","7521.28","7333.25","6003.11","1518.17","0.0","0.0","0.0","Sep-2020","327.68","Oct-2020","Sep-2020","0","53","1","Individual","","","","0","520","16440","3","1","1","1","2","10171","100","2","5","404","28","47700","0","3","5","6","1265","20037","2.3","0","0","61","119","1","1","0","1","","1","40","1","2","4","6","8","3","14","22","4","15","0","0","0","3","92","0","0","0","57871","16440","20500","10171","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","10000","10000","10000"," 36 months"," 16.91%","356.08","C","C5","Key Accounts Manager","2 years","RENT","80000","Not Verified","Oct-2018","Current","n","","","other","Other","021xx","MA","17.72","1","Sep-2006","0","14","","17","0","1942","30.8%","31","w","4202.86","4202.86","8180.45","8180.45","5797.14","2383.31","0.0","0.0","0.0","Sep-2020","356.08","Oct-2020","Sep-2020","0","25","1","Individual","","","","0","0","59194","0","15","1","1","12","57252","85","0","0","1942","80","6300","0","5","0","1","3482","2058","48.5","0","0","144","142","40","12","0","131","30","","30","3","1","1","1","5","22","2","9","1","17","0","0","0","1","74.2","0","0","0","73669","59194","4000","67369","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
#
#
# Total amount funded in policy code 1: 2050322100
# Total amount funded in policy code 2: 819980372

# %% [markdown]
# As we look at the raw file itself, do you see anything that might cause us trouble as we read in the CSV file to a dataframe?

# %%
# Read in the CSV
# Beacuse if additional info in the beggining and end of file this way produces weird looking df. Need to specify header
import pandas as pd

df = pd.read_csv('LoanStats_2018Q4.csv' )

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128381, 1)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# id  member_id loan_amnt funded_amnt funded_amnt_inv term       int_rate installment grade sub_grade emp_title     emp_length home_ownership annual_inc verification_status issue_d  loan_status       pymnt_plan url desc purpose            title                   zip_code addr_state dti   delinq_2yrs earliest_cr_line inq_last_6mths mths_since_last_delinq mths_since_last_record open_acc pub_rec revol_bal revol_util total_acc initial_list_status out_prncp out_prncp_inv total_pymnt total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt next_pymnt_d last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog policy_code application_type annual_inc_joint dti_joint verification_status_joint acc_now_delinq tot_coll_amt tot_cur_bal open_acc_6m open_act_il open_il_12m open_il_24m mths_since_rcnt_il total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m acc_open_past_24mths avg_cur_bal bc_open_to_buy bc_util chargeoff_within_12_mths delinq_amnt mo_sin_old_il_acct mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op mo_sin_rcnt_tl mort_acc mths_since_recent_bc mths_since_recent_bc_dlq mths_since_recent_inq mths_since_recent_revol_delinq num_accts_ever_120_pd num_actv_bc_tl num_actv_rev_tl num_bc_sats num_bc_tl num_il_tl num_op_rev_tl num_rev_accts num_rev_tl_bal_gt_0 num_sats num_tl_120dpd_2m num_tl_30dpd num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit total_il_high_credit_limit revol_bal_joint sec_app_earliest_cr_line sec_app_inq_last_6mths sec_app_mort_acc sec_app_open_acc sec_app_revol_util sec_app_open_act_il sec_app_num_rev_accts sec_app_chargeoff_within_12_mths sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog hardship_flag hardship_type hardship_reason hardship_status deferral_term hardship_amount hardship_start_date hardship_end_date payment_plan_start_date hardship_length hardship_dpd hardship_loan_status orig_projected_additional_accrued_interest hardship_payoff_balance_amount hardship_last_payment_amount debt_settlement_flag debt_settlement_flag_date settlement_status settlement_date settlement_amount settlement_percentage                                    settlement_term
# NaN NaN       5000      5000        5000             36 months  11.31%  164.43      B     B3        Shipping      2 years    RENT           40000      Source Verified     Dec-2018 Current           n          NaN NaN  debt_consolidation Debt consolidation      284xx    NC         9.66  0           Oct-2007         0              NaN                    NaN                    8        0       1070      17.5%      27        w                   2770.45   2770.45       2956.61     2956.61         2229.55         727.06        0.0                0.0        0.0                     Sep-2020     164.43          Oct-2020     Sep-2020           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              550          144979      1           2           0           1           13                 143909       78      1           3           170        44       6100             1      0           1            4                    18122       3283           8.8     0                        0           134                86                   6                     6              0        6                    NaN                      9                     NaN                            0                     2              5               3           3         19        6             8             5                   8        0                0            0                  1                  100            0                0                    0         125853          144979            3600           119753                     NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             CVD19SKIP     INCOMECURT      COMPLETE        2             0               Apr-2020            Jun-2020          May-2020                2               0            ACTIVE               58.8                                       3121.41                        164.43                       N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               10000     10000       10000            36 months  18.94%  366.26      D     D2        Especialist 1 7 years    MORTGAGE       37115      Not Verified        Dec-2018 Current           n          NaN NaN  other              Other                   891xx    NV         33.57 0           Jan-2002         0              38                     NaN                    9        0       5837      53.1%      15        w                   5147.99   5147.99       7309.42     7309.42         4852.01         2457.41       0.0                0.0        0.0                     Sep-2020     366.26          Oct-2020     Sep-2020           0                          38                          1           
aN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                                                NaN
# Total amount funded in policy code 2: 819980372  NaN NaN   NaN   NaN   NaN        NaN     NaN    NaN NaN NaN                  NaN       NaN      NaN     NaN             NaN      NaN     NaN NaN NaN NaN                NaN                     NaN   NaN NaN   NaN NaN      NaN NaN  NaN NaN NaN NaN  NaN   NaN NaN NaN     NaN     NaN     NaN     NaN     NaN     NaN NaN NaN NaN      NaN    NaN      NaN      NaN NaN  NaN NaN        NaN NaN NaN NaN NaN  NaN   NaN NaN NaN NaN NaN  NaN     NaN   NaN NaN NaN  NaN  NaN   NaN NaN NaN NaN NaN    NaN     NaN  NaN NaN NaN   NaN NaN NaN NaN NaN   NaN  NaN NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  NaN NaN NaN     NaN   NaN   NaN     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                                                NaN

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1 )

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128380, 144)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 1  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 2  NaN        NaN    20000.0      20000.0          20000.0   36 months
# 3  NaN        NaN     6500.0       6500.0           6500.0   36 months
# 4  NaN        NaN    25000.0      25000.0          25000.0   60 months
#
#   int_rate  installment grade sub_grade      emp_title emp_length  \
# 0   11.31%       164.43     B        B3       Shipping    2 years
# 1   18.94%       366.26     D        D2  Especialist 1    7 years
# 2    7.56%       622.68     A        A3        Teacher  10+ years
# 3   11.80%       215.28     B        B4      Educator     2 years
# 4   12.98%       568.58     B        B5   Tire builder  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d        loan_status  \
# 0           RENT     40000.0     Source Verified  Dec-2018            Current
# 1       MORTGAGE     37115.0        Not Verified  Dec-2018            Current
# 2       MORTGAGE    100000.0        Not Verified  Dec-2018         Fully Paid
# 3           RENT     46500.0     Source Verified  Dec-2018  Late (16-30 days)
# 4       MORTGAGE     85000.0        Not Verified  Dec-2018         Fully Paid
#
#   pymnt_plan  url  desc             purpose                    title zip_code  \
# 0          n  NaN   NaN  debt_consolidation       Debt consolidation    284xx
# 1          n  NaN   NaN               other                    Other    891xx
# 2          n  NaN   NaN         credit_card  Credit card refinancing    982xx
# 3          n  NaN   NaN  debt_consolidation       Debt consolidation    352xx
# 4          n  NaN   NaN  debt_consolidation       Debt consolidation    356xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NC   9.66          0.0         Oct-2007             0.0
# 1         NV  33.57          0.0         Jan-2002             0.0
# 2         WA  18.92          0.0         Feb-1999             0.0
# 3         AL  21.01          0.0         Aug-2011             1.0
# 4         AL  36.67          1.0         Oct-1993             1.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                     NaN       8.0      0.0
# 1                    38.0                     NaN       9.0      0.0
# 2                    48.0                     NaN       9.0      0.0
# 3                    61.0                     NaN      24.0      0.0
# 4                    10.0                     NaN      14.0      0.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1070.0      17.5%       27.0                   w    2770.45
# 1     5837.0      53.1%       15.0                   w    5147.99
# 2    25416.0      29.9%       19.0                   w       0.00
# 3     6741.0      41.6%       30.0                   w    3354.53
# 4    26630.0      53.3%       27.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 
_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                    0.0             2.0              5.0          3.0
# 1                    1.0             2.0              5.0          3.0
# 2                    0.0             5.0              5.0          5.0
# 3                    2.0             6.0             10.0          6.0
# 4                    1.0             4.0              5.0          4.0
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0        3.0       19.0            6.0            8.0                  5.0
# 1        6.0        4.0            6.0           10.0                  5.0
# 2        6.0        5.0            5.0            9.0                  5.0
# 3        6.0       14.0           11.0           16.0                 10.0
# 4        5.0       13.0            6.0           10.0                  5.0
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0       8.0               0.0           0.0                 0.0
# 1       9.0               0.0           0.0                 0.0
# 2       9.0               0.0           0.0                 0.0
# 3      24.0               0.0           0.0                 0.0
# 4      14.0               0.0           0.0                 0.0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                 1.0           100.0               0.0                   0.0
# 1                 4.0            93.3              33.3                   0.0
# 2                 1.0            94.7              20.0                   0.0
# 3                 9.0            93.3               0.0                   0.0
# 4                 2.0            85.2               0.0                   0.0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0        0.0         125853.0           144979.0          3600.0
# 1        0.0         253346.0            40345.0          5600.0
# 2        0.0         622183.0            71569.0         85100.0
# 3        0.0          50845.0            40223.0         13300.0
# 4        0.0         275691.0            96143.0         43900.0
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                    119753.0              NaN                      NaN
# 1                     41060.0          19051.0                 Jan-2016
# 2                     74833.0          43287.0                 Aug-1998
# 3                     34645.0              NaN                      NaN
# 4                     99691.0          48711.0                 Oct-1993
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     1.0               1.0               9.0
# 2                     0.0               3.0              10.0
# 3                     NaN               NaN               NaN
# 4                     1.0               4.0              16.0
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                76.4                  2.0                    7.0
# 2                29.7                  2.0                    7.0
# 3                 NaN                  NaN                    NaN
# 4                56.5                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.tail()
# Out:
#                                                       id  member_id  \
# 128375                                               NaN        NaN
# 128376                                               NaN        NaN
# 128377                                               NaN        NaN
# 128378  Total amount funded in policy code 1: 2050322100        NaN
# 128379   Total amount funded in policy code 2: 819980372        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128375     5000.0       5000.0           5000.0   36 months   13.56%
# 128376    10000.0      10000.0           9750.0   36 months   11.06%
# 128377    10000.0      10000.0          10000.0   36 months   16.91%
# 128378        NaN          NaN              NaN         NaN      NaN
# 128379        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade             emp_title emp_length  \
# 128375       169.83     C        C1          Payoff Clerk  10+ years
# 128376       327.68     B        B3                   NaN        NaN
# 128377       356.08     C        C5  Key Accounts Manager    2 years
# 128378          NaN   NaN       NaN                   NaN        NaN
# 128379          NaN   NaN       NaN                   NaN        NaN
#
#        home_ownership  annual_inc verification_status   issue_d loan_status  \
# 128375       MORTGAGE     35360.0        Not Verified  Oct-2018     Current
# 128376           RENT     44400.0     Source Verified  Oct-2018     Current
# 128377           RENT     80000.0        Not Verified  Oct-2018     Current
# 128378            NaN         NaN                 NaN       NaN         NaN
# 128379            NaN         NaN                 NaN       NaN         NaN
#
#        pymnt_plan  url  desc             purpose                    title  \
# 128375          n  NaN   NaN  debt_consolidation       Debt consolidation
# 128376          n  NaN   NaN         credit_card  Credit card refinancing
# 128377          n  NaN   NaN               other                    Other
# 128378        NaN  NaN   NaN                 NaN                      NaN
# 128379        NaN  NaN   NaN                 NaN                      NaN
#
#        zip_code addr_state    dti  delinq_2yrs earliest_cr_line  \
# 128375    381xx         TN  11.30          1.0         Jun-2006
# 128376    980xx         WA  11.78          0.0         Oct-2008
# 128377    021xx         MA  17.72          1.0         Sep-2006
# 128378      NaN        NaN    NaN          NaN              NaN
# 128379      NaN        NaN    NaN          NaN              NaN
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 128375             0.0                    21.0                     NaN
# 128376             2.0                    40.0                     NaN
# 128377             0.0                    14.0                     NaN
# 128378             NaN                     NaN                     NaN
# 128379             NaN                     NaN                     NaN
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 128375       9.0      0.0     2597.0      27.3%       15.0
# 128376      15.0      0.0     6269.0      13.1%       25.0
# 128377      17.0      0.0     1942.0      30.8%       31.0
# 128378       NaN      NaN        NaN        NaN        NaN
# 128379       NaN      NaN        NaN        NaN        NaN
#
#        initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 128375                   f    2042.26        2042.26      3902.32
# 128376                   f    3996.89        3896.97      7521.28
# 128377                   w    4202.86        4202.86      8180.45
# 128378                 NaN        NaN            NaN          NaN
# 128379                 NaN        NaN            NaN          NaN
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 128375          3902.32          2957.74         944.58                 0.0
# 128376          7333.25          6003.11        1518.17                 0.0
# 128377          8180.45          5797.14        2383.31                 0.0
# 128378              NaN              NaN            NaN                 NaN
# 128379              NaN              NaN            NaN                 NaN
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 128375         0.0                      0.0     Sep-2020           169.83
# 128376         0.0                      0.0     Sep-2020           327.68
# 128377         0.0                      0.0     Sep-2020           356.08
# 128378         NaN                      NaN          NaN              NaN
# 128379         NaN                      NaN          NaN              NaN
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 128375     Oct-2020           Sep-2020                         0.0
# 128376     Oct-2020           Sep-2020                         0.0
# 128377     Oct-2020           Sep-2020                         0.0
# 128378          NaN                NaN                         NaN
# 128379          NaN                NaN                         NaN
#
#         mths_since_last_major_derog  policy_code application_type  \
# 128375                          NaN          1.0       Individual
# 128376                         53.0          1.0       Individual
# 128377                         25.0          1.0       Individual
# 128378                          NaN          NaN              NaN
# 128379                          NaN          NaN              NaN
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 128375               NaN        NaN                       NaN             0.0
# 128376               NaN        NaN                       NaN             0.0
# 128377               NaN        NaN                       NaN             0.0
# 128378               NaN        NaN                       NaN             NaN
# 128379               NaN        NaN                       NaN             NaN
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 128375        1413.0      69785.0          0.0          2.0          0.0
# 128376         520.0      16440.0          3.0          1.0          1.0
# 128377           0.0      59194.0          0.0         15.0          1.0
# 128378           NaN          NaN          NaN          NaN          NaN
# 128379           NaN          NaN          NaN          NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 128375          1.0                16.0        2379.0     40.0          3.0
# 128376          1.0                 2.0       10171.0    100.0          2.0
# 128377          1.0                12.0       57252.0     85.0          0.0
# 128378          NaN                 NaN           NaN      NaN          NaN
# 128379          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 128375          4.0      1826.0      32.0            9500.0     0.0
# 128376          5.0       404.0      28.0           47700.0     0.0
# 128377          0.0      1942.0      80.0            6300.0     0.0
# 128378          NaN         NaN       NaN               NaN     NaN
# 128379          NaN         NaN       NaN               NaN     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 128375          0.0           1.0                   5.0       8723.0
# 128376          3.0           5.0                   6.0       1265.0
# 128377          5.0           0.0                   1.0       3482.0
# 128378          NaN           NaN                   NaN          NaN
# 128379          NaN           NaN                   NaN          NaN
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 128375          1174.0     60.9                       0.0          0.0
# 128376         20037.0      2.3                       0.0          0.0
# 128377          2058.0     48.5                       0.0          0.0
# 128378             NaN      NaN                       NaN          NaN
# 128379             NaN      NaN                       NaN          NaN
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 128375               147.0                  85.0                    9.0
# 128376                61.0                 119.0                    1.0
# 128377               144.0                 142.0                   40.0
# 128378                 NaN                   NaN                    NaN
# 128379                 NaN                   NaN                    NaN
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 128375             9.0       2.0                  10.0
# 128376             1.0       0.0                   1.0
# 128377            12.0       0.0                 131.0
# 128378             NaN       NaN                   NaN
# 128379             NaN       NaN                   NaN
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 128375                      21.0                    9.0
# 128376                       NaN                    1.0
# 128377                      30.0                    NaN
# 128378                       NaN                    NaN
# 128379                       NaN                    NaN
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 128375                            21.0                    0.0             1.0
# 128376                            40.0                    1.0             2.0
# 128377                            30.0                    3.0             1.0
# 128378                             NaN                    NaN             NaN
# 128379                             NaN                    NaN             NaN
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 128375              3.0          2.0        2.0        6.0            6.0
# 128376              4.0          6.0        8.0        3.0           14.0
# 128377              1.0          1.0        5.0       22.0            2.0
# 128378              NaN          NaN        NaN        NaN            NaN
# 128379              NaN          NaN        NaN        NaN            NaN
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 128375            7.0                  3.0       9.0               0.0
# 128376           22.0                  4.0      15.0               0.0
# 128377            9.0                  1.0      17.0               0.0
# 128378            NaN                  NaN       NaN               NaN
# 128379            NaN                  NaN       NaN               NaN
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 128375           0.0                 0.0                 3.0            92.9
# 128376           0.0                 0.0                 3.0            92.0
# 128377           0.0                 0.0                 1.0            74.2
# 128378           NaN                 NaN                 NaN             NaN
# 128379           NaN                 NaN                 NaN             NaN
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 128375              50.0                   0.0        0.0          93908.0
# 128376               0.0                   0.0        0.0          57871.0
# 128377               0.0                   0.0        0.0          73669.0
# 128378               NaN                   NaN        NaN              NaN
# 128379               NaN                   NaN        NaN              NaN
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 128375             4976.0          3000.0                      6028.0
# 128376            16440.0         20500.0                     10171.0
# 128377            59194.0          4000.0                     67369.0
# 128378                NaN             NaN                         NaN
# 128379                NaN             NaN                         NaN
#
#         revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 128375              NaN                      NaN                     NaN
# 128376              NaN                      NaN                     NaN
# 128377              NaN                      NaN                     NaN
# 128378              NaN                      NaN                     NaN
# 128379              NaN                      NaN                     NaN
#
#         sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 128375               NaN               NaN                 NaN
# 128376               NaN               NaN                 NaN
# 128377               NaN               NaN                 NaN
# 128378               NaN               NaN                 NaN
# 128379               NaN               NaN                 NaN
#
#         sec_app_open_act_il  sec_app_num_rev_accts  \
# 128375                  NaN                    NaN
# 128376                  NaN                    NaN
# 128377                  NaN                    NaN
# 128378                  NaN                    NaN
# 128379                  NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 128375                               NaN                                 NaN
# 128376                               NaN                                 NaN
# 128377                               NaN                                 NaN
# 128378                               NaN                                 NaN
# 128379                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 128375                                  NaN             N           NaN
# 128376                                  NaN             N           NaN
# 128377                                  NaN             N           NaN
# 128378                                  NaN           NaN           NaN
# 128379                                  NaN           NaN           NaN
#
#        hardship_reason hardship_status  deferral_term  hardship_amount  \
# 128375             NaN             NaN            NaN              NaN
# 128376             NaN             NaN            NaN              NaN
# 128377             NaN             NaN            NaN              NaN
# 128378             NaN             NaN            NaN              NaN
# 128379             NaN             NaN            NaN              NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 128375                 NaN               NaN                     NaN
# 128376                 NaN               NaN                     NaN
# 128377                 NaN               NaN                     NaN
# 128378                 NaN               NaN                     NaN
# 128379                 NaN               NaN                     NaN
#
#         hardship_length  hardship_dpd hardship_loan_status  \
# 128375              NaN           NaN                  NaN
# 128376              NaN           NaN                  NaN
# 128377              NaN           NaN                  NaN
# 128378              NaN           NaN                  NaN
# 128379              NaN           NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 128375                                         NaN
# 128376                                         NaN
# 128377                                         NaN
# 128378                                         NaN
# 128379                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 128375                             NaN                           NaN
# 128376                             NaN                           NaN
# 128377                             NaN                           NaN
# 128378                             NaN                           NaN
# 128379                             NaN                           NaN
#
#        debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 128375                    N                       NaN               NaN
# 128376                    N                       NaN               NaN
# 128377                    N                       NaN               NaN
# 128378                  NaN                       NaN               NaN
# 128379                  NaN                       NaN               NaN
#
#        settlement_date  settlement_amount  settlement_percentage  \
# 128375             NaN                NaN                    NaN
# 128376             NaN                NaN                    NaN
# 128377             NaN                NaN                    NaN
# 128378             NaN                NaN                    NaN
# 128379             NaN                NaN                    NaN
#
#         settlement_term
# 128375              NaN
# 128376              NaN
# 128377              NaN
# 128378              NaN
# 128379              NaN

# %% [markdown]
# The extra rows at the top and bottom of the file have done two things:
#
# 1) The top row has made it so that the entire dataset is being interpreted as column headers
#
# 2) The bottom two rows have been read into the 'id' column and are causing every column to have at least two `NaN` values in it.

# %%
# We can fix the header problem by using the 'skiprows' parameter
# This is another way to fix header problem
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 1  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 2  NaN        NaN    20000.0      20000.0          20000.0   36 months
# 3  NaN        NaN     6500.0       6500.0           6500.0   36 months
# 4  NaN        NaN    25000.0      25000.0          25000.0   60 months
#
#   int_rate  installment grade sub_grade      emp_title emp_length  \
# 0   11.31%       164.43     B        B3       Shipping    2 years
# 1   18.94%       366.26     D        D2  Especialist 1    7 years
# 2    7.56%       622.68     A        A3        Teacher  10+ years
# 3   11.80%       215.28     B        B4      Educator     2 years
# 4   12.98%       568.58     B        B5   Tire builder  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d        loan_status  \
# 0           RENT     40000.0     Source Verified  Dec-2018            Current
# 1       MORTGAGE     37115.0        Not Verified  Dec-2018            Current
# 2       MORTGAGE    100000.0        Not Verified  Dec-2018         Fully Paid
# 3           RENT     46500.0     Source Verified  Dec-2018  Late (16-30 days)
# 4       MORTGAGE     85000.0        Not Verified  Dec-2018         Fully Paid
#
#   pymnt_plan  url  desc             purpose                    title zip_code  \
# 0          n  NaN   NaN  debt_consolidation       Debt consolidation    284xx
# 1          n  NaN   NaN               other                    Other    891xx
# 2          n  NaN   NaN         credit_card  Credit card refinancing    982xx
# 3          n  NaN   NaN  debt_consolidation       Debt consolidation    352xx
# 4          n  NaN   NaN  debt_consolidation       Debt consolidation    356xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NC   9.66          0.0         Oct-2007             0.0
# 1         NV  33.57          0.0         Jan-2002             0.0
# 2         WA  18.92          0.0         Feb-1999             0.0
# 3         AL  21.01          0.0         Aug-2011             1.0
# 4         AL  36.67          1.0         Oct-1993             1.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                     NaN       8.0      0.0
# 1                    38.0                     NaN       9.0      0.0
# 2                    48.0                     NaN       9.0      0.0
# 3                    61.0                     NaN      24.0      0.0
# 4                    10.0                     NaN      14.0      0.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1070.0      17.5%       27.0                   w    2770.45
# 1     5837.0      53.1%       15.0                   w    5147.99
# 2    25416.0      29.9%       19.0                   w       0.00
# 3     6741.0      41.6%       30.0                   w    3354.53
# 4    26630.0      53.3%       27.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 
o_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0             6.0       0.0                   6.0                       NaN
# 1             4.0       1.0                   5.0                      38.0
# 2             1.0       5.0                   1.0                       NaN
# 3             1.0       0.0                   3.0                       NaN
# 4             3.0       4.0                   9.0                      10.0
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    9.0                             NaN
# 1                    7.0                            38.0
# 2                   13.0                            48.0
# 3                    5.0                            61.0
# 4                    3.0                            10.0
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                    0.0             2.0              5.0          3.0
# 1                    1.0             2.0              5.0          3.0
# 2                    0.0             5.0              5.0          5.0
# 3                    2.0             6.0             10.0          6.0
# 4                    1.0             4.0              5.0          4.0
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0        3.0       19.0            6.0            8.0                  5.0
# 1        6.0        4.0            6.0           10.0                  5.0
# 2        6.0        5.0            5.0            9.0                  5.0
# 3        6.0       14.0           11.0           16.0                 10.0
# 4        5.0       13.0            6.0           10.0                  5.0
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0       8.0               0.0           0.0                 0.0
# 1       9.0               0.0           0.0                 0.0
# 2       9.0               0.0           0.0                 0.0
# 3      24.0               0.0           0.0                 0.0
# 4      14.0               0.0           0.0                 0.0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                 1.0           100.0               0.0                   0.0
# 1                 4.0            93.3              33.3                   0.0
# 2                 1.0            94.7              20.0                   0.0
# 3                 9.0            93.3               0.0                   0.0
# 4                 2.0            85.2               0.0                   0.0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0        0.0         125853.0           144979.0          3600.0
# 1        0.0         253346.0            40345.0          5600.0
# 2        0.0         622183.0            71569.0         85100.0
# 3        0.0          50845.0            40223.0         13300.0
# 4        0.0         275691.0            96143.0         43900.0
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                    119753.0              NaN                      NaN
# 1                     41060.0          19051.0                 Jan-2016
# 2                     74833.0          43287.0                 Aug-1998
# 3                     34645.0              NaN                      NaN
# 4                     99691.0          48711.0                 Oct-1993
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     1.0               1.0               9.0
# 2                     0.0               3.0              10.0
# 3                     NaN               NaN               NaN
# 4                     1.0               4.0              16.0
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                76.4                  2.0                    7.0
# 2                29.7                  2.0                    7.0
# 3                 NaN                  NaN                    NaN
# 4                56.5                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %% [markdown]
# Lets look at the NaN values of each column so that you can see the problem that the extra rows at the bottom of the file are creating for us

# %%
# Sum null values by column and sort from least to greatest
df.isnull().sum()
# Out:
# id                                            128378
# member_id                                     128380
# loan_amnt                                          2
# funded_amnt                                        2
# funded_amnt_inv                                    2
# term                                               2
# int_rate                                           2
# installment                                        2
# grade                                              2
# sub_grade                                          2
# emp_title                                      20945
# emp_length                                     11703
# home_ownership                                     2
# annual_inc                                         2
# verification_status                                2
# issue_d                                            2
# loan_status                                        2
# pymnt_plan                                         2
# url                                           128380
# desc                                          128380
# purpose                                            2
# title                                              2
# zip_code                                           2
# addr_state                                         2
# dti                                              239
# delinq_2yrs                                        2
# earliest_cr_line                                   2
# inq_last_6mths                                     2
# mths_since_last_delinq                         72182
# mths_since_last_record                        112934
# open_acc                                           2
# pub_rec                                            2
# revol_bal                                          2
# revol_util                                       158
# total_acc                                          2
# initial_list_status                                2
# out_prncp                                          2
# out_prncp_inv                                      2
# total_pymnt                                        2
# total_pymnt_inv                                    2
# total_rec_prncp                                    2
# total_rec_int                                      2
# total_rec_late_fee                                 2
# recoveries                                         2
# collection_recovery_fee                            2
# last_pymnt_d                                     161
# last_pymnt_amnt                                    2
# next_pymnt_d                                   48414
# last_credit_pull_d                                 3
# collections_12_mths_ex_med                         2
# mths_since_last_major_derog                    99210
# policy_code                                        2
# application_type                                   2
# annual_inc_joint                              111602
# dti_joint                                     111602
# verification_status_joint                     113536
# acc_now_delinq                                     2
# tot_coll_amt                                       2
# tot_cur_bal                                        2
# open_acc_6m                                        2
# open_act_il                                        2
# open_il_12m                                        2
# open_il_24m                                        2
# mths_since_rcnt_il                              4480
# total_bal_il                                       2
# il_util                                        20272
# open_rv_12m                                        2
# open_rv_24m                                        2
# max_bal_bc                                         2
# all_util                                          39
# total_rev_hi_lim                                   2
# inq_fi                                             2
# total_cu_tl                                        2
# inq_last_12m                                       2
# acc_open_past_24mths                               2
# avg_cur_bal                                       15
# bc_open_to_buy                                  1693
# bc_util                                         1756
# chargeoff_within_12_mths                           2
# delinq_amnt                                        2
# mo_sin_old_il_acct                              4480
# mo_sin_old_rev_tl_op                               2
# mo_sin_rcnt_rev_tl_op                              2
# mo_sin_rcnt_tl                                     2
# mort_acc                                           2
# mths_since_recent_bc                            1593
# mths_since_recent_bc_dlq                      103221
# mths_since_recent_inq                          16045
# mths_since_recent_revol_delinq                 91611
# num_accts_ever_120_pd                              2
# num_actv_bc_tl                                     2
# num_actv_rev_tl                                    2
# num_bc_sats                                        2
# num_bc_tl                                          2
# num_il_tl                                          2
# num_op_rev_tl                                      2
# num_rev_accts                                      2
# num_rev_tl_bal_gt_0                                2
# num_sats                                           2
# num_tl_120dpd_2m                                2860
# num_tl_30dpd                                       2
# num_tl_90g_dpd_24m                                 2
# num_tl_op_past_12m                                 2
# pct_tl_nvr_dlq                                     2
# percent_bc_gt_75                                1694
# pub_rec_bankruptcies                               2
# tax_liens                                          2
# tot_hi_cred_lim                                    2
# total_bal_ex_mort                                  2
# total_bc_limit                                     2
# total_il_high_credit_limit                         2
# revol_bal_joint                               111602
# sec_app_earliest_cr_line                      111602
# sec_app_inq_last_6mths                        111602
# sec_app_mort_acc                              111602
# sec_app_open_acc                              111602
# sec_app_revol_util                            111860
# sec_app_open_act_il                           111602
# sec_app_num_rev_accts                         111602
# sec_app_chargeoff_within_12_mths              111602
# sec_app_collections_12_mths_ex_med            111602
# sec_app_mths_since_last_major_derog           123227
# hardship_flag                                   5298
# hardship_type                                 115088
# hardship_reason                               115075
# hardship_status                               115074
# deferral_term                                 115074
# hardship_amount                               109777
# hardship_start_date                           115074
# hardship_end_date                             115074
# payment_plan_start_date                       115087
# hardship_length                               115074
# hardship_dpd                                  115075
# hardship_loan_status                          117489
# orig_projected_additional_accrued_interest    109787
# hardship_payoff_balance_amount                109777
# hardship_last_payment_amount                  109777
# debt_settlement_flag                               2
# debt_settlement_flag_date                     127443
# settlement_status                             127443
# settlement_date                               127443
# settlement_amount                             127443
# settlement_percentage                         127443
# settlement_term                               127443
# dtype: int64

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# mo_sin_old_rev_tl_op                               2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# open_il_12m                                        2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# application_type                                   2
# policy_code                                        2
# mo_sin_rcnt_rev_tl_op                              2
# collections_12_mths_ex_med                         2
# mo_sin_rcnt_tl                                     2
# num_accts_ever_120_pd                              2
# total_il_high_credit_limit                         2
# total_bc_limit                                     2
# total_bal_ex_mort                                  2
# tot_hi_cred_lim                                    2
# tax_liens                                          2
# pub_rec_bankruptcies                               2
# pct_tl_nvr_dlq                                     2
# num_tl_op_past_12m                                 2
# num_tl_90g_dpd_24m                                 2
# num_tl_30dpd                                       2
# num_sats                                           2
# num_rev_tl_bal_gt_0                                2
# num_rev_accts                                      2
# num_op_rev_tl                                      2
# num_il_tl                                          2
# num_bc_tl                                          2
# num_bc_sats                                        2
# num_actv_rev_tl                                    2
# num_actv_bc_tl                                     2
# mort_acc                                           2
# last_pymnt_amnt                                    2
# max_bal_bc                                         2
# collection_recovery_fee                            2
# earliest_cr_line                                   2
# delinq_2yrs                                        2
# addr_state                                         2
# zip_code                                           2
# title                                              2
# purpose                                            2
# pymnt_plan                                         2
# loan_status                                        2
# issue_d                                            2
# inq_last_6mths                                     2
# verification_status                                2
# home_ownership                                     2
# sub_grade                                          2
# grade                                              2
# installment                                        2
# int_rate                                           2
# term                                               2
# funded_amnt_inv                                    2
# funded_amnt                                        2
# loan_amnt                                          2
# annual_inc                                         2
# open_acc                                           2
# debt_settlement_flag                               2
# total_rec_int                                      2
# total_rec_prncp                                    2
# total_pymnt_inv                                    2
# total_pymnt                                        2
# pub_rec                                            2
# out_prncp_inv                                      2
# out_prncp                                          2
# initial_list_status                                2
# revol_bal                                          2
# total_rec_late_fee                                 2
# recoveries                                         2
# total_acc                                          2
# last_credit_pull_d                                 3
# avg_cur_bal                                       15
# all_util                                          39
# revol_util                                       158
# last_pymnt_d                                     161
# dti                                              239
# mths_since_recent_bc                            1593
# bc_open_to_buy                                  1693
# percent_bc_gt_75                                1694
# bc_util                                         1756
# num_tl_120dpd_2m                                2860
# mo_sin_old_il_acct                              4480
# mths_since_rcnt_il                              4480
# hardship_flag                                   5298
# emp_length                                     11703
# mths_since_recent_inq                          16045
# il_util                                        20272
# emp_title                                      20945
# next_pymnt_d                                   48414
# mths_since_last_delinq                         72182
# mths_since_recent_revol_delinq                 91611
# mths_since_last_major_derog                    99210
# mths_since_recent_bc_dlq                      103221
# hardship_amount                               109777
# hardship_payoff_balance_amount                109777
# hardship_last_payment_amount                  109777
# orig_projected_additional_accrued_interest    109787
# annual_inc_joint                              111602
# sec_app_collections_12_mths_ex_med            111602
# sec_app_chargeoff_within_12_mths              111602
# sec_app_num_rev_accts                         111602
# sec_app_open_act_il                           111602
# sec_app_open_acc                              111602
# dti_joint                                     111602
# sec_app_inq_last_6mths                        111602
# sec_app_earliest_cr_line                      111602
# revol_bal_joint                               111602
# sec_app_mort_acc                              111602
# sec_app_revol_util                            111860
# mths_since_last_record                        112934
# verification_status_joint                     113536
# hardship_length                               115074
# hardship_end_date                             115074
# hardship_start_date                           115074
# hardship_status                               115074
# deferral_term                                 115074
# hardship_reason                               115075
# hardship_dpd                                  115075
# payment_plan_start_date                       115087
# hardship_type                                 115088
# hardship_loan_status                          117489
# sec_app_mths_since_last_major_derog           123227
# debt_settlement_flag_date                     127443
# settlement_status                             127443
# settlement_amount                             127443
# settlement_date                               127443
# settlement_term                               127443
# settlement_percentage                         127443
# id                                            128378
# desc                                          128380
# url                                           128380
# member_id                                     128380
# dtype: int64

# %%
# Address the extra NaNs in each column by skipping the footer as well.
# This way produces a warning because Panda is uing a C compliler, but the skpfooter wasnt implemented yet in C
#   can ingnore, or just use specific engine='python' designation
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# (128378, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       5000         5000           5000.0   36 months
# 1 NaN        NaN      10000        10000          10000.0   36 months
# 2 NaN        NaN      20000        20000          20000.0   36 months
# 3 NaN        NaN       6500         6500           6500.0   36 months
# 4 NaN        NaN      25000        25000          25000.0   60 months
#
#   int_rate  installment grade sub_grade      emp_title emp_length  \
# 0   11.31%       164.43     B        B3       Shipping    2 years
# 1   18.94%       366.26     D        D2  Especialist 1    7 years
# 2    7.56%       622.68     A        A3        Teacher  10+ years
# 3   11.80%       215.28     B        B4      Educator     2 years
# 4   12.98%       568.58     B        B5   Tire builder  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d        loan_status  \
# 0           RENT     40000.0     Source Verified  Dec-2018            Current
# 1       MORTGAGE     37115.0        Not Verified  Dec-2018            Current
# 2       MORTGAGE    100000.0        Not Verified  Dec-2018         Fully Paid
# 3           RENT     46500.0     Source Verified  Dec-2018  Late (16-30 days)
# 4       MORTGAGE     85000.0        Not Verified  Dec-2018         Fully Paid
#
#   pymnt_plan  url  desc             purpose                    title zip_code  \
# 0          n  NaN   NaN  debt_consolidation       Debt consolidation    284xx
# 1          n  NaN   NaN               other                    Other    891xx
# 2          n  NaN   NaN         credit_card  Credit card refinancing    982xx
# 3          n  NaN   NaN  debt_consolidation       Debt consolidation    352xx
# 4          n  NaN   NaN  debt_consolidation       Debt consolidation    356xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NC   9.66            0         Oct-2007               0
# 1         NV  33.57            0         Jan-2002               0
# 2         WA  18.92            0         Feb-1999               0
# 3         AL  21.01            0         Aug-2011               1
# 4         AL  36.67            1         Oct-1993               1
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                     NaN         8        0
# 1                    38.0                     NaN         9        0
# 2                    48.0                     NaN         9        0
# 3                    61.0                     NaN        24        0
# 4                    10.0                     NaN        14        0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0       1070      17.5%         27                   w    2770.45
# 1       5837      53.1%         15                   w    5147.99
# 2      25416      29.9%         19                   w       0.00
# 3       6741      41.6%         30                   w    3354.53
# 4      26630      53.3%         27                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        2770.45   2956.610000          2956.61          2229.55
# 1        5147.99   7309.420000          7309.42          4852.01
# 2           0.00  20215.792430         20215.79         20000.00
# 3        3354.53   4083.930000          4083.93          3145.47
# 4           0.00  29563.763968         29563.76         25000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         727.06                 0.0         0.0                      0.0
# 1        2457.41                 0.0         0.0                      0.0
# 2         215.79                 0.0         0.0                      0.0
# 3         938.46                 0.0         0.0                      0.0
# 4        4563.76                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Sep-2020           164.43     Oct-2020           Sep-2020
# 1     Sep-2020           366.26     Oct-2020           Sep-2020
# 2     Feb-2019         20228.39          NaN           Feb-2019
# 3     Jul-2020           215.28     Oct-2020           Sep-2020
# 4     Aug-2020         19356.36          NaN           Aug-2020
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                           0                          NaN            1
# 1                           0                         38.0            1
# 2                           0                          NaN            1
# 3                           0                         61.0            1
# 4                           0                         40.0            1
#
#   application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 0       Individual               NaN        NaN                       NaN
# 1        Joint App           91115.0      18.61              Not Verified
# 2        Joint App          190000.0      11.75              Not Verified
# 3       Individual               NaN        NaN                       NaN
# 4        Joint App          140000.0      23.08              Not Verified
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 0               0           550       144979            1            2
# 1               0             0       240589            3            2
# 2               0             0       515779            1            2
# 3               0             0        40223            4           12
# 4               0            56       206980            1            7
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0            0            1                13.0        143909     78.0
# 1            1            2                 8.0         34508     88.0
# 2            0            1                13.0         46153     71.0
# 3            2            2                 5.0         33482     97.0
# 4            1            3                 3.0         69513     81.0
#
#    open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0            1            3         170      44.0              6100       1
# 1            2            3        1659      64.0             11000       2
# 2            1            2        9759      39.0             85100       2
# 3            7           12        3662      79.0             16200       2
# 4            1            1       17292      68.0             50000       1
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0            0             1                     4      18122.0
# 1            0             5                     6      26732.0
# 2            2             0                     5      57309.0
# 3            0             4                    14       1749.0
# 4            3             1                     4      14784.0
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0          3283.0      8.8                         0            0
# 1          2669.0     52.3                         0            0
# 2         59684.0     29.9                         0            0
# 3          7694.0     42.2                         0            0
# 4         18581.0     57.7                         0            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               134.0                    86                      6
# 1               158.0                   203                      4
# 2               171.0                   238                      1
# 3                88.0                    72                      1
# 4               186.0                   185                      9
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0               6         0                   6.0                       NaN
# 1               4         1                   5.0                      38.0
# 2               1         5                   1.0                       NaN
# 3               1         0                   3.0                       NaN
# 4               3         4                   9.0                      10.0
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    9.0                             NaN
# 1                    7.0                            38.0
# 2                   13.0                            48.0
# 3                    5.0                            61.0
# 4                    3.0                            10.0
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      0               2                5            3
# 1                      1               2                5            3
# 2                      0               5                5            5
# 3                      2               6               10            6
# 4                      1               4                5            4
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0          3         19              6              8                    5
# 1          6          4              6             10                    5
# 2          6          5              5              9                    5
# 3          6         14             11             16                   10
# 4          5         13              6             10                    5
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0         8               0.0             0                   0
# 1         9               0.0             0                   0
# 2         9               0.0             0                   0
# 3        24               0.0             0                   0
# 4        14               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   1           100.0               0.0                     0
# 1                   4            93.3              33.3                     0
# 2                   1            94.7              20.0                     0
# 3                   9            93.3               0.0                     0
# 4                   2            85.2               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0           125853             144979            3600
# 1          0           253346              40345            5600
# 2          0           622183              71569           85100
# 3          0            50845              40223           13300
# 4          0           275691              96143           43900
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                      119753              NaN                      NaN
# 1                       41060          19051.0                 Jan-2016
# 2                       74833          43287.0                 Aug-1998
# 3                       34645              NaN                      NaN
# 4                       99691          48711.0                 Oct-1993
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     1.0               1.0               9.0
# 2                     0.0               3.0              10.0
# 3                     NaN               NaN               NaN
# 4                     1.0               4.0              16.0
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                76.4                  2.0                    7.0
# 2                29.7                  2.0                    7.0
# 3                 NaN                  NaN                    NaN
# 4                56.5                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python') 
#no warning now
print(df.shape)
df.head()
# Out:
# (128378, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       5000         5000           5000.0   36 months
# 1 NaN        NaN      10000        10000          10000.0   36 months
# 2 NaN        NaN      20000        20000          20000.0   36 months
# 3 NaN        NaN       6500         6500           6500.0   36 months
# 4 NaN        NaN      25000        25000          25000.0   60 months
#
#   int_rate  installment grade sub_grade      emp_title emp_length  \
# 0   11.31%       164.43     B        B3       Shipping    2 years
# 1   18.94%       366.26     D        D2  Especialist 1    7 years
# 2    7.56%       622.68     A        A3        Teacher  10+ years
# 3   11.80%       215.28     B        B4      Educator     2 years
# 4   12.98%       568.58     B        B5   Tire builder  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d        loan_status  \
# 0           RENT     40000.0     Source Verified  Dec-2018            Current
# 1       MORTGAGE     37115.0        Not Verified  Dec-2018            Current
# 2       MORTGAGE    100000.0        Not Verified  Dec-2018         Fully Paid
# 3           RENT     46500.0     Source Verified  Dec-2018  Late (16-30 days)
# 4       MORTGAGE     85000.0        Not Verified  Dec-2018         Fully Paid
#
#   pymnt_plan  url  desc             purpose                    title zip_code  \
# 0          n  NaN   NaN  debt_consolidation       Debt consolidation    284xx
# 1          n  NaN   NaN               other                    Other    891xx
# 2          n  NaN   NaN         credit_card  Credit card refinancing    982xx
# 3          n  NaN   NaN  debt_consolidation       Debt consolidation    352xx
# 4          n  NaN   NaN  debt_consolidation       Debt consolidation    356xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NC   9.66            0         Oct-2007               0
# 1         NV  33.57            0         Jan-2002               0
# 2         WA  18.92            0         Feb-1999               0
# 3         AL  21.01            0         Aug-2011               1
# 4         AL  36.67            1         Oct-1993               1
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                     NaN         8        0
# 1                    38.0                     NaN         9        0
# 2                    48.0                     NaN         9        0
# 3                    61.0                     NaN        24        0
# 4                    10.0                     NaN        14        0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0       1070      17.5%         27                   w    2770.45
# 1       5837      53.1%         15                   w    5147.99
# 2      25416      29.9%         19                   w       0.00
# 3       6741      41.6%         30                   w    3354.53
# 4      26630      53.3%         27                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        2770.45   2956.610000          2956.61          2229.55
# 1        5147.99   7309.420000          7309.42          4852.01
# 2           0.00  20215.792430         20215.79         20000.00
# 3        3354.53   4083.930000          4083.93          3145.47
# 4           0.00  29563.763968         29563.76         25000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         727.06                 0.0         0.0                      0.0
# 1        2457.41                 0.0         0.0                      0.0
# 2         215.79                 0.0         0.0                      0.0
# 3         938.46                 0.0         0.0                      0.0
# 4        4563.76                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Sep-2020           164.43     Oct-2020           Sep-2020
# 1     Sep-2020           366.26     Oct-2020           Sep-2020
# 2     Feb-2019         20228.39          NaN           Feb-2019
# 3     Jul-2020           215.28     Oct-2020           Sep-2020
# 4     Aug-2020         19356.36          NaN           Aug-2020
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                           0                          NaN            1
# 1                           0                         38.0            1
# 2                           0                          NaN            1
# 3                           0                         61.0            1
# 4                           0                         40.0            1
#
#   application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 0       Individual               NaN        NaN                       NaN
# 1        Joint App           91115.0      18.61              Not Verified
# 2        Joint App          190000.0      11.75              Not Verified
# 3       Individual               NaN        NaN                       NaN
# 4        Joint App          140000.0      23.08              Not Verified
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 0               0           550       144979            1            2
# 1               0             0       240589            3            2
# 2               0             0       515779            1            2
# 3               0             0        40223            4           12
# 4               0            56       206980            1            7
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0            0            1                13.0        143909     78.0
# 1            1            2                 8.0         34508     88.0
# 2            0            1                13.0         46153     71.0
# 3            2            2                 5.0         33482     97.0
# 4            1            3                 3.0         69513     81.0
#
#    open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0            1            3         170      44.0              6100       1
# 1            2            3        1659      64.0             11000       2
# 2            1            2        9759      39.0             85100       2
# 3            7           12        3662      79.0             16200       2
# 4            1            1       17292      68.0             50000       1
#
#    total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0            0             1                     4      18122.0
# 1            0             5                     6      26732.0
# 2            2             0                     5      57309.0
# 3            0             4                    14       1749.0
# 4            3             1                     4      14784.0
#
#    bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0          3283.0      8.8                         0            0
# 1          2669.0     52.3                         0            0
# 2         59684.0     29.9                         0            0
# 3          7694.0     42.2                         0            0
# 4         18581.0     57.7                         0            0
#
#    mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0               134.0                    86                      6
# 1               158.0                   203                      4
# 2               171.0                   238                      1
# 3                88.0                    72                      1
# 4               186.0                   185                      9
#
#    mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  \
# 0               6         0                   6.0                       NaN
# 1               4         1                   5.0                      38.0
# 2               1         5                   1.0                       NaN
# 3               1         0                   3.0                       NaN
# 4               3         4                   9.0                      10.0
#
#    mths_since_recent_inq  mths_since_recent_revol_delinq  \
# 0                    9.0                             NaN
# 1                    7.0                            38.0
# 2                   13.0                            48.0
# 3                    5.0                            61.0
# 4                    3.0                            10.0
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  \
# 0                      0               2                5            3
# 1                      1               2                5            3
# 2                      0               5                5            5
# 3                      2               6               10            6
# 4                      1               4                5            4
#
#    num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  \
# 0          3         19              6              8                    5
# 1          6          4              6             10                    5
# 2          6          5              5              9                    5
# 3          6         14             11             16                   10
# 4          5         13              6             10                    5
#
#    num_sats  num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 0         8               0.0             0                   0
# 1         9               0.0             0                   0
# 2         9               0.0             0                   0
# 3        24               0.0             0                   0
# 4        14               0.0             0                   0
#
#    num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 0                   1           100.0               0.0                     0
# 1                   4            93.3              33.3                     0
# 2                   1            94.7              20.0                     0
# 3                   9            93.3               0.0                     0
# 4                   2            85.2               0.0                     0
#
#    tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0          0           125853             144979            3600
# 1          0           253346              40345            5600
# 2          0           622183              71569           85100
# 3          0            50845              40223           13300
# 4          0           275691              96143           43900
#
#    total_il_high_credit_limit  revol_bal_joint sec_app_earliest_cr_line  \
# 0                      119753              NaN                      NaN
# 1                       41060          19051.0                 Jan-2016
# 2                       74833          43287.0                 Aug-1998
# 3                       34645              NaN                      NaN
# 4                       99691          48711.0                 Oct-1993
#
#    sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 0                     NaN               NaN               NaN
# 1                     1.0               1.0               9.0
# 2                     0.0               3.0              10.0
# 3                     NaN               NaN               NaN
# 4                     1.0               4.0              16.0
#
#    sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                 NaN                  NaN                    NaN
# 1                76.4                  2.0                    7.0
# 2                29.7                  2.0                    7.0
# 3                 NaN                  NaN                    NaN
# 4                56.5                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
df.tail()

# %% [markdown]
# For good measure, we'll also drop some columns that are made up completely of NaN values.
#
# Why might LendingClub have included columns in their dataset that are 100% blank?

# %%
#By leaving the columns blank they protect user identity.

# %%
df=df.drop(['id', 'member_id', 'desc', 'url'], axis=1)
# can also use df.drop(['id', 'member_id', 'desc', 'url'], axis=1, inplace=True)  No need to use df=
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4      Educator     2 years           RENT     46500.0
# 4     B        B5   Tire builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          2956.61          2229.55         727.06                 0.0
# 1          7309.42          4852.01        2457.41                 0.0
# 2         20215.79         20000.00         215.79                 0.0
# 3          4083.93          3145.47         938.46                 0.0
# 4         29563.76         25000.00        4563.76                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                      0.0     Sep-2020           164.43
# 1         0.0                      0.0     Sep-2020           366.26
# 2         0.0                      0.0     Feb-2019         20228.39
# 3         0.0                      0.0     Jul-2020           215.28
# 4         0.0                      0.0     Aug-2020         19356.36
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 
ec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %% [markdown]
# ### Clean up the `int_rate` column
#
# When we're preparing a dataset for a machine learning model we typically don't want to leave any string values in our dataset --because it's hard to do math on words.
#
# Specifically, we have a column that is representing a numeric value, but currently doesn't have a numeric datatype. Lets look at the first 10 values of the `int_rate` column:

# %%
# Look at the first 10 values of the int_rate column
df.int_rate.head(10)
# Out:
# 0     11.31%
# 1     18.94%
# 2      7.56%
# 3     11.80%
# 4     12.98%
# 5     10.33%
# 6     19.92%
# 7     23.40%
# 8     15.02%
# 9     12.98%
# Name: int_rate, dtype: object

# %%
# Look at a specific value from the int_rate column

df.int_rate[0]
# Out:
# ' 11.31%'

# %% [markdown]
# Problems that we need to address with this column:
#
# - String column that should be numeric
# - Percent sign `%` included with the number
# - Leading space at the beginning of the string
#
# However, we're not going to try and write exactly the right code to fix this column in one go. We're going to methodically build up to the code that will help us address these problems.

# %%
# Lets start with just fixing a single string.
# If we can fix one, we can usually fix all of them

# %%
#Remove extra white space
' 14.47%'.strip()
# Out:
# '14.47%'

# %%
#Doesn't work if there isn't any extra white space to remove

'14.47%'.strip('%')
# Out:
# '14.47'

# %%
#You can "chain" two strip functions to remove both the spaces and the % sign
' 14.47%'.strip('%').strip()
# Out:
# '14.47'

# %%
#another way to do it is to use slicing
' 14.47%'[1:-1]
# Out:
# '14.47'

# %%
# "Cast" the string value to a float
# "cast" -> Change something's data type
# This is the line of code that we're after! ->
float('14.47')
# Out:
# 14.47

# %% [markdown]
# ### Write a function to make our solution reusable!

# %%
# Write a function that can do what we have written above to any 
# string that is passsed to it.
def intRateTofloat(str):
  return float(str.strip('%').strip())

# %%
# Test out our function by calling it on our example

x=intRateTofloat(' 14.47%')
print(x)
# Out:
# 14.47

# %%
# is the data type correct?
type(x)
# Out:
# float

# %% [markdown]
# ### Apply our solution to every cell in a column

# %%
# pass in *only* the name of the function, don't call it. 
# This works because we know the function works on every item in the column
# so I can simply "apply" it to the entire column

df['int_rate'].apply(intRateTofloat)
# Out:
# 0         11.31
# 1         18.94
# 2          7.56
# 3         11.80
# 4         12.98
#           ...
# 128373    15.02
# 128374    15.02
# 128375    13.56
# 128376    11.06
# 128377    16.91
# Name: int_rate, Length: 128378, dtype: float64

# %%
# What type of data is held in our new column?
df['new_int_rate']=df['int_rate'].apply(intRateTofloat)
# Look at the datatypes of the last 5 columns
df.dtypes.tail()
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# new_int_rate             float64
# dtype: object

# %%
df.new_int_rate.mean()

# %% [markdown]
# ## Challenge
#
# We can create a new column with our cleaned values or overwrite the original, whatever we think best suits our needs. On your assignment you will take the same approach in trying to methodically build up the complexity of your code until you have a few lines that will work for any cell in a column. At that point you'll contain all of that functionality in a reusable function block and then use the `.apply()` function to... well... apply those changes to an entire column.

# %% [markdown]
# # [Objective 03](#pandas-apply) - Modify and Create Columns using `.apply()`

# %% [markdown]
# ## Overview
#
# We're already seen one example of using the `.apply()` function to clean up a column. Lets see if we can do it again, but this time on a slightly more complicated use case.
#
# Remember, the goal here is to write a function that will work correctly on any **individual** cell of a specific column. Then we can reuse that function on those individual cells of a dataframe column via the `.apply()` function.
#
# Lets clean up the emp_title "Employment Title" column!

# %% [markdown]
# ## Follow Along
#
# First we'll try and diagnose how bad the problem is and what improvements we might be able to make.

# %%
# Look at the top 20 employment titles

df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20943
# Teacher                2089
# Manager                1773
# Registered Nurse        950
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
df['emp_title'].nunique()
# Out:
# 43881

# %%
# How often is the employment_title null?
print(df['emp_title'].isnull().sum())
df['emp_title'].isnull()
# Out:
# 20943
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 128373    False
# 128374    False
# 128375    False
# 128376     True
# 128377    False
# Name: emp_title, Length: 128378, dtype: bool

# %% [markdown]
# What are some possible reasons as to why a person's employment title may have not been provided?

# %%
# Create some examples that represent the cases that we want to clean up
import numpy as np
examples=['manager',' Operating Manager','Regitered Nurse', np.NaN, 'OWNER']

# %%
# Write a function to clean up these use cases and increase uniformity.

def clean_emp_title(title):
  if isinstance(title, str):
    print(title.title())
  else:
    print('NaN')
clean_emp_title('OWNER')
# Out:
# Owner

# %%
# Using a for loop
for i in examples:
  clean_emp_title(i)
# Out:
# Manager
#  Operating Manager
# Regitered Nurse
# NaN
# Owner

# %%
  # print things that you want to force to be shown in the notebook output

# %%
# The value of the last thing to be returned gets printed out
# now return instead of printing
def clean_emp_title(title):
  if isinstance(title, str):
    return(title.title())
  else:
    return('Unknown')
for i in examples:
  print(clean_emp_title(i))
# Out:
# Manager
#  Operating Manager
# Regitered Nurse
# Unknown
# Owner

# %%
# now add removing of white spaces in front and the end of titles
# chaining executes from Left to Right
def clean_emp_title(title):
  if isinstance(title, str):
    return(title.strip().title())
  else:
    return('Unknown')
for i in examples:
  print(clean_emp_title(i))
# Out:
# Manager
# Operating Manager
# Regitered Nurse
# Unknown
# Owner

# %%
# if the last thing to be returned gets saved to a variable
# then it won't get printed out

# %%
# if I include just a variable name, it will get printed out

# %%
#Apply the function to every row of the emp_title variable

df['emp_title_cleaned']=df['emp_title'].apply(clean_emp_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4      Educator     2 years           RENT     46500.0
# 4     B        B5   Tire builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          2956.61          2229.55         727.06                 0.0
# 1          7309.42          4852.01        2457.41                 0.0
# 2         20215.79         20000.00         215.79                 0.0
# 3          4083.93          3145.47         938.46                 0.0
# 4         29563.76         25000.00        4563.76                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 
ec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned
# 0          Shipping
# 1     Especialist 1
# 2           Teacher
# 3          Educator
# 4      Tire Builder

# %%
df.tail()
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128373      23000        23000          23000.0   36 months   15.02%
# 128374      10000        10000          10000.0   36 months   15.02%
# 128375       5000         5000           5000.0   36 months   13.56%
# 128376      10000        10000           9750.0   36 months   11.06%
# 128377      10000        10000          10000.0   36 months   16.91%
#
#         installment grade sub_grade             emp_title emp_length  \
# 128373       797.53     C        C3        Tax Consultant  10+ years
# 128374       346.76     C        C3        security guard    5 years
# 128375       169.83     C        C1          Payoff Clerk  10+ years
# 128376       327.68     B        B3                   NaN        NaN
# 128377       356.08     C        C5  Key Accounts Manager    2 years
#
#        home_ownership  annual_inc verification_status   issue_d  loan_status  \
# 128373       MORTGAGE     75000.0     Source Verified  Oct-2018  Charged Off
# 128374       MORTGAGE     38000.0        Not Verified  Oct-2018      Current
# 128375       MORTGAGE     35360.0        Not Verified  Oct-2018      Current
# 128376           RENT     44400.0     Source Verified  Oct-2018      Current
# 128377           RENT     80000.0        Not Verified  Oct-2018      Current
#
#        pymnt_plan             purpose                    title zip_code  \
# 128373          n  debt_consolidation       Debt consolidation    352xx
# 128374          n  debt_consolidation       Debt consolidation    443xx
# 128375          n  debt_consolidation       Debt consolidation    381xx
# 128376          n         credit_card  Credit card refinancing    980xx
# 128377          n               other                    Other    021xx
#
#        addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 128373         AL  20.95            1         Aug-1985               2
# 128374         OH  13.16            3         Jul-1982               0
# 128375         TN  11.30            1         Jun-2006               0
# 128376         WA  11.78            0         Oct-2008               2
# 128377         MA  17.72            1         Sep-2006               0
#
#         mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 128373                    22.0                     NaN        12        0
# 128374                     6.0                     NaN        11        0
# 128375                    21.0                     NaN         9        0
# 128376                    40.0                     NaN        15        0
# 128377                    14.0                     NaN        17        0
#
#         revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 128373      22465      43.6%         28                   w       0.00
# 128374       5634      37.1%         16                   w    4136.11
# 128375       2597      27.3%         15                   f    2042.26
# 128376       6269      13.1%         25                   f    3996.89
# 128377       1942      30.8%         31                   w    4202.86
#
#         out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 128373           0.00      1547.08          1547.08          1025.67
# 128374        4136.11      7967.14          7967.14          5863.89
# 128375        2042.26      3902.32          3902.32          2957.74
# 128376        3896.97      7521.28          7333.25          6003.11
# 128377        4202.86      8180.45          8180.45          5797.14
#
#         total_rec_int  total_rec_late_fee  recoveries  \
# 128373         521.41                 0.0         0.0
# 128374        2103.25                 0.0         0.0
# 128375         944.58                 0.0         0.0
# 128376        1518.17                 0.0         0.0
# 128377        2383.31                 0.0         0.0
#
#         collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# 128373                      0.0     Dec-2018           797.53          NaN
# 128374                      0.0     Sep-2020           346.76     Oct-2020
# 128375                      0.0     Sep-2020           169.83     Oct-2020
# 128376                      0.0     Sep-2020           327.68     Oct-2020
# 128377                      0.0     Sep-2020           356.08     Oct-2020
#
#        last_credit_pull_d  collections_12_mths_ex_med  \
# 128373           Nov-2018                           0
# 128374           Sep-2020                           0
# 128375           Sep-2020                           0
# 128376           Sep-2020                           0
# 128377           Sep-2020                           0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 128373                          NaN            1       Individual
# 128374                          NaN            1       Individual
# 128375                          NaN            1       Individual
# 128376                         53.0            1       Individual
# 128377                         25.0            1       Individual
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 128373               NaN        NaN                       NaN               0
# 128374               NaN        NaN                       NaN               0
# 128375               NaN        NaN                       NaN               0
# 128376               NaN        NaN                       NaN               0
# 128377               NaN        NaN                       NaN               0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 128373             0       259658            4            2            3
# 128374           155        77424            0            1            0
# 128375          1413        69785            0            2            0
# 128376           520        16440            3            1            1
# 128377             0        59194            0           15            1
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 128373            3                 6.0         18149     86.0            4
# 128374            0                34.0           200     10.0            1
# 128375            1                16.0          2379     40.0            3
# 128376            1                 2.0         10171    100.0            2
# 128377            1                12.0         57252     85.0            0
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 128373            6       12843      56.0             51500       2
# 128374            1        1866      42.0             15200       2
# 128375            4        1826      32.0              9500       0
# 128376            5         404      28.0             47700       0
# 128377            0        1942      80.0              6300       0
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 128373            2             5                    11      21638.0
# 128374            0             0                     2       7039.0
# 128375            0             1                     5       8723.0
# 128376            3             5                     6       1265.0
# 128377            5             0                     1       3482.0
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 128373         26321.0     44.1                         0            0
# 128374          4537.0     50.1                         0            0
# 128375          1174.0     60.9                         0            0
# 128376         20037.0      2.3                         0            0
# 128377          2058.0     48.5                         0            0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 128373                12.0                   397                      4
# 128374                34.0                   434                     11
# 128375               147.0                    85                      9
# 128376                61.0                   119                      1
# 128377               144.0                   142                     40
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 128373               4         6                   5.0
# 128374              11         3                  11.0
# 128375               9         2                  10.0
# 128376               1         0                   1.0
# 128377              12         0                 131.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 128373                      22.0                    4.0
# 128374                       6.0                   17.0
# 128375                      21.0                    9.0
# 128376                       NaN                    1.0
# 128377                      30.0                    NaN
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 128373                            22.0                      0               4
# 128374                             6.0                      0               3
# 128375                            21.0                      0               1
# 128376                            40.0                      1               2
# 128377                            30.0                      3               1
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 128373                5            7         14          3              9
# 128374                5            5          6          1              8
# 128375                3            2          2          6              6
# 128376                4            6          8          3             14
# 128377                1            1          5         22              2
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 128373             19                    5        12               0.0
# 128374             11                    5        11               0.0
# 128375              7                    3         9               0.0
# 128376             22                    4        15               0.0
# 128377              9                    1        17               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 128373             0                   0                   7            96.4
# 128374             0                   0                   1            73.3
# 128375             0                   0                   3            92.9
# 128376             0                   0                   3            92.0
# 128377             0                   0                   1            74.2
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 128373              14.3                     0          0           296500
# 128374              40.0                     0          0            91403
# 128375              50.0                     0          0            93908
# 128376               0.0                     0          0            57871
# 128377               0.0                     0          0            73669
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 128373              40614           47100                       21000
# 128374               9323            9100                        2000
# 128375               4976            3000                        6028
# 128376              16440           20500                       10171
# 128377              59194            4000                       67369
#
#         revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 128373              NaN                      NaN                     NaN
# 128374              NaN                      NaN                     NaN
# 128375              NaN                      NaN                     NaN
# 128376              NaN                      NaN                     NaN
# 128377              NaN                      NaN                     NaN
#
#         sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 128373               NaN               NaN                 NaN
# 128374               NaN               NaN                 NaN
# 128375               NaN               NaN                 NaN
# 128376               NaN               NaN                 NaN
# 128377               NaN               NaN                 NaN
#
#         sec_app_open_act_il  sec_app_num_rev_accts  \
# 128373                  NaN                    NaN
# 128374                  NaN                    NaN
# 128375                  NaN                    NaN
# 128376                  NaN                    NaN
# 128377                  NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 128373                               NaN                                 NaN
# 128374                               NaN                                 NaN
# 128375                               NaN                                 NaN
# 128376                               NaN                                 NaN
# 128377                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 128373                                  NaN             N           NaN
# 128374                                  NaN             N           NaN
# 128375                                  NaN             N           NaN
# 128376                                  NaN             N           NaN
# 128377                                  NaN             N           NaN
#
#        hardship_reason hardship_status  deferral_term  hardship_amount  \
# 128373             NaN             NaN            NaN              NaN
# 128374             NaN             NaN            NaN              NaN
# 128375             NaN             NaN            NaN              NaN
# 128376             NaN             NaN            NaN              NaN
# 128377             NaN             NaN            NaN              NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 128373                 NaN               NaN                     NaN
# 128374                 NaN               NaN                     NaN
# 128375                 NaN               NaN                     NaN
# 128376                 NaN               NaN                     NaN
# 128377                 NaN               NaN                     NaN
#
#         hardship_length  hardship_dpd hardship_loan_status  \
# 128373              NaN           NaN                  NaN
# 128374              NaN           NaN                  NaN
# 128375              NaN           NaN                  NaN
# 128376              NaN           NaN                  NaN
# 128377              NaN           NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 128373                                         NaN
# 128374                                         NaN
# 128375                                         NaN
# 128376                                         NaN
# 128377                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 128373                             NaN                           NaN
# 128374                             NaN                           NaN
# 128375                             NaN                           NaN
# 128376                             NaN                           NaN
# 128377                             NaN                           NaN
#
#        debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 128373                    N                       NaN               NaN
# 128374                    N                       NaN               NaN
# 128375                    N                       NaN               NaN
# 128376                    N                       NaN               NaN
# 128377                    N                       NaN               NaN
#
#        settlement_date  settlement_amount  settlement_percentage  \
# 128373             NaN                NaN                    NaN
# 128374             NaN                NaN                    NaN
# 128375             NaN                NaN                    NaN
# 128376             NaN                NaN                    NaN
# 128377             NaN                NaN                    NaN
#
#         settlement_term  new_int_rate     emp_title_cleaned
# 128373              NaN         15.02        Tax Consultant
# 128374              NaN         15.02        Security Guard
# 128375              NaN         13.56          Payoff Clerk
# 128376              NaN         11.06               Unknown
# 128377              NaN         16.91  Key Accounts Manager

# %%
#Top 20 titles
df['emp_title_cleaned'].value_counts().head(20)
# Out:
# Unknown               20943
# Teacher                2556
# Manager                2395
# Registered Nurse       1416
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              419
# Engineer                412
# Name: emp_title_cleaned, dtype: int64

# %%
#uniqu titles
df['emp_title_cleaned'].nunique()
# Out:
# 34895

# %%
#Top 20 titles
df['emp_title_cleaned'].value_counts(dropna=False).head(20)
# Out:
# Unknown               20943
# Teacher                2556
# Manager                2395
# Registered Nurse       1416
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              419
# Engineer                412
# Name: emp_title_cleaned, dtype: int64

# %%
df['emp_title_cleaned'].nunique()
# Out:
# 34895

# %%
# list comprehensions can combine function calls and for loops over lists
# into one succinct and fairly readable single line of code.

[clean_emp_title(i) for i in examples]
# Out:
# ['Manager', 'Operating Manager', 'Regitered Nurse', 'Unknown', 'Owner']

# %%
# We have a function that works as expected. Lets apply it to our column.
# This time we'll overwrite the original column
df['emp_title']=df['emp_title'].apply(clean_emp_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          2956.61          2229.55         727.06                 0.0
# 1          7309.42          4852.01        2457.41                 0.0
# 2         20215.79         20000.00         215.79                 0.0
# 3          4083.93          3145.47         938.46                 0.0
# 4         29563.76         25000.00        4563.76                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                      0.0     Sep-2020           164.43
# 1         0.0                      0.0     Sep-2020           366.26
# 2         0.0                      0.0     Feb-2019         20228.39
# 3         0.0                      0.0     Jul-2020           215.28
# 4         0.0                      0.0     Aug-2020         19356.36
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0     Oct-2020           Sep-2020                           0
# 1     Oct-2020           Sep-2020                           0
# 2          NaN           Feb-2019                           0
# 3     Oct-2020           Sep-2020                           0
# 4          NaN           Aug-2020                           0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       Individual
# 1                         38.0            1        Joint App
# 2                          NaN            1        Joint App
# 3                         61.0            1       Individual
# 4                         40.0            1        Joint App
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN               0
# 1           91115.0      18.61              Not Verified               0
# 2          190000.0      11.75              Not Verified               0
# 3               NaN        NaN                       NaN               0
# 4          140000.0      23.08              Not Verified               0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           550       144979            1            2            0
# 1             0       240589            3            2            1
# 2             0       515779            1            2            0
# 3             0        40223            4           12            2
# 4            56       206980            1            7            1
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0            1                13.0        143909     78.0            1
# 1            2                 8.0         34508     88.0            2
# 2            1                13.0         46153     71.0            1
# 3            2                 5.0         33482     97.0            7
# 4            3                 3.0         69513     81.0            1
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0            3         170      44.0              6100       1            0
# 1            3        1659      64.0             11000       2            0
# 2            2        9759      39.0             85100       2            2
# 3           12        3662      79.0             16200       2            0
# 4            1       17292      68.0             50000       1            3
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0             1                     4      18122.0          3283.0      8.8
# 1             5                     6      26732.0          2669.0     52.3
# 2             0                     5      57309.0         59684.0     29.9
# 3             4                    14       1749.0          7694.0     42.2
# 4             1                     4      14784.0         18581.0     57.7
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                         0            0               134.0
# 1                         0            0               158.0
# 2                         0            0               171.0
# 3                         0            0                88.0
# 4                         0            0               186.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                    86                      6               6         0
# 1                   203                      4               4         1
# 2                   238                      1               1         5
# 3                    72                      1               1         0
# 4                   185                      9               3         4
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   6.0                       NaN                    9.0
# 1                   5.0                      38.0                    7.0
# 2                   1.0                       NaN                   13.0
# 3                   3.0                       NaN                    5.0
# 4                   9.0                      10.0                    3.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      0               2
# 1                            38.0                      1               2
# 2                            48.0                      0               5
# 3                            61.0                      2               6
# 4                            10.0                      1               4
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                5            3          3         19              6
# 1                5            3          6          4              6
# 2                5            5          6          5              5
# 3               10            6          6         14             11
# 4                5            4          5         13              6
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              8                    5         8               0.0
# 1             10                    5         9               0.0
# 2              9                    5         9               0.0
# 3             16                   10        24               0.0
# 4             10                    5        14               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   1           100.0
# 1             0                   0                   4            93.3
# 2             0                   0                   1            94.7
# 3             0                   0                   9            93.3
# 4             0                   0                   2            85.2
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                     0          0           125853
# 1              33.3                     0          0           253346
# 2              20.0                     0          0           622183
# 3               0.0                     0          0            50845
# 4               0.0                     0          0           275691
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             144979            3600                      119753
# 1              40345            5600                       41060
# 2              71569           85100                       74833
# 3              40223           13300                       34645
# 4              96143           43900                       99691
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1          19051.0                 Jan-2016                     1.0
# 2          43287.0                 Aug-1998                     0.0
# 3              NaN                      NaN                     NaN
# 4          48711.0                 Oct-1993                     1.0
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned
# 0          Shipping
# 1     Especialist 1
# 2           Teacher
# 3          Educator
# 4      Tire Builder

# %%
# Usint for loop instead of .apply()
empt_title=[]
for i in df['emp_title']:
  empt_title.append(clean_emp_title(i))
df['emp_title_cleaned2']=pd.Series(empt_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          2956.61          2229.55         727.06                 0.0
# 1          7309.42          4852.01        2457.41                 0.0
# 2         20215.79         20000.00         215.79                 0.0
# 3          4083.93          3145.47         938.46                 0.0
# 4         29563.76         25000.00        4563.76                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 
ec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1          19051.0                 Jan-2016                     1.0
# 2          43287.0                 Aug-1998                     0.0
# 3              NaN                      NaN                     NaN
# 4          48711.0                 Oct-1993                     1.0
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned emp_title_cleaned2
# 0          Shipping           Shipping
# 1     Especialist 1      Especialist 1
# 2           Teacher            Teacher
# 3          Educator           Educator
# 4      Tire Builder       Tire Builder

# %% [markdown]
# We can use the same code as we did earlier to see how much progress was made.

# %%
# Look at the top 20 employment titles

df['emp_title_cleaned'].value_counts(dropna=False).sort_values(ascending=False).head(20)
# Out:
# Unknown               20943
# Teacher                2556
# Manager                2395
# Registered Nurse       1416
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              419
# Engineer                412
# Name: emp_title_cleaned, dtype: int64

# %%
# How many different unique employment titles are there currently?
df['emp_title_cleaned'].nunique()
# Out:
# 34895

# %%
# How often is the employment_title null (NaN)?
df['emp_title_cleaned'].value_counts().isna()
# Out:
# Unknown                             False
# Teacher                             False
# Manager                             False
# Registered Nurse                    False
# Driver                              False
#                                     ...
# Kitchen Bar Manager                 False
# Beu                                 False
# Director Revenue Integrity Ph&Sa    False
# Manufacturing Coordinator           False
# Managing Partner/Proprietor         False
# Name: emp_title_cleaned, Length: 34895, dtype: bool

# %%
#df['emp_title_cleaned'].isna()

# %%
#works both ways
print(df['emp_title_cleaned'].value_counts().isna().sum())
print(df['emp_title_cleaned'].isna().sum())
# Out:
# 0
# 0

# %% [markdown]
# ## Challenge
#
# Using the .apply() function isn't always about creating new columns on a dataframe, we can use it to clean up or modify existing columns as well.

# %% [markdown]
# # [Objective](#dates-and-times) Work with Dates and Times with Pandas

# %% [markdown]
# ## Overview
#
# Pandas has its own datatype that makes it extremely convenient to convert strings that are in standard date formates to datetime objects and then use those datetime objects to either create new features on a dataframe or work with the dataset in a timeseries fashion.
#
# This section will demonstrate how to take a column of date strings, convert it to a datetime object and then use the datetime formatting `.dt` to access specific parts of the date (year, month, day) to generate useful columns on a dataframe.

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Work with Dates
#
# pandas documentation
# - [to_datetime](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# - [Time/Date Components](https://pandas.pydata.org/pandas-docs/stable/timeseries.html#time-date-components) "You can access these properties via the `.dt` accessor"
#
# Many of the most useful date columns in this dataset have the suffix `_d` to indicate that they correspond to dates.
#
# We'll use a list comprehension to print them out

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %% [markdown]
# Lets look at the string format of the `issue_d` column

# %%
df['issue_d'][0].format()
# Out:
# 'Dec-2018'

# %% [markdown]
# Because this string format %m-%y is a common datetime format, we can just let Pandas detect this format and translate it to the appropriate datetime object.

# %%
df['issue_d_new']=pd.to_datetime(df['issue_d'])
df['issue_d_new'].head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d_new, dtype: datetime64[ns]

# %% [markdown]
# Now we can see that the `issue_d` column has been changed to hold `datetime` objects.
#
# Lets look at one of the cells specifically to see what a datetime object looks like:

# %%
print([df['issue_d'][0], df['issue_d_new'][0]])
df.head()
# Out:
# ['Dec-2018', Timestamp('2018-12-01 00:00:00')]
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   6.0                       NaN                    9.0
# 1                   5.0                      38.0                    7.0
# 2                   1.0                       NaN                   13.0
# 3                   3.0                       NaN                    5.0
# 4                   9.0                      10.0                    3.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      0               2
# 1                            38.0                      1               2
# 2                            48.0                      0               5
# 3                            61.0                      2               6
# 4                            10.0                      1               4
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                5            3          3         19              6
# 1                5            3          6          4              6
# 2                5            5          6          5              5
# 3               10            6          6         14             11
# 4                5            4          5         13              6
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              8                    5         8               0.0
# 1             10                    5         9               0.0
# 2              9                    5         9               0.0
# 3             16                   10        24               0.0
# 4             10                    5        14               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   1           100.0
# 1             0                   0                   4            93.3
# 2             0                   0                   1            94.7
# 3             0                   0                   9            93.3
# 4             0                   0                   2            85.2
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                     0          0           125853
# 1              33.3                     0          0           253346
# 2              20.0                     0          0           622183
# 3               0.0                     0          0            50845
# 4               0.0                     0          0           275691
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             144979            3600                      119753
# 1              40345            5600                       41060
# 2              71569           85100                       74833
# 3              40223           13300                       34645
# 4              96143           43900                       99691
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1          19051.0                 Jan-2016                     1.0
# 2          43287.0                 Aug-1998                     0.0
# 3              NaN                      NaN                     NaN
# 4          48711.0                 Oct-1993                     1.0
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned emp_title_cleaned2 issue_d_new
# 0          Shipping           Shipping  2018-12-01
# 1     Especialist 1      Especialist 1  2018-12-01
# 2           Teacher            Teacher  2018-12-01
# 3          Educator           Educator  2018-12-01
# 4      Tire Builder       Tire Builder  2018-12-01

# %% [markdown]
# You can see how the month and year have been indicated by the strings that were contained in the column previously, and that the rest of the values have been inferred.

# %% [markdown]
# We can use the `.dt` accessor to now grab specific parts of the datetime object. Lets grab just the year from the all of the cells in the `issue_d` column

# %%
df['issue_d_new'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128373    2018
# 128374    2018
# 128375    2018
# 128376    2018
# 128377    2018
# Name: issue_d_new, Length: 128378, dtype: int64

# %% [markdown]
# Now the month.

# %%
df['issue_d_new'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128373    10
# 128374    10
# 128375    10
# 128376    10
# 128377    10
# Name: issue_d_new, Length: 128378, dtype: int64

# %% [markdown]
# It's just that easy! Now, instead of printing them out, lets add these year and month values as new columns on our dataframe. Again, you'll have to scroll all the way over to the right in the table to see the new columns.

# %%
df['issue_d_year']=df['issue_d_new'].dt.year 
df['issue_d_month']=df['issue_d_new'].dt.month
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             144979            3600                      119753
# 1              40345            5600                       41060
# 2              71569           85100                       74833
# 3              40223           13300                       34645
# 4              96143           43900                       99691
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1          19051.0                 Jan-2016                     1.0
# 2          43287.0                 Aug-1998                     0.0
# 3              NaN                      NaN                     NaN
# 4          48711.0                 Oct-1993                     1.0
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned emp_title_cleaned2 issue_d_new  issue_d_year  \
# 0          Shipping           Shipping  2018-12-01          2018
# 1     Especialist 1      Especialist 1  2018-12-01          2018
# 2           Teacher            Teacher  2018-12-01          2018
# 3          Educator           Educator  2018-12-01          2018
# 4      Tire Builder       Tire Builder  2018-12-01          2018
#
#    issue_d_month
# 0             12
# 1             12
# 2             12
# 3             12
# 4             12

# %%
#check for NaNs
df['issue_d'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Because all of these dates come from Q4 of 2018, the `issue_d` column isn't all that interesting. Lets look at the `earliest_cr_line` column, which is also a string, but that could be converted to datetime format.
#
# We're going to create a new column called `days_from_earliest_credit_to_issue`
#
# It's a long column header, but think about how valuable this piece of information could be. This number will essentially indicate the length of a person's credit history and if that is correlated with repayment or other factors could be a valuable predictor!

# %%
df['earliest_cr_line_new']=pd.to_datetime(df['earliest_cr_line'])

# %%
df['issue_d_new']-df['earliest_cr_line_new']
# Out:
# 0         4079 days
# 1         6178 days
# 2         7243 days
# 3         2679 days
# 4         9192 days
#             ...
# 128373   12114 days
# 128374   13241 days
# 128375    4505 days
# 128376    3652 days
# 128377    4413 days
# Length: 128378, dtype: timedelta64[ns]

# %%
df['days_from_earliest_credit_to_issue']=(df['issue_d_new']-df['earliest_cr_line_new']).dt.days  #use dt.days to eliminate 'days'
df=df.drop(axis=1, columns=['credit_hist_len','credit_hist_len_new'])
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          2956.61          2229.55         727.06                 0.0
# 1          7309.42          4852.01        2457.41                 0.0
# 2         20215.79         20000.00         215.79                 0.0
# 3          4083.93          3145.47         938.46                 0.0
# 4         29563.76         25000.00        4563.76                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                      0.0     Sep-2020           164.43
# 1         0.0                      0.0     Sep-2020           366.26
# 2         0.0                      0.0     Feb-2019         20228.39
# 3         0.0                      0.0     Jul-2020           215.28
# 4         0.0                      0.0     Aug-2020         19356.36
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0     Oct-2020           Sep-2020                           0
# 1     Oct-2020           Sep-2020                           0
# 2          NaN           Feb-2019                           0
# 3     Oct-2020           Sep-2020                           0
# 4          NaN           Aug-2020                           0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       Individual
# 1                         38.0            1        Joint App
# 2                          NaN            1        Joint App
# 3                         61.0            1       Individual
# 4                         40.0            1        Joint App
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN               0
# 1           91115.0      18.61              Not Verified               0
# 2          190000.0      11.75              Not Verified               0
# 3               NaN        NaN                       NaN               0
# 4          140000.0      23.08              Not Verified               0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           550       144979            1            2            0
# 1             0       240589            3            2            1
# 2             0       515779            1            2            0
# 3             0        40223            4           12            2
# 4            56       206980            1            7            1
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0            1                13.0        143909     78.0            1
# 1            2                 8.0         34508     88.0            2
# 2            1                13.0         46153     71.0            1
# 3            2                 5.0         33482     97.0            7
# 4            3                 3.0         69513     81.0            1
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0            3         170      44.0              6100       1            0
# 1            3        1659      64.0             11000       2            0
# 2            2        9759      39.0             85100       2            2
# 3           12        3662      79.0             16200       2            0
# 4            1       17292      68.0             50000       1            3
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0             1                     4      18122.0          3283.0      8.8
# 1             5                     6      26732.0          2669.0     52.3
# 2             0                     5      57309.0         59684.0     29.9
# 3             4                    14       1749.0          7694.0     42.2
# 4             1                     4      14784.0         18581.0     57.7
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                         0            0               134.0
# 1                         0            0               158.0
# 2                         0            0               171.0
# 3                         0            0                88.0
# 4                         0            0               186.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                    86                      6               6         0
# 1                   203                      4               4         1
# 2                   238                      1               1         5
# 3                    72                      1               1         0
# 4                   185                      9               3         4
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   6.0                       NaN                    9.0
# 1                   5.0                      38.0                    7.0
# 2                   1.0                       NaN                   13.0
# 3                   3.0                       NaN                    5.0
# 4                   9.0                      10.0                    3.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      0               2
# 1                            38.0                      1               2
# 2                            48.0                      0               5
# 3                            61.0                      2               6
# 4                            10.0                      1               4
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                5            3          3         19              6
# 1                5            3          6          4              6
# 2                5            5          6          5              5
# 3               10            6          6         14             11
# 4                5            4          5         13              6
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              8                    5         8               0.0
# 1             10                    5         9               0.0
# 2              9                    5         9               0.0
# 3             16                   10        24               0.0
# 4             10                    5        14               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   1           100.0
# 1             0                   0                   4            93.3
# 2             0                   0                   1            94.7
# 3             0                   0                   9            93.3
# 4             0                   0                   2            85.2
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                     0          0           125853
# 1              33.3                     0          0           253346
# 2              20.0                     0          0           622183
# 3               0.0                     0          0            50845
# 4               0.0                     0          0           275691
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             144979            3600                      119753
# 1              40345            5600                       41060
# 2              71569           85100                       74833
# 3              40223           13300                       34645
# 4              96143           43900                       99691
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1          19051.0                 Jan-2016                     1.0
# 2          43287.0                 Aug-1998                     0.0
# 3              NaN                      NaN                     NaN
# 4          48711.0                 Oct-1993                     1.0
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned emp_title_cleaned2 issue_d_new  issue_d_year  \
# 0          Shipping           Shipping  2018-12-01          2018
# 1     Especialist 1      Especialist 1  2018-12-01          2018
# 2           Teacher            Teacher  2018-12-01          2018
# 3          Educator           Educator  2018-12-01          2018
# 4      Tire Builder       Tire Builder  2018-12-01          2018
#
#    issue_d_month earliest_cr_line_new  days_from_earliest_credit_to_issue
# 0             12           2007-10-01                                4079
# 1             12           2002-01-01                                6178
# 2             12           1999-02-01                                7243
# 3             12           2011-08-01                                2679
# 4             12           1993-10-01                                9192

# %%
# length of credit history in years
#Don't forget leap year = 365.25 each year.
df['credit_hist_len']=df['days_from_earliest_credit_to_issue']/365.25
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      0               2
# 1                            38.0                      1               2
# 2                            48.0                      0               5
# 3                            61.0                      2               6
# 4                            10.0                      1               4
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                5            3          3         19              6
# 1                5            3          6          4              6
# 2                5            5          6          5              5
# 3               10            6          6         14             11
# 4                5            4          5         13              6
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              8                    5         8               0.0
# 1             10                    5         9               0.0
# 2              9                    5         9               0.0
# 3             16                   10        24               0.0
# 4             10                    5        14               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   1           100.0
# 1             0                   0                   4            93.3
# 2             0                   0                   1            94.7
# 3             0                   0                   9            93.3
# 4             0                   0                   2            85.2
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                     0          0           125853
# 1              33.3                     0          0           253346
# 2              20.0                     0          0           622183
# 3               0.0                     0          0            50845
# 4               0.0                     0          0           275691
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             144979            3600                      119753
# 1              40345            5600                       41060
# 2              71569           85100                       74833
# 3              40223           13300                       34645
# 4              96143           43900                       99691
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1          19051.0                 Jan-2016                     1.0
# 2          43287.0                 Aug-1998                     0.0
# 3              NaN                      NaN                     NaN
# 4          48711.0                 Oct-1993                     1.0
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned emp_title_cleaned2 issue_d_new  issue_d_year  \
# 0          Shipping           Shipping  2018-12-01          2018
# 1     Especialist 1      Especialist 1  2018-12-01          2018
# 2           Teacher            Teacher  2018-12-01          2018
# 3          Educator           Educator  2018-12-01          2018
# 4      Tire Builder       Tire Builder  2018-12-01          2018
#
#    issue_d_month earliest_cr_line_new  days_from_earliest_credit_to_issue  \
# 0             12           2007-10-01                                4079
# 1             12           2002-01-01                                6178
# 2             12           1999-02-01                                7243
# 3             12           2011-08-01                                2679
# 4             12           1993-10-01                                9192
#
#    credit_hist_len
# 0        11.167693
# 1        16.914442
# 2        19.830253
# 3         7.334702
# 4        25.166324

# %% [markdown]
# What we're about to do is so cool! Pandas' datetime format is so smart that we can simply use the subtraction operator `-` in order to calculate the amount of time between two dates.
#
# Think about everything that's going on under the hood in order to give us such straightforward syntax! Handling months of different lengths, leap years, etc. Pandas datetime objects are seriously powerful!

# %%
df['credit_hist_len_new']=(df['issue_d_new']-df['earliest_cr_line_new']).dt.days
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           5000.0   36 months   11.31%       164.43
# 1      10000        10000          10000.0   36 months   18.94%       366.26
# 2      20000        20000          20000.0   36 months    7.56%       622.68
# 3       6500         6500           6500.0   36 months   11.80%       215.28
# 4      25000        25000          25000.0   60 months   12.98%       568.58
#
#   grade sub_grade      emp_title emp_length home_ownership  annual_inc  \
# 0     B        B3       Shipping    2 years           RENT     40000.0
# 1     D        D2  Especialist 1    7 years       MORTGAGE     37115.0
# 2     A        A3        Teacher  10+ years       MORTGAGE    100000.0
# 3     B        B4       Educator    2 years           RENT     46500.0
# 4     B        B5   Tire Builder  10+ years       MORTGAGE     85000.0
#
#   verification_status   issue_d        loan_status pymnt_plan  \
# 0     Source Verified  Dec-2018            Current          n
# 1        Not Verified  Dec-2018            Current          n
# 2        Not Verified  Dec-2018         Fully Paid          n
# 3     Source Verified  Dec-2018  Late (16-30 days)          n
# 4        Not Verified  Dec-2018         Fully Paid          n
#
#               purpose                    title zip_code addr_state    dti  \
# 0  debt_consolidation       Debt consolidation    284xx         NC   9.66
# 1               other                    Other    891xx         NV  33.57
# 2         credit_card  Credit card refinancing    982xx         WA  18.92
# 3  debt_consolidation       Debt consolidation    352xx         AL  21.01
# 4  debt_consolidation       Debt consolidation    356xx         AL  36.67
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0         Oct-2007               0                     NaN
# 1            0         Jan-2002               0                    38.0
# 2            0         Feb-1999               0                    48.0
# 3            0         Aug-2011               1                    61.0
# 4            1         Oct-1993               1                    10.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         8        0       1070      17.5%         27
# 1                     NaN         9        0       5837      53.1%         15
# 2                     NaN         9        0      25416      29.9%         19
# 3                     NaN        24        0       6741      41.6%         30
# 4                     NaN        14        0      26630      53.3%         27
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   w    2770.45        2770.45   2956.610000
# 1                   w    5147.99        5147.99   7309.420000
# 2                   w       0.00           0.00  20215.792430
# 3                   w    3354.53        3354.53   4083.930000
# 4                   w       0.00           0.00  29563.763968
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          2956.61          2229.55         727.06                 0.0
# 1          7309.42          4852.01        2457.41                 0.0
# 2         20215.79         20000.00         215.79                 0.0
# 3          4083.93          3145.47         938.46                 0.0
# 4         29563.76         25000.00        4563.76                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 
ec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               1.0               9.0                76.4
# 2               3.0              10.0                29.7
# 3               NaN               NaN                 NaN
# 4               4.0              16.0                56.5
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  2.0                    7.0
# 2                  2.0                    7.0
# 3                  NaN                    NaN
# 4                  8.0                   12.0
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               0.0                                 0.0
# 2                               0.0                                 0.0
# 3                               NaN                                 NaN
# 4                               0.0                                 0.0
#
#    sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 0                                  NaN             N     CVD19SKIP
# 1                                  NaN             N           NaN
# 2                                  NaN             N           NaN
# 3                                  NaN             N           NaN
# 4                                 49.0             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0      INCOMECURT        COMPLETE            2.0              0.0
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0            Apr-2020          Jun-2020                May-2020
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              2.0           0.0               ACTIVE
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                        58.8                         3121.41
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                        164.43                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term  new_int_rate  \
# 0                NaN                    NaN              NaN         11.31
# 1                NaN                    NaN              NaN         18.94
# 2                NaN                    NaN              NaN          7.56
# 3                NaN                    NaN              NaN         11.80
# 4                NaN                    NaN              NaN         12.98
#
#   emp_title_cleaned emp_title_cleaned2 issue_d_new  issue_d_year  \
# 0          Shipping           Shipping  2018-12-01          2018
# 1     Especialist 1      Especialist 1  2018-12-01          2018
# 2           Teacher            Teacher  2018-12-01          2018
# 3          Educator           Educator  2018-12-01          2018
# 4      Tire Builder       Tire Builder  2018-12-01          2018
#
#    issue_d_month earliest_cr_line_new  days_from_earliest_credit_to_issue  \
# 0             12           2007-10-01                                4079
# 1             12           2002-01-01                                6178
# 2             12           1999-02-01                                7243
# 3             12           2011-08-01                                2679
# 4             12           1993-10-01                                9192
#
#    credit_hist_len  credit_hist_len_new
# 0        11.167693                 4079
# 1        16.914442                 6178
# 2        19.830253                 7243
# 3         7.334702                 2679
# 4        25.166324                 9192

# %% [markdown]
# What's oldest credit history that was involved in Q4 2018?

# %%
df['credit_hist_len'].describe()
# Out:
# count    128378.000000
# mean         16.043800
# std           7.903200
# min           3.082820
# 25%          11.085558
# 50%          14.417522
# 75%          19.832991
# max          68.914442
# Name: credit_hist_len, dtype: float64

# %% [markdown]
# 25,171 days is ~ 68.96 years of credit history!

# %% [markdown]
# ## Challenge
#
# Pandas' datetime format is so easy to work with that there's really no excuse for not using dates to make features on a dataframe! Get ready to practice more of this on your assignment.
