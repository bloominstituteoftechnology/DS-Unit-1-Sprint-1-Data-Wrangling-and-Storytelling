# %% [markdown]
# <a href="https://colab.research.google.com/github/rsmecking/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Ryan_Mecking_LS_DS12_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-15 14:54:47--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [             <=>    ]  21.72M  1.88MB/s    in 12s
#
# 2020-01-15 14:54:59 (1.88 MB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22776791]
#
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128399, 144)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                  60.01             24.0
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
pd.set_option('display.max_rows', 200)
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# max_bal_bc                                         2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# hardship_flag                                      2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
#This line of code excludes the first line of the table and the last two lines to elimate the NaNs.  We specified the engine to get rid of some info displayed above the table.
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
print(df.shape)
df.head()
# Out:
# (128397, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
#dropped all NaN valued columns 
df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0       6000         6000  ...                  60.01            24.0
# 1      24000        24000  ...                    NaN             NaN
# 2      30000        30000  ...                    NaN             NaN
# 3       8000         8000  ...                    NaN             NaN
# 4      22400        22400  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
#####Convert the term column from string to integer.#####
#Going to look at the column 'term'
df['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     36 months
# 3     36 months
# 4     60 months
# Name: term, dtype: object

# %%
#I need to elimanate the spacing in the front as well as the months after to have it read as an Integer.
term = '     36 months'
term.strip().strip(' months')
# Out:
# '36'

# %%
print(int(term.strip().strip(' months')))
type(int(term.strip().strip(' months')))
# Out:
# 36
# int

# %%
#Now that I know it works I need make it reusable. 
def term_to_int(cell_contents):
  return int(cell_contents.strip().strip(' months'))
term_to_int(term)
# Out:
# 36

# %%
#Now I need to apply the code to all the cells.
new_list = []
for cell in df['term']:
  new_list.append(term_to_int(cell))
new_list[0:10]
# Out:
# [36, 36, 36, 36, 60, 36, 60, 36, 36, 60]

# %%
#Now I will apply term_months into the table
df['term_months'] = pd.Series(new_list)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term term_months
# 0       6000         6000  ...             24.0          36
# 1      24000        24000  ...              NaN          36
# 2      30000        30000  ...              NaN          36
# 3       8000         8000  ...              NaN          36
# 4      22400        22400  ...              NaN          60
#
# [5 rows x 141 columns]

# %%
#making sure the new colmn is still an int.
df.dtypes[-2:]
# Out:
# settlement_term    float64
# term_months          int64
# dtype: object

# %%
#doing the same thing as above but with the .apply() function
df['term_months_from_apply'] = df['term'].apply(term_to_int)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  term_months term_months_from_apply
# 0       6000         6000  ...           36                     36
# 1      24000        24000  ...           36                     36
# 2      30000        30000  ...           36                     36
# 3       8000         8000  ...           36                     36
# 4      22400        22400  ...           60                     60
#
# [5 rows x 142 columns]

# %%
#####Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.#####
def loan_status_is_great(loan_status):
  if loan_status == "Current" or loan_status == "Fully Paid":
    return 1
  else:
    return 0

df['loan_status'] = df['loan_status'].apply(loan_status_is_great)
df.head()
#cant seem to grab the two variables 
df.loan_status
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 128392    0
# 128393    1
# 128394    1
# 128395    1
# 128396    1
# Name: loan_status, Length: 128397, dtype: int64

# %%
#####Make last_pymnt_d_month and last_pymnt_d_year columns.#####
print (df['last_pymnt_d'].iloc[0])
df['last_pymnt_d'].head(10)
#need to convert it so pandas can do the work for me.
# Out:
# Apr-2019
# 0    Apr-2019
# 1    Dec-2019
# 2    Feb-2019
# 3    Dec-2019
# 4    Dec-2019
# 5    Dec-2019
# 6    Dec-2019
# 7    Dec-2019
# 8    Dec-2019
# 9    Dec-2019
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)
df.dtypes[:45]
# Out:
# loan_amnt                           int64
# funded_amnt                         int64
# funded_amnt_inv                   float64
# term                               object
# int_rate                           object
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_title                          object
# emp_length                         object
# home_ownership                     object
# annual_inc                        float64
# verification_status                object
# issue_d                            object
# loan_status                         int64
# pymnt_plan                         object
# purpose                            object
# title                              object
# zip_code                           object
# addr_state                         object
# dti                               float64
# delinq_2yrs                         int64
# ...

# %%
df['last_pymnt_d'].iloc[0]
# Out:
# Timestamp('2019-04-01 00:00:00')

# %%
import math
x = float('NaN')
math.isnan(x)
True
#Trying to convert all NaN values into an int.
# Out:
# True

# %%
#now I'll create the new colemns splitting the approprate data.
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month

df.head()
#if I had more time I would convert the floats to int.
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_year last_pymnt_d_month
# 0       6000         6000  ...             2019.0                4.0
# 1      24000        24000  ...             2019.0               12.0
# 2      30000        30000  ...             2019.0                2.0
# 3       8000         8000  ...             2019.0               12.0
# 4      22400        22400  ...             2019.0               12.0
#
# [5 rows x 144 columns]

# %%
print (df['last_pymnt_d_year'].isnull().sum())
df['last_pymnt_d_month'].isnull().sum()
# Out:
# 159
# 159

# %%
df.dtypes[-2:]
# Out:
# last_pymnt_d_year     float64
# last_pymnt_d_month    float64
# dtype: object

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-01-15 14:55:47--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.92.29
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.92.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  46.0MB/s    in 4.6s
#
# 2020-01-15 14:55:52 (42.3 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_year last_pymnt_d_month
# 0       6000         6000  ...             2019.0                4.0
# 1      24000        24000  ...             2019.0               12.0
# 2      30000        30000  ...             2019.0                2.0
# 3       8000         8000  ...             2019.0               12.0
# 4      22400        22400  ...             2019.0               12.0
#
# [5 rows x 144 columns]

# %%
import pandas as pd

df = pd.read_csv('instacart_2017_05_01', engine='python')
print(df.shape)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-542a514c9d2f> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('instacart_2017_05_01', engine='python')
#       4 print(df.shape)
#       5 df.head(5)
#
# ...
