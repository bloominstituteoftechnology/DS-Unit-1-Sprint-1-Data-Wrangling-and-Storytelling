# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeOcean/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Jaime_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd

# %%
# Lets take a look at the Ames Iowa Housing Dataset :
source_url = 'https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv'

# %%
Iowa = pd.read_csv(source_url)

# %%
# first few rows
Iowa.sample(5)
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 132    133          20       RL  ...        WD         Normal    150750
# 1430  1431          60       RL  ...        WD         Normal    192140
# 4        5          60       RL  ...        WD         Normal    250000
# 1232  1233          90       RL  ...        WD         Normal    101800
# 899    900          20       RL  ...        WD         Normal    135000
#
# [5 rows x 81 columns]

# %%
# Shape
Iowa.shape
# Out:
# (1460, 81)

# %%
Iowa.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# describe 2
Iowa['YearBuilt'].describe()
# Out:
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
# describe 3
Iowa[['YearBuilt','MSSubClass']].describe()
# Out:
#          YearBuilt   MSSubClass
# count  1460.000000  1460.000000
# mean   1971.267808    56.897260
# std      30.202904    42.300571
# min    1872.000000    20.000000
# 25%    1954.000000    20.000000
# 50%    1973.000000    50.000000
# 75%    2000.000000    70.000000
# max    2010.000000   190.000000

# %%
# column types
# pd.set_option('display.max_rows',100)
Iowa.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# colum types 2
pd.set_option('display.max_rows',100)
Iowa.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# Heating           object
# HeatingQC         object
# CentralAir        object
# Electrical        object
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# dtype: object

# %%
# colum types 3
pd.set_option('display.max_rows', 100)
Iowa.dtypes[:5]
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
# dtype: object

# %%
# Look at the first ten rows of the 'BedroomAbvGr' column.
# Looks like integers to me:
Iowa['BedroomAbvGr'].dtype
# Out:
# dtype('int64')

# %%
# Another way to call columns: dot method
Iowa.Fireplaces.sample(4)
# Out:
# 1232    0
# 451     2
# 83      0
# 1390    0
# Name: Fireplaces, dtype: int64

# %%
# Another way to call columns: dot menthod 2 , bracket format
Iowa['Fireplaces'].sample(4)
# Out:
# 64      0
# 1289    1
# 902     1
# 950     0
# Name: Fireplaces, dtype: int64

# %%
# Cont... Two columns 3
Iowa[['Fireplaces','BedroomAbvGr']].sample(4)
# Out:
#       Fireplaces  BedroomAbvGr
# 118            2             5
# 469            0             3
# 1143           0             3
# 626            1             3

# %%
# Look at the first ten rows of the 'LotFrontage' column.
Iowa['LotFrontage'].head()
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# Name: LotFrontage, dtype: float64

# %%
# Cont... value
Iowa['LotFrontage'].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 110, dtype: int64

# %%
# Cont... missing value
Iowa['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
# Nan is the most common value in this column, What is a NaN -not a number-
import numpy as np
np.nan
# Out:
# nan

# %%
# What is the datatype of NaN?
type(np.nan)
# Out:
# float

# %%
# How much data missing
Iowa['LotFrontage'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: LotFrontage, Length: 1460, dtype: bool

# %%
# Cont... sum
Iowa['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
# How Big
Iowa.shape
# Out:
# (1460, 81)

# %%
# drop missing data
Iowa['LotFrontage'].dropna(inplace=True)

# %%
Iowa['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
# MAKING NEW FEATURES
# I can make smaller dataframe with a few specific column headers
# by passing a list of column headers inside of the square brackets
small=Iowa[['TotalBsmtSF','1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()
small.sample(3)
# Out:
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 360           888       912         0     156000
# 468          1626      1634         0     250000
# 1443          952       952         0     121000

# %%
# SYNTAX for creating new columns
# Lets add up all of the square footage to get a single square footage
# Column for the entire dataset
# Using bracket syntax to make a new 'TotalSquareFootage' column
small['TotalSF'] = small['TotalBsmtSF'] + small['1stFlrSF'] + small['2ndFlrSF']
small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
# Lets make another new column that is 'PricePerSqFt' by dividing the price by the square footage
small['PricePerSF'] = small['SalePrice'] / small['TotalSF']
small.sample(5)
# Out:
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSF
# 978           894       894         0     110000     1788   61.521253
# 1136         1032      1032       220     119000     2284   52.101576
# 4            1145      1145      1053     250000     3343   74.783129
# 449           649       679       504     120000     1832   65.502183
# 1413         1844      1844         0     257000     3688   69.685466

# %%
# Cont... In summary: SF price varies and House579 has more SF than House501 and is almost a third of the price

# %%
## Crosstabs
# Focus on categorical
Iowa.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# What are some categorical columns?
Iowa[['LotShape', 'Alley','Street','SaleCondition']].sample(5)
# Out:
#      LotShape Alley Street SaleCondition
# 724       IR1   NaN   Pave        Normal
# 802       Reg   NaN   Pave        Normal
# 1045      IR1   NaN   Pave        Normal
# 856       IR1   NaN   Pave        Normal
# 1250      Reg   NaN   Pave        Normal

# %%
# Values of the sale condition

Iowa['SaleCondition'].value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
# Create a new categorical condition (creating new variable)
Iowa['NormalCondition'] = np.where(Iowa['SaleCondition']== 'Normal', "yes", "no")
Iowa['NormalCondition'].value_counts()
# Out:
# yes    1198
# no      262
# Name: NormalCondition, dtype: int64

# %%
# Value counts of categorical variable
Iowa['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
# Map this from four down to 3 value
Iowa['LotShape3'] = Iowa['LotShape'].map({'Reg':'Regular',
                                          'IR1':'Irregular',
                                          'IR2':'Other',
                                          'IR3':'Other'})
Iowa['LotShape3'].value_counts()
# Out:
# Regular      925
# Irregular    484
# Other         51
# Name: LotShape3, dtype: int64

# %%
# Value counts of categorical variable
Iowa['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
# Third way using .loc
Iowa['top_neighbors']='All Others'
Iowa[['top_neighbors','Neighborhood']].head()
# Out:
#   top_neighbors Neighborhood
# 0    All Others      CollgCr
# 1    All Others      Veenker
# 2    All Others      CollgCr
# 3    All Others      Crawfor
# 4    All Others      NoRidge

# %%
# Step 2: remap just the ones I want: using.loc
Iowa.loc[Iowa['Neighborhood']=='NAmes', 'top_neighbors']=='North Ames'
Iowa[['top_neighbors','Neighborhood']].head()
# Out:
#   top_neighbors Neighborhood
# 0    All Others      CollgCr
# 1    All Others      Veenker
# 2    All Others      CollgCr
# 3    All Others      Crawfor
# 4    All Others      NoRidge

# %%
# Step 2: remap just the ones I want: using.loc
Iowa.loc[Iowa['Neighborhood']=='NAmes', 'top_neighbors']='North Ames'
Iowa[['top_neighbors','Neighborhood']].sample(10)
# Out:
#      top_neighbors Neighborhood
# 1430    All Others      Gilbert
# 728     North Ames        NAmes
# 123     All Others      SawyerW
# 310     All Others      Gilbert
# 790     All Others      Blmngtn
# 849     All Others      Veenker
# 27      All Others      NridgHt
# 451     All Others      ClearCr
# 683     All Others      CollgCr
# 84      All Others      Gilbert

# %%
# Do this multiple times if needed

# %%
Iowa.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'NormalCondition', 'LotShape3',
#        'top_neighbors'],
#       dtype='object')

# %%
Iowa['top_neighbors'].value_counts()
Iowa['top_neighbors']
# Out:
# 0       All Others
# 1       All Others
# 2       All Others
# 3       All Others
# 4       All Others
#            ...
# 1455    All Others
# 1456    All Others
# 1457    All Others
# 1458    North Ames
# 1459    All Others
# Name: top_neighbors, Length: 1460, dtype: object

# %%
# Step 2: remap just the ones I want: using.loc
Iowa.loc[Iowa['Neighborhood']=='CollgCr', 'top_neighbors']='College Circle'
Iowa[['top_neighbors','Neighborhood']].sample(10)
# Out:
#        top_neighbors Neighborhood
# 1005  College Circle      CollgCr
# 836       All Others      OldTown
# 375       All Others      Edwards
# 1031      All Others        SWISU
# 680       All Others      SawyerW
# 447       All Others      Gilbert
# 857       All Others      Gilbert
# 201       All Others      Mitchel
# 1178      All Others      Crawfor
# 776   College Circle      CollgCr

# %%
Iowa['top_neighbors'].value_counts()
# Out:
# All Others        1085
# North Ames         225
# College Circle     150
# Name: top_neighbors, dtype: int64

# %%
# Step 2: remap just the ones I want: using.loc
Iowa.loc[Iowa['Neighborhood']=='CollgCr', 'top_neighbors']='College Circle'
Iowa.loc[Iowa['Neighborhood']=='Gilbert', 'top_neighbors']='Favorite Neighborhood'
Iowa.loc[Iowa['Neighborhood']=='Somerst', 'top_neighbors']='Favorite Neighborhood'
Iowa[['top_neighbors','Neighborhood']].sample(10)
# Out:
#               top_neighbors Neighborhood
# 1374  Favorite Neighborhood      Somerst
# 528              All Others      Edwards
# 431              All Others      OldTown
# 326              All Others      Veenker
# 1303  Favorite Neighborhood      Somerst
# 145              All Others      Edwards
# 332              All Others      NridgHt
# 212   Favorite Neighborhood      Somerst
# 718              All Others      NoRidge
# 1310             All Others      Crawfor

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'])
# Out:
# LotShape3              Irregular  Other  Regular
# top_neighbors
# All Others                   294     23      603
# College Circle                53     11       86
# Favorite Neighborhood         71     15       79
# North Ames                    66      2      157

# %%
# Adding Margins

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'], margins=True)
# Out:
# LotShape3              Irregular  Other  Regular   All
# top_neighbors
# All Others                   294     23      603   920
# College Circle                53     11       86   150
# Favorite Neighborhood         71     15       79   165
# North Ames                    66      2      157   225
# All                          484     51      925  1460

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'], margins=True)
# Out:
# LotShape3              Irregular  Other  Regular   All
# top_neighbors
# All Others                   294     23      603   920
# College Circle                53     11       86   150
# Favorite Neighborhood         71     15       79   165
# North Ames                    66      2      157   225
# All                          484     51      925  1460

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'], margins=True)
# Out:
# LotShape3              Irregular  Other  Regular   All
# top_neighbors
# All Others                   294     23      603   920
# College Circle                53     11       86   150
# Favorite Neighborhood         71     15       79   165
# North Ames                    66      2      157   225
# All                          484     51      925  1460

# %%
# Proportions

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'], normalize='index')
# Out:
# LotShape3              Irregular     Other   Regular
# top_neighbors
# All Others              0.319565  0.025000  0.655435
# College Circle          0.353333  0.073333  0.573333
# Favorite Neighborhood   0.430303  0.090909  0.478788
# North Ames              0.293333  0.008889  0.697778

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'], normalize='index', margins=True)
# Out:
# LotShape3              Irregular     Other   Regular
# top_neighbors
# All Others              0.319565  0.025000  0.655435
# College Circle          0.353333  0.073333  0.573333
# Favorite Neighborhood   0.430303  0.090909  0.478788
# North Ames              0.293333  0.008889  0.697778
# All                     0.331507  0.034932  0.633562

# %%
# Crosstab
pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape3'], normalize='columns', margins=True)
# Out:
# LotShape3              Irregular     Other   Regular       All
# top_neighbors
# All Others              0.607438  0.450980  0.651892  0.630137
# College Circle          0.109504  0.215686  0.092973  0.102740
# Favorite Neighborhood   0.146694  0.294118  0.085405  0.113014
# North Ames              0.136364  0.039216  0.169730  0.154110

# %%
# Display
myresults = pd.crosstab(Iowa['top_neighbors'], Iowa['LotShape'])
myresults.plot(kind='bar');

# %%
pd.crosstab(Iowa['OverallQual'], Iowa['top_neighbors'])
# Out:
# top_neighbors  All Others  College Circle  Favorite Neighborhood  North Ames
# OverallQual
# 1                       2               0                      0           0
# 2                       3               0                      0           0
# 3                      17               0                      0           3
# 4                      94               1                      1          20
# 5                     253              28                      3         113
# 6                     232              24                     44          74
# 7                     159              71                     77          12
# 8                     108              23                     34           3
# 9                      35               3                      5           0
# 10                     17               0                      1           0

# %%
# Flip that
myresults.plot(kind='barh');

# %%
! wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-05-09 20:51:42--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 54.201.144.36, 44.225.46.60, 52.89.126.95
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|54.201.144.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [           <=>      ]  22.05M  1.93MB/s    in 12s
#
# 2020-05-09 20:51:54 (1.91 MB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [23121687]
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-54-34d7a31e2576> in <module>()
# ----> 1 get_ipython().system(' wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     353
#     354   hide_args = ['cell_remove_stdin', {}]
# --> 355   _message.blocking_request(*hide_args, parent=shell.parent_header)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: CustomError: Timed out waiting for output iframe load.

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# Read in the cvs
loans = pd.read_csv('LoanStats_2018Q4.csv')
loans.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# id  member_id loan_amnt funded_amnt funded_amnt_inv term       int_rate installment grade sub_grade emp_title             emp_length home_ownership annual_inc verification_status issue_d  loan_status pymnt_plan url desc purpose            title                   zip_code addr_state dti   delinq_2yrs earliest_cr_line inq_last_6mths mths_since_last_delinq mths_since_last_record open_acc pub_rec revol_bal revol_util total_acc initial_list_status out_prncp out_prncp_inv total_pymnt      total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt next_pymnt_d last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog policy_code application_type annual_inc_joint dti_joint verification_status_joint acc_now_delinq tot_coll_amt tot_cur_bal open_acc_6m open_act_il open_il_12m open_il_24m mths_since_rcnt_il total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m acc_open_past_24mths avg_cur_bal bc_open_to_buy bc_util chargeoff_within_12_mths delinq_amnt mo_sin_old_il_acct mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op mo_sin_rcnt_tl mort_acc mths_since_recent_bc mths_since_recent_bc_dlq mths_since_recent_inq mths_since_recent_revol_delinq num_accts_ever_120_pd num_actv_bc_tl num_actv_rev_tl num_bc_sats num_bc_tl num_il_tl num_op_rev_tl num_rev_accts num_rev_tl_bal_gt_0 num_sats num_tl_120dpd_2m num_tl_30dpd num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit total_il_high_credit_limit revol_bal_joint sec_app_earliest_cr_line sec_app_inq_last_6mths sec_app_mort_acc sec_app_open_acc sec_app_revol_util sec_app_open_act_il sec_app_num_rev_accts sec_app_chargeoff_within_12_mths sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog hardship_flag hardship_type hardship_reason hardship_status deferral_term hardship_amount hardship_start_date hardship_end_date payment_plan_start_date hardship_length hardship_dpd hardship_loan_status orig_projected_additional_accrued_interest hardship_payoff_balance_amount hardship_last_payment_amount debt_settlement_flag debt_settlement_flag_date settlement_status settlement_date settlement_amount settlement_percentage                                    settlement_term
# NaN NaN       10000     10000       10000            60 months  16.14%  243.93      C     C4        Sale Consultant       2 years    RENT           90000      Not Verified        Dec-2018 Fully Paid  n          NaN NaN  debt_consolidation Debt consolidation      079xx    NJ         8.8   0           Mar-1991         1              NaN                    43                     11       1       10582     58.5%      32        w                   0.00      0.00          10661.0577272374 10661.06        10000.00        661.06        0.0                0.0        0.0                     May-2019     9698.79         NaN          Dec-2019           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            15470       1           1           0           1           18                 4888         65      1           3           2969       60       18100            2      0           2            4                    1719        4906           67.3    0                        0           133                333                  2                     2              1        2                    NaN                      1                     NaN                            0                     4              6               5           15        6         8             23            6                   11       0                0            0                  1                  100            80               1                    0         25600           15470             15000          7500                       NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               6500      6500        6500             36 months  11.80%  215.28      B     B4        Educator              2 years    RENT           46500      Source Verified     Dec-2018 Current     n          NaN NaN  debt_consolidation Debt consolidation      352xx    AL         21.01 0           Aug-2011         1              61                     NaN                    24       0       6741      41.6%      30        w                   4066.26   4066.26       3222.81          3222.81         2433.74         789.07        0.0                0.0        0.0                     Mar-2020     215.28          Apr-2020     Apr-2020           0                          61                          1           Individual       NaN              NaN       NaN                       0              0            40223       4           12          2           2           5                  33482        97      7           12          3662       79       16200            2      0           4            14                   1749        7694           42.2    0                        0           88                 72                   1                     1              0        3                    NaN                      5                     61                             2                     6              10              6           6         14        11            16            10                  24       0                0            0                  9                  93.3           0                0                    0         50845           40223             13300          34645                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               4500      4500        4500             36 months  11.31%  147.99      B     B3        Accounts Examiner III 10+ years  RENT           38500      Not Verified        Dec-2018 Fully Paid  n          NaN NaN  credit_card        Credit card refinancing 786xx    TX         4.64  0           Dec-2003         0              25                     NaN                    12       0       4472      15.3%      25        w                   0.00      0.00          4549.2171485504  4549.22         4500.00         49.22         0.0                0.0        0.0                     Feb-2019     4553.46         NaN          Feb-2020           0                          25                          1           Individual       NaN              NaN       NaN                       0              306          29137       2           1           1           1           3                  24665        100     3           7           3612       54       29200            0      3           3            8                    2428        10735          28.9    0                        0           180                69                   2                     2              0        2                    NaN                      6                     NaN                            1                     3              5               5           6         10        11            15            5                   12       0                0            0                  4                  91.7           0                0                    0         53795           29137             15100          24595                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               25000     25000       25000            60 months  14.47%  587.82      C     C2        teacher               10+ years  OWN            110000     Not Verified        Dec-2018 Charged Off n          NaN NaN  credit_card        Credit card refinancing 117xx    NY         26.43 1           Jan-1997         0              7                      NaN                    23       0       39053     45.7%      49        w                   0.00      0.00          5848.05          5848.05         3024.11         2823.94       0.0                0.0        0.0                     Oct-2019     587.82          NaN          Apr-2020           0                          7                           1           Individual       NaN              NaN       NaN                       0              0            95648       0           3           0           0           35                 54716        23      1           2           8422       39       85500            0      1           0            2                    4159        34837          44.5    0                        0           263                246                  10                    10             0        48                   NaN                      NaN                   NaN                            0                     9              13              10          14        21        19            27            13                  23       0                0            1                  1                  98             10               0                    0         179321          95648             62800          91424                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN

# %%
loans = pd.read_csv('LoanStats_2018Q4.csv')
loans.tail()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# NaN                                              NaN 5000  5000  5000   36 months  13.56% 169.83 C   C1  Payoff Clerk         10+ years MORTGAGE 35360.0 Not Verified    Oct-2018 Current n   NaN NaN debt_consolidation Debt consolidation      381xx TN  11.3  1   Jun-2006 0   21.0 NaN 9   0   2597 27.3% 15  f   2751.79 2751.79 3053.17 3053.17 2248.21 804.96  0.0 0.0 0.0 Apr-2020 169.83 May-2020 Apr-2020 0   NaN  1   Individual NaN NaN NaN 0   1413 69785 0   2   0   1   16.0 2379    40.0  3   4   1826 32.0 9500  0   0   1   5   8723   1174.0  60.9 0   0   147.0 85  9   9   2   10.0  21.0 9.0 21.0 0   1   3   2   2   6   6   7   3   9   0.0 0   0   3   92.9 50.0 0   0   93908   4976  3000  6028.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN                                                NaN
#                                                      10000 10000 9750   36 months  11.06% 327.68 B   B3  NaN                  NaN       RENT     44400.0 Source Verified Oct-2018 Current n   NaN NaN credit_card        Credit card refinancing 980xx WA  11.78 0   Oct-2008 2   40.0 NaN 15  0   6269 13.1% 25  f   5411.74 5276.45 5882.88 5735.81 4588.26 1294.62 0.0 0.0 0.0 Apr-2020 327.68 May-2020 Apr-2020 0   53.0 1   Individual NaN NaN NaN 0   520  16440 3   1   1   1   2.0  10171   100.0 2   5   404  28.0 47700 0   3   5   6   1265.0 20037.0 2.3  0   0   61.0  119 1   1   0   1.0   NaN  1.0 40.0 1   2   4   6   8   3   14  22  4   15  0.0 0   0   3   92.0 0.0  0   0   57871.0 16440 20500 10171.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN                                                NaN
#                                                                  10000  36 months  16.91% 356.08 C   C5  Key Accounts Manager 2 years   RENT     80000.0 Not Verified    Oct-2018 Current n   NaN NaN other              Other                   021xx MA  17.72 1   Sep-2006 0   14.0 NaN 17  0   1942 30.8% 31  w   5626.39 5626.39 6400.05 6400.05 4373.61 2026.44 0.0 0.0 0.0 Apr-2020 356.08 May-2020 Apr-2020 0   25.0 1   Individual NaN NaN NaN 0   0    59194 0   15  1   1   12.0 57252.0 85.0  0   0   1942 80.0 6300  0   5   0   1   3482   2058.0  48.5 0   0   144.0 142 40  12  0   131.0 30.0 NaN 30.0 3   1   1   1   5   22  2   9   1   17  0.0 0   0   1   74.2 0.0  0   0   73669   59194 4000  67369   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN N   NaN NaN NaN NaN NaN                                                NaN
# Total amount funded in policy code 1: 2050909275 NaN NaN   NaN   NaN   NaN        NaN     NaN    NaN NaN NaN                  NaN       NaN      NaN     NaN             NaN      NaN     NaN NaN NaN NaN                NaN                     NaN   NaN NaN   NaN NaN      NaN NaN  NaN NaN NaN NaN  NaN   NaN NaN NaN     NaN     NaN     NaN     NaN     NaN     NaN NaN NaN NaN      NaN    NaN      NaN      NaN NaN  NaN NaN        NaN NaN NaN NaN NaN  NaN   NaN NaN NaN NaN NaN  NaN     NaN   NaN NaN NaN  NaN  NaN   NaN NaN NaN NaN NaN    NaN     NaN  NaN NaN NaN   NaN NaN NaN NaN NaN   NaN  NaN NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  NaN NaN NaN     NaN   NaN   NaN     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                                                NaN
# Total amount funded in policy code 2: 820109297  NaN NaN   NaN   NaN   NaN        NaN     NaN    NaN NaN NaN                  NaN       NaN      NaN     NaN             NaN      NaN     NaN NaN NaN NaN                NaN                     NaN   NaN NaN   NaN NaN      NaN NaN  NaN NaN NaN NaN  NaN   NaN NaN NaN     NaN     NaN     NaN     NaN     NaN     NaN NaN NaN NaN      NaN    NaN      NaN      NaN NaN  NaN NaN        NaN NaN NaN NaN NaN  NaN   NaN NaN NaN NaN NaN  NaN     NaN   NaN NaN NaN  NaN  NaN   NaN NaN NaN NaN NaN    NaN     NaN  NaN NaN NaN   NaN NaN NaN NaN NaN   NaN  NaN NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  NaN  NaN NaN NaN     NaN   NaN   NaN     NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                                                NaN

# %%
# we can fix header problem by using the 'skiprows' parameter
loans = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2)
loans.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
loans.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# 128410 NaN        NaN  ...                    NaN              NaN
# 128411 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
## NaN values
# Sum null values by column and sort from least to greatest
pd.set_option('display.max_rows', 100)
loans.isnull().sum()
# Out:
# id                       128412
# member_id                128412
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
#                           ...
# settlement_status        127661
# settlement_date          127661
# settlement_amount        127661
# settlement_percentage    127661
# settlement_term          127661
# Length: 144, dtype: int64

# %%
pd.set_option('display.max_rows', 1000)
loans.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128412
# member_id                                     128412
# url                                           128412
# desc                                          128412
# settlement_percentage                         127661
# settlement_term                               127661
# settlement_date                               127661
# debt_settlement_flag_date                     127661
# settlement_status                             127661
# settlement_amount                             127661
# sec_app_mths_since_last_major_derog           123258
# hardship_loan_status                          117705
# hardship_status                               117691
# hardship_reason                               117691
# hardship_dpd                                  117690
# hardship_length                               117690
# payment_plan_start_date                       117690
# hardship_end_date                             117690
# hardship_start_date                           117690
# deferral_term                                 117690
# hardship_type                                 117690
# orig_projected_additional_accrued_interest    114943
# hardship_last_payment_amount                  114919
# hardship_amount                               114919
# hardship_payoff_balance_amount                114919
# verification_status_joint                     113564
# mths_since_last_record                        112962
# sec_app_revol_util                            111888
# sec_app_collections_12_mths_ex_med            111630
# sec_app_num_rev_accts                         111630
# sec_app_open_act_il                           111630
# sec_app_open_acc                              111630
# sec_app_mort_acc                              111630
# sec_app_inq_last_6mths                        111630
# sec_app_earliest_cr_line                      111630
# revol_bal_joint                               111630
# dti_joint                                     111630
# annual_inc_joint                              111630
# sec_app_chargeoff_within_12_mths              111630
# mths_since_recent_bc_dlq                      103243
# mths_since_last_major_derog                    99232
# mths_since_recent_revol_delinq                 91630
# mths_since_last_delinq                         72196
# next_pymnt_d                                   36394
# emp_title                                      20947
# il_util                                        20274
# mths_since_recent_inq                          16047
# emp_length                                     11704
# mths_since_rcnt_il                              4478
# mo_sin_old_il_acct                              4478
# num_tl_120dpd_2m                                2859
# hardship_flag                                   2771
# bc_util                                         1754
# percent_bc_gt_75                                1692
# bc_open_to_buy                                  1691
# mths_since_recent_bc                            1591
# dti                                              237
# last_pymnt_d                                     159
# revol_util                                       156
# all_util                                          37
# avg_cur_bal                                       13
# last_credit_pull_d                                 1
# pub_rec                                            0
# revol_bal                                          0
# total_pymnt_inv                                    0
# total_acc                                          0
# initial_list_status                                0
# out_prncp                                          0
# out_prncp_inv                                      0
# total_pymnt                                        0
# total_rec_prncp                                    0
# total_rec_late_fee                                 0
# recoveries                                         0
# total_rec_int                                      0
# debt_settlement_flag                               0
# open_acc                                           0
# annual_inc                                         0
# loan_amnt                                          0
# funded_amnt                                        0
# funded_amnt_inv                                    0
# term                                               0
# int_rate                                           0
# installment                                        0
# grade                                              0
# sub_grade                                          0
# home_ownership                                     0
# verification_status                                0
# inq_last_6mths                                     0
# issue_d                                            0
# loan_status                                        0
# pymnt_plan                                         0
# purpose                                            0
# title                                              0
# zip_code                                           0
# addr_state                                         0
# delinq_2yrs                                        0
# earliest_cr_line                                   0
# collection_recovery_fee                            0
# max_bal_bc                                         0
# last_pymnt_amnt                                    0
# mort_acc                                           0
# num_actv_bc_tl                                     0
# num_actv_rev_tl                                    0
# num_bc_sats                                        0
# num_bc_tl                                          0
# num_il_tl                                          0
# num_op_rev_tl                                      0
# num_rev_accts                                      0
# num_rev_tl_bal_gt_0                                0
# num_sats                                           0
# num_tl_30dpd                                       0
# num_tl_90g_dpd_24m                                 0
# num_tl_op_past_12m                                 0
# pct_tl_nvr_dlq                                     0
# pub_rec_bankruptcies                               0
# tax_liens                                          0
# tot_hi_cred_lim                                    0
# total_bal_ex_mort                                  0
# total_bc_limit                                     0
# total_il_high_credit_limit                         0
# num_accts_ever_120_pd                              0
# mo_sin_rcnt_tl                                     0
# collections_12_mths_ex_med                         0
# mo_sin_rcnt_rev_tl_op                              0
# policy_code                                        0
# application_type                                   0
# acc_now_delinq                                     0
# tot_coll_amt                                       0
# tot_cur_bal                                        0
# open_acc_6m                                        0
# open_act_il                                        0
# open_il_12m                                        0
# open_il_24m                                        0
# total_bal_il                                       0
# open_rv_12m                                        0
# open_rv_24m                                        0
# total_rev_hi_lim                                   0
# total_cu_tl                                        0
# inq_last_12m                                       0
# acc_open_past_24mths                               0
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# mo_sin_old_rev_tl_op                               0
# inq_fi                                             0
# dtype: int64

# %%
loans.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# 128410 NaN        NaN  ...                    NaN              NaN
# 128411 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
loans.shape
# Out:
# (128412, 144)

# %%
pd.set_option('display.max_rows', 144)
loans.isnull().sum()
# Out:
# id                                            128412
# member_id                                     128412
# loan_amnt                                          0
# funded_amnt                                        0
# funded_amnt_inv                                    0
# term                                               0
# int_rate                                           0
# installment                                        0
# grade                                              0
# sub_grade                                          0
# emp_title                                      20947
# emp_length                                     11704
# home_ownership                                     0
# annual_inc                                         0
# verification_status                                0
# issue_d                                            0
# loan_status                                        0
# pymnt_plan                                         0
# url                                           128412
# desc                                          128412
# purpose                                            0
# title                                              0
# zip_code                                           0
# addr_state                                         0
# dti                                              237
# delinq_2yrs                                        0
# earliest_cr_line                                   0
# inq_last_6mths                                     0
# mths_since_last_delinq                         72196
# mths_since_last_record                        112962
# open_acc                                           0
# pub_rec                                            0
# revol_bal                                          0
# revol_util                                       156
# total_acc                                          0
# initial_list_status                                0
# out_prncp                                          0
# out_prncp_inv                                      0
# total_pymnt                                        0
# total_pymnt_inv                                    0
# total_rec_prncp                                    0
# total_rec_int                                      0
# total_rec_late_fee                                 0
# recoveries                                         0
# collection_recovery_fee                            0
# last_pymnt_d                                     159
# last_pymnt_amnt                                    0
# next_pymnt_d                                   36394
# last_credit_pull_d                                 1
# collections_12_mths_ex_med                         0
# mths_since_last_major_derog                    99232
# policy_code                                        0
# application_type                                   0
# annual_inc_joint                              111630
# dti_joint                                     111630
# verification_status_joint                     113564
# acc_now_delinq                                     0
# tot_coll_amt                                       0
# tot_cur_bal                                        0
# open_acc_6m                                        0
# open_act_il                                        0
# open_il_12m                                        0
# open_il_24m                                        0
# mths_since_rcnt_il                              4478
# total_bal_il                                       0
# il_util                                        20274
# open_rv_12m                                        0
# open_rv_24m                                        0
# max_bal_bc                                         0
# all_util                                          37
# total_rev_hi_lim                                   0
# inq_fi                                             0
# total_cu_tl                                        0
# inq_last_12m                                       0
# acc_open_past_24mths                               0
# avg_cur_bal                                       13
# bc_open_to_buy                                  1691
# bc_util                                         1754
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# mo_sin_old_il_acct                              4478
# mo_sin_old_rev_tl_op                               0
# mo_sin_rcnt_rev_tl_op                              0
# mo_sin_rcnt_tl                                     0
# mort_acc                                           0
# mths_since_recent_bc                            1591
# mths_since_recent_bc_dlq                      103243
# mths_since_recent_inq                          16047
# mths_since_recent_revol_delinq                 91630
# num_accts_ever_120_pd                              0
# num_actv_bc_tl                                     0
# num_actv_rev_tl                                    0
# num_bc_sats                                        0
# num_bc_tl                                          0
# num_il_tl                                          0
# num_op_rev_tl                                      0
# num_rev_accts                                      0
# num_rev_tl_bal_gt_0                                0
# num_sats                                           0
# num_tl_120dpd_2m                                2859
# num_tl_30dpd                                       0
# num_tl_90g_dpd_24m                                 0
# num_tl_op_past_12m                                 0
# pct_tl_nvr_dlq                                     0
# percent_bc_gt_75                                1692
# pub_rec_bankruptcies                               0
# tax_liens                                          0
# tot_hi_cred_lim                                    0
# total_bal_ex_mort                                  0
# total_bc_limit                                     0
# total_il_high_credit_limit                         0
# revol_bal_joint                               111630
# sec_app_earliest_cr_line                      111630
# sec_app_inq_last_6mths                        111630
# sec_app_mort_acc                              111630
# sec_app_open_acc                              111630
# sec_app_revol_util                            111888
# sec_app_open_act_il                           111630
# sec_app_num_rev_accts                         111630
# sec_app_chargeoff_within_12_mths              111630
# sec_app_collections_12_mths_ex_med            111630
# sec_app_mths_since_last_major_derog           123258
# hardship_flag                                   2771
# hardship_type                                 117690
# hardship_reason                               117691
# hardship_status                               117691
# deferral_term                                 117690
# hardship_amount                               114919
# hardship_start_date                           117690
# hardship_end_date                             117690
# payment_plan_start_date                       117690
# hardship_length                               117690
# hardship_dpd                                  117690
# hardship_loan_status                          117705
# orig_projected_additional_accrued_interest    114943
# hardship_payoff_balance_amount                114919
# hardship_last_payment_amount                  114919
# debt_settlement_flag                               0
# debt_settlement_flag_date                     127661
# settlement_status                             127661
# settlement_date                               127661
# settlement_amount                             127661
# settlement_percentage                         127661
# settlement_term                               127661
# dtype: int64

# %%
# Drop an entire column
loans.drop('url',axis=1, inplace=True)

# %%
loans.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# 128410 NaN        NaN  ...                    NaN              NaN
# 128411 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 143 columns]

# %%
loans.shape
# Out:
# (128412, 143)

# %%
# Look at the first 10 values of the int_rate column
loans['int_rate'].head(10)
# Out:
# 0     16.14%
# 1     11.80%
# 2     11.31%
# 3     14.47%
# 4     27.27%
# 5     16.14%
# 6     12.98%
# 7     12.98%
# 8     10.33%
# 9     23.40%
# Name: int_rate, dtype: object

# %%
loans['int_rate'][3]
# Out:
# ' 14.47%'

# %%
# confirm that
loans['int_rate'].dtype
# Out:
# dtype('O')

# %%
# Confirm again
type(loans['int_rate'][3])
# Out:
# str

# %%
# String problem that should be numeric
# Percent sign % included with the number
# Leading space at the beginning of the string

# %%
# Fixing single string -if we can fix one, usually we can fix all of them
int_rate = ' 14.47%'

# %%
# remove leading space - python -
int_rate.strip()
# Out:
# '14.47%'

# %%
# remove the percent
int_rate.strip('%')
# Out:
# ' 14.47'

# %%
# remove both
int_rate.strip().strip('%')
# Out:
# '14.47'

# %%
# "Cast" the string value to a float
float('14.47')
# Out:
# 14.47

# %%
# put all together
float(int_rate.strip().strip('%'))
# Out:
# 14.47

# %%
# check your work
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
# write a function that can do what we have written above to any string that is passed to it.
def myfunc(my_input_value):
    return float(my_input_value.strip().strip('%'))

# %%
# testt out our function by calling it on our examples
myfunc(int_rate)
# Out:
# 14.47

# %%
# is the data type correct?
type (myfunc(int_rate))
# Out:
# float

# %%
## Apply our solution to every cell in a column
# for loop:
new_list=[]
for cell in loans['int_rate']:
  new_list.append(myfunc(cell))
# look at first 10 values of that list:
new_list[:10]
# compare to original value
loans['int_rate'].head()
list(loans['int_rate'][:10])
# convert that list to a new column (not a list:)
loans['int_rate_clean']=pd.Series(new_list)
# comparision
loans[['int_rate','int_rate_clean']].sample(7)
# convert that list to a new column (not a list:)
loans['int_rate_clean'].dtype
# what type of data is held in our new column?
# Out:
# dtype('float64')

# %%
### THERE IS A BETTER WAY
## Improve all of this code with the .apply function:
loans['int_rate_clean2'] = loans['int_rate'].apply(myfunc)

# %%
#  COMPARISON
loans[['int_rate','int_rate_clean','int_rate_clean2']].sample(7)
# Out:
#        int_rate  int_rate_clean  int_rate_clean2
# 8302      8.81%            8.81             8.81
# 52974    11.80%           11.80            11.80
# 88158    19.92%           19.92            19.92
# 23057    11.80%           11.80            11.80
# 50914     6.46%            6.46             6.46
# 110974   10.08%           10.08            10.08
# 7073      7.02%            7.02             7.02

# %%
# .apply()
# First we will try and diagnose how bad the problem is and what improvements we might able to make
# look at the top 20 rows
loans['emp_title'].head(20)
# Out:
# 0                          Sale Consultant
# 1                                Educator
# 2                    Accounts Examiner III
# 3                                  teacher
# 4                           Claims Analyst
# 5                         Training Manager
# 6                             Tire builder
# 7               Program Support Assistant
# 8                                   Driver
# 9                                   BANKER
# 10                        Business Analyst
# 11                                OPERATOR
# 12                        Shift Supervisor
# 13                                 Driver
# 14    Assistant to the Treasurer (Payroll)
# 15               Reimbursement specialist
# 16                       Financial Advisor
# 17                                Engineer
# 18                   Sales Account Manager
# 19                                     Cna
# Name: emp_title, dtype: object

# %%
# look at the top 20 employment titles
loans['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
loans['emp_title'].unique()
# Out:
# array(['Sale Consultant', 'Educator ', 'Accounts Examiner III', ...,
#        'Oncology Medical Assistant', 'Tax Consultant', 'Payoff Clerk'],
#       dtype=object)

# %%
len(loans['emp_title'].unique())
# Out:
# 43893

# %%
print(loans.shape)
# Out:
# (128412, 145)

# %%
# Another say to do this
loans['emp_title'].nunique()
# Out:
# 43892

# %%
# How often is the employment_title null?
loans['emp_title'].isnull().sum()
# Out:
# 20947

# %%
# Create some examples that represent the cases that we want to clean up
examples = ['owner','Supervisor',' Project Manager', np.nan]

# %%
# do that same function in individual steps
type('Supervisor')
# Out:
# str

# %%
isinstance('Supervisor', str)
# Out:
# True

# %%
# what about the strip
'supervisor'.title().strip()
# Out:
# 'Supervisor'

# %%
# write a function to clean up these use cases and increase uniformity.
def clean_title(jobtitle):
  if isinstance(jobtitle, str):
   return (jobtitle.title().strip())
  else:
   return 'Unknown'

# %%
# test our function
clean_title('superviSOR')
clean_title(np.nan)
# Out:
# 'Unknown'

# %%
# create a for loop:
mylist = []
for jobtitle in examples:
  mylist.append(clean_title(jobtitle))
  mylist

# %%
#list comprehensions can combine function calls and for loops over lists
# into one succint and fairly readable single line of code.
[clean_title(jobtitle) for jobtitle in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
# we have a function that works as expected. Lets apply it to our column.
# This time we will overwrite the original column
loans['clean_title'] = loans['emp_title'].apply(clean_title)

# %%
loans[['emp_title','clean_title']].head()
# Out:
#                emp_title            clean_title
# 0        Sale Consultant        Sale Consultant
# 1              Educator                Educator
# 2  Accounts Examiner III  Accounts Examiner Iii
# 3                teacher                Teacher
# 4         Claims Analyst         Claims Analyst

# %%
loans[['emp_title','clean_title']].sample(20)
# Out:
#                               emp_title                      clean_title
# 108535                              NaN                          Unknown
# 109849      Childrens Ministry Director      Childrens Ministry Director
# 46714   Background Clearance Compliance  Background Clearance Compliance
# 100361                 Sales Consultant                 Sales Consultant
# 77516                  Leave Consultant                 Leave Consultant
# 125166                        HVAC Tech                        Hvac Tech
# 27679                          Mechanic                         Mechanic
# 107081       SURVEILLANCE SHIFT MANAGER       Surveillance Shift Manager
# 89165                                RN                               Rn
# 109668                     Electrician                       Electrician
# 106968                              NaN                          Unknown
# 32254                        Estimator                         Estimator
# 106492                     Group Leader                     Group Leader
# 47258                  Registered Nurse                 Registered Nurse
# 67570                     Oven Operator                    Oven Operator
# 27671                        Warehouse                         Warehouse
# 74799                        Supervisor                       Supervisor
# 21031                         Operator                          Operator
# 2801                  Manager/Analytics                Manager/Analytics
# 48675                Physical Therapist               Physical Therapist

# %%
# look at the top 20 employment titles
loans.head()
# Out:
#    id  member_id  ...  int_rate_clean2            clean_title
# 0 NaN        NaN  ...            16.14        Sale Consultant
# 1 NaN        NaN  ...            11.80               Educator
# 2 NaN        NaN  ...            11.31  Accounts Examiner Iii
# 3 NaN        NaN  ...            14.47                Teacher
# 4 NaN        NaN  ...            27.27         Claims Analyst
#
# [5 rows x 146 columns]

# %%
loans.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'debt_settlement_flag', 'debt_settlement_flag_date',
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'int_rate_clean',
#        'int_rate_clean2', 'clean_title'],
#       dtype='object', length=146)

# %%
loans['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
# as a for loop
mylist = []
for col in loans.columns:
  if col.endswith('_d'):
    mylist.append(col)

# %%
# as a list comprehension
my_date_cols = [col for col in loans.columns if col.endswith('_d')]
my_date_cols
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
# dtype
type(loans['issue_d'][0])
# Out:
# str

# %%
loans.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'int_rate_clean',
#        'int_rate_clean2', 'clean_title', 'new_issue-d', 'new_issue_d'],
#       dtype='object', length=148)

# %%
#infer_datetime_format=True
loans['new_issue_d'] = pd.to_datetime(loans['issue_d'], infer_datetime_format=True)

# %%
loans[['issue_d', 'new_issue_d']].head()
# Out:
#     issue_d new_issue_d
# 0  Dec-2018  2018-12-01
# 1  Dec-2018  2018-12-01
# 2  Dec-2018  2018-12-01
# 3  Dec-2018  2018-12-01
# 4  Dec-2018  2018-12-01

# %%
loans['new_issue_d']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-01
# 3        2018-12-01
# 4        2018-12-01
#             ...
# 128407   2018-10-01
# 128408   2018-10-01
# 128409   2018-10-01
# 128410   2018-10-01
# 128411   2018-10-01
# Name: new_issue_d, Length: 128412, dtype: datetime64[ns]

# %%
#check our work
type(loans['new_issue_d'][3])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
loans['new_issue_d'].dtype
# Out:
# dtype('<M8[ns]')

# %%
print(loans['new_issue_d'].dtype)
# Out:
# datetime64[ns]

# %%
loans['new_issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# create new feature/variable
loans['year'] = loans['new_issue_d'].dt.year
loans[['issue_d','new_issue_d','year']].head()
# Out:
#     issue_d new_issue_d  year
# 0  Dec-2018  2018-12-01  2018
# 1  Dec-2018  2018-12-01  2018
# 2  Dec-2018  2018-12-01  2018
# 3  Dec-2018  2018-12-01  2018
# 4  Dec-2018  2018-12-01  2018

# %%
# now month

# %%
# create new feature/variable
loans['month'] = loans['new_issue_d'].dt.year
loans[['issue_d','new_issue_d','month']].head()
# Out:
#     issue_d new_issue_d  month
# 0  Dec-2018  2018-12-01   2018
# 1  Dec-2018  2018-12-01   2018
# 2  Dec-2018  2018-12-01   2018
# 3  Dec-2018  2018-12-01   2018
# 4  Dec-2018  2018-12-01   2018

# %%
# create new feature/variable
loans['weekday'] = loans['new_issue_d'].dt.year
loans[['issue_d','new_issue_d','year','month','weekday']].head()
# Out:
#     issue_d new_issue_d  year  month  weekday
# 0  Dec-2018  2018-12-01  2018   2018     2018
# 1  Dec-2018  2018-12-01  2018   2018     2018
# 2  Dec-2018  2018-12-01  2018   2018     2018
# 3  Dec-2018  2018-12-01  2018   2018     2018
# 4  Dec-2018  2018-12-01  2018   2018     2018

# %%
# same... sample(10)

# %%
# try different variable
loans['new_pull'] = pd.to_datetime(loans['last_credit_pull_d'])
loans['month_pull'] = loans['new_issue_d'].dt.year
loans[['last_credit_pull_d','new_pull','month_pull']].head()
# Out:
#   last_credit_pull_d   new_pull  month_pull
# 0           Dec-2019 2019-12-01        2018
# 1           Apr-2020 2020-04-01        2018
# 2           Feb-2020 2020-02-01        2018
# 3           Apr-2020 2020-04-01        2018
# 4           Apr-2020 2020-04-01        2018

# %%
#date arithmetic
loans['day_diff'] = loans['new_issue_d'] - loans['new_pull']

# %%
loans.head(3)
# Out:
#    id  member_id  loan_amnt  ...  month_pul  month_pull  day_diff
# 0 NaN        NaN      10000  ...       2018        2018 -365 days
# 1 NaN        NaN       6500  ...       2018        2018 -487 days
# 2 NaN        NaN       4500  ...       2018        2018 -427 days
#
# [3 rows x 155 columns]

# %%
loans.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'clean_title', 'new_issue-d', 'new_issue_d', 'year', 'month', 'weekday',
#        'new_pull', 'month_pul', 'month_pull', 'day_diff'],
#       dtype='object', length=155)

# %%
loans[['clean_title','year']].iloc[9999]
# Out:
# clean_title    Unknown
# year              2018
# Name: 9999, dtype: object

# %% [markdown]
# # Jaime
# ## Jaime
# https://youtu.be/YYXdXT2l-Gg?t=488
#
# [python tutorial](https://youtu.be/YYXdXT2l-Gg?t=488)

# %%
loans.clean_title
# Out:
# 0               Sale Consultant
# 1                      Educator
# 2         Accounts Examiner Iii
# 3                       Teacher
# 4                Claims Analyst
#                   ...
# 128407           Tax Consultant
# 128408           Security Guard
# 128409             Payoff Clerk
# 128410                  Unknown
# 128411     Key Accounts Manager
# Name: clean_title, Length: 128412, dtype: object

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
