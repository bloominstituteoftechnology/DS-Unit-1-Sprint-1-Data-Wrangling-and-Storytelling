# %% [markdown]
# <a href="https://colab.research.google.com/github/Cal-0/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Copy_of_LS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-10-29 19:27:43--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [             <=>    ]  21.62M   412KB/s    in 56s
#
# 2019-10-29 19:28:46 (395 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22667400]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
import pandas as pd
import numpy as np

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4122.15","4122.15","2081.76","2081.76","1477.85","603.91","0.0","0.0","0.0","Sep-2019","190.21","Oct-2019","Sep-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 100

# %%
df = pd.read_csv('LoanStats_2018Q4.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,123,124,125,126,127,128,129,130,131,132,133,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header = 1, skipfooter = 2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df.shape
# Out:
# (128412, 144)

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      25000        25000          25000.0   60 months
# 2 NaN        NaN      26500        26500          26500.0   60 months
# 3 NaN        NaN      10400        10400          10400.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   60 months
#
#   int_rate  installment grade sub_grade                         emp_title  \
# 0   14.47%       688.13     C        C2                        bus driver
# 1   16.14%       609.82     C        C4                Production Manager
# 2   11.31%       580.28     B        B3               Compliance Director
# 3   12.98%       350.32     B        B5        Program Support Assistant
# 4   12.98%       796.00     B        B5  Sr. Vice President -Risk Manager
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
df.dtypes
# Out:
# id                                            float64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df1 = df.drop(['member_id','url','desc', 'id'], axis = 1)

# %%
df1.head(1)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
#
#   grade sub_grade   emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2  bus driver    4 years            OWN     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan             purpose  \
# 0     Source Verified  Dec-2018     Current          n  debt_consolidation
#
#                 title zip_code addr_state    dti  delinq_2yrs  \
# 0  Debt consolidation    681xx         NE  30.65            1
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Jun-1979               2                    15.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         6        0      15048        73%         22
#
#   initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# ...

# %%
df['int_rate']
# Out:
# 0          14.47%
# 1          16.14%
# 2          11.31%
# 3          12.98%
# 4          12.98%
#            ...
# 128407     15.02%
# 128408     15.02%
# 128409     13.56%
# 128410     11.06%
# 128411     16.91%
# Name: int_rate, Length: 128412, dtype: object

# %%
df['int_rate'][:10].iloc[0]
#Are loc and iloc the same because the axis is 1?
# Out:
# ' 14.47%'

# %%
int_rate = ' 14.47%'

# %%
int_rate.strip().strip('%')
# Out:
# '14.47'

# %%
print (int_rate)
type(int_rate)
# Out:
#  14.47%
# str

# %%
int_rate_float = int_rate.strip().strip('%')

# %%
print (int_rate_float)
type (int_rate_float)
# Out:
# 14.47
# str

# %%
type(float(int_rate_float))
# Out:
# float

# %%
def int_rate_to_float (int_rate_string):
  return float(int_rate_string.strip().strip('%'))

# %%
df1 ['int_rate'].apply(int_rate_to_float)
# Out:
# 0         14.47
# 1         16.14
# 2         11.31
# 3         12.98
# 4         12.98
#           ...
# 128407    15.02
# 128408    15.02
# 128409    13.56
# 128410    11.06
# 128411    16.91
# Name: int_rate, Length: 128412, dtype: float64

# %%
df1['int_rate'] = df['int_rate'].apply(int_rate_to_float)

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        bus driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5        Program Support Assistant   10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df['emp_title'][:10]
# Out:
# 0                                  bus driver
# 1                          Production Manager
# 2                         Compliance Director
# 3                  Program Support Assistant
# 4            Sr. Vice President -Risk Manager
# 5                                     Teacher
# 6                        Help Tech Supervisor
# 7    Assistant Athletic Director of Marketing
# 8                      Transportation Manager
# 9                                  Pharmacist
# Name: emp_title, dtype: object

# %%
df["emp_title"][:10].iloc[0]
# Out:
# 'bus driver'

# %%
df['emp_title'].value_counts(dropna=False)[:15]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Name: emp_title, dtype: int64

# %%
len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
def clean_title (title):
  if isinstance (title,str):
    return title.strip().title()
  else:
    return "Unknown"

# %%
[clean_title(item) for item in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df1['emp_title'] = df['emp_title'].apply(clean_title)

# %%
df1['emp_title']
# Out:
# 0                               Bus Driver
# 1                       Production Manager
# 2                      Compliance Director
# 3                Program Support Assistant
# 4         Sr. Vice President -Risk Manager
#                         ...
# 128407                      Tax Consultant
# 128408                      Security Guard
# 128409                        Payoff Clerk
# 128410                             Unknown
# 128411                Key Accounts Manager
# Name: emp_title, Length: 128412, dtype: object

# %%
df1['emp_title_manager'] = df1['emp_title'].str.contains('Manager')

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        Bus Driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5         Program Support Assistant  10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
condition = (df1['emp_title_manager'] ==True)
condition
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 128407    False
# 128408    False
# 128409    False
# 128410    False
# 128411     True
# Name: emp_title_manager, Length: 128412, dtype: bool

# %%
managers = df1[condition]

# %%
managers.head()
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 1       25000        25000          25000.0   60 months     16.14
# 4       35000        35000          35000.0   60 months     12.98
# 8       12000        12000          12000.0   36 months     11.80
# 16      12000        12000          12000.0   36 months     16.14
# 18      20400        20400          20400.0   60 months     10.33
#
#     installment grade sub_grade                         emp_title emp_length  \
# 1        609.82     C        C4                Production Manager    5 years
# 4        796.00     B        B5  Sr. Vice President -Risk Manager    7 years
# 8        397.43     B        B4            Transportation Manager  10+ years
# 16       422.72     C        C4             Sales Account Manager    4 years
# 18       436.76     B        B1                    Bakery Manager  10+ years
#
#    home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
non_managers = df1[~condition]
non_managers.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 5      20000        20000          20000.0   36 months      7.56       622.68
# 6      13000        13000          13000.0   36 months     17.97       469.79
#
#   grade sub_grade                  emp_title emp_length home_ownership  \
# 0     C        C2                 Bus Driver    4 years            OWN
# 2     B        B3        Compliance Director  10+ years       MORTGAGE
# 3     B        B5  Program Support Assistant  10+ years       MORTGAGE
# 5     A        A3                    Teacher  10+ years       MORTGAGE
# 6     D        D1       Help Tech Supervisor  10+ years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
import seaborn as sns

# %%
sns.distplot(non_managers['int_rate'])
sns.distplot(managers['int_rate'])

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df1['issue_d']
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
#             ...
# 128407    Oct-2018
# 128408    Oct-2018
# 128409    Oct-2018
# 128410    Oct-2018
# 128411    Oct-2018
# Name: issue_d, Length: 128412, dtype: object

# %%
df1['issue_d'] = pd.to_datetime(df1['issue_d'], infer_datetime_format=True)

# %%
df1.dtypes
# Out:
# loan_amnt                                              int64
# funded_amnt                                            int64
# funded_amnt_inv                                      float64
# term                                                  object
# int_rate                                             float64
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# issue_d                                       datetime64[ns]
# loan_status                                           object
# ...

# %%
df1['issue_d'].iloc[0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df1['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
df1['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df1['issue_year'] = df1['issue_d'].dt.year
df1['issue_month'] = df1['issue_d'].dt.month

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      25000        25000          25000.0   60 months     16.14       609.82
# 2      26500        26500          26500.0   60 months     11.31       580.28
# 3      10400        10400          10400.0   36 months     12.98       350.32
# 4      35000        35000          35000.0   60 months     12.98       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        Bus Driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5         Program Support Assistant  10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df1['earliest_cr_line'].head()
# Out:
# 0    Jun-1979
# 1    Sep-2003
# 2    Dec-2006
# 3    Jul-2013
# 4    Sep-1985
# Name: earliest_cr_line, dtype: object

# %%
df1['earliest_cr_line'] = pd.to_datetime(df1['earliest_cr_line'], infer_datetime_format=True)

# %% [markdown]
# # **Part 2**

# %%
df['term'].head()
# Out:
# 0     36 months
# 1     60 months
# 2     60 months
# 3     36 months
# 4     60 months
# Name: term, dtype: object

# %%
df['term'].iloc[0]
# Out:
# ' 36 months'

# %%
def term_to_date(term_str):
  return int(term_str.strip().strip(' months'))

# %%
df1['term'] = df['term'].apply(term_to_date)

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      20000        20000          20000.0    36     14.47       688.13     C
# 1      25000        25000          25000.0    60     16.14       609.82     C
# 2      26500        26500          26500.0    60     11.31       580.28     B
# 3      10400        10400          10400.0    36     12.98       350.32     B
# 4      35000        35000          35000.0    60     12.98       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        Bus Driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5         Program Support Assistant  10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df['loan_status'].head(40)
# Out:
# 0         Current
# 1      Fully Paid
# 2         Current
# 3         Current
# 4      Fully Paid
# 5      Fully Paid
# 6         Current
# 7      Fully Paid
# 8         Current
# 9         Current
# 10     Fully Paid
# 11     Fully Paid
# 12        Current
# 13        Current
# 14        Current
# 15        Current
# 16        Current
# 17        Current
# 18     Fully Paid
# 19        Current
# 20        Current
# 21        Current
# 22        Current
# 23        Current
# 24        Current
# 25        Current
# 26     Fully Paid
# 27        Current
# 28        Current
# 29        Current
# 30        Current
# 31    Charged Off
# 32        Current
# 33     Fully Paid
# 34     Fully Paid
# 35        Current
# 36     Fully Paid
# 37     Fully Paid
# 38        Current
# 39        Current
# Name: loan_status, dtype: object

# %%
def loan_simple(loan_str):
  if loan_str ==('Current' or 'Fully Paid'):
    return 1
  else:
        return 0

# %%
df1['loan_status_is_great'].isnull().sum()
# Out:
# 0

# %%
df1['loan_status_is_great'] = df['loan_status'].apply(loan_simple)

# %%
df1['loan_status_is_great'].value_counts()
# Out:
# 1    105925
# 0     22487
# Name: loan_status_is_great, dtype: int64

# %%
df['last_pymnt_d'].head()
# Out:
# 0    Sep-2019
# 1    Apr-2019
# 2    Sep-2019
# 3    Sep-2019
# 4    Apr-2019
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d'].isnull().sum()
# Out:
# 159

# %%
df['last_pymnt_d'].isnull().head().iloc[0]
# Out:
# False

# %%
df1['last_pymnt_d'] = df['last_pymnt_d'].replace(False, )

# %%
df1['last_pymnt_d'].isnull().head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: last_pymnt_d, dtype: bool

# %%
def get_rid_nan(nan_values):
  if nan_values == False:
    return 0

# %%
df1['last_pymnt_d'] = df['last_pymnt_d'].apply(get_rid_nan)

# %%
df1['last_pymnt_d'] = df1['last_pymnt_d'].dt.year
df1['last_pymnt_d'] = df1['last_pymnt_d'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-261-4e5fa0f91df1> in <module>()
# ----> 1 df1['last_pymnt_d'] = df1['last_pymnt_d'].dt.year
#       2 df1['last_pymnt_d'] = df1['last_pymnt_d'].dt.month
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
