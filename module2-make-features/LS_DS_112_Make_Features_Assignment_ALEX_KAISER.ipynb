# %% [markdown]
# <a href="https://colab.research.google.com/github/Lord-Kanzler/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/LS_DS_112_Make_Features_Assignment_ALEX_KAISER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

# %%
#Load Iowa housing data
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_rows', 150)
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
#BedroomAbvGr 
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
# LotFrontage 
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
#MSZoning
df['MSZoning']
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
#Numpy and NAN
import numpy as np
type(np.NaN)
# Out:
# float

# %%
#New Features
df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
#Column TotalSF
df_small['TotalSF'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF'] 
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF
# 0          856       856       854     208500     2566
# 1         1262      1262         0     181500     2524
# 2          920       920       866     223500     2706
# 3          756       961       756     140000     2473
# 4         1145      1145      1053     250000     3343

# %%
#Column PricePerSqFt
df_small['PricePerSqFt'] = df_small['SalePrice'] / df_small['TotalSF']
df_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSF  PricePerSqFt
# 0          856       856       854     208500     2566     81.254871
# 1         1262      1262         0     181500     2524     71.909667
# 2          920       920       866     223500     2706     82.594235
# 3          756       961       756     140000     2473     56.611403
# 4         1145      1145      1053     250000     3343     74.783129

# %%
###############################################################################################################################################################################

# %%
###Work with Strings with Pandas

# %%
#Loading and unzipping
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-02-11 20:40:06--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [      <=>           ]  21.74M   701KB/s    in 34s
#
# 2020-02-11 20:40:41 (663 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22793561]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3537.82","3537.82","2842.6","2842.60","2062.18","780.42","0.0","0.0","0.0","Jan-2020","190.21","Feb-2020","Jan-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
pd.set_option('display.max_rows', 150)

# %%
# Read in the CSV
df = pd.read_csv('LoanStats_2018Q4.csv')
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128415, 1)
# ...

# %%
# removing first row with skiprow
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
#Sum null values and sort
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# max_bal_bc                                         2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# hardship_flag                                      2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
#Remove footer and extra NaN
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# (128412, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# loan_amnt                                          0
# mo_sin_rcnt_rev_tl_op                              0
# mo_sin_old_rev_tl_op                               0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# total_cu_tl                                        0
# inq_fi                                             0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# open_il_12m                                        0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# ...

# %%
#dropping NaN columns
df = df.drop(['url', 'member_id', 'desc', 'id'])

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      35000        35000  ...                    NaN             NaN
# 1       5000         5000  ...                    NaN             NaN
# 2      10000        10000  ...                    NaN             NaN
# 3      17100        17100  ...                    NaN             NaN
# 4       4000         4000  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
#Clean up int_rate

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
df['int_rate'][:10]
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
df['int_rate'].describe()
# Out:
# count      128412
# unique         46
# top        13.56%
# freq         6972
# Name: int_rate, dtype: object

# %%
#fixing column values with .strip()
int_rate = ' 13.56%'

# %%
int_rate.strip()
# Out:
# '13.56%'

# %%
int_rate.strip("%")
# Out:
# ' 13.56'

# %%
float("8.5")
# Out:
# 8.5

# %%
float(int_rate.strip().strip('%'))
# Out:
# 13.56

# %%
float(df['int_rate'][0].strip().strip('%'))
# Out:
# 14.47

# %%
float(df['int_rate'][1].strip().strip('%'))
# Out:
# 22.35

# %%
#for loop for column
new_int_rate = []

for cell in df['int_rate']:
  new_int_rate.append(float(cell.strip().strip('%')))
new_int_rate
# Out:
# [14.47,
#  22.35,
#  23.4,
#  18.94,
#  10.72,
#  11.31,
#  11.31,
#  11.8,
#  11.8,
#  18.94,
#  16.91,
#  14.47,
#  11.8,
#  23.4,
#  17.97,
#  11.8,
#  19.92,
#  17.97,
#  26.31,
#  14.47,
#  23.4,
#  23.4,
#  20.89,
#  26.31,
#  14.47,
#  14.47,
#  16.14,
#  16.14,
#  12.98,
#  10.72,
#  23.4,
#  19.92,
#  10.33,
#  15.02,
#  17.97,
#  18.94,
#  11.31,
#  14.47,
#  17.97,
#  16.14,
#  16.14,
#  17.97,
#  12.98,
#  23.4,
#  6.46,
#  10.33,
#  14.47,
#  10.33,
#  27.27,
#  16.91,
#  15.02,
#  12.98,
#  14.47,
#  17.97,
#  16.14,
#  18.94,
#  11.31,
#  7.56,
#  12.98,
#  10.72,
#  14.47,
#  13.56,
#  13.56,
#  14.47,
#  12.98,
#  27.27,
#  16.14,
#  16.14,
#  11.31,
#  11.8,
#  7.56,
#  10.72,
#  11.8,
#  17.97,
#  11.31,
#  8.19,
#  16.91,
#  14.47,
#  11.31,
#  17.97,
#  8.19,
#  20.89,
#  27.27,
#  15.02,
#  17.97,
#  8.81,
#  14.47,
#  12.98,
#  11.31,
#  23.4,
#  16.14,
#  15.02,
#  14.47,
#  10.72,
#  14.47,
#  14.47,
#  8.81,
#  10.33,
#  18.94,
#  15.02,
#  30.75,
#  8.19,
# ...

# %%
#same as a function
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

int_rate_to_float(int_rate)
# Out:
# 13.56

# %%
type(int_rate_to_float(int_rate))
# Out:
# float

# %%
#Use .apply() to apply function to every cell
df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      35000        35000  ...              NaN          14.47
# 1       5000         5000  ...              NaN          22.35
# 2      10000        10000  ...              NaN          23.40
# 3      17100        17100  ...              NaN          18.94
# 4       4000         4000  ...              NaN          10.72
#
# [5 rows x 141 columns]

# %%
df.dtypes[-1] #or type['int_rate_float']
# Out:
# dtype('float64')

# %%
df.dtypes[-5:]
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# int_rate_float           float64
# dtype: object

# %%
#Modify and Create Columns using .apply()
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
#unique
len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
#null
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
import numpy as np
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
#Function to clean NaN
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

cleaned_titles = []
for example in examples:
  cleaned_titles.append(clean_title(example))

cleaned_titles
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
[clean_title(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
#Using .apply()
df['emp_title'] = df['emp_title'].apply(clean_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      35000        35000  ...              NaN          14.47
# 1       5000         5000  ...              NaN          22.35
# 2      10000        10000  ...              NaN          23.40
# 3      17100        17100  ...              NaN          18.94
# 4       4000         4000  ...              NaN          10.72
#
# [5 rows x 141 columns]

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
len(df['emp_title'].value_counts())
# Out:
# 34902

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
##Dates and Times
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'].value_counts()
# Out:
# Oct-2018    46305
# Nov-2018    41973
# Dec-2018    40134
# Name: issue_d, dtype: int64

# %%
df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      35000        35000  ...        2018          12
# 1       5000         5000  ...        2018          12
# 2      10000        10000  ...        2018          12
# 3      17100        17100  ...        2018          12
# 4       4000         4000  ...        2018          12
#
# [5 rows x 143 columns]

# %%
df['earliest_cr_line'].head()
# Out:
# 0    Apr-1995
# 1    Mar-2010
# 2    Apr-2007
# 3    Mar-1998
# 4    Sep-2006
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days
# Out:
# 0          8645
# 1          3197
# 2          4262
# 3          7580
# 4          4474
#           ...
# 128407    12114
# 128408    13241
# 128409     4505
# 128410     3652
# 128411     4413
# Length: 128412, dtype: int64

# %%
df['days_from_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df['days_from_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: days_from_credit_to_issue, dtype: float64

# %%
#############################################################################################################################################################################

# %%
#Convert the term column from string to integer.
df['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     60 months
# 3     36 months
# 4     36 months
# Name: term, dtype: object

# %%
df['term'][0]
# Out:
# ' 36 months'

# %%
df['term'].describe()
# Out:
# count         128412
# unique             2
# top        36 months
# freq           88179
# Name: term, dtype: object

# %%
term_test = ' 30 months'
term_test.strip()
# Out:
# '30 months'

# %%
term_test.strip().strip('months')
# Out:
# '30 '

# %%
term_test.strip().strip('months').strip() #Nice!
# Out:
# '30'

# %%
type("term_test.strip().strip('months').strip()")
# Out:
# str

# %%
#Function
def term_to_integer(cell_contents):
  return int(cell_contents.strip().strip('months').strip())

# %%
type('term')
# Out:
# str

# %%
term_to_integer(term_test)
# Out:
# 30

# %%
type(term_to_integer(term_test))
# Out:
# int

# %%
df['term_int'] = df['term'].apply(term_to_integer)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  days_from_credit_to_issue term_int
# 0      35000        35000  ...                       8645       36
# 1       5000         5000  ...                       3197       36
# 2      10000        10000  ...                       4262       60
# 3      17100        17100  ...                       7580       36
# 4       4000         4000  ...                       4474       36
#
# [5 rows x 145 columns]

# %%
df.dtypes['term_int']
# Out:
# dtype('int64')

# %%
######################################################################################################################################
#Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.
df['loan_status'].head()

def current_fully_to_binary(cell_contents):
  if cell_contents == 'Current':
    return int(1)
  elif cell_contents == 'Fully Paid':
    return int(1)
  else:
    return int(0)

# %%
test = '1'
current_fully_to_binary(test)
# Out:
# 0

# %%
df['loan_status_is_great'] = df['loan_status'].apply(current_fully_to_binary)
df.head(20)
# Out:
#     loan_amnt  funded_amnt  ...  term_int loan_status_is_great
# 0       35000        35000  ...        36                    1
# 1        5000         5000  ...        36                    1
# 2       10000        10000  ...        60                    1
# 3       17100        17100  ...        36                    1
# 4        4000         4000  ...        36                    1
# 5       10475        10475  ...        36                    1
# 6        7500         7500  ...        36                    0
# 7        3600         3600  ...        36                    0
# 8       22000        22000  ...        60                    1
# 9       10450        10450  ...        36                    1
# 10       4800         4800  ...        36                    1
# 11      15400        15400  ...        60                    1
# 12      10000        10000  ...        36                    1
# 13       4000         4000  ...        36                    0
# ...

# %%
#Make last_pymnt_d_month and last_pymnt_d_year columns.
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['last_pymnt_d'].value_counts()
# Out:
# Jan-2020    96082
# Dec-2019     3603
# Jul-2019     3146
# Oct-2019     2784
# Sep-2019     2780
# Aug-2019     2717
# May-2019     2547
# Nov-2019     2515
# Apr-2019     2356
# Jun-2019     2289
# Mar-2019     1984
# Feb-2019     1915
# Jan-2019     1561
# Dec-2018     1054
# Nov-2018      679
# Oct-2018      234
# Feb-2020        7
# Name: last_pymnt_d, dtype: int64

# %%
df['last_pymnt_d'].isnull().sum()
# Out:
# 159

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)
df['last_pymnt_d'][0]
# Out:
# Timestamp('2019-08-01 00:00:00')

# %%
df['last_pymnt_d'].head().values
# Out:
# array(['2019-08-01T00:00:00.000000000', '2019-07-01T00:00:00.000000000',
#        '2020-01-01T00:00:00.000000000', '2020-01-01T00:00:00.000000000',
#        '2020-01-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_month last_pymnt_d_year
# 0      35000        35000  ...                 8.0            2019.0
# 1       5000         5000  ...                 7.0            2019.0
# 2      10000        10000  ...                 1.0            2020.0
# 3      17100        17100  ...                 1.0            2020.0
# 4       4000         4000  ...                 1.0            2020.0
#
# [5 rows x 148 columns]

# %%
df.dtypes["last_pymnt_d_month"]
# Out:
# dtype('float64')

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
#Lending Club
#There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
#revol_util	
df['revol_util'].head(10)
# Out:
# 0    43.2%
# 1    47.1%
# 2    53.9%
# 3      53%
# 4    28.6%
# 5    40.2%
# 6    16.3%
# 7    17.4%
# 8    44.7%
# 9      87%
# Name: revol_util, dtype: object

# %%
df['revol_util'][0]
# Out:
# '43.2%'

# %%
df['revol_util'].isnull().sum()
# Out:
# 156

# %%
df['revol_util'].dropna(inplace=True)

# %%
df['revol_util'].isnull().sum()
# Out:
# 0

# %%
#loading int_rate_to_float with modification to function
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip('%'))

# %%
df['revol_util_float'] = df['revol_util'].apply(int_rate_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_year revol_util_float
# 0      35000        35000  ...             2019.0             43.2
# 1       5000         5000  ...             2019.0             47.1
# 2      10000        10000  ...             2020.0             53.9
# 3      17100        17100  ...             2020.0             53.0
# 4       4000         4000  ...             2020.0             28.6
#
# [5 rows x 149 columns]

# %%
df['revol_util_float'].dtypes
# Out:
# dtype('float64')

# %%
#Modify the emp_title column to replace titles with 'Other' if the title is not in the top 20.
df['emp_title'].head()
# Out:
# 0        Staff Physician
# 1      Director Of Sales
# 2                Unknown
# 3           Receptionist
# 4    Extrusion Assistant
# Name: emp_title, dtype: object

# %%
 top_twenty = []
 top_twenty = df['emp_title'].value_counts(dropna=False).head(20)
 top_twenty
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
top_twenty
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
top_twenty.describe()
# Out:
# count       20.000000
# mean      1923.550000
# std       4518.213416
# min        412.000000
# 25%        513.500000
# 50%        797.000000
# 75%       1184.500000
# max      20947.000000
# Name: emp_title, dtype: float64

# %%
list(top_twenty)
# Out:
# [20947,
#  2557,
#  2395,
#  1418,
#  1258,
#  1160,
#  920,
#  834,
#  805,
#  803,
#  791,
#  720,
#  625,
#  523,
#  518,
#  500,
#  440,
#  425,
#  420,
#  412]

# %%
#making function
def top_twent_of_emp_title(cell_contents):
  if cell_contents != 
    return 'Other'

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
