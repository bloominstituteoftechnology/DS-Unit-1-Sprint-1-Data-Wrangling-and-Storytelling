# %% [markdown]
# <a href="https://colab.research.google.com/github/jiobu1/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Jisha_Obukwelu_DSPT5_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - [x] Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# -[x] Convert the `term` column from string to integer.
# -  [x] Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# -  [x] Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - [x] There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - [x] Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - [x] Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# ##Lending Club Data

# %% [markdown]
# ###Making Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Loading dataset

# %%
#Retrieving data
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-16 02:43:00--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [        <=>         ]  21.72M  1.83MB/s    in 12s
#
# 2020-01-16 02:43:12 (1.80 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22776791]

# %%
#Unzipping data
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
#Loading a cleaner copy of the data
#Addressing header with the 'skiprows' parameter
#Deleting footer 

loan = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
print(loan.shape)
loan.head()
# Out:
# (128397, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                  60.01             24.0
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %% [markdown]
# ###Data Exploration

# %%
loan.describe()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# count  0.0        0.0  ...             451.000000       451.000000
# mean   NaN        NaN  ...              51.851907        18.607539
# std    NaN        NaN  ...               8.713731         6.838053
# min    NaN        NaN  ...              40.000000         1.000000
# 25%    NaN        NaN  ...              45.000000        16.500000
# 50%    NaN        NaN  ...              45.440000        18.000000
# 75%    NaN        NaN  ...              60.000000        24.000000
# max    NaN        NaN  ...              98.240000        60.000000
#
# [8 rows x 108 columns]

# %%
loan.describe(exclude='number').T
# Out:
#                             count  ...    freq
# term                       128397  ...   88171
# int_rate                   128397  ...    6972
# grade                      128397  ...   38007
# sub_grade                  128397  ...    9769
# emp_title                  107455  ...    2090
# emp_length                 116696  ...   38821
# home_ownership             128397  ...   63481
# verification_status        128397  ...   58346
# issue_d                    128397  ...   46299
# loan_status                128397  ...   97694
# pymnt_plan                 128397  ...  128304
# purpose                    128397  ...   70595
# title                      128397  ...   70595
# zip_code                   128397  ...    1370
# addr_state                 128397  ...   17878
# earliest_cr_line           128397  ...    1130
# revol_util                 128241  ...    1132
# initial_list_status        128397  ...  114483
# last_pymnt_d               128238  ...   98862
# ...

# %%
pd.set_option('display.max_rows', 200)
loan.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128397
# desc                                          128397
# member_id                                     128397
# url                                           128397
# orig_projected_additional_accrued_interest    128191
# hardship_type                                 128164
# hardship_last_payment_amount                  128164
# hardship_payoff_balance_amount                128164
# hardship_reason                               128164
# hardship_loan_status                          128164
# hardship_dpd                                  128164
# hardship_length                               128164
# payment_plan_start_date                       128164
# hardship_end_date                             128164
# hardship_start_date                           128164
# hardship_amount                               128164
# deferral_term                                 128164
# hardship_status                               128164
# ...

# %% [markdown]
# ###Data Cleaning

# %% [markdown]
# ***Dropping the 100% blank columns***

# %%
loan = loan.drop(['url', 'member_id', 'desc', 'id'], axis=1)

# %%
loan.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0       6000         6000  ...                  60.01            24.0
# 1      24000        24000  ...                    NaN             NaN
# 2      30000        30000  ...                    NaN             NaN
# 3       8000         8000  ...                    NaN             NaN
# 4      22400        22400  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
loan.shape
# Out:
# (128397, 140)

# %% [markdown]
# ***Cleaning the int_rate column***

# %%
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
loan['int_rate_to_float'] = loan['int_rate'].apply(int_rate_to_float)
loan.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_to_float
# 0       6000         6000  ...             24.0             14.47
# 1      24000        24000  ...              NaN             10.33
# 2      30000        30000  ...              NaN             15.02
# 3       8000         8000  ...              NaN             12.98
# 4      22400        22400  ...              NaN             16.14
#
# [5 rows x 141 columns]

# %% [markdown]
# ###Making Features

# %% [markdown]
# Converting the string format of issue_d to datetime

# %%
loan['issue_d'] = pd.to_datetime(loan['issue_d'], infer_datetime_format=True)
loan['issue_d'].head(5)
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
loan['issue_year'] = loan['issue_d'].dt.year
loan['issue_month'] = loan['issue_d'].dt.month

# %%
loan.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0       6000         6000  ...        2018          12
# 1      24000        24000  ...        2018          12
# 2      30000        30000  ...        2018          12
# 3       8000         8000  ...        2018          12
# 4      22400        22400  ...        2018          12
#
# [5 rows x 143 columns]

# %% [markdown]
# ***Convert term column from string to integer***

# %%
#TRYING A NEW FORMULA TO CHANGE TERM COLUMN FROM STRING TO INT
convert_str_to_int = lambda x:int(x[:-7])

# %%
loan['term'] = loan['term'].apply(convert_str_to_int)
loan['term'].head(5)
# Out:
# 0    36
# 1    36
# 2    36
# 3    36
# 4    60
# Name: term, dtype: int64

# %% [markdown]
# ***Loan_status_is_great***

# %%
#Define Loan_status_is_great
loan['loan_status_is_great'] = loan['loan_status'].str.contains('Current', 'Fully Paid')
loan['loan_status_is_great'].head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: loan_status_is_great, dtype: bool

# %%
#Convert T/F to 0 and 1
loan['loan_status_is_great'] = loan['loan_status_is_great']*1
loan['loan_status_is_great'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: loan_status_is_great, dtype: int64

# %%
loan.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_month  loan_status_is_great
# 0       6000         6000  ...           12                     0
# 1      24000        24000  ...           12                     1
# 2      30000        30000  ...           12                     0
# 3       8000         8000  ...           12                     1
# 4      22400        22400  ...           12                     1
#
# [5 rows x 144 columns]

# %% [markdown]
# ***Make last_pymnt_d_month and last_pymnt_d_year columns***

# %% [markdown]
# Months

# %%
#The months would be the same since loan terms are between 3 and 5 years
loan['last_pymnt_d_month'] = loan['issue_d'].dt.month
loan.head()
# Out:
#    loan_amnt  funded_amnt  ...  loan_status_is_great  last_pymnt_d_month
# 0       6000         6000  ...                     0                  12
# 1      24000        24000  ...                     1                  12
# 2      30000        30000  ...                     0                  12
# 3       8000         8000  ...                     1                  12
# 4      22400        22400  ...                     1                  12
#
# [5 rows x 145 columns]

# %% [markdown]
# Years

# %%
#Finding out how many 3 and 5 year loans there are
loan['term'].value_counts()
# Out:
# 36    88171
# 60    40226
# Name: term, dtype: int64

# %%
#Have to add either 3 or 5 to the loan year
loan['last_pymnt_d_year'] = loan['term']/12 + loan['issue_d'].dt.year
loan['last_pymnt_d_year'] = loan['last_pymnt_d_year'].astype(int)
loan['last_pymnt_d_year'].head(5)
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2023
# Name: last_pymnt_d_year, dtype: int64

# %%
#Checking that I added correctly
loan['last_pymnt_d_year'].value_counts()
# Out:
# 2021    88171
# 2023    40226
# Name: last_pymnt_d_year, dtype: int64

# %%
loan.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_month  last_pymnt_d_year
# 0       6000         6000  ...                  12               2021
# 1      24000        24000  ...                  12               2021
# 2      30000        30000  ...                  12               2021
# 3       8000         8000  ...                  12               2021
# 4      22400        22400  ...                  12               2023
#
# [5 rows x 146 columns]

# %% [markdown]
# ***days_from_earliest_credit_to_issue***

# %%
loan['earliest_cr_line'].head()
# Out:
# 0    Jun-2006
# 1    Oct-1996
# 2    May-2007
# 3    Mar-2009
# 4    Dec-2004
# Name: earliest_cr_line, dtype: object

# %%
loan['earliest_cr_line'] = pd.to_datetime(loan['earliest_cr_line'], infer_datetime_format=True)

# %%
loan['days_from_earliest_credit_to_issue'] = (loan['issue_d'] - loan['earliest_cr_line']).dt.days

# %%
loan.head()
# Out:
#    loan_amnt  ...  days_from_earliest_credit_to_issue
# 0       6000  ...                                4566
# 1      24000  ...                                8096
# 2      30000  ...                                4232
# 3       8000  ...                                3562
# 4      22400  ...                                5113
#
# [5 rows x 147 columns]

# %% [markdown]
# #***STRETCH***

# %% [markdown]
# ###Still Data Cleaning

# %% [markdown]
# ***Dropping hardship columns***
# - most are NaNs

# %%
#Using list comprehension to find harship columns
hardship_cols = [col for col in loan.columns if col.startswith('hardship_')]
hardship_cols
# Out:
# ['hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount']

# %%
#Dropping hardship columns
loan = loan.drop(columns = hardship_cols)

# %%
#Making sure these columns got dropped
loan.shape
# Out:
# (128397, 135)

# %% [markdown]
# ***Cleaning emp_title***

# %% [markdown]
# Look at top 20 titles

# %%
loan['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20942
# Teacher                2090
# Manager                1773
# Registered Nurse        951
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
loan['emp_title'].nunique()
# Out:
# 43889

# %% [markdown]
# Clean the title and handling the missing values

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'unknown'

# %%
loan['emp_title'] = loan['emp_title'].apply(clean_title)

# %% [markdown]
# Combine like job titles

# %%
loan['emp_title'] = loan['emp_title'].replace('Registered Nurse', 'Nurse')
loan['emp_title'] = loan['emp_title'].replace('Rn', 'Nurse')

# %%
loan['emp_title'].value_counts(dropna=False).head(20)
# Out:
# unknown                     20942
# Nurse                        2675
# Teacher                      2557
# Manager                      2395
# Driver                       1258
# Supervisor                   1160
# Truck Driver                  920
# Office Manager                804
# Sales                         803
# General Manager               791
# Project Manager               720
# Owner                         625
# Director                      523
# Operations Manager            518
# Sales Manager                 500
# Police Officer                440
# Technician                    420
# Engineer                      412
# Administrative Assistant      409
# Store Manager                 398
# Name: emp_title, dtype: int64

# %%
#Trying not to manually type a list
top_20 = loan['emp_title'].value_counts()[1:21].index.tolist()
top_20
# Out:
# ['Nurse',
#  'Teacher',
#  'Manager',
#  'Driver',
#  'Supervisor',
#  'Truck Driver',
#  'Office Manager',
#  'Sales',
#  'General Manager',
#  'Project Manager',
#  'Owner',
#  'Director',
#  'Operations Manager',
#  'Sales Manager',
#  'Police Officer',
#  'Technician',
#  'Engineer',
#  'Administrative Assistant',
#  'Store Manager',
#  'Mechanic']

# %%
def change_to_other(x):
  if x in top_20:
    return x
  else:
    return 'Other'

# %%
loan['emp_title'] = loan['emp_title'].apply(change_to_other)
loan['emp_title'].value_counts()
# Out:
# Other                       109678
# Nurse                         2675
# Teacher                       2557
# Manager                       2395
# Driver                        1258
# Supervisor                    1160
# Truck Driver                   920
# Office Manager                 804
# Sales                          803
# General Manager                791
# Project Manager                720
# Owner                          625
# Director                       523
# Operations Manager             518
# Sales Manager                  500
# Police Officer                 440
# Technician                     420
# Engineer                       412
# Administrative Assistant       409
# Store Manager                  398
# Mechanic                       391
# Name: emp_title, dtype: int64

# %% [markdown]
# ***Cleaning the revol_util column***

# %%
loan['revol_util'] = loan['revol_util'].str.replace("%", " ")
loan['revol_util'].head(5)
# Out:
# 0    91.2
# 1    27.7
# 2      48
# 3    33.3
# 4    38.2
# Name: revol_util, dtype: object

# %% [markdown]
# #Exploratory Visuals

# %%
loan.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'settlement_amount', 'settlement_percentage', 'settlement_term',
#        'int_rate_to_float', 'issue_year', 'issue_month',
#        'loan_status_is_great', 'last_pymnt_d_month', 'last_pymnt_d_year',
#        'days_from_earliest_credit_to_issue'],
#       dtype='object', length=135)

# %%
pd.crosstab(loan['grade'], loan['emp_title'])
# Out:
# emp_title  Administrative Assistant  Director  ...  Technician  Truck Driver
# grade                                          ...
# A                               107       168  ...         121           200
# B                               115       155  ...         121           271
# C                                99       114  ...          93           249
# D                                57        66  ...          63           150
# E                                30        19  ...          19            43
# F                                 1         1  ...           2             5
# G                                 0         0  ...           1             2
#
# [7 rows x 21 columns]

# %%
grade_vs_title = pd.crosstab(loan['grade'], loan['emp_title'])

# %%
# %matplotlib inline

grade_vs_title.plot.bar(stacked=True)
plt.legend(loc='upper right', prop={'size': 6})
plt.show();

# %% [markdown]
# #Instacart Data

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
