# %% [markdown]
# <a href="https://colab.research.google.com/github/JraHike76/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Jay_Adamo_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd

# %%
pd.set_option('display.max_rows',150)
pd.set_option('display.max_columns',100)

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-05-05 20:45:48--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 52.89.161.10, 54.68.72.83, 34.211.18.146
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|52.89.161.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [              <=>   ]  22.05M  2.01MB/s    in 11s
#
# 2020-05-05 20:46:00 (2.00 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23121687]

# %%
# !unzip LoanStats_2018Q4.csv
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 1  NaN        NaN     6500.0       6500.0           6500.0   36 months
# 2  NaN        NaN     4500.0       4500.0           4500.0   36 months
# 3  NaN        NaN    25000.0      25000.0          25000.0   60 months
# 4  NaN        NaN    30000.0      30000.0          30000.0   60 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   16.14%       243.93     C        C4        Sale Consultant    2 years
# 1   11.80%       215.28     B        B4              Educator     2 years
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# mo_sin_old_rev_tl_op                               2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# open_il_12m                                        2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
df.tail()
# Out:
#                                                       id  member_id  \
# 128409                                               NaN        NaN
# 128410                                               NaN        NaN
# 128411                                               NaN        NaN
# 128412  Total amount funded in policy code 1: 2050909275        NaN
# 128413   Total amount funded in policy code 2: 820109297        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128409     5000.0       5000.0           5000.0   36 months   13.56%
# 128410    10000.0      10000.0           9750.0   36 months   11.06%
# 128411    10000.0      10000.0          10000.0   36 months   16.91%
# 128412        NaN          NaN              NaN         NaN      NaN
# 128413        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade             emp_title emp_length  \
# ...

# %%
# Addressing the NaNs
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine="python")

print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   60 months
# 1 NaN        NaN       6500         6500           6500.0   36 months
# 2 NaN        NaN       4500         4500           4500.0   36 months
# 3 NaN        NaN      25000        25000          25000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   16.14%       243.93     C        C4        Sale Consultant    2 years
# 1   11.80%       215.28     B        B4              Educator     2 years
# 2   11.31%       147.99     B        B3  Accounts Examiner III  10+ years
# 3   14.47%       587.82     C        C2                teacher  10+ years
# 4   27.27%       920.91     E        E5         Claims Analyst     1 year
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
#dropping the private columns
df = df.drop(['url','member_id','id','desc'], axis=1)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   60 months   16.14%       243.93
# 1       6500         6500           6500.0   36 months   11.80%       215.28
# 2       4500         4500           4500.0   36 months   11.31%       147.99
# 3      25000        25000          25000.0   60 months   14.47%       587.82
# 4      30000        30000          30000.0   60 months   27.27%       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %% [markdown]
# Convert the **term** column from string to integer.

# %%
#checking the head of the term column
df['term'].head()
# Out:
# 0     60 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     60 months
# Name: term, dtype: object

# %%
#inspecting a value in the column 
df['term'][0]
# Out:
# ' 60 months'

# %%
#there is a leading space and the word months that have to be dealt with
#first check for value counts
df['term'].value_counts()
# Out:
#  36 months    88179
#  60 months    40233
# Name: term, dtype: int64

# %%
#there are only 2 types of terms, 36 and 60 months
term = ' 36 months'

# %%
#I will strip both the leading space and the word months
term.strip().strip(' months')
# Out:
# '36'

# %%
#I can then use the integer function
int(term.strip().strip(' months'))
# Out:
# 36

# %%
#I need a function to change all of the values in the term column

def term_to_int(loan_term_string):
  if isinstance(loan_term_string, str):
    return int(term.strip().strip(' months'))
  else:
    return np.NaN

term_to_int(term)
# Out:
# 36

# %%
#I will apply to the new column which should appear all the way to the right
df['term_int'] = df['term'].apply(term_to_int)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   60 months   16.14%       243.93
# 1       6500         6500           6500.0   36 months   11.80%       215.28
# 2       4500         4500           4500.0   36 months   11.31%       147.99
# 3      25000        25000          25000.0   60 months   14.47%       587.82
# 4      30000        30000          30000.0   60 months   27.27%       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %% [markdown]
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
#first I want to inspect the head of the loan_status column
df['loan_status'].head()
# Out:
# 0     Fully Paid
# 1        Current
# 2     Fully Paid
# 3    Charged Off
# 4        Current
# Name: loan_status, dtype: object

# %%
#check out a value in the column for any issues
df['loan_status'][3]
# Out:
# 'Charged Off'

# %%
#I need to create a function for the new column

def loan_status_is_great(loan_status):
  if loan_status == 'Current' or loan_status == 'Fully Paid':
    df['loan_status_is_great'] = 1
  else:
    df['loan_status_is_great'] = 0

# %%
dfloan_status_is_great = []
# Out:
#   File "<ipython-input-73-bbf8bd5a2afd>", line 1
#     loan_status_is_great(Charged Off)
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Make last_pymnt_d_month and last_pymnt_d_year columns.

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
