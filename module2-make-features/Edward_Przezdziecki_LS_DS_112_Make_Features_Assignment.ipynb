# %% [markdown]
# <a href="https://colab.research.google.com/github/nedprz/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Edward_Przezdziecki_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd 

#Pandas Disp
pd.set_option('display.max_rows',150)
pd.set_option('display.max_rows',100)



# Lets take a look at the Ames Iowa Housing Dataset:
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
df['LotFrontage'].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 110, dtype: int64

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
import numpy as np

type(np.NaN)
# Out:
# float

# %%
df_small = df_small = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']]

df_small
# Out:
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0             856       856       854     208500
# 1            1262      1262         0     181500
# 2             920       920       866     223500
# 3             756       961       756     140000
# 4            1145      1145      1053     250000
# ...           ...       ...       ...        ...
# 1455          953       953       694     175000
# 1456         1542      2073         0     210000
# 1457         1152      1188      1152     266500
# 1458         1078      1078         0     142125
# 1459         1256      1256         0     147500
#
# [1460 rows x 4 columns]

# %%
df_small.TotalBsmtSF
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_small['TotalBsmtSF']
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
df_small['TotalSquareFootage'] = df_small['TotalBsmtSF'] + df_small['1stFlrSF'] + df_small['2ndFlrSF']

df_small
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage
# 0             856       856       854     208500                2566
# 1            1262      1262         0     181500                2524
# 2             920       920       866     223500                2706
# 3             756       961       756     140000                2473
# 4            1145      1145      1053     250000                3343
# ...           ...       ...       ...        ...                 ...
# 1455          953       953       694     175000                2600
# ...

# %%
df_small['PricePerSqFt'] = df_small['SalePrice']/df_small['TotalSquareFootage']
df_small
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       TotalBsmtSF  1stFlrSF  ...  TotalSquareFootage  PricePerSqFt
# 0             856       856  ...                2566     81.254871
# 1            1262      1262  ...                2524     71.909667
# 2             920       920  ...                2706     82.594235
# 3             756       961  ...                2473     56.611403
# 4            1145      1145  ...                3343     74.783129
# ...           ...       ...  ...                 ...           ...
# 1455          953       953  ...                2600     67.307692
# ...

# %%
### Work with strings with pandas

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-04-08 17:57:32--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 54.69.167.66, 52.32.57.66, 50.112.132.61
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|54.69.167.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [            <=>     ]  21.77M  2.05MB/s    in 11s
#
# 2020-04-08 17:57:44 (1.91 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22826918]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3235.65","3235.65","3223.02","3223.02","2364.35","858.67","0.0","0.0","0.0","Mar-2020","190.21","Apr-2020","Mar-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# read csv

df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

print(df.shape)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#                                                       id  ...  settlement_term
# 0                                                    NaN  ...              NaN
# 1                                                    NaN  ...              NaN
# 2                                                    NaN  ...              NaN
# 3                                                    NaN  ...              NaN
# 4                                                    NaN  ...              NaN
# ...                                                  ...  ...              ...
# 128409                                               NaN  ...              NaN
# 128410                                               NaN  ...              NaN
# ...

# %%
#sum null values by column and sort from least to greatest

df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
#                                                ...
# orig_projected_additional_accrued_interest    128155
# id                                            128412
# url                                           128414
# member_id                                     128414
# desc                                          128414
# Length: 144, dtype: int64

# %%
#fix footer problem 

df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1,skipfooter=2)
print(df.shape)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# (128412, 144)
#         id  member_id  ...  settlement_percentage  settlement_term
# 0      NaN        NaN  ...                    NaN              NaN
# 1      NaN        NaN  ...                    NaN              NaN
# 2      NaN        NaN  ...                    NaN              NaN
# 3      NaN        NaN  ...                    NaN              NaN
# 4      NaN        NaN  ...                    NaN              NaN
# ...     ..        ...  ...                    ...              ...
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# ...

# %%
df.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128407 NaN        NaN  ...                    NaN              NaN
# 128408 NaN        NaN  ...                    NaN              NaN
# 128409 NaN        NaN  ...                    NaN              NaN
# 128410 NaN        NaN  ...                    NaN              NaN
# 128411 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df = df.drop(['url', 'member_id', 'id','desc'],axis=1)
df
# Out:
#         loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0           35000        35000  ...                    NaN             NaN
# 1            5000         5000  ...                    NaN             NaN
# 2           10000        10000  ...                    NaN             NaN
# 3           17100        17100  ...                    NaN             NaN
# 4            4000         4000  ...                    NaN             NaN
# ...           ...          ...  ...                    ...             ...
# 128407      23000        23000  ...                    NaN             NaN
# 128408      10000        10000  ...                    NaN             NaN
# 128409       5000         5000  ...                    NaN             NaN
# 128410      10000        10000  ...                    NaN             NaN
# 128411      10000        10000  ...                    NaN             NaN
#
# [128412 rows x 140 columns]

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
int_rate =" 16.57%"

# %%
int_rate.strip("%")
# Out:
# ' 16.57'

# %%
#chaining functions to strip space and %
int_rate.strip().strip("%")
# Out:
# '16.57'

# %%
#same but casts to float
float(int_rate.strip().strip("%"))
# Out:
# 16.57

# %%
def int_rate_to_float(dirty_int_rate):
  return float(dirty_int_rate.strip().strip("%"))

# %%
int_rate_to_float(int_rate)
# Out:
# 16.57

# %%
int_rate_to_float(" 15.69")
# Out:
# 15.69

# %%
my_int_rate_var=' 12.11%'
int_rate_to_float(my_int_rate_var)
# Out:
# 12.11

# %%
#check datatype

type(int_rate_to_float(int_rate))
# Out:
# float

# %%
#apply solution to every cell in column

# %%
df['int_rate'].head()
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# Name: int_rate, dtype: object

# %%
int_rates=[' 16.57%', ' 16.52%', ' 16.58%', ' 16.41%', ' 15.47%']
clean_int_rates=[]
for int_rate in int_rates:
  clean_int_rates.append(int_rate_to_float(int_rate))

clean_int_rates
# Out:
# [16.57, 16.52, 16.58, 16.41, 15.47]

# %%
clean_int_rates=pd.Series(clean_int_rates)

clean_int_rates
# Out:
# 0    16.57
# 1    16.52
# 2    16.58
# 3    16.41
# 4    15.47
# dtype: float64

# %%
# the apply function

# %%
# you pass the apply function another function

df['int_rate_cleaned'] = df['int_rate'].apply(int_rate_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_cleaned
# 0      35000        35000  ...              NaN            14.47
# 1       5000         5000  ...              NaN            22.35
# 2      10000        10000  ...              NaN            23.40
# 3      17100        17100  ...              NaN            18.94
# 4       4000         4000  ...              NaN            10.72
#
# [5 rows x 141 columns]

# %%
df.dtypes.tail()
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# dtype: object

# %%
#challenge

# %%
# Look at the top 20 employment titles
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
#how many different unique employment titles are there curently?
df['emp_title'].nunique()
# Out:
# 43892

# %%
len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
# How often is the employment_title null?
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
#creates example of class to clean up
import numpy as np

examples = ['owner', 'supervisor', 'Project',np.NaN]

# %%
def clean_emp_title(title):
  if isinstance(title,str):
    return title.strip().title()
  else:
    return "Unknown"

for example in examples:
  print(clean_emp_title(example))
# Out:
# Owner
# Supervisor
# Project
# Unknown

# %%
[clean_emp_title(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project', 'Unknown']

# %%
df['emp_title'].head(10)
# Out:
# 0                        Staff Physician
# 1                      Director of Sales
# 2                                    NaN
# 3                          Receptionist
# 4                   Extrusion assistant
# 5                                Teacher
# 6                             Supervisor
# 7                                Analyst
# 8    Corporate Communications Strategist
# 9                        Project Manager
# Name: emp_title, dtype: object

# %%
df['emp_title'].apply(clean_emp_title).head(10)
# Out:
# 0                        Staff Physician
# 1                      Director Of Sales
# 2                                Unknown
# 3                           Receptionist
# 4                    Extrusion Assistant
# 5                                Teacher
# 6                             Supervisor
# 7                                Analyst
# 8    Corporate Communications Strategist
# 9                        Project Manager
# Name: emp_title, dtype: object

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_cleaned
# 0      35000        35000  ...              NaN            14.47
# 1       5000         5000  ...              NaN            22.35
# 2      10000        10000  ...              NaN            23.40
# 3      17100        17100  ...              NaN            18.94
# 4       4000         4000  ...              NaN            10.72
#
# [5 rows x 141 columns]

# %%
#Look at the top 20 employment titles

df['emp_title'].value_counts().head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].value_counts().head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 34902

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
#Dates and Times

# %%
[col for col in df if col.endswith('_d')] 
#if it ends with underscore d it refers to a date
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d']
# Out:
# 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
#             ...
# 128407    Oct-2018
# 128408    Oct-2018
# 128409    Oct-2018
# 128410    Oct-2018
# 128411    Oct-2018
# Name: issue_d, Length: 128412, dtype: object

# %%
df['issue_d'].value_counts()
# Out:
# Oct-2018    46305
# Nov-2018    41973
# Dec-2018    40134
# Name: issue_d, dtype: int64

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df['issue_d']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-01
# 3        2018-12-01
# 4        2018-12-01
#             ...
# 128407   2018-10-01
# 128408   2018-10-01
# 128409   2018-10-01
# 128410   2018-10-01
# 128411   2018-10-01
# Name: issue_d, Length: 128412, dtype: datetime64[ns]

# %%
df['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      35000        35000  ...        2018          12
# 1       5000         5000  ...        2018          12
# 2      10000        10000  ...        2018          12
# 3      17100        17100  ...        2018          12
# 4       4000         4000  ...        2018          12
#
# [5 rows x 143 columns]

# %%
df.dtypes[-5:]
# Out:
# settlement_percentage    float64
# settlement_term          float64
# int_rate_cleaned         float64
# issue_year                 int64
# issue_month                int64
# dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['earliest_cr_line'].head()
# Out:
# 0   1995-04-01
# 1   2010-03-01
# 2   2007-04-01
# 3   1998-03-01
# 4   2006-09-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days
# Out:
# 0          8645
# 1          3197
# 2          4262
# 3          7580
# 4          4474
#           ...
# 128407    12114
# 128408    13241
# 128409     4505
# 128410     3652
# 128411     4413
# Length: 128412, dtype: int64

# %%
df['years_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days / 365

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_month years_from_earliest_credit_to_issue
# 0      35000        35000  ...           12                           23.684932
# 1       5000         5000  ...           12                            8.758904
# 2      10000        10000  ...           12                           11.676712
# 3      17100        17100  ...           12                           20.767123
# 4       4000         4000  ...           12                           12.257534
#
# [5 rows x 144 columns]

# %%
df['years_from_earliest_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean         16.054497
# std           7.908317
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: years_from_earliest_credit_to_issue, dtype: float64

# %%
#convert the term column from string to int


def convert_to_int(x):
  return int(x.strip().strip(" months"))

# %%
convert_to_int(" 36 months")
# Out:
# 36

# %%
type(convert_to_int(" 36 months"))
# Out:
# int

# %%
df['term_cleaned']=df['term'].apply(convert_to_int)

# %%
#Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." 
#Else it should contain the integer 0.

# %%
def loan_status_checker(loan_status):
  if loan_status == 'Current' or loan_status == 'Fully Paid':
    return 1
  else:
    return 0

# %%
loan_status_checker('Fully Paid')
# check one of the conditions and it works
# Out:
# 1

# %%
loan_status_checker('blah ')
#check something else and it doesnt work, good
# Out:
# 0

# %%
# create and add on the new column loan_status_is_great

df['loan_status_is_great']=df['loan_status'].apply(loan_status_checker)

# %%
df
#check for new column and its there with some 0s and 1s
# Out:
#         loan_amnt  funded_amnt  ...  term_cleaned loan_status_is_great
# 0           35000        35000  ...            36                    1
# 1            5000         5000  ...            36                    1
# 2           10000        10000  ...            60                    1
# 3           17100        17100  ...            36                    1
# 4            4000         4000  ...            36                    1
# ...           ...          ...  ...           ...                  ...
# 128407      23000        23000  ...            36                    0
# 128408      10000        10000  ...            36                    1
# 128409       5000         5000  ...            36                    1
# 128410      10000        10000  ...            36                    1
# 128411      10000        10000  ...            36                    1
#
# [128412 rows x 146 columns]

# %%
#Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
def find_last_pay_month(last_pymnt_d):
  if last_pymnt_d == np.NaN:
    return "Unknown"
  else:
    return pd.to_datetime((last_pymnt_d), infer_datetime_format=True).month

# %%
find_last_pay_month('Dec-2018')
# Out:
# 12

# %%
import math
df['last_pymnt_d_month']=df['last_pymnt_d'].apply(find_last_pay_month).fillna(0).apply(math.floor)
df.head(5)
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_month last_pymnt_d_year
# 0      35000        35000  ...                   8              2019
# 1       5000         5000  ...                   7              2019
# 2      10000        10000  ...                   3              2020
# 3      17100        17100  ...                   3              2020
# 4       4000         4000  ...                   3              2020
#
# [5 rows x 148 columns]

# %%
def find_last_pay_year(last_pymnt_d):
  if last_pymnt_d == np.NaN:
    return "Unknown"
  else:
    return pd.to_datetime((last_pymnt_d), infer_datetime_format=True).year

# %%
find_last_pay_year('Oct-2020')
# Out:
# 2020

# %%
df['last_pymnt_d_year']=df['last_pymnt_d'].apply(find_last_pay_year).fillna(0).apply(math.floor)

df.head(5)
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_month last_pymnt_d_year
# 0      35000        35000  ...                 8.0              2019
# 1       5000         5000  ...                 7.0              2019
# 2      10000        10000  ...                 3.0              2020
# 3      17100        17100  ...                 3.0              2020
# 4       4000         4000  ...                 3.0              2020
#
# [5 rows x 148 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
