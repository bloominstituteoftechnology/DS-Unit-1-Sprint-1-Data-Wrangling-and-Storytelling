# %% [markdown]
# <a href="https://colab.research.google.com/github/shemaaali/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/LS_DS_112_Make_Features_Assignment/S_A_2_LS_DS18_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

import pandas as pd
import numpy as np

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-07-07 19:39:16--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 34.213.98.158, 35.166.36.92, 52.11.197.48, ...
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|34.213.98.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [       <=>          ]  22.21M  1.77MB/s    in 13s
#
# 2020-07-07 19:39:30 (1.73 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23289953]

# %%
# We can unzip the file
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# We look at the raw file by using the !head shell command
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","2769.48","2769.48","3793.65","3793.65","2830.52","963.13","0.0","0.0","0.0","Jun-2020","190.21","Jul-2020","Jun-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# Read in the CSV

df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    18000.0      18000.0          18000.0   36 months
# 1  NaN        NaN    18500.0      18500.0          18500.0   60 months
# 2  NaN        NaN    32000.0      32000.0          32000.0   60 months
# 3  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 4  NaN        NaN    13000.0      13000.0          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# ...

# %%
# We can fix the header problem by using the 'skiprows' parameter

df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    18000.0      18000.0          18000.0   36 months
# 1  NaN        NaN    18500.0      18500.0          18500.0   60 months
# 2  NaN        NaN    32000.0      32000.0          32000.0   60 months
# 3  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 4  NaN        NaN    13000.0      13000.0          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# ...

# %%
# Sum null values by column and sort from least to greatest

df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# mo_sin_old_rev_tl_op                               2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# open_il_12m                                        2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
# Address the extra NaNs in each column by skipping the footer as well.

df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# mo_sin_old_rev_tl_op                               0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# open_il_12m                                        0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df1 = df.drop(['desc', 'url', 'member_id', 'id'], axis=1)

df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      18000        18000          18000.0   36 months    8.81%       570.81
# 1      18500        18500          18500.0   60 months   12.98%       420.75
# 2      32000        32000          32000.0   60 months   14.47%       752.41
# 3       5000         5000           5000.0   36 months   17.97%       180.69
# 4      13000        13000          13000.0   36 months   23.40%       505.95
#
#   grade sub_grade             emp_title emp_length home_ownership  annual_inc  \
# 0     A        A5                 Sever   < 1 year           RENT     40000.0
# 1     B        B5  Supply Chain Analyst    5 years           RENT     96500.0
# 2     C        C2               Teacher  10+ years       MORTGAGE    110000.0
# 3     D        D1        Administrative    6 years       MORTGAGE     59280.0
# 4     E        E1   Sale Representative    2 years       MORTGAGE     90000.0
#
# ...

# %%
# Look at the first 10 values of the int_rate column

df['int_rate'].head(10)
# Out:
# 0      8.81%
# 1     12.98%
# 2     14.47%
# 3     17.97%
# 4     23.40%
# 5     26.31%
# 6     19.92%
# 7     23.40%
# 8     23.40%
# 9     11.80%
# Name: int_rate, dtype: object

# %%
# Look at a specific value from the int_rate column
df['int_rate'][0]
# Out:
# '  8.81%'

# %%
df['int_rate'][1]
# Out:
# ' 12.98%'

# %%
# Lets start with just fixing a single string.
# If we can fix one, we can usually fix all of them

int_rate = " 12.45%"

int_rate
# Out:
# ' 12.45%'

# %%
int_rate.strip()
# Out:
# '12.45%'

# %%
int_rate.strip('%')
# Out:
# ' 12.45'

# %%
int_rate.strip().strip('%')
# Out:
# '12.45'

# %%
# "Cast" the string value to a float

float(int_rate.strip().strip('%'))
# Out:
# 12.45

# %%
# Write a function that can do what we have written above to any 
# string that is passsed to it.

# Goal: write a function that will work on any cell in a column

def int_rate_to_float(int_rate):
  return float(int_rate.strip().strip('%'))

# %%
cleaned_int_rates = []

for int_rate in df['int_rate']:
  cleaned_int_rates.append(int_rate_to_float(int_rate))

df['int_rate_cleaned'] = pd.Series(cleaned_int_rates)

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
df['int_rate_cleaned'].mean()
# Out:
# 12.928038734699749

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
df['int_rate_2'] = df['int_rate'].apply(int_rate_to_float)

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
df['term']
# Out:
# 0          36 months
# 1          60 months
# 2          60 months
# 3          36 months
# 4          36 months
#              ...
# 128407     36 months
# 128408     36 months
# 128409     36 months
# 128410     36 months
# 128411     36 months
# Name: term, Length: 128412, dtype: object

# %%
def term_string_to_integer(term):
  return int(term.strip('months'))

# %%
df['loan_status_is_great'] = df['term'].apply(term_string_to_integer)

def loan_status(status):
  if status == 'Current' or status == 'Fully Paid':
    return 1 
  else: 
    return 0

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
# Another way to convert string to integer
df['loan_status_is_great'] = df['term'].str.strip('months').astype(int)
df['term'][0]
type(df['loan_status_is_great'][0])
# Out:
# numpy.int64

# %%
df['loan_status_is_great']
# Out:
# 0         36
# 1         60
# 2         60
# 3         36
# 4         36
#           ..
# 128407    36
# 128408    36
# 128409    36
# 128410    36
# 128411    36
# Name: loan_status_is_great, Length: 128412, dtype: int64

# %%
df['loan_status_is_great'].value_counts()
# Out:
# 36    88179
# 60    40233
# Name: loan_status_is_great, dtype: int64

# %%
df['term'].value_counts()
# Out:
#  36 months    88179
#  60 months    40233
# Name: term, dtype: int64

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'].tail
# Out:
# <bound method NDFrame.tail of 0         Dec-2018
# 1         Dec-2018
# 2         Dec-2018
# 3         Dec-2018
# 4         Dec-2018
#             ...
# 128407    Oct-2018
# 128408    Oct-2018
# 128409    Oct-2018
# 128410    Oct-2018
# 128411    Oct-2018
# Name: issue_d, Length: 128412, dtype: object>

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status    issue_d  loan_status  \
# ...

# %%
df['last_pymnt_d'].tail
# Out:
# <bound method NDFrame.tail of 0        2019-10-01
# 1        2020-06-01
# 2        2020-05-01
# 3        2019-10-01
# 4        2020-06-01
#             ...
# 128407   2018-12-01
# 128408   2020-06-01
# 128409   2020-06-01
# 128410   2020-06-01
# 128411   2020-06-01
# Name: last_pymnt_d, Length: 128412, dtype: datetime64[ns]>

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status    issue_d  loan_status  \
# ...

# %%
df.dtypes
# Out:
# id                      float64
# member_id               float64
# loan_amnt                 int64
# funded_amnt               int64
# funded_amnt_inv         float64
#                          ...
# loan_status_is_great      int64
# issue_year                int64
# issue_month               int64
# last_pymnt_d_month      float64
# last_pymnt_d_year       float64
# Length: 151, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['earliest_cr_line'].head()
# Out:
# 0   2014-04-01
# 1   2009-05-01
# 2   2000-10-01
# 3   2011-04-01
# 4   2007-05-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
(df['issue_d'] - df['earliest_cr_line']).dt.days / 365
# Out:
# 0          4.671233
# 1          9.591781
# 2         18.178082
# 3          7.673973
# 4         11.594521
#             ...
# 128407    33.189041
# 128408    36.276712
# 128409    12.342466
# 128410    10.005479
# 128411    12.090411
# Length: 128412, dtype: float64

# %%
df['length_of_credit_history'] = (df['issue_d'] - df['earliest_cr_line']).dt.days / 365

# %%
df['length_of_credit_history'].describe()
# Out:
# count    128412.000000
# mean         16.054497
# std           7.908317
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: length_of_credit_history, dtype: float64

# %%
(df['last_pymnt_d']-df['issue_d']).dt.days /365
# Out:
# 0         0.832877
# 1         1.501370
# 2         1.416438
# 3         0.832877
# 4         1.501370
#             ...
# 128407    0.167123
# 128408    1.668493
# 128409    1.668493
# 128410    1.668493
# 128411    1.668493
# Length: 128412, dtype: float64

# %%
df['payment_hist_standing'] = (df['last_pymnt_d']-df['issue_d']).dt.days /365

# %%
df['payment_hist_standing'].describe()
# Out:
# count    128253.000000
# mean          1.335515
# std           0.438203
# min           0.000000
# 25%           1.167123
# 50%           1.501370
# 75%           1.583562
# max           1.920548
# Name: payment_hist_standing, dtype: float64

# %%
df.drop(['length_of_payment_history'], axis=1)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0      NaN        NaN      18000        18000          18000.0   36 months
# 1      NaN        NaN      18500        18500          18500.0   60 months
# 2      NaN        NaN      32000        32000          32000.0   60 months
# 3      NaN        NaN       5000         5000           5000.0   36 months
# 4      NaN        NaN      13000        13000          13000.0   36 months
# ...     ..        ...        ...          ...              ...         ...
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
# ...

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status    issue_d  loan_status  \
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
# We can do cleaning from with other methed to look for 5 rows
df['int_rate'][:10]
# Return them all back
int_rate = ' 14.17%'
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status    issue_d  loan_status  \
# ...

# %%
type(int_rate.strip().strip('%'))
# Out:
# str

# %%
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
def int_rate_to_float(int_rate):
  return float(int_rate.strip().strip('%'))
  if isinstance(int_rate, str):
    return float(int_rate.strip( '%'))
  elif isintance(int_rate, float): 
    return 0

# %%
int_rate_to_float(int_rate)
# Out:
# 8.81

# %%
df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)

df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      18000        18000          18000.0   36 months
# 1 NaN        NaN      18500        18500          18500.0   60 months
# 2 NaN        NaN      32000        32000          32000.0   60 months
# 3 NaN        NaN       5000         5000           5000.0   36 months
# 4 NaN        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0    8.81%       570.81     A        A5                 Sever   < 1 year
# 1   12.98%       420.75     B        B5  Supply Chain Analyst    5 years
# 2   14.47%       752.41     C        C2               Teacher  10+ years
# 3   17.97%       180.69     D        D1        Administrative    6 years
# 4   23.40%       505.95     E        E1   Sale Representative    2 years
#
#   home_ownership  annual_inc verification_status    issue_d  loan_status  \
# ...

# %%
# Modify the emp_title column to replace titles with 'Other'
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
df['emp_title'].nunique()
# Out:
# 43892

# %%
# How often is the employment_title null?
df['emp_title'].isnull().sum()
# Out:
# 20947

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# Create some examples that represent the cases that we want to clean up
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
# Write a function to clean up these use cases and increase uniformity.

def clean_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

for example in examples:
  print(clean_emp_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
# list comprehensions can combine function calls and for loops over lists
# into one succinct and fairly readable single line of code.

[clean_emp_title(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
# We have a function that works as expected. Lets apply it to our column.
# This time we'll overwrite the original column

df['emp_title'] = df['emp_title'].apply(clean_emp_title)

# %%
# Look at the top 20 employment titles

len(df['emp_title'].value_counts())
# Out:
# 34902

# %%
df['emp_title'].head(20)
# Out:
# 0                                        Sever
# 1                         Supply Chain Analyst
# 2                                      Teacher
# 3                               Administrative
# 4                          Sale Representative
# 5             Financial Relationship Associate
# 6                             Material Handler
# 7                           Driver Coordinator
# 8                                     Security
# 9                           Nursing Supervisor
# 10                                     Unknown
# 11                   Instructional Coordinator
# 12                               Gas Attendant
# 13                                 Casino Host
# 14    Assistant Athletic Director Of Marketing
# 15                                     Unknown
# 16                          Production Manager
# 17                                   Carpenter
# 18                            Business Analyst
# 19                                      Banker
# ...

# %%
# How often is the employment_title null (NaN)?

df['emp_title'].isnull().sum()
# Out:
# 0

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-07-07 23:58:51--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.178.173
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.178.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  16.8MB/s    in 13s
#
# 2020-07-07 23:59:05 (14.9 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
 # !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
 # %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
# !ls -lh *.csv
# Out:
# -rw-r--r-- 1 502 staff 2.6K May  2  2017 aisles.csv
# -rw-r--r-- 1 502 staff  270 May  2  2017 departments.csv
# -rw-r--r-- 1 502 staff 551M May  2  2017 order_products__prior.csv
# -rw-r--r-- 1 502 staff  24M May  2  2017 order_products__train.csv
# -rw-r--r-- 1 502 staff 104M May  2  2017 orders.csv
# -rw-r--r-- 1 502 staff 2.1M May  2  2017 products.csv

# %%
order_products_prior = pd.read_csv('order_products__prior.csv')
print(order_products_prior.shape)
order_products_prior.head()
# Out:
# (32434489, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
orders = pd.read_csv('orders.csv')
print(orders.shape)
orders.head()
# Out:
# (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products = pd.read_csv('products.csv')
print(products.shape)
products.head()
# Out:
# (49688, 4)
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
order_products__train = pd.read_csv('order_products__train.csv')
print(order_products__train.shape)
order_products__train.head()
# Out:
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
departments = pd.read_csv('departments.csv')
print(departments.shape)
departments.head()
# Out:
# (21, 2)
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
departments = pd.read_csv('departments.csv')
print(departments.shape)
departments.head()

# %%
aisles = pd.read_csv('aisles.csv')
print(aisles.shape)
aisles.head()
# Out:
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
