# %% [markdown]
# <a href="https://colab.research.google.com/github/chrislopez630/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Chris_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-08-05 12:28:01--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 52.42.71.195, 54.245.103.170, 52.32.28.252, ...
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|52.42.71.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [     <=>            ]  22.26M  3.72MB/s    in 8.4s
#
# 2020-08-05 12:28:10 (2.64 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23339743]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
import pandas as pd
df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.dtypes
# Out:
# id                        object
# member_id                float64
# loan_amnt                float64
# funded_amnt              float64
# funded_amnt_inv          float64
#                           ...
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 144, dtype: object

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                           2
# mo_sin_old_rev_tl_op             2
# delinq_amnt                      2
# chargeoff_within_12_mths         2
# acc_open_past_24mths             2
#                              ...
# settlement_percentage       127477
# id                          128412
# desc                        128414
# url                         128414
# member_id                   128414
# Length: 144, dtype: int64

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')

print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                           0
# mo_sin_old_rev_tl_op             0
# delinq_amnt                      0
# chargeoff_within_12_mths         0
# acc_open_past_24mths             0
#                              ...
# settlement_percentage       127475
# desc                        128412
# url                         128412
# member_id                   128412
# id                          128412
# Length: 144, dtype: int64

# %%
df.dtypes
# Out:
# id                       float64
# member_id                float64
# loan_amnt                  int64
# funded_amnt                int64
# funded_amnt_inv          float64
#                           ...
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 144, dtype: object

# %%
df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df = df.drop(['id', 'member_id', 'desc', 'url'], axis=1)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      20000        20000  ...                    NaN             NaN
# 1      12000        12000  ...                    NaN             NaN
# 2       7000         7000  ...                    NaN             NaN
# 3      25000        25000  ...                    NaN             NaN
# 4      10400        10400  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
df['term'].head(10)
# Out:
# 0     36 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     36 months
# 5     36 months
# 6     36 months
# 7     60 months
# 8     36 months
# 9     60 months
# Name: term, dtype: object

# %%
df['term'][0]
# Out:
# ' 36 months'

# %%
term = '36 months'

my_num = 0

# %%
term.strip()
# Out:
# '36 months'

# %%
term = '36 months'

term.strip().strip(' months')
# Out:
# '36'

# %%
term.strip().strip(' months')
# Out:
# '36'

# %%
float(term.strip().strip(' months'))
# Out:
# 36.0

# %%
type(36.0)
# Out:
# float

# %%
type('36 months')
# Out:
# str

# %%
type(float(term.strip().strip(' months')))
# Out:
# float

# %%
df['term'].head()
# Out:
# 0     36 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     36 months
# Name: term, dtype: object

# %%
def term_to_float(cell_contents):
  return float(cell_contents.strip().strip(' months'))

# %%
term_to_float(term)
# Out:
# 36.0

# %%
type(term_to_float(term))
# Out:
# float

# %%
df['term'].apply(term_to_float)
# Out:
# 0         36.0
# 1         36.0
# 2         36.0
# 3         60.0
# 4         36.0
#           ...
# 128407    36.0
# 128408    36.0
# 128409    36.0
# 128410    36.0
# 128411    36.0
# Name: term, Length: 128412, dtype: float64

# %%
df['term_cleaned'] = df['term'].apply(term_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term term_cleaned
# 0      20000        20000  ...              NaN         36.0
# 1      12000        12000  ...              NaN         36.0
# 2       7000         7000  ...              NaN         36.0
# 3      25000        25000  ...              NaN         60.0
# 4      10400        10400  ...              NaN         36.0
#
# [5 rows x 141 columns]

# %%
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
import numpy as np

examples = ['owner', 'Supervisor', 'Project Manager', 'TEACHER', np.NaN]

# %%
def clean_emp_title(title):

  if isinstance(title, str): 

    return title.strip().title()
  else:
    return "unknown"

# %%
for examples in examples:

  print(clean_emp_title(examples))
# Out:
# Owner
# Supervisor
# Project Manager
# Teacher
# unknown

# %%
clean_emp_title("owner")
clean_emp_title("TEACHER")
# Out:
# 'Teacher'

# %%
new_title = clean_emp_title("TEACHER")

# %%
new_title
# Out:
# 'Teacher'

# %%
df['Loan_Status_is_Great'] = df['emp_title'].apply(clean_emp_title)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  term_cleaned       Loan_Status_is_Great
# 0      20000        20000  ...          36.0                 Bus Driver
# 1      12000        12000  ...          36.0      Sales Account Manager
# 2       7000         7000  ...          36.0           Business Analyst
# 3      25000        25000  ...          60.0         Production Manager
# 4      10400        10400  ...          36.0  Program Support Assistant
#
# [5 rows x 142 columns]

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['last_pymnt_d'].head()
# Out:
# 0    Feb-2020
# 1    Jul-2020
# 2    Jul-2019
# 3    Apr-2019
# 4    Jun-2020
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d'][2]
# Out:
# 'Jul-2019'

# %%
pd.to_datetime(df['last_pymnt_d'])
# Out:
# 0        2020-02-01
# 1        2020-07-01
# 2        2019-07-01
# 3        2019-04-01
# 4        2020-06-01
#             ...
# 128407   2018-12-01
# 128408   2020-07-01
# 128409   2020-07-01
# 128410   2020-07-01
# 128411   2020-07-01
# Name: last_pymnt_d, Length: 128412, dtype: datetime64[ns]

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      20000        20000  ...        2018          12
# 1      12000        12000  ...        2018          12
# 2       7000         7000  ...        2018          12
# 3      25000        25000  ...        2018          12
# 4      10400        10400  ...        2018          12
#
# [5 rows x 144 columns]

# %%
df['last_pymnt_d'].head()
# Out:
# 0   2020-02-01
# 1   2020-07-01
# 2   2019-07-01
# 3   2019-04-01
# 4   2020-06-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df['last_pymnt_d'][0]
# Out:
# Timestamp('2020-02-01 00:00:00')

# %%
df['last_pymnt_d'].dt.year
# Out:
# 0         2020.0
# 1         2020.0
# 2         2019.0
# 3         2019.0
# 4         2020.0
#            ...
# 128407    2018.0
# 128408    2020.0
# 128409    2020.0
# 128410    2020.0
# 128411    2020.0
# Name: last_pymnt_d, Length: 128412, dtype: float64

# %%
df['last_pymnt_d'].dt.month
# Out:
# 0          2.0
# 1          7.0
# 2          7.0
# 3          4.0
# 4          6.0
#           ...
# 128407    12.0
# 128408     7.0
# 128409     7.0
# 128410     7.0
# 128411     7.0
# Name: last_pymnt_d, Length: 128412, dtype: float64

# %%
df['last_pymnt_d_year'] = df['issue_d'].dt.year
df['last_pymnt_d_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_year last_pymnt_d_month
# 0      20000        20000  ...               2018                 12
# 1      12000        12000  ...               2018                 12
# 2       7000         7000  ...               2018                 12
# 3      25000        25000  ...               2018                 12
# 4      10400        10400  ...               2018                 12
#
# [5 rows x 146 columns]

# %%
df.Loan_Status_is_Great
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_year last_pymnt_d_month
# 0      20000        20000  ...               2018                 12
# 1      12000        12000  ...               2018                 12
# 2       7000         7000  ...               2018                 12
# 3      25000        25000  ...               2018                 12
# 4      10400        10400  ...               2018                 12
#
# [5 rows x 146 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
