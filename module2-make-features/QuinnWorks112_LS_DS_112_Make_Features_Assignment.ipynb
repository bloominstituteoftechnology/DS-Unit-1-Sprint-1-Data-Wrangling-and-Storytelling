# %% [markdown]
# <a href="https://colab.research.google.com/github/Avery1493/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/QuinnWorks112_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
#Import Pandas Library and Ames Iowa Housing Dataset
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#view data types
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#Display data types for all 81 columns (Display Options)
pd.set_option('Display.max_rows', 200)
pd.set_option('Display.max_columns', 200)
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
print(df['BedroomAbvGr'].head())
#NaN - not a number
df['LotFrontage'].head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# Name: BedroomAbvGr, dtype: int64
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# 5    85.0
# 6    75.0
# 7     NaN
# 8    51.0
# 9    50.0
# Name: LotFrontage, dtype: float64

# %%
#chaining
df['LotFrontage'].value_counts(dropna=False).head()
# Out:
# NaN     259
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# Name: LotFrontage, dtype: int64

# %%
#See data type of a NaN
import numpy as np
type(np.NaN)
# Out:
# float

# %%
#Creating New Data Frame  
small_df = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
small_df['SalePrice'][0:10]
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# 5    143000
# 6    307000
# 7    200000
# 8    129900
# 9    118000
# Name: SalePrice, dtype: int64

# %%
#Making New Column with bracket syntax
small_df['TotalSquareFootage'] = small_df['TotalBsmtSF'] + small_df['1stFlrSF'] + small_df['2ndFlrSF']
small_df
# Out:
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage
# 0             856       856       854     208500                2566
# 1            1262      1262         0     181500                2524
# 2             920       920       866     223500                2706
# 3             756       961       756     140000                2473
# 4            1145      1145      1053     250000                3343
# ...           ...       ...       ...        ...                 ...
# 1455          953       953       694     175000                2600
# 1456         1542      2073         0     210000                3615
# 1457         1152      1188      1152     266500                3492
# 1458         1078      1078         0     142125                2156
# 1459         1256      1256         0     147500                2512
#
# [1460 rows x 5 columns]

# %%
#Creating New Column to get more useful information
small_df['PricePerSqFt'] = small_df['SalePrice'] / small_df['TotalSquareFootage']
small_df
# Out:
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage  \
# 0             856       856       854     208500                2566
# 1            1262      1262         0     181500                2524
# 2             920       920       866     223500                2706
# 3             756       961       756     140000                2473
# 4            1145      1145      1053     250000                3343
# ...           ...       ...       ...        ...                 ...
# 1455          953       953       694     175000                2600
# 1456         1542      2073         0     210000                3615
# 1457         1152      1188      1152     266500                3492
# 1458         1078      1078         0     142125                2156
# 1459         1256      1256         0     147500                2512
#
#       PricePerSqFt
# 0        81.254871
# 1        71.909667
# 2        82.594235
# 3        56.611403
# 4        74.783129
# ...

# %% [markdown]
# NEW DATA SET with string values

# %%
#import Leaning Club data using shell command
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-15 22:57:03--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [         <=>        ]  21.72M  1.85MB/s    in 12s
#
# 2020-01-15 22:57:15 (1.83 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22776791]

# %%
#Unzip file
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3686.37","3686.37","2652.39","2652.39","1913.63","738.76","0.0","0.0","0.0","Dec-2019","190.21","Jan-2020","Nov-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv')
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128400, 1)
# ...

# %%
#Skip 1st row and delete last two rows
df = pd.read_csv('LoanStats_2018Q4.csv', header = 1, skipfooter = 2)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# (128397, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       6000         6000           6000.0   36 months
# 1 NaN        NaN      24000        24000          24000.0   36 months
# 2 NaN        NaN      30000        30000          30000.0   36 months
# 3 NaN        NaN       8000         8000           8000.0   36 months
# 4 NaN        NaN      22400        22400          22400.0   60 months
#
#   int_rate  installment grade sub_grade                emp_title emp_length  \
# 0   14.47%       206.44     C        C2                  Manager  10+ years
# 1   10.33%       778.14     B        B1      Maintenance Manager  10+ years
# ...

# %%
df.tail()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128392 NaN        NaN      23000        23000          23000.0   36 months
# 128393 NaN        NaN      10000        10000          10000.0   36 months
# 128394 NaN        NaN       5000         5000           5000.0   36 months
# 128395 NaN        NaN      10000        10000           9750.0   36 months
# 128396 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128392   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128393   15.02%       346.76     C        C3        security guard    5 years
# 128394   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128395   11.06%       327.68     B        B3                   NaN        NaN
# 128396   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
#'url', 'member_id', 'desc', 'id' all have completly empty cells
print(df.isnull().sum().sort_values())
df.shape
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
# Drop empty columns
# axis = 0 operations performed on rows
# axis = 1 operation is performed on the columns
df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)

# %%
# Four less columns
print(df.shape)
df.head()
# Out:
# (128397, 140)
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3             Firefighter   10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %% [markdown]
# CLEAN UP int_rate AND term COLUMNS

# %%
# leading space, %, and str
df['int_rate'][6]
# Out:
# ' 15.02%'

# %%
df['term'][6]
# Out:
# ' 60 months'

# %%
# Both strings
print(type(df['int_rate'][6]))
type(df['term'][6])
# Out:
# <class 'str'>
# str

# %%
int_rate = ' 15.02%' 
term = ' 60 months'

# %%
#Chain Strip function 
int_rate.strip().strip('%')
# Out:
# '15.02'

# %%
term.strip().strip(' months')
# Out:
# '60'

# %%
#Convert the term column from string to integer.
#CAST string to float AND string to integer
print(float(int_rate.strip().strip('%')))
int(term.strip().strip(' months'))
# Out:
# 15.02
# 60

# %% [markdown]
# CREATING FUNCTION TO DO ALL PRIVIOUS STEPS

# %%
#Function 
def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
def term_to_int(cell_contents):
  return int(cell_contents.strip().strip(' months'))

# %%
int_rate_to_float(int_rate)
# Out:
# 15.02

# %%
term_to_int(term)
# Out:
# 60

# %%
####??
new_list = []
for cell in df['int_rate']:
  new_list.append(int_rate_to_float(cell))

new_list[0:10]
# Out:
# [14.47, 10.33, 15.02, 12.98, 16.14, 12.98, 15.02, 16.14, 14.47, 13.56]

# %%
#####??
df['int_rate_cleaned'] = pd.Series(new_list)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3             Firefighter   10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
#.appy()
df['int_rate_cleaned_from_apply'] = df['int_rate'].apply(int_rate_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3             Firefighter   10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
df['term_cleaned'] = df['term'].apply(term_to_int)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3             Firefighter   10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %% [markdown]
# LOOKING AT Job Titles

# %%
#NaNs, duplicates/lowercase
df['emp_title'].value_counts(dropna=False)[:20]
# Out:
# NaN                   20942
# Teacher                2090
# Manager                1773
# Registered Nurse        951
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
#43889 unique titles
df['emp_title'].value_counts()
# Out:
# Teacher                                2090
# Manager                                1773
# Registered Nurse                        951
# Driver                                  924
# RN                                      726
#                                        ...
# Culinary Management                       1
# bk rep                                    1
# In Home Health Care Worker                1
# Petroleum infrastructure technician       1
# Assembly Line Team Member                 1
# Name: emp_title, Length: 43889, dtype: int64

# %%
print(df['emp_title'].isnull().sum())
len(df['emp_title'].unique())
# Out:
# 20942
# 43890

# %%
#Expamples of cases we want to clean up: capitalization, leading spaces, NaN values
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
# New Function (.title only works on strings and NaN is a float)
def clean_titles(job_title):
  return job_title.title().strip()

# %%
#for title in examples:
  #print(clean_titles(title))

# %%
#Use if to handle diff data types
def clean_titles(job_title):
  if isinstance(job_title, str):
    return job_title.title().strip()
  else:
    return 'Unknown'

# %%
for title in examples:
  print(clean_titles(title))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
###?? List Comprehension
[clean_titles(title) for title in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
#Replacing column 
df['emp_title'] = df['emp_title'].apply(clean_titles)
df['emp_title'].value_counts()
# Out:
# Unknown                        20942
# Teacher                         2557
# Manager                         2395
# Registered Nurse                1417
# Driver                          1258
#                                ...
# Direct Staff                       1
# Ferry Department Manager           1
# Corrugator                         1
# Course Services Assistant 3        1
# Assembly Line Team Member          1
# Name: emp_title, Length: 34899, dtype: int64

# %%
#Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" 
#or "Fully Paid." Else it should contain the integer 0.

# %%
###??
ex = ['Current', 'Fully Paid', 'Charged Off' ]
def status(loan_status):
  if loan_status == 'Current':
    return 1
  elif loan_status == 'Fully Paid':
    return 1
  else:
    return 0

for loan_status in ex:
  print(status(loan_status))
# Out:
# 1
# 1
# 0

# %%
#Adding new column
df['loan_status_is_great'] = df['loan_status'].apply(status)
df[0:6]
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
# 5       5000         5000           5000.0   36 months   12.98%       168.43
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3              Firefighter  10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
# ...

# %% [markdown]
# WORKING WITH DATES AND TIMES

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'][:10]
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
# Changing data type to datetime64[ns]
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
#.dt accessor
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128392    2018
# 128393    2018
# 128394    2018
# 128395    2018
# 128396    2018
# Name: issue_d, Length: 128397, dtype: int64

# %%
# Make last_pymnt_d_month and last_pymnt_d_year columns.
df.last_pymnt_d.dtypes
# Out:
# dtype('O')

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)
df.last_pymnt_d.head()
# Out:
# 0   2019-04-01
# 1   2019-12-01
# 2   2019-02-01
# 3   2019-12-01
# 4   2019-12-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3              Firefighter  10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
df.head(1)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
#
#   grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 0     C        C2   Manager  10+ years           RENT     55000.0
#
#   verification_status    issue_d  loan_status pymnt_plan      purpose  \
# 0            Verified 2018-12-01  Charged Off          n  credit_card
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0  Credit card refinancing    104xx         NY  10.65            0
#
#   earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0         Jun-2006               0                     NaN
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         6        0       4196      91.2%          8
#
#   initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  \
# ...

# %%
df2= df.copy()
df2.head()
df2 = df2[['emp_title','revol_util']]
print(df2.shape)
df2.head(1)
# Out:
# (128397, 2)
#   emp_title revol_util
# 0   Manager      91.2%

# %%
df2.dtypes
# Out:
# emp_title     object
# revol_util    object
# dtype: object

# %%
#checking for NaNs
#156 missing values did catch on first glance
df2['revol_util'].value_counts(dropna=False, ascending=False)[340:350]
# Out:
# 66%      157
# 21%      156
# 26.9%    156
# 56.9%    156
# NaN      156
# 44.2%    156
# 54.3%    156
# 51.6%    155
# 20.4%    155
# 77%      155
# Name: revol_util, dtype: int64

# %%
df2['revol_util'].isnull().sum()
# Out:
# 156

# %%
#float(df2['revol_util'].strip('%'))

# %%
credit_used = '91.2%'
float(credit_used.strip('%'))
# Out:
# 91.2

# %%
def credit_used_to_float(cell): 
  if isinstance(cell, float):
    return 'Unknown'
  else:
   return float(cell.strip('%'))

# %%
type(credit_used_to_float(credit_used))
# Out:
# float

# %%
df2['revol_util'] = df2['revol_util'].apply(credit_used_to_float)

# %%
#There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
df2.head()
# Out:
#                  emp_title revol_util
# 0                  Manager       91.2
# 1      Maintenance Manager       27.7
# 2              Firefighter         48
# 3               Controller       33.3
# 4  Paramedic/ Fire Fighter       38.2

# %%
#NaNs replaced with 'Unknown'
df2['revol_util'][240]
# Out:
# 'Unknown'

# %%
#Modify the emp_title column to replace titles with 'Other' if the title is not in the top 20.
df2['emp_title'].value_counts(ascending =False)[:22]
# Out:
# Unknown                     20942
# Teacher                      2557
# Manager                      2395
# Registered Nurse             1417
# Driver                       1258
# Supervisor                   1160
# Truck Driver                  920
# Rn                            834
# Office Manager                804
# Sales                         803
# General Manager               791
# Project Manager               720
# Owner                         625
# Director                      523
# Operations Manager            518
# Sales Manager                 500
# Police Officer                440
# Nurse                         424
# Technician                    420
# Engineer                      412
# Administrative Assistant      409
# Store Manager                 398
# Name: emp_title, dtype: int64

# %%
ex = ['Store Manager' , 'Engineer', 'Unknown', 'Teacher']

# %%
top20 = ['Teacher', 'Manager', 'Registered Nurse', 'Driver',
         'Supervisor','Truck Driver', 'Rn', 'Office Manager',
         'Sales', 'General Manager', 'Project Manager', 'Owner',
         'Director', 'Operations Manager', 'Sales Manager', 'Police Officer',
         'Nurse', 'Technician', 'Engineer', 'Administrative Assistant']

# %%
#https://stackoverflow.com/questions/46028725/is-it-possible-to-filter-list-of-substrings-by-another-list-of-strings-in-python
[x for x in ex if[y for y in top20 if x in y]]
# Out:
# ['Engineer', 'Teacher']

# %%
top20 = df2['emp_title'].value_counts(ascending =False)[1:21]
top20.head()
# Out:
# Teacher             2557
# Manager             2395
# Registered Nurse    1417
# Driver              1258
# Supervisor          1160
# Name: emp_title, dtype: int64

# %%
for x in top20:
    if x == 'Teacher' or x =='Manager' or x == 'Registered Nurse' or x =='Driver' or x =='Supervisor' or x =='Truck Driver' or x == 'Rn' or x =='Office Manager' or x =='Sales' or x == 'General Manager' or x == 'Project Manager' or x == 'Owner' or x =='Director' or x =='Operations Manager' or x == 'Sales Manager' or x == 'Police Officer'or x =='Nurse' or x == 'Technician' or x == 'Engineer' or x == 'Administrative Assistant':
      print(x)
    else:
      print('Other')
# Out:
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other

# %%
def replace_w_other(list_of_titles):
  for x in list_of_titles:
    if x == 'Teacher' or x =='Manager' or x == 'Registered Nurse' or x =='Driver' or x =='Supervisor' or x =='Truck Driver' or x == 'Rn' or x =='Office Manager' or x =='Sales' or x == 'General Manager' or x == 'Project Manager' or x == 'Owner' or x =='Director' or x =='Operations Manager' or x == 'Sales Manager' or x == 'Police Officer'or x =='Nurse' or x == 'Technician' or x == 'Engineer' or x == 'Administrative Assistant':
      return print(x)
    else:
      return print('Other')

# %%
replace_w_other(top20)
# Out:
# Other

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
