# %% [markdown]
# <a href="https://colab.research.google.com/github/calebmckay1/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Caleb_McKay_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

# %%
import pandas as pd
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 100)

# %%
hdf = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
print(hdf.shape)
hdf.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
hdf.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
hdf['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
hdf['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
hdf['LotFrontage'].value_counts()
# Out:
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 82.0      12
# 40.0      12
# 43.0      12
# 67.0      12
# 57.0      12
# 69.0      11
# 76.0      11
# 86.0      10
# 53.0      10
# 34.0      10
# 92.0      10
# 88.0      10
# 62.0       9
# 44.0       9
# 84.0       9
# 77.0       9
# 35.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 120.0      7
# 95.0       7
# 58.0       7
# 41.0       6
# 30.0       6
# 81.0       6
# 89.0       6
# 105.0      6
# 48.0       6
# 110.0      6
# 94.0       6
# 54.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 37.0       5
# 83.0       5
# 56.0       5
# 87.0       5
# ...

# %%
hdf['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
hdf['MSZoning'].value_counts(dropna=False)
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
hdf['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
import numpy as np
type(np.NaN)
# Out:
# float

# %%
hdf_small = hdf[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

hdf_small = hdf[["TotalBsmtSF", '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

hdf_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
hdf_small.dtypes
# Out:
# TotalBsmtSF    int64
# 1stFlrSF       int64
# 2ndFlrSF       int64
# SalePrice      int64
# dtype: object

# %%
hdf_small['TotalSqFT'] = hdf_small['1stFlrSF'] + hdf_small['2ndFlrSF'] + hdf_small['TotalBsmtSF']
hdf_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSqFT
# 0          856       856       854     208500       2566
# 1         1262      1262         0     181500       2524
# 2          920       920       866     223500       2706
# 3          756       961       756     140000       2473
# 4         1145      1145      1053     250000       3343

# %%
hdf_small['PricePerSqFt'] = hdf_small['SalePrice'] / hdf_small['TotalSqFT']
hdf_small.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSqFT  PricePerSqFt
# 0          856       856       854     208500       2566     81.254871
# 1         1262      1262         0     181500       2524     71.909667
# 2          920       920       866     223500       2706     82.594235
# 3          756       961       756     140000       2473     56.611403
# 4         1145      1145      1053     250000       3343     74.783129

# %%
# Next Dataset, working with strings.

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-05-05 20:45:31--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 34.211.18.146, 54.68.72.83, 52.89.161.10
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|34.211.18.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [    <=>             ]  22.05M  2.99MB/s    in 7.9s
#
# 2020-05-05 20:45:39 (2.79 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23121687]

# %%
# !unzip LoanStats_2018Q4.csv
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3082.01","3082.01","3413.23","3413.23","2517.99","895.24","0.0","0.0","0.0","Apr-2020","190.21","May-2020","Apr-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
mdf = pd.read_csv('LoanStats_2018Q4.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(mdf.shape)
mdf.head()
# Out:
# (128415, 1)
# ...

# %%
mdf = pd.read_csv('LoanStats_2018Q4.csv', header=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(mdf.shape)
mdf.head()
# Out:
# (128414, 144)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 1  NaN        NaN     6500.0       6500.0           6500.0   36 months
# 2  NaN        NaN     4500.0       4500.0           4500.0   36 months
# 3  NaN        NaN    25000.0      25000.0          25000.0   60 months
# 4  NaN        NaN    30000.0      30000.0          30000.0   60 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   16.14%       243.93     C        C4        Sale Consultant    2 years
# 1   11.80%       215.28     B        B4              Educator     2 years
# 2   11.31%       147.99     B        B3  Accounts Examiner III  10+ years
# 3   14.47%       587.82     C        C2                teacher  10+ years
# 4   27.27%       920.91     E        E5         Claims Analyst     1 year
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
mdf.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# mo_sin_old_rev_tl_op                               2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# open_il_12m                                        2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
mdf.tail()
# Out:
#                                                       id  member_id  \
# 128409                                               NaN        NaN
# 128410                                               NaN        NaN
# 128411                                               NaN        NaN
# 128412  Total amount funded in policy code 1: 2050909275        NaN
# 128413   Total amount funded in policy code 2: 820109297        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 128409     5000.0       5000.0           5000.0   36 months   13.56%
# 128410    10000.0      10000.0           9750.0   36 months   11.06%
# 128411    10000.0      10000.0          10000.0   36 months   16.91%
# 128412        NaN          NaN              NaN         NaN      NaN
# 128413        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade             emp_title emp_length  \
# ...

# %%
mdf = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')

# %%
mdf.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      10000        10000          10000.0   60 months
# 1 NaN        NaN       6500         6500           6500.0   36 months
# 2 NaN        NaN       4500         4500           4500.0   36 months
# 3 NaN        NaN      25000        25000          25000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade              emp_title emp_length  \
# 0   16.14%       243.93     C        C4        Sale Consultant    2 years
# 1   11.80%       215.28     B        B4              Educator     2 years
# 2   11.31%       147.99     B        B3  Accounts Examiner III  10+ years
# 3   14.47%       587.82     C        C2                teacher  10+ years
# 4   27.27%       920.91     E        E5         Claims Analyst     1 year
#
#   home_ownership  annual_inc verification_status   issue_d  loan_status  \
# ...

# %%
mdf = mdf.drop(['id', 'member_id', 'url', 'desc'], axis=1)
mdf.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      10000        10000          10000.0   60 months   16.14%       243.93
# 1       6500         6500           6500.0   36 months   11.80%       215.28
# 2       4500         4500           4500.0   36 months   11.31%       147.99
# 3      25000        25000          25000.0   60 months   14.47%       587.82
# 4      30000        30000          30000.0   60 months   27.27%       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
mdf['int_rate'].head(10)
# Out:
# 0     16.14%
# 1     11.80%
# 2     11.31%
# 3     14.47%
# 4     27.27%
# 5     16.14%
# 6     12.98%
# 7     12.98%
# 8     10.33%
# 9     23.40%
# Name: int_rate, dtype: object

# %%
mdf['int_rate'][7]
# Out:
# ' 12.98%'

# %%
int_rate_list = ' 11.80%'

# %%
int_rate_list.strip('%')
# Out:
# ' 11.80'

# %%
int_rate_list.strip()
# Out:
# '11.80%'

# %%
int_rate_list.strip('%').strip()
# Out:
# '11.80'

# %%
type(int_rate_list.strip('%').strip())
# Out:
# str

# %%
float(int_rate_list.strip('%').strip())
# Out:
# 11.8

# %%
def int_rate_list_to_float(int_rate_list):
  return float(int_rate_list.strip('%').strip())

# %%
int_rate_list_to_float(' 11.80%')
# Out:
# '11.80'

# %%
type(int_rate_list_to_float(' 11.80%'))
# Out:
# float

# %%
new_int_rate_list = []

for int_rate_list in mdf['int_rate']:
  new_int_rate_list.append(int_rate_list_to_float(int_rate_list))

# %%
mdf['new_int_rate'] = pd.Series(new_int_rate_list)

# %%
mdf.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   60 months     16.14       243.93
# 1       6500         6500           6500.0   36 months     11.80       215.28
# 2       4500         4500           4500.0   36 months     11.31       147.99
# 3      25000        25000          25000.0   60 months     14.47       587.82
# 4      30000        30000          30000.0   60 months     27.27       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4              Educator     2 years           RENT
# 2     B        B3  Accounts Examiner III  10+ years           RENT
# 3     C        C2                teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
mdf.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
mdf['new_int_rate'].mean()
# Out:
# 12.928038734699742

# %%
mdf['int_rate'] = mdf['int_rate'].apply(int_rate_list_to_float)

# %%
mdf['int_rate'].head()
# Out:
# 0    16.14
# 1    11.80
# 2    11.31
# 3    14.47
# 4    27.27
# Name: int_rate, dtype: float64

# %%
mdf.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# purpose                                        object
# ...

# %%
mdf['emp_title'].value_counts().head(20)
# Out:
# Teacher                     2090
# Manager                     1773
# Registered Nurse             952
# Driver                       924
# RN                           726
# Supervisor                   697
# Sales                        580
# Project Manager              526
# General Manager              523
# Office Manager               521
# Owner                        420
# Director                     402
# Operations Manager           387
# Truck Driver                 387
# Nurse                        326
# Engineer                     325
# Sales Manager                304
# manager                      301
# Supervisor                   270
# Administrative Assistant     269
# Name: emp_title, dtype: int64

# %%
mdf['emp_title'].nunique()
# Out:
# 43892

# %%
mdf['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
models = ['ENGINEER', ' director','DriVEr', np.NaN]

# %%
def fresh_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

for model in models:
  print(fresh_emp_title(model))
# Out:
# Engineer
# Director
# Driver
# Unknown

# %%
[fresh_emp_title(title) for title in models]
# Out:
# ['Engineer', 'Director', 'Driver', 'Unknown']

# %%
mdf['emp_title'] = mdf['emp_title'].apply(fresh_emp_title)
mdf['emp_title'].value_counts(dropna=False).head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
mdf['emp_title'].nunique()
# Out:
# 34902

# %%
mdf['emp_title'].isnull().sum()
# Out:
# 0

# %%
[col for col in mdf if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
mdf['issue_d'].head(10)
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
mdf['issue_d'].value_counts()
# Out:
# Oct-2018    46305
# Nov-2018    41973
# Dec-2018    40134
# Name: issue_d, dtype: int64

# %%
mdf['issue_d'] = pd.to_datetime(mdf['issue_d'], infer_datetime_format=True)

# %%
mdf['issue_d'][2]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
mdf['issue_d'].head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: issue_d, dtype: datetime64[ns]

# %%
mdf['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
mdf['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
mdf['issue_year'] = mdf['issue_d'].dt.year
mdf['issue_month'] = mdf['issue_d'].dt.month
mdf.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      10000        10000          10000.0   60 months     16.14       243.93
# 1       6500         6500           6500.0   36 months     11.80       215.28
# 2       4500         4500           4500.0   36 months     11.31       147.99
# 3      25000        25000          25000.0   60 months     14.47       587.82
# 4      30000        30000          30000.0   60 months     27.27       920.91
#
#   grade sub_grade              emp_title emp_length home_ownership  \
# 0     C        C4        Sale Consultant    2 years           RENT
# 1     B        B4               Educator    2 years           RENT
# 2     B        B3  Accounts Examiner Iii  10+ years           RENT
# 3     C        C2                Teacher  10+ years            OWN
# 4     E        E5         Claims Analyst     1 year           RENT
#
#    annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# ...

# %%
mdf.dtypes[-5:]
# Out:
# settlement_percentage    float64
# settlement_term          float64
# new_int_rate             float64
# issue_year                 int64
# issue_month                int64
# dtype: object

# %%
mdf['earliest_cr_line'] = pd.to_datetime(mdf['earliest_cr_line'],infer_datetime_format=True)

# %%
mdf['earliest_cr_line'].head()
# Out:
# 0   1991-03-01
# 1   2011-08-01
# 2   2003-12-01
# 3   1997-01-01
# 4   1997-12-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
mdf['years_of_credit_to_issue'] = (mdf['issue_d'] - mdf['earliest_cr_line']).dt.days / 365
mdf['years_of_credit_to_issue'].head()
# Out:
# 0    27.772603
# 1     7.339726
# 2    15.010959
# 3    21.928767
# 4    21.013699
# Name: years_of_credit_to_issue, dtype: float64

# %%
mdf['years_of_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean         16.054497
# std           7.908317
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: years_of_credit_to_issue, dtype: float64

# %%
# convert 'term' column from string to int
print(mdf['term'].describe())
print(mdf['term'].isnull().sum())
print(mdf['term'].head())
print(mdf['term'].tail())
mdf['term'].value_counts(dropna=False)
# Out:
# count         128412
# unique             2
# top        36 months
# freq           88179
# Name: term, dtype: object
# 0
# 0     60 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     60 months
# Name: term, dtype: object
# 128407     36 months
# 128408     36 months
# 128409     36 months
# 128410     36 months
# 128411     36 months
# Name: term, dtype: object
#  36 months    88179
#  60 months    40233
# Name: term, dtype: int64

# %%
def term_to_int(term):
  return int(term.strip('months').strip())

mdf['term'] = mdf['term'].apply(term_to_int)
mdf['term'].head()
# Out:
# 0    60
# 1    36
# 2    36
# 3    60
# 4    60
# Name: term, dtype: int64

# %%
# successfully converted 'term' from strings to integers
# might need help with the above code though, in like understanding 
# conceptually how that def line works. I know what to input but idk how 
# that line of code technically functions fundamentally

# %%
mdf.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      10000        10000          10000.0    60     16.14       243.93     C
# 1       6500         6500           6500.0    36     11.80       215.28     B
# 2       4500         4500           4500.0    36     11.31       147.99     B
# 3      25000        25000          25000.0    60     14.47       587.82     C
# 4      30000        30000          30000.0    60     27.27       920.91     E
#
#   sub_grade              emp_title emp_length home_ownership  annual_inc  \
# 0        C4        Sale Consultant    2 years           RENT     90000.0
# 1        B4               Educator    2 years           RENT     46500.0
# 2        B3  Accounts Examiner Iii  10+ years           RENT     38500.0
# 3        C2                Teacher  10+ years            OWN    110000.0
# 4        E5         Claims Analyst     1 year           RENT     50000.0
#
# ...

# %%
def loan_is_great():
   if (mdf['loan_status']).any == 'Current' or (mdf['loan_status']).any == 'Fully Paid':
     return 1
   else:
     return 0

mdf['loan_status_is_great'] = mdf['loan_status'].isin(['Current','Fully Paid']).astype(int)

# got help from google on this using 20 min rule but still struggling to 
# understand it conceptually. The thing that is stumping me the most is the 
# very first line 'def' and what its role is within the syntax.

# %%
mdf['loan_status_is_great'].value_counts()
# Out:
# 1    116959
# 0     11453
# Name: loan_status_is_great, dtype: int64

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
mdf['last_pymnt_d_month'] = np.NaN
mdf['last_pymnt_d_year'] = np.NaN

# not sure if it was just create NaN columns or add values in so I added what I 
# thought made the most sense below in a different cell.

# %%
mdf.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0      10000        10000          10000.0    60     16.14       243.93     C
# 1       6500         6500           6500.0    36     11.80       215.28     B
# 2       4500         4500           4500.0    36     11.31       147.99     B
# 3      25000        25000          25000.0    60     14.47       587.82     C
# 4      30000        30000          30000.0    60     27.27       920.91     E
#
#   sub_grade              emp_title emp_length home_ownership  annual_inc  \
# 0        C4        Sale Consultant    2 years           RENT     90000.0
# 1        B4               Educator    2 years           RENT     46500.0
# 2        B3  Accounts Examiner Iii  10+ years           RENT     38500.0
# 3        C2                Teacher  10+ years            OWN    110000.0
# 4        E5         Claims Analyst     1 year           RENT     50000.0
#
# ...

# %%
mdf['last_pymnt_d_month'] = pd.to_datetime(mdf['last_pymnt_d'],infer_datetime_format=True).dt.to_period('M')

# %%
mdf['last_pymnt_d_month'].head()
# Out:
# 0    2019-05
# 1    2020-03
# 2    2019-02
# 3    2019-10
# 4    2020-03
# Name: last_pymnt_d_month, dtype: period[M]

# %%
mdf['last_pymnt_d_year'] = pd.to_datetime(mdf['last_pymnt_d'], infer_datetime_format=True).dt.to_period('Y')

# %%
mdf['last_pymnt_d_year'].head()
# figured ('M') did the trick for month so tried ('Y') and it seemed to work lol
# Out:
# 0    2019
# 1    2020
# 2    2019
# 3    2019
# 4    2020
# Name: last_pymnt_d_year, dtype: period[A-DEC]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
