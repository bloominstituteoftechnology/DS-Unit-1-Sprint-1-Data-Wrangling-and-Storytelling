# %% [markdown]
# <a href="https://colab.research.google.com/github/TobyChen320/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Toby_Chen_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd
! wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-03-13 15:35:25--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [                 <=>]  21.71M   850KB/s    in 26s
#
# 2020-03-13 15:35:52 (850 KB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22763850]

# %%
! unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
loans_df = pd.read_csv('LoanStats_2018Q4.csv')
loans_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
loans_df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
loans_df.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128279 NaN        NaN  ...                    NaN              NaN
# 128280 NaN        NaN  ...                    NaN              NaN
# 128281 NaN        NaN  ...                    NaN              NaN
# 128282 NaN        NaN  ...                    NaN              NaN
# 128283 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
loans_df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')
loans_df.tail()
# Out:
#         id  member_id  ...  settlement_percentage  settlement_term
# 128279 NaN        NaN  ...                    NaN              NaN
# 128280 NaN        NaN  ...                    NaN              NaN
# 128281 NaN        NaN  ...                    NaN              NaN
# 128282 NaN        NaN  ...                    NaN              NaN
# 128283 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
pd.set_option('display.max_rows', 100)
loans_df.isnull().sum().sort_values(ascending=False)
# Out:
# id                                            128284
# desc                                          128284
# member_id                                     128284
# url                                           128284
# orig_projected_additional_accrued_interest    128025
#                                                ...
# inq_last_12m                                       0
# acc_open_past_24mths                               0
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# inq_fi                                             0
# Length: 144, dtype: int64

# %%
loans_df['term'].head()
# Out:
# 0     60 months
# 1     36 months
# 2     36 months
# 3     60 months
# 4     60 months
# Name: term, dtype: object

# %%
loans_df['term'][0]
# Out:
# ' 60 months'

# %%
term = ' 60 months'
term.strip().strip('months').rstrip()
# Out:
# '60'

# %%
int(term.strip().strip('months').rstrip())
# Out:
# 60

# %%
type(int(term.strip().strip('months').rstrip()))
# Out:
# int

# %%
def function(cell_contents):
  return int(cell_contents.strip().strip('months').rstrip())

# %%
function(term)
# Out:
# 60

# %%
type(function(term))
# Out:
# int

# %%
new_list = []

# %%
for cell in loans_df['term']:                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
  new_list.append(function(cell))

# %%
new_list[:10]
# Out:
# [60, 36, 36, 60, 60, 36, 60, 36, 36, 36]

# %%
loans_df['term_cleaned']=new_list
loans_df[['term', 'term_cleaned']].head()
# Out:
#          term  term_cleaned
# 0   60 months            60
# 1   36 months            36
# 2   36 months            36
# 3   60 months            60
# 4   60 months            60

# %%
loans_df[['term', 'term_cleaned']].dtypes
# Out:
# term            object
# term_cleaned     int64
# dtype: object

# %%
loans_df['term_cleaned'] = loans_df['term'].apply(function)
loans_df[['term', 'term_cleaned']].head()
# Out:
#          term  term_cleaned
# 0   60 months            60
# 1   36 months            36
# 2   36 months            36
# 3   60 months            60
# 4   60 months            60

# %%
loans_df['loan_status'].head(10)
# Out:
# 0            Fully Paid
# 1               Current
# 2            Fully Paid
# 3    Late (31-120 days)
# 4               Current
# 5               Current
# 6               Current
# 7               Current
# 8            Fully Paid
# 9            Fully Paid
# Name: loan_status, dtype: object

# %%
loans_df['loan_status']=loans_df['loan_status_is_great']

# %%
loans_df[['loan_status', 'loan_status_is_great']].head()
# Out:
#           loan_status loan_status_is_great
# 0          Fully Paid           Fully Paid
# 1             Current              Current
# 2          Fully Paid           Fully Paid
# 3  Late (31-120 days)   Late (31-120 days)
# 4             Current              Current

# %%
def loan_status_is_great(loan_status):
  if(loan_status =='Current') or (loan_status =='Fully Paid'):
    return '1'  
  else:
      return '0'
print(loan_status_is_great)
# Out:
# <function loan_status_is_great at 0x7f186d69a7b8>

# %%
loans_df['loan_status_is_great']=loans_df['loan_status'].apply(loan_status_is_great)

# %%
loans_df[['loan_status', 'loan_status_is_great']].head()
# Out:
#           loan_status loan_status_is_great
# 0          Fully Paid                    1
# 1             Current                    1
# 2          Fully Paid                    1
# 3  Late (31-120 days)                    0
# 4             Current                    1

# %%
loans_df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
mylist = []
for col in loans_df.columns:
  if col.endswith('_d'):
    mylist.append(col)
mylist
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
print(loans_df['issue_d'][0])
type(loans_df['issue_d'][0])
# Out:
# Dec-2018
# str

# %%
loans_df['last_pymnt_d_month']=pd.to_datetime(loans_df['last_pymnt_d'], infer_datetime_format=True)
loans_df[['last_pymnt_d', 'last_pymnt_d_month']].head()
# Out:
#   last_pymnt_d last_pymnt_d_month
# 0     May-2019         2019-05-01
# 1     Feb-2020         2020-02-01
# 2     Feb-2019         2019-02-01
# 3     Oct-2019         2019-10-01
# 4     Feb-2020         2020-02-01

# %%
loans_df['month'] = loans_df['last_pymnt_d_month'].dt.month
loans_df[['last_pymnt_d', 'last_pymnt_d_month', 'month']].head()
# Out:
#   last_pymnt_d last_pymnt_d_month  month
# 0     May-2019         2019-05-01    5.0
# 1     Feb-2020         2020-02-01    2.0
# 2     Feb-2019         2019-02-01    2.0
# 3     Oct-2019         2019-10-01   10.0
# 4     Feb-2020         2020-02-01    2.0

# %%
loans_df['last_pymnt_d_year']=pd.to_datetime(loans_df['last_pymnt_d'], infer_datetime_format=True)
loans_df[['last_pymnt_d', 'last_pymnt_d_year']].head()
# Out:
#   last_pymnt_d last_pymnt_d_year
# 0     May-2019        2019-05-01
# 1     Feb-2020        2020-02-01
# 2     Feb-2019        2019-02-01
# 3     Oct-2019        2019-10-01
# 4     Feb-2020        2020-02-01

# %%
loans_df['year'] = loans_df['last_pymnt_d_year'].dt.year
loans_df[['last_pymnt_d', 'last_pymnt_d_year', 'year']].head()
# Out:
#   last_pymnt_d last_pymnt_d_year    year
# 0     May-2019        2019-05-01  2019.0
# 1     Feb-2020        2020-02-01  2020.0
# 2     Feb-2019        2019-02-01  2019.0
# 3     Oct-2019        2019-10-01  2019.0
# 4     Feb-2020        2020-02-01  2020.0

# %%
loans_df[['last_pymnt_d', 'month', 'year']].head()
# Out:
#   last_pymnt_d  month    year
# 0     May-2019    5.0  2019.0
# 1     Feb-2020    2.0  2020.0
# 2     Feb-2019    2.0  2019.0
# 3     Oct-2019   10.0  2019.0
# 4     Feb-2020    2.0  2020.0

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
loans_df['int_rate'].head()
# Out:
# 0     16.14%
# 1     11.80%
# 2     11.31%
# 3     14.47%
# 4     27.27%
# Name: int_rate, dtype: object

# %%
loans_df['int_rate'][0]
# Out:
# ' 16.14%'

# %%
int_rate = ' 16.14%'
int_rate.strip().strip('%')
# Out:
# '16.14'

# %%
float(int_rate.strip().strip('%'))
# Out:
# 16.14

# %%
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
loans_df.isnull().sum()
# Out:
# id                                         128284
# member_id                                  128284
# loan_amnt                                       0
# funded_amnt                                     0
# funded_amnt_inv                                 0
#                                             ...
# last_pymnt_d_month                            159
# (last_pymnt_d_month, last_pymnt_d_year)       159
# last_pymnt_d_year                             159
# month                                         159
# year                                          159
# Length: 152, dtype: int64

# %%
loans_df.dropna(inplace=True)
loans_df.isnull().sum()
# Out:
# id                                         0
# member_id                                  0
# loan_amnt                                  0
# funded_amnt                                0
# funded_amnt_inv                            0
#                                           ..
# last_pymnt_d_month                         0
# (last_pymnt_d_month, last_pymnt_d_year)    0
# last_pymnt_d_year                          0
# month                                      0
# year                                       0
# Length: 152, dtype: int64

# %%
def my_function(cell_contents):
  if loans_df['emp_title'] is loans_df['emp_title'].head(20)
  return loans_df['emp_title']
  else:
    return other
# Out:
#   File "<ipython-input-164-3a80d7c41a35>", line 2
#     if loans_df['emp_title'] is loans_df['emp_title'].head(20)
#                                                               ^
# SyntaxError: invalid syntax

# %%
for cell in lans_df['emp_title']:

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
