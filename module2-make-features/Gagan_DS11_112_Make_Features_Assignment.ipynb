# %% [markdown]
# <a href="https://colab.research.google.com/github/gagansingh23/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/Gagan_DS11_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
#load data 
import pandas as pd

# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-12-03 20:35:34--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.2’
#
# LoanStats_2018Q4.cs     [     <=>            ]  21.69M   417KB/s    in 54s
#
# 2019-12-03 20:36:28 (411 KB/s) - ‘LoanStats_2018Q4.csv.zip.2’ saved [22744357]

# %%
#unzip data
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
#use bash/shell to view raw files

# !head LoanStats_2018Q4.csv
# !tail LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
#view the data 

df = pd.read_csv('LoanStats_2018Q4.csv')
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128415, 1)
# ...

# %%
#fix header if column headers incorrect

df = pd.read_csv('LoanStats_2018Q4.csv', header=1)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
#find null values in each column and sort

pd.set_option('display.max_rows', 150)

df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# max_bal_bc                                         2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# hardship_flag                                      2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
#have 2 null values because of footer, adress issue

df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2)
print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# (128412, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
#check for Nan Values updated

df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
#get rid of blank columns which show number of entires = null values using drop function(axis means columns)

df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
df.head()

# %%
df['int_rate'][2]
# Out:
# ' 11.31%'

# %%
#fix one string at a time #leading space issue

int_rate = ' 11.31%'

# %%
#use .strip() to clear empty space if nothing between parentheses
int_rate.strip()

# %%
#use .strip() to remove percent sign
int_rate.strip('%')

# %%
#put both together to clean
int_rate.strip().strip('%')

# %%
#find value then typcast to change
type(int_rate.strip().strip('%'))

float(int_rate.strip().strip('%'))

type(float(int_rate.strip().strip('%')))

# %%
# declare a function so we can use it for the whole columns

def fix_rate(cell_c):
  return(float(cell_c.strip().strip('%')))

# %%
#test function 
fix_rate(int_rate)
# Out:
# 11.31

# %%
#check datatype
type(fix_rate(int_rate))
# Out:
# float

# %%
#now the fun part, apply to every cell in our columns for df

df['int_rate_float'] = df['int_rate'].apply(fix_rate)
df.head(5)

# %%
#fix other values
df['emp_title'].value_counts(dropna=False)[:20]

# %%
#see how many different employee titles using len() function
len(df['emp_title'].value_counts())
# Out:
# 34902

# %%
#how many null values for employment title using isnull().sum()
df['emp_title'].isnull().sum()

# %%
examples = ['owner', 'Supervior', 'Project Manager', np.NaN]

# %%
#start by fixing one example / .title() capitalizes and lowercases

def new_title(job_title):
  if isinstance(job_title, str):
    return job_title.title().strip()
  else:
    return "Unknown"

for title in examples:
  print(new_title(title))

# %%
#apply new function to column overwrite original column

df['emp_title'] = df['emp_title'].apply(new_title)

df.head(100)

# %%
df['emp_title'].value_counts(dropna=False,ascending=False)[:20]

# %%
#check for null values
df['emp_title'].isnull().sum()
# Out:
# 20949

# %%
df['term'].value_counts()
# Out:
#  36 months    88179
#  60 months    40233
# Name: term, dtype: int64

# %%
#convert term column from string to int
df['term'].value_counts(dropna=False)
# Out:
#  36 months    88179
#  60 months    40233
# Name: term, dtype: int64

# %%
#declare a function to change string to int
df['term'][1]
# Out:
# ' 60 months'

# %%
#apply function to term column every cell
#small steps to create function 
term_s = ' 48 month'
term_s.strip('month')
# Out:
# ' 48 '

# %%
int(term_s.strip('month'))
# Out:
# 48

# %%
type(int(term_s.strip('month')))
# Out:
# int

# %%
#create a function
def convert_to_int(cell_contents):
  return (int(cell_contents.strip('months')))

# %%
#CONVERT TERM COLUMN FROM STRING TO INT
df['term'] = df['term'].apply(convert_to_int)
df.head()
# Out:
#    id  member_id  ...  last_pymnt_d_year  last_payment_d_month
# 0 NaN        NaN  ...               2018                    12
# 1 NaN        NaN  ...               2018                    12
# 2 NaN        NaN  ...               2018                    12
# 3 NaN        NaN  ...               2018                    12
# 4 NaN        NaN  ...               2018                    12
#
# [5 rows x 149 columns]

# %%
df.dtypes['term']
# Out:
# dtype('int64')

# %%
Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
#Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.
df['loan_status'].head()
# Out:
# 0       Current
# 1    Fully Paid
# 2       Current
# 3       Current
# 4    Fully Paid
# Name: loan_status, dtype: object

# %%
#create a function for new column
def f(loan_status):
  if (loan_status) == "Current" or  (loan_status) == "Fully Paid":
    return 1
  else: 
    return 0

# %%
#NEW COLUMN LOAN_STATUS_IS_GREAT
df['loan_status_is_great'] = df['loan_status'].apply(f)


df['loan_status_is_great'].tail(10)
# Out:
# 128402    1
# 128403    1
# 128404    1
# 128405    1
# 128406    1
# 128407    0
# 128408    1
# 128409    1
# 128410    1
# 128411    1
# Name: loan_status_is_great, dtype: int64

# %%
#verify the codes correspond correctly
df['loan_status'].tail(10)
# Out:
# 128402        Current
# 128403        Current
# 128404        Current
# 128405     Fully Paid
# 128406        Current
# 128407    Charged Off
# 128408        Current
# 128409        Current
# 128410        Current
# 128411        Current
# Name: loan_status, dtype: object

# %%
#DT FORMAT 

[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

df.dtypes[:15]
# Out:
# id                     float64
# member_id              float64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                     int64
# int_rate                object
# installment            float64
# grade                   object
# sub_grade               object
# emp_title               object
# emp_length              object
# home_ownership          object
# annual_inc             float64
# verification_status     object
# dtype: object

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

# %%
#Make last_pymnt_d_month and last_pymnt_d_year columns
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year
df['last_payment_d_month'] = df['last_pymnt_d'].dt.month

df.tail()
# Out:
#         id  member_id  ...  last_pymnt_d_year  last_payment_d_month
# 128407 NaN        NaN  ...               2018                    10
# 128408 NaN        NaN  ...               2018                    10
# 128409 NaN        NaN  ...               2018                    10
# 128410 NaN        NaN  ...               2018                    10
# 128411 NaN        NaN  ...               2018                    10
#
# [5 rows x 149 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
