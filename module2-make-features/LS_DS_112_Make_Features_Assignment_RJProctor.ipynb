# %% [markdown]
# <a href="https://colab.research.google.com/github/jproctor-rebecca/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/LS_DS_112_Make_Features_Assignment_RJProctor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# ---
#
#
#
# - *Replicate the lesson code.*
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - *Convert the `term` column from string to integer.*
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd
import numpy as np
# needed for dataframes

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
# Ames Iowa Housing Dataset

print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df.dtypes
# may print truncated display settings with elipses
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# sets parameters for data display to avoid truncation
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 100)


df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df['BedroomAbvGr'].head(10)
# view data to determine/confirm data type
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# 5    1
# 6    3
# 7    3
# 8    2
# 9    2
# Name: BedroomAbvGr, dtype: int64

# %%
df['LotFrontage'].head(10)
# view data to determine/confirm data type
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# 5    85.0
# 6    75.0
# 7     NaN
# 8    51.0
# 9    50.0
# Name: LotFrontage, dtype: float64

# %%
df["LotFrontage"].value_counts(dropna=False).head()
# note that NaN is the most common value in column
# Out:
# NaN     259
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# Name: LotFrontage, dtype: int64

# %%
# needed for mathematical computations

type(np.NaN)
# Out:
# float

# %%
# make a smaller dataframe with a few specific column headers
# by passing a list of column headers inside of the square brackets
# save to a new data frame with all links to old dataframe broken
small_df = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
# add the square footage to get a total square footage column
# remember to use bracket syntax to make a new column in dataframes
# we make new columns that say new things about our data using the current data 
# this is one of the most important ways to improve machine learning model

small_df['TotalSquareFootage'] = small_df['TotalBsmtSF'] + small_df['1stFlrSF'] + small_df['2ndFlrSF']

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343

# %%
# add another column by dividing the price by the square footage
small_df['PricePerSqFt'] = (small_df['SalePrice'] / small_df['TotalSquareFootage'])

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage  \
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343
#
#    PricePerSqFt
# 0     81.254871
# 1     71.909667
# 2     82.594235
# 3     56.611403
# 4     74.783129

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-08-04 17:10:25--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 34.217.168.192, 52.42.71.195, 52.32.28.252, ...
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|34.217.168.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.2’
#
# LoanStats_2018Q4.cs     [               <=>  ]  22.25M  6.64MB/s    in 4.2s
#
# 2020-08-04 17:10:30 (5.27 MB/s) - ‘LoanStats_2018Q4.csv.zip.2’ saved [23327114]

# %%
# df = pd.read_csv('LoanStats_2018Q4')

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: LoanStats_2018Q4.csv

# %%
# need to skip first row - just notes & being used as header
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# need to skipp footer - currently included in nulls for every column
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","2610.57","2610.57","3983.86","3983.86","2989.43","994.43","0.0","0.0","0.0","Jul-2020","190.21","Aug-2020","Jul-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# need to fix the header problem by using the 'skiprows' parameter
loans_cleaned = pd.read_csv('LoanStats_2018Q4.csv', header=1, skiprows=(128413,128414), skipfooter=2, engine='python')

print(loans.shape)
loans
# Out:
# (128411, 144)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0      NaN        NaN      20000        20000          20000.0   36 months
# 1      NaN        NaN      12000        12000          12000.0   36 months
# 2      NaN        NaN       7000         7000           6975.0   36 months
# 3      NaN        NaN      25000        25000          25000.0   60 months
# 4      NaN        NaN      10400        10400          10400.0   36 months
# ...     ..        ...        ...          ...              ...         ...
# 128406 NaN        NaN       5600         5600           5600.0   36 months
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
#
# ...

# %%
# check for nulls by summing null values by column and sorting
# from least to greatest

loans_cleaned.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# mo_sin_old_rev_tl_op                               0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# open_il_12m                                        0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
# publicly traded data cannot be used to track individuals
# make sure to include column axis=1 or row axis=1 parameter

loans_cleaned = loans.drop(['url', 'member_id', 'desc', 'id'], axis=1)
# dropping columns that are completely blank

print(loans_cleaned.shape)
loans_cleaned
# Out:
# (128411, 140)
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           20000        20000          20000.0   36 months   14.47%
# 1           12000        12000          12000.0   36 months   16.14%
# 2            7000         7000           6975.0   36 months   10.72%
# 3           25000        25000          25000.0   60 months   16.14%
# 4           10400        10400          10400.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
#
#         installment grade sub_grade                   emp_title emp_length  \
# ...

# %%
# view the first 10 values of the int_rate column

loans_cleaned['int_rate'][:10]
# df1['int_rate'](10) '''example used in class created error'''
# Out:
# 0     14.47%
# 1     16.14%
# 2     10.72%
# 3     16.14%
# 4     12.98%
# 5      7.56%
# 6     17.97%
# 7     14.47%
# 8     11.31%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
loans_cleaned['int_rate']
# Out:
# 0          14.47%
# 1          16.14%
# 2          10.72%
# 3          16.14%
# 4          12.98%
#            ...
# 128406     13.56%
# 128407     15.02%
# 128408     15.02%
# 128409     13.56%
# 128410     11.06%
# Name: int_rate, Length: 128411, dtype: object

# %%
# view a specific value from the int_rate column

loans_cleaned['int_rate'][0]
# Out:
# ' 14.47%'

# %%
loans_cleaned['int_rate'][1]
# Out:
# ' 16.14%'

# %%
# removes whitespace and string characters
# chaining functions
# int_rate.strip().strip('%')

# now cast string value to a float
# float(int_rate.strip().strip('%'))

# now do this for the entire column
# must be held in a function
# name funtion so that it is clear what function does
# write a function that will work on any cell in the column
# Use .apply() to call the function

# %%
# def int_rate_to_float(cell_contents):
  #return float(cell_contents.strip().strip('%'))
# def int_to_float(int_rate):
 # return float(int_rate.strip().strip('%'))

### example used in class provided errors ###
### running clean with no errors but not stripping and converting ###

def int_to_float(int_rate):
  rate = str(int_rate)
  rate = rate.strip('%')
  rate = rate.strip(' ')
  # rate = str(int_rate).drop(128412, axis=0).drop(128413, axis=0)
  # rate = rate.strip('%').drop(128412, axis=0).drop(128413, axis=0)
  # rate = rate.strip(' ').drop(128412, axis=0).drop(128413, axis=0)
  return float(rate)

# %%
loans_cleaned['int_rate_float'] = loans_cleaned['int_rate'].apply(int_to_float)

loans_cleaned


# Cleaned_int_rates = []

# for int_rate in df('int_rate'):
   # cleadened_int_rates.append(int_rate_to_float(int_rate))

# df1['cleaned_int_rate'] = pd.Series(cleaded_int_rates)

# df1.head() 

# For loop is the long way of modifying multiple items in a 
# dataframe and not suggested but is listed below to show what is happening 
# under the hood .apply() is called
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           20000        20000          20000.0   36 months   14.47%
# 1           12000        12000          12000.0   36 months   16.14%
# 2            7000         7000           6975.0   36 months   10.72%
# 3           25000        25000          25000.0   60 months   16.14%
# 4           10400        10400          10400.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
#
#         installment grade sub_grade                   emp_title emp_length  \
# ...

# %%
# convert the string 'term' to an integer
# inspecting the feature
loans_cleaned['term'][:]
# Out:
# 0          36 months
# 1          36 months
# 2          36 months
# 3          60 months
# 4          36 months
#              ...
# 128406     36 months
# 128407     36 months
# 128408     36 months
# 128409     36 months
# 128410     36 months
# Name: term, Length: 128411, dtype: object

# %%
def term_to_int(term):
 #return int(term.strip().strip('months'))

#loans_cleaned['term_to_int'] = loans_cleaned['term'].apply(term_to_int)

#loans_cleaned.head()

### example used in class provided errors ###

  string = str(term)
  string = string.strip('months')
  string = string.strip('a')
  string = string.strip('month')
  string = string.strip(' ')
 
  return int(float(string))

# %%
loans_cleaned['term_to_int'] = loans_cleaned['term'].apply(term_to_int)
loans_cleaned
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           20000        20000          20000.0   36 months   14.47%
# 1           12000        12000          12000.0   36 months   16.14%
# 2            7000         7000           6975.0   36 months   10.72%
# 3           25000        25000          25000.0   60 months   16.14%
# 4           10400        10400          10400.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
#
#         installment grade sub_grade                   emp_title emp_length  \
# ...

# %%
# checking work
loans_cleaned['term_to_int'][:]
# Out:
# 0         36
# 1         36
# 2         36
# 3         60
# 4         36
#           ..
# 128406    36
# 128407    36
# 128408    36
# 128409    36
# 128410    36
# Name: term_to_int, Length: 128411, dtype: int64

# %%
# df1['term_to_int'] = df1['term'][1].apply(term_to_int)

# %%
# view datatypes of the last 5 columns
loans_cleaned.dtypes[-5:]
# Out:
# settlement_percentage    float64
# settlement_term          float64
# int_rate_float           float64
# term_to_float            float64
# term_to_int                int64
# dtype: object

# %%
# unique employment titles
len(loans_cleaned['emp_title'].value_counts())
# Out:
# 43892

# %%
loans_cleaned['emp_title'].nunique()
# Out:
# 43892

# %%
loans_cleaned['emp_title'].isna().sum()
# df1['emp_title'].isnull().sum() '''example given in class ran with errors'''
# Out:
# 20947

# %%
# emplyment titles we want to clean up

examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
"""def clean_emp_title(title):
  if isinstance(title, string):
    return title.strip().title()
  else
    return "NA"
    # will get changed to a NaN again

  for example in examples:
    print(clean_emp_title(example))"""

# %%
# function cleans up cases and increase uniformity

def clean_title(title):
  if isinstance(title, str):
    return title.strip().upper()  
    # could use .title() to make Title case; .lower() for lower case 
  else:
    return "unknown"

for example in examples:
  print(clean_title(example))
# Out:
# OWNER
# SUPERVISOR
# PROJECT MANAGER
# unknown

# %%
# list comprehensions can combine function calls and for loops over lists
# into one succinct and fairly readable single line of code.
# list comprehensions can make your lists a little more readable

[clean_title(example) for example in examples]
# Out:
# ['OWNER', 'SUPERVISOR', 'PROJECT MANAGER', 'unknown']

# %%
# overwrite the original column 

loans_cleaned['emp_title'] = loans_cleaned['emp_title'].apply(clean_title)

loans_cleaned
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           20000        20000          20000.0   36 months   14.47%
# 1           12000        12000          12000.0   36 months   16.14%
# 2            7000         7000           6975.0   36 months   10.72%
# 3           25000        25000          25000.0   60 months   16.14%
# 4           10400        10400          10400.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
#
#         installment grade sub_grade                  emp_title emp_length  \
# ...

# %%
# view top 20 employment titles
# view top 20 unique employment titles

loans_cleaned['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# unknown               20947
# TEACHER                2557
# MANAGER                2395
# REGISTERED NURSE       1418
# DRIVER                 1258
# SUPERVISOR             1160
# TRUCK DRIVER            920
# RN                      834
# OFFICE MANAGER          805
# SALES                   803
# GENERAL MANAGER         791
# PROJECT MANAGER         720
# OWNER                   625
# DIRECTOR                523
# OPERATIONS MANAGER      518
# SALES MANAGER           500
# POLICE OFFICER          440
# NURSE                   425
# TECHNICIAN              420
# ENGINEER                412
# Name: emp_title, dtype: int64

# %%
loans_cleaned['emp_title'].dtype
# Out:
# dtype('O')

# %%
# check for null (NaN) by using sum of emplyment titles
loans_cleaned['emp_title'].isnull().sum()
# Out:
# 0

# %%
# add another column that describes the status of the loan
# assign an integer value of 1 IF the loan_status is "Current" or "Fully Paid"
# ELSE assign and integer value of 0 to loan_status_is_great

# %%
great_status = ['Current','Fully Paid']

# def loan_status_is_great(loan_status):
  # for status in loan_status_is_great:
    # if status in loan_status:
      # return int(1)
    # else:
      # return int(0)

def status_check(loan_status):

  if loan_status == "Current" or loan_status == "Fully Paid":
    return 1
  else:
    return 0
      
  for example in examples:
    print(loan_status_is_great(example))

# %%
loans_cleaned['loan_status_is_great'] = loans_cleaned['loan_status'].apply(status_check)
loans_cleaned['loan_status_is_great']
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 128406    1
# 128407    0
# 128408    1
# 128409    1
# 128410    1
# Name: loan_status_is_great, Length: 128411, dtype: int64

# %%
# create a column list of all columns headers that end with "_d"
[col for col in loans_cleaned if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
# issue date: month and year; string
loans_cleaned['issue_d'][:10]
# df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
# convert from string to numeric data using datetime stamp
loans_cleaned['issue_d'] = pd.to_datetime(loans_cleaned['issue_d'], infer_datetime_format=True)
loans_cleaned['issue_d']
# Out:
# 0        2018-12-01
# 1        2018-12-01
# 2        2018-12-01
# 3        2018-12-01
# 4        2018-12-01
#             ...
# 128406   2018-10-01
# 128407   2018-10-01
# 128408   2018-10-01
# 128409   2018-10-01
# 128410   2018-10-01
# Name: issue_d, Length: 128411, dtype: datetime64[ns]

# %%
# check for persistance of conversion
#df['issue_d'].iloc[0]
loans_cleaned['issue_d'][0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
'''example notation'''
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
      # '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
       #'2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')
# Out:
# 'example notation'

# %%
# returns year of datetime
loans_cleaned['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128406    2018
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# Name: issue_d, Length: 128411, dtype: int64

# %%
# returns month of datetime
loans_cleaned['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128406    10
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# Name: issue_d, Length: 128411, dtype: int64

# %%
# assigning numeric values makes them easy to manipulate
loans_cleaned['issue_year'] = loans_cleaned['issue_d'].dt.year
loans_cleaned['issue_month'] = loans_cleaned['issue_d'].dt.month

loans_cleaned.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      12000        12000          12000.0   36 months   16.14%       422.72
# 2       7000         7000           6975.0   36 months   10.72%       228.25
# 3      25000        25000          25000.0   60 months   16.14%       609.82
# 4      10400        10400          10400.0   36 months   12.98%       350.32
#
#   grade sub_grade                  emp_title emp_length home_ownership  \
# 0     C        C2                 BUS DRIVER    4 years            OWN
# 1     C        C4      SALES ACCOUNT MANAGER    4 years           RENT
# 2     B        B2           BUSINESS ANALYST   < 1 year       MORTGAGE
# 3     C        C4         PRODUCTION MANAGER    5 years       MORTGAGE
# 4     B        B5  PROGRAM SUPPORT ASSISTANT  10+ years       MORTGAGE
#
#    annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# ...

# %%
# add column last_pymt_d_month
# convert from string to numeric data using datetime stamp
# assigning numeric values makes them easy to manipulate
loans_cleaned['last_pymnt_d'] = pd.to_datetime(loans_cleaned['last_pymnt_d'], infer_datetime_format=True)
loans_cleaned['last_payment_d_month'] = loans_cleaned['last_pymnt_d'].dt.month
loans_cleaned['last_payment_d_month']
# Out:
# 0          2.0
# 1          7.0
# 2          7.0
# 3          4.0
# 4          7.0
#           ...
# 128406     7.0
# 128407    12.0
# 128408     7.0
# 128409     7.0
# 128410     7.0
# Name: last_payment_d_month, Length: 128411, dtype: float64

# %%
# checking work
loans_cleaned

# %%
# add column last_pymt_d_year
# assigning numeric values makes them easy to manipulate
loans_cleaned['last_payment_d_year'] = loans_cleaned['last_pymnt_d'].dt.year
loans_cleaned['last_payment_d_year']
# Out:
# 0         2020.0
# 1         2020.0
# 2         2019.0
# 3         2019.0
# 4         2020.0
#            ...
# 128406    2020.0
# 128407    2018.0
# 128408    2020.0
# 128409    2020.0
# 128410    2020.0
# Name: last_payment_d_year, Length: 128411, dtype: float64

# %%
# checking work
loans_cleaned
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           20000        20000          20000.0   36 months   14.47%
# 1           12000        12000          12000.0   36 months   16.14%
# 2            7000         7000           6975.0   36 months   10.72%
# 3           25000        25000          25000.0   60 months   16.14%
# 4           10400        10400          10400.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
#
#         installment grade sub_grade                  emp_title emp_length  \
# ...

# %%
# view first 5 of column containing customer's earliest line of credit
loans_cleaned['earliest_cr_line'].head()
# Out:
# 0    Jun-1979
# 1    Nov-2013
# 2    Sep-2011
# 3    Sep-2003
# 4    Jul-2013
# Name: earliest_cr_line, dtype: object

# %%
# creating new column
loans_cleaned['earliest_cr_line'] = pd.to_datetime(loans_cleaned['earliest_cr_line'], 
                                        infer_datetime_format=True)
loans_cleaned['earliest_cr_line']
# Out:
# 0        1979-06-01
# 1        2013-11-01
# 2        2011-09-01
# 3        2003-09-01
# 4        2013-07-01
#             ...
# 128406   2012-08-01
# 128407   1985-08-01
# 128408   1982-07-01
# 128409   2006-06-01
# 128410   2008-10-01
# Name: earliest_cr_line, Length: 128411, dtype: datetime64[ns]

# %%
# number of years of credit history
loans_cleaned['years_from_earliest_credit_to_issue'] = (loans_cleaned['issue_d'] 
                                                        - loans_cleaned['earliest_cr_line']
                                                        ).dt.days / 365

loans_cleaned['years_from_earliest_credit_to_issue']
# Out:
# 0         39.528767
# 1          5.084932
# 2          7.254795
# 3         15.260274
# 4          5.421918
#             ...
# 128406     6.169863
# 128407    33.189041
# 128408    36.276712
# 128409    12.342466
# 128410    10.005479
# Name: years_from_earliest_credit_to_issue, Length: 128411, dtype: float64

# %%
loans_cleaned['years_from_earliest_credit_to_issue'].describe()
# Out:
# count    128411.000000
# mean         16.054528
# std           7.908340
# min           3.084932
# 25%          11.093151
# 50%          14.427397
# 75%          19.846575
# max          68.961644
# Name: years_from_earliest_credit_to_issue, dtype: float64

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
###LendingClub###

# %%
# Remove %; convert to floats; handle missing values (revol_util)

# %%
def revol_util_to_float(revol_util):

  string = str(revol_util)
  string = string.strip('%')
  string = string.strip(' ')
 
  return float(string)

# %%
loans_cleaned['revol_util_to_float'] = loans_cleaned['revol_util'].apply(revol_util_to_float)
loans_cleaned
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           20000        20000          20000.0   36 months   14.47%
# 1           12000        12000          12000.0   36 months   16.14%
# 2            7000         7000           6975.0   36 months   10.72%
# 3           25000        25000          25000.0   60 months   16.14%
# 4           10400        10400          10400.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128406       5600         5600           5600.0   36 months   13.56%
# 128407      23000        23000          23000.0   36 months   15.02%
# 128408      10000        10000          10000.0   36 months   15.02%
# 128409       5000         5000           5000.0   36 months   13.56%
# 128410      10000        10000           9750.0   36 months   11.06%
#
#         installment grade sub_grade                  emp_title emp_length  \
# ...

# %%
# checking work
loans_cleaned['revol_util_to_float'][:]
# Out:
# 0         73.0
# 1         61.8
# 2          7.5
# 3         36.8
# 4          9.8
#           ...
# 128406    34.5
# 128407    43.6
# 128408    37.1
# 128409    27.3
# 128410    13.1
# Name: revol_util_to_float, Length: 128411, dtype: float64

# %%
# replace/modify emp_title with 'Other' if not in top 20

# %%
loans_cleaned['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# unknown               20947
# TEACHER                2557
# MANAGER                2395
# REGISTERED NURSE       1418
# DRIVER                 1258
# SUPERVISOR             1160
# TRUCK DRIVER            920
# RN                      834
# OFFICE MANAGER          805
# SALES                   803
# GENERAL MANAGER         791
# PROJECT MANAGER         720
# OWNER                   625
# DIRECTOR                523
# OPERATIONS MANAGER      518
# SALES MANAGER           500
# POLICE OFFICER          440
# NURSE                   425
# TECHNICIAN              420
# ENGINEER                412
# Name: emp_title, dtype: int64

# %%
great_title = [emp_title,'Other']


def title_check(emp_title):

  if loans_cleaned['emp_title'].value_counts(dropna=False, ascending=False)[0] >= 412
  # if loans_cleaned['emp_title'].value_counts(dropna=False, ascending=False)[0] >= loans_cleaned['emp_title'].value_counts(dropna=False, ascending=False)[:20]
  return emp_title
  else:
    return 'Other'
      
  for example in examples:
    print(top_20_emp_title(example))

###still working on this one###
# Out:
#   File "<ipython-input-183-c83092501f75>", line 6
#     if loans_cleaned['emp_title'].value_counts(dropna=False, ascending=False)[0] >= 412
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
loans_cleaned['top_20_emp_title'] = loans_cleaned['emp_title'].apply(title_check)
loans_cleaned['top_20_emp_title']

# %%
# optional

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
###Instacart###

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-08-04 21:16:40--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.100.246
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.100.246|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  34.8MB/s    in 6.3s
#
# 2020-08-04 21:16:47 (31.4 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01

# %%
# counts_by_day_of_week (Onodera)

# %%
# counts_by_hour (Onodera)

# %%
# Simple Exploration Notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
###subprocess.check_output raises CalledProcessError as listed in Kaggle notebook###
file_list = []

import subprocess
file_list = subprocess.Popen(["ls", "../input"])
file_list = file_list.decode("utf8")
print(file_list)

###I know what I really want to do is load and read these files not create a list of them###
###I just haven't figured out how to backtrace the laguage the Kaggle notebook is using###
###to do that without throwing errors###
