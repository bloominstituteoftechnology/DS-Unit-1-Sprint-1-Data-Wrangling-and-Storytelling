# %% [markdown]
# <a href="https://colab.research.google.com/github/gitHasty-0321/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/STEVEN_HASTINGS_Module_2_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)
pd.set_option('display.max_colwidth',200)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

# %%
df.shape
# Out:
# (1460, 81)

# %%
pd.set_option('display.max_rows', 100)

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df['BedroomAbvGr'].head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# 5    1
# 6    3
# 7    3
# 8    2
# 9    2
# Name: BedroomAbvGr, dtype: int64

# %%
df['LotFrontage'].head(10)
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# 5    85.0
# 6    75.0
# 7     NaN
# 8    51.0
# 9    50.0
# Name: LotFrontage, dtype: float64

# %%
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
import numpy as np

# %%
type(np.NaN)
# Out:
# float

# %%
dfnums = df.select_dtypes(include='number')

# %%
dfnums.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
dfobj = df.select_dtypes(include= object ,exclude='number')
dfobj.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
dfobj['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
df['BedroomAbvGr']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       4
#        ..
# 1455    3
# 1456    3
# 1457    4
# 1458    2
# 1459    3
# Name: BedroomAbvGr, Length: 1460, dtype: int64

# %%
df['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
small_df = df[['TotalBsmtSF','1stFlrSF','2ndFlrSF', 'SalePrice']].copy()

# %%
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
small_df['TotalSquareFootage'] = small_df['1stFlrSF'] + small_df['2ndFlrSF']

# %%
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage
# 0          856       856       854     208500                1710
# 1         1262      1262         0     181500                1262
# 2          920       920       866     223500                1786
# 3          756       961       756     140000                1717
# 4         1145      1145      1053     250000                2198

# %%
small_df['PricePerSqFt'] = (small_df['SalePrice']/small_df['TotalSquareFootage'])

# %%
small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage  \
# 0          856       856       854     208500                1710
# 1         1262      1262         0     181500                1262
# 2          920       920       866     223500                1786
# 3          756       961       756     140000                1717
# 4         1145      1145      1053     250000                2198
#
#    PricePerSqFt
# 0    121.929825
# 1    143.819334
# 2    125.139978
# 3     81.537566
# 4    113.739763

# %%
bath_df = df[['BsmtFullBath','BsmtHalfBath','FullBath','HalfBath']]

# %%
bath_df
# Out:
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath
# 0                1             0         2         1
# 1                0             1         2         0
# 2                1             0         2         1
# 3                1             0         1         0
# 4                1             0         2         1
# ...            ...           ...       ...       ...
# 1455             0             0         2         1
# 1456             1             0         2         0
# 1457             0             0         2         0
# 1458             1             0         1         0
# 1459             1             0         1         1
#
# [1460 rows x 4 columns]

# %%
#### finish bath aggregation

# %%
dfnums
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-01-18 03:30:39--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.6’
#
# LoanStats_2018Q4.cs     [                <=> ]  21.72M   773KB/s    in 29s
#
# 2020-01-18 03:31:09 (757 KB/s) - ‘LoanStats_2018Q4.csv.zip.6’ saved [22776791]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","3686.37","3686.37","2652.39","2652.39","1913.63","738.76","0.0","0.0","0.0","Dec-2019","190.21","Jan-2020","Nov-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv',skiprows= 1,skipfooter=2,engine='python')

# %%
print(df.shape)
print(df.head())
# Out:
# (128397, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       6000         6000           6000.0   36 months
# 1 NaN        NaN      24000        24000          24000.0   36 months
# 2 NaN        NaN      30000        30000          30000.0   36 months
# 3 NaN        NaN       8000         8000           8000.0   36 months
# 4 NaN        NaN      22400        22400          22400.0   60 months
#
#   int_rate  installment grade sub_grade                emp_title emp_length  \
# 0   14.47%       206.44     C        C2                  Manager  10+ years
# 1   10.33%       778.14     B        B1      Maintenance Manager  10+ years
# 2   15.02%      1040.26     C        C3             Firefighter   10+ years
# 3   12.98%       269.48     B        B5               Controller    4 years
# 4   16.14%       546.40     C        C4  Paramedic/ Fire Fighter  10+ years
#
# ...

# %%
print(df.tail())
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128392 NaN        NaN      23000        23000          23000.0   36 months
# 128393 NaN        NaN      10000        10000          10000.0   36 months
# 128394 NaN        NaN       5000         5000           5000.0   36 months
# 128395 NaN        NaN      10000        10000           9750.0   36 months
# 128396 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128392   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128393   15.02%       346.76     C        C3        security guard    5 years
# 128394   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128395   11.06%       327.68     B        B3                   NaN        NaN
# 128396   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
df = df.drop(['url','member_id', 'desc', 'id'], axis=1)

# %%
print(df.shape)
# Out:
# (128397, 140)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3             Firefighter   10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# loan_amnt                                          0
# mo_sin_rcnt_rev_tl_op                              0
# mo_sin_old_rev_tl_op                               0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
#                                                ...
# hardship_status                               128164
# hardship_reason                               128164
# hardship_dpd                                  128164
# hardship_loan_status                          128164
# orig_projected_additional_accrued_interest    128191
# Length: 140, dtype: int64

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     10.33%
# 2     15.02%
# 3     12.98%
# 4     16.14%
# 5     12.98%
# 6     15.02%
# 7     16.14%
# 8     14.47%
# 9     13.56%
# Name: int_rate, dtype: object

# %%
df['int_rate'][0:10]
# Out:
# 0     14.47%
# 1     10.33%
# 2     15.02%
# 3     12.98%
# 4     16.14%
# 5     12.98%
# 6     15.02%
# 7     16.14%
# 8     14.47%
# 9     13.56%
# Name: int_rate, dtype: object

# %%
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
df['int_rate'][3:7]
# Out:
# 3     12.98%
# 4     16.14%
# 5     12.98%
# 6     15.02%
# Name: int_rate, dtype: object

# %%
df['int_rate'][3]
# Out:
# ' 12.98%'

# %%
int_rate = ' 14.17%'

# %%
int_rate.strip()
# Out:
# '14.17%'

# %%
int_rate.strip('%')
# Out:
# ' 14.17'

# %%
int_rate.strip().strip('%')
# Out:
# '14.17'

# %%
type(int_rate.strip().strip('%'))
# Out:
# str

# %%
float(int_rate.strip().strip('%'))
# Out:
# 14.17

# %%
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
df['int_rate'].str.replace(' ','')
# Out:
# 0         14.47%
# 1         10.33%
# 2         15.02%
# 3         12.98%
# 4         16.14%
#            ...
# 128392    15.02%
# 128393    15.02%
# 128394    13.56%
# 128395    11.06%
# 128396    16.91%
# Name: int_rate, Length: 128397, dtype: object

# %%
df['int_rate'].str.strip('')
# Out:
# 0          14.47%
# 1          10.33%
# 2          15.02%
# 3          12.98%
# 4          16.14%
#            ...
# 128392     15.02%
# 128393     15.02%
# 128394     13.56%
# 128395     11.06%
# 128396     16.91%
# Name: int_rate, Length: 128397, dtype: object

# %%
def int_rate_to_float(cell_contents):
  #do some stuff
  return float(cell_contents.strip().strip('%'))

# %%
int_rate_to_float(int_rate)
# Out:
# 14.17

# %%
type(int_rate_to_float(int_rate))
# Out:
# float

# %%
# new_list = []
# for cell in df['int_rate']:
#   new_list.append(int_rate_to_float(cell))

# df['int_rate_column'] = pd.Series(new_list)

# %%
df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)

# %%
df['int_rate_float']
# Out:
# 0         14.47
# 1         10.33
# 2         15.02
# 3         12.98
# 4         16.14
#           ...
# 128392    15.02
# 128393    15.02
# 128394    13.56
# 128395    11.06
# 128396    16.91
# Name: int_rate_float, Length: 128397, dtype: float64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3             Firefighter   10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
df.dtypes[-5:]
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# int_rate_float           float64
# dtype: object

# %%
df['emp_title'].value_counts(dropna=False)[:20]
# Out:
# NaN                   20942
# Teacher                2090
# Manager                1773
# Registered Nurse        951
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
len(df['emp_title'].value_counts())
# Out:
# 43889

# %%
df['emp_title'].isnull().sum()
# Out:
# 20942

# %%
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
def clean_title(rigadoon):
  if isinstance(rigadoon, str):
    return rigadoon.strip().title()
  else:
      return "Unknown"

for example in examples:
  print(clean_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
# def clean_title(rigadoon):
#   if isinstance(rigadoon, str):
#     return rigadoon.title().strip()
#   else:
#       return "Unknown"

# for title in examples:
#   print(clean_title(title))

# %%
# list comprehension
[clean_title(example) for example in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3              Firefighter  10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# ...

# %%
len(df['emp_title'].value_counts())
# Out:
# 34899

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'][:10]
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
df['issue_d'].iloc[0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128392    2018
# 128393    2018
# 128394    2018
# 128395    2018
# 128396    2018
# Name: issue_d, Length: 128397, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128392    10
# 128393    10
# 128394    10
# 128395    10
# 128396    10
# Name: issue_d, Length: 128397, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3              Firefighter  10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# ...

# %%
df['earliest_cr_line'].head()
# Out:
# 0    Jun-2006
# 1    Oct-1996
# 2    May-2007
# 3    Mar-2009
# 4    Dec-2004
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)

# %%
df['days_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df['days_from_earliest_credit_to_issue'].head()
# Out:
# 0    4566
# 1    8096
# 2    4232
# 3    3562
# 4    5113
# Name: days_from_earliest_credit_to_issue, dtype: int64

# %%
df['days_from_earliest_credit_to_issue'].describe()
# Out:
# count    128397.000000
# mean       5859.918464
# std        2886.617678
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: days_from_earliest_credit_to_issue, dtype: float64

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
df['int_term'] = df['term'].str.strip('months')

# %%
df['int_term'] = df['int_term'].astype(int,copy=True)

# %%
df['int_term'].dtypes
# Out:
# dtype('int64')

# %%
type(df['int_term'][3])
# Out:
# numpy.int64

# %%
df['int_term'][3]
# Out:
# 36

# %%
df['loan_status']
# Out:
# 0         Charged Off
# 1             Current
# 2          Fully Paid
# 3             Current
# 4             Current
#              ...
# 128392    Charged Off
# 128393        Current
# 128394        Current
# 128395        Current
# 128396        Current
# Name: loan_status, Length: 128397, dtype: object

# %%
df.isnull().sum()
# Out:
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
#                                      ..
# int_rate_float                        0
# issue_year                            0
# issue_month                           0
# days_from_earliest_credit_to_issue    0
# int_term                              0
# Length: 145, dtype: int64

# %%
df.shape
# Out:
# (128397, 145)

# %%
df[(df['loan_status'] == 'Current') | (df['loan_status'] == 'Fully Paid')]
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 1           24000        24000          24000.0   36 months   10.33%
# 2           30000        30000          30000.0   36 months   15.02%
# 3            8000         8000           8000.0   36 months   12.98%
# 4           22400        22400          22400.0   60 months   16.14%
# 5            5000         5000           5000.0   36 months   12.98%
# ...           ...          ...              ...         ...      ...
# 128391       5600         5600           5600.0   36 months   13.56%
# 128393      10000        10000          10000.0   36 months   15.02%
# 128394       5000         5000           5000.0   36 months   13.56%
# 128395      10000        10000           9750.0   36 months   11.06%
# 128396      10000        10000          10000.0   36 months   16.91%
#
#         installment grade sub_grade                emp_title emp_length  \
# ...

# %%
df['loan_status'].value_counts()
# Out:
# Current               97694
# Fully Paid            21476
# Charged Off            5260
# Late (31-120 days)     2656
# In Grace Period         784
# Late (16-30 days)       524
# Default                   3
# Name: loan_status, dtype: int64

# %%
df['loan_status_is_great'] = df['loan_status'].map({"Current": 1,"Fully Paid": 1,"Charged Off": 0,"Late (31-120 days)": 0, "In Grace Period": 0,"Late (16-30 days)": 0,"Default": 0})

# %%
df['loan_status_is_great']
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 128392    0
# 128393    1
# 128394    1
# 128395    1
# 128396    1
# Name: loan_status_is_great, Length: 128397, dtype: int64

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        ...
#        'settlement_date', 'settlement_amount', 'settlement_percentage',
#        'settlement_term', 'int_rate_float', 'issue_year', 'issue_month',
#        'days_from_earliest_credit_to_issue', 'int_term',
#        'loan_status_is_great'],
#       dtype='object', length=146)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       6000         6000           6000.0   36 months   14.47%       206.44
# 1      24000        24000          24000.0   36 months   10.33%       778.14
# 2      30000        30000          30000.0   36 months   15.02%      1040.26
# 3       8000         8000           8000.0   36 months   12.98%       269.48
# 4      22400        22400          22400.0   60 months   16.14%       546.40
#
#   grade sub_grade                emp_title emp_length home_ownership  \
# 0     C        C2                  Manager  10+ years           RENT
# 1     B        B1      Maintenance Manager  10+ years       MORTGAGE
# 2     C        C3              Firefighter  10+ years           RENT
# 3     B        B5               Controller    4 years       MORTGAGE
# 4     C        C4  Paramedic/ Fire Fighter  10+ years            OWN
#
#    annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128397 entries, 0 to 128396
# Columns: 146 entries, loan_amnt to loan_status_is_great
# dtypes: datetime64[ns](2), float64(54), int64(56), object(34)
# memory usage: 143.0+ MB

# %%
df['settlement_date'].isnull().sum()
# Out:
# 127946

# %%
df['last_pymnt_d'].fillna(method='ffill',inplace=True)

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'],infer_datetime_format=True)

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month

# %%
df['last_pymnt_d_month'].isnull().sum()
# Out:
# 0

# %%
# df['last_pymnt_d_month'].fillna(method='ffill',inplace=True)

# %%
# df['last_pymnt_d_month'] = df['last_pymnt_d_month'].astype('datetime64[ns]')

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d_month'].astype(int)

# %%
df['last_pymnt_d_month']
# Out:
# 0          4
# 1         12
# 2          2
# 3         12
# 4         12
#           ..
# 128392    12
# 128393    12
# 128394    12
# 128395    12
# 128396    12
# Name: last_pymnt_d_month, Length: 128397, dtype: int64

# %%
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year

# %%
df['last_pymnt_d_year'].head()
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# Name: last_pymnt_d_year, dtype: int64

# %%
df.isnull().sum()
# Out:
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
#                                      ..
# days_from_earliest_credit_to_issue    0
# int_term                              0
# loan_status_is_great                  0
# last_pymnt_d_month                    0
# last_pymnt_d_year                     0
# Length: 148, dtype: int64

# %%
df.drop(['int_rate'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  installment grade  \
# 0       6000         6000           6000.0   36 months       206.44     C
# 1      24000        24000          24000.0   36 months       778.14     B
# 2      30000        30000          30000.0   36 months      1040.26     C
# 3       8000         8000           8000.0   36 months       269.48     B
# 4      22400        22400          22400.0   60 months       546.40     C
#
#   sub_grade                emp_title emp_length home_ownership  annual_inc  \
# 0        C2                  Manager  10+ years           RENT     55000.0
# 1        B1      Maintenance Manager  10+ years       MORTGAGE    100000.0
# 2        C3              Firefighter  10+ years           RENT     90000.0
# 3        B5               Controller    4 years       MORTGAGE     95000.0
# 4        C4  Paramedic/ Fire Fighter  10+ years            OWN     56000.0
#
# ...

# %%
df['revol_util'].isnull().sum()
# Out:
# 156

# %%
df['revol_util'].ffill(inplace=True)

# %%
df['revol_util'].isnull().sum()
# Out:
# 0

# %%
df['revol_util'][3]
# Out:
# '33.3%'

# %%
df['revol_util'] = df['revol_util'].str.strip('%')

# %%
df['revol_util'].value_counts()
# Out:
# 0        1135
# 43        225
# 49        222
# 39.1      220
# 32        218
#          ...
# 104.4       1
# 103.6       1
# 132.6       1
# 108.8       1
# 102.1       1
# Name: revol_util, Length: 1074, dtype: int64

# %%
df['revol_util'] = df['revol_util'].astype(float,copy=True)

# %%
df.select_dtypes(include=['int','float'])
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  installment  annual_inc  \
# 0            6000         6000           6000.0       206.44     55000.0
# 1           24000        24000          24000.0       778.14    100000.0
# 2           30000        30000          30000.0      1040.26     90000.0
# 3            8000         8000           8000.0       269.48     95000.0
# 4           22400        22400          22400.0       546.40     56000.0
# ...           ...          ...              ...          ...         ...
# 128392      23000        23000          23000.0       797.53     75000.0
# 128393      10000        10000          10000.0       346.76     38000.0
# 128394       5000         5000           5000.0       169.83     35360.0
# 128395      10000        10000           9750.0       327.68     44400.0
# 128396      10000        10000          10000.0       356.08     80000.0
#
#           dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# ...

# %%
# df['revol_util'] = pd.to_numeric(df['revol_util'],downcast='float')

# %%
df['revol_util'].dtypes
# Out:
# dtype('float64')

# %%
df.drop('term',axis=1,inplace=True)

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (128397, 146)

# %%
counts = df.emp_title.value_counts()

# %%
counts.shape
# Out:
# (34899,)

# %%
big20 = counts[:20]

# %%
big20
# Out:
# Unknown               20942
# Teacher                2557
# Manager                2395
# Registered Nurse       1417
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          804
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   424
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
counts[20:] = 'OTHER'

# %%
counts.head(20)
# Out:
# Unknown               20942
# Teacher                2557
# Manager                2395
# Registered Nurse       1417
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          804
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   424
# Technician              420
# Engineer                412
# Name: emp_title, dtype: object

# %%
counts.tail(1000)
# Out:
# Social Security Disability Specialist    OTHER
# Salesrep                                 OTHER
# Sustainable Agriculture Specialist       OTHER
# Sr Software Configuration Specialist     OTHER
# Repossession Agent                       OTHER
#                                          ...
# Graphic Designer/ Printer                OTHER
# Ops Finance Controller                   OTHER
# Customer Service Representative V        OTHER
# Realestate Agent                         OTHER
# Lubrication Specialist                   OTHER
# Name: emp_title, Length: 1000, dtype: object

# %%
var_added = pd.DataFrame(counts)

# %%
print(var_added)
# Out:
#                                   emp_title
# Unknown                               20942
# Teacher                                2557
# Manager                                2395
# Registered Nurse                       1417
# Driver                                 1258
# ...                                     ...
# Graphic Designer/ Printer             OTHER
# Ops Finance Controller                OTHER
# Customer Service Representative V     OTHER
# Realestate Agent                      OTHER
# Lubrication Specialist                OTHER
#
# [34899 rows x 1 columns]

# %%
var_added.head(21)
# Out:
#                          emp_title
# Unknown                      20942
# Teacher                       2557
# Manager                       2395
# Registered Nurse              1417
# Driver                        1258
# Supervisor                    1160
# Truck Driver                   920
# Rn                             834
# Office Manager                 804
# Sales                          803
# General Manager                791
# Project Manager                720
# Owner                          625
# Director                       523
# Operations Manager             518
# Sales Manager                  500
# Police Officer                 440
# Nurse                          424
# Technician                     420
# Engineer                       412
# Administrative Assistant     OTHER

# %%
var_added.tail()
# Out:
#                                   emp_title
# Graphic Designer/ Printer             OTHER
# Ops Finance Controller                OTHER
# Customer Service Representative V     OTHER
# Realestate Agent                      OTHER
# Lubrication Specialist                OTHER

# %%
dfinalplz= df.append(var_added,ignore_index=True,sort=False)

# %%
dfinalplz.emp_title
# Out:
# 0                         Manager
# 1             Maintenance Manager
# 2                     Firefighter
# 3                      Controller
# 4         Paramedic/ Fire Fighter
#                    ...
# 163291                      OTHER
# 163292                      OTHER
# 163293                      OTHER
# 163294                      OTHER
# 163295                      OTHER
# Name: emp_title, Length: 163296, dtype: object

# %%
dfinalplz
# Out:
#         loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0          6000.0       6000.0  ...                  60.01            24.0
# 1         24000.0      24000.0  ...                    NaN             NaN
# 2         30000.0      30000.0  ...                    NaN             NaN
# 3          8000.0       8000.0  ...                    NaN             NaN
# 4         22400.0      22400.0  ...                    NaN             NaN
# ...           ...          ...  ...                    ...             ...
# 163291        NaN          NaN  ...                    NaN             NaN
# 163292        NaN          NaN  ...                    NaN             NaN
# 163293        NaN          NaN  ...                    NaN             NaN
# 163294        NaN          NaN  ...                    NaN             NaN
# 163295        NaN          NaN  ...                    NaN             NaN
#
# [163296 rows x 140 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data
