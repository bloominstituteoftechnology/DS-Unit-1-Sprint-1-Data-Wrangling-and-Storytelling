# %% [markdown]
# <a href="https://colab.research.google.com/github/nouretienne/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Nour_Etienne_Day_3_ds9_warmup_10_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Practice

# %%
# Read a csv file from a specified source and print the first 5 rows
import pandas as pd
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

print(diamonds.shape)
diamonds.head()
# Out:
# (53940, 10)
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Engineer a new feature named 'quality_color' using 'cut' and 'color', don't overthink it
diamonds['quality_color'] = diamonds['color'] + ' ' + diamonds['cut']
diamonds.head()
# Out:
#    carat      cut color clarity  depth  ...  price     x     y     z  quality_color
# 0   0.23    Ideal     E     SI2   61.5  ...    326  3.95  3.98  2.43        E Ideal
# 1   0.21  Premium     E     SI1   59.8  ...    326  3.89  3.84  2.31      E Premium
# 2   0.23     Good     E     VS1   56.9  ...    327  4.05  4.07  2.31         E Good
# 3   0.29  Premium     I     VS2   62.4  ...    334  4.20  4.23  2.63      I Premium
# 4   0.31     Good     J     SI2   63.3  ...    335  4.34  4.35  2.75         J Good
#
# [5 rows x 11 columns]

# %%
# Rename two of the columns
diamonds.rename(columns = {'x': 'width', 'y': 'length'})
diamonds.head()
# Out:
#    carat      cut color clarity  depth  ...  price     x     y     z  quality_color
# 0   0.23    Ideal     E     SI2   61.5  ...    326  3.95  3.98  2.43        E Ideal
# 1   0.21  Premium     E     SI1   59.8  ...    326  3.89  3.84  2.31      E Premium
# 2   0.23     Good     E     VS1   56.9  ...    327  4.05  4.07  2.31         E Good
# 3   0.29  Premium     I     VS2   62.4  ...    334  4.20  4.23  2.63      I Premium
# 4   0.31     Good     J     SI2   63.3  ...    335  4.34  4.35  2.75         J Good
#
# [5 rows x 11 columns]

# %%
# Drop the 'carat' column from the dataframe
diamonds_drop = diamonds.drop(columns = ['carat'])
diamonds_drop.head()
# Out:
#        cut color clarity  depth  table  price     x     y     z quality_color
# 0    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43       E Ideal
# 1  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31     E Premium
# 2     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31        E Good
# 3  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63     I Premium
# 4     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75        J Good

# %%
# Use the 'carat' column to sort the dataframe, ascending
diamonds_ascending = diamonds.sort_values('carat', ascending = True)
diamonds_ascending.head()
# Out:
#        carat      cut color clarity  ...     x     y     z  quality_color
# 31593    0.2  Premium     E     VS2  ...  3.81  3.78  2.32      E Premium
# 31597    0.2    Ideal     D     VS2  ...  3.81  3.77  2.33        D Ideal
# 31596    0.2  Premium     F     VS2  ...  3.73  3.71  2.33      F Premium
# 31595    0.2    Ideal     E     VS2  ...  3.86  3.84  2.30        E Ideal
# 31594    0.2  Premium     E     VS2  ...  3.84  3.80  2.28      E Premium
#
# [5 rows x 11 columns]

# %%
# Find diamonds where x (length) > 5, y (width) > 5, and z (depth) > 5
diamonds[diamonds['x']>5 , diamonds['y'] > 5 , diamonds['z'] >5];
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-c37c8d1d7e46> in <module>()
# ----> 1 diamonds[diamonds['x']>5 , diamonds['y'] > 5 , diamonds['z'] >5];
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 53910     True
# 53911     True
# 53912     True
# 53913     True
# 53914     True
# 53915     True
# 53916     True
# 53917     True
# 53918     True
# 53919     True
# 53920     True
# 53921     True
# 53922     True
# 53923     True
# 53924     True
# 53925     True
# 53926     True
# 53927     True
# 53928     True
# 53929     True
# 53930     True
# 53931     True
# 53932     True
# 53933     True
# 53934     True
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: x, Length: 53940, dtype: bool, 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 53910     True
# 53911     True
# 53912     True
# 53913     True
# 53914     True
# 53915     True
# 53916     True
# 53917     True
# 53918     True
# 53919     True
# 53920     True
# 53921     True
# 53922     True
# 53923     True
# 53924     True
# 53925     True
# 53926     True
# 53927     True
# 53928     True
# 53929     True
# 53930     True
# 53931     True
# 53932     True
# 53933     True
# 53934     True
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: y, Length: 53940, dtype: bool, 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 53910    False
# 53911    False
# 53912    False
# 53913    False
# 53914    False
# 53915    False
# 53916    False
# 53917    False
# 53918    False
# 53919    False
# 53920    False
# 53921    False
# 53922    False
# 53923    False
# 53924    False
# 53925    False
# 53926    False
# 53927    False
# 53928    False
# 53929    False
# 53930    False
# 53931    False
# 53932    False
# 53933    False
# 53934    False
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: z, Length: 53940, dtype: bool)' is an invalid key

# %%
# Filter the dataframe to display only diamonds that are 'premium' or 'ideal'

# %%
# STRETCH
# Choose an appropriate visualization to plot 2 continuous variables on the x and y axis

# %%
# Apply a seaborn pairplot and explore relationships
# What does this visualization say about our features?
# https://seaborn.pydata.org/generated/seaborn.pairplot.html
