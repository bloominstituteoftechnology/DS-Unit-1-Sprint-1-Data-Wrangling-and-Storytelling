# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiasofiaC/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Claudia_Make_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-10-01 19:25:55--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [                 <=>]  21.62M   899KB/s    in 25s
#
# 2019-10-01 19:26:20 (895 KB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22667400]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
#check out the head of our data set
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
#now lets look at the tail
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4122.15","4122.15","2081.76","2081.76","1477.85","603.91","0.0","0.0","0.0","Sep-2019","190.21","Oct-2019","Sep-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
#lets look at the data in a tabular form

import pandas as pd

df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
#show all nulls in order
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
#we want to drop columns that are just made up of NaNs

df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)

# %%
#check if it worked
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      20000        20000  ...                    NaN             NaN
# 1      25000        25000  ...                    NaN             NaN
# 2      26500        26500  ...                    NaN             NaN
# 3      10400        10400  ...                    NaN             NaN
# 4      35000        35000  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
#replace strings with floats
#check types of each column

df.dtypes[:10]
# Out:
# id                 float64
# member_id          float64
# loan_amnt            int64
# funded_amnt          int64
# funded_amnt_inv    float64
# term                object
# int_rate            object
# installment        float64
# grade               object
# sub_grade           object
# dtype: object

# %%
#int_rate is considered an object because of the '%'

df['int_rate'][:10]
# Out:
# 0     14.47%
# 1     16.14%
# 2     11.31%
# 3     12.98%
# 4     12.98%
# 5      7.56%
# 6     17.97%
# 7     14.47%
# 8     11.80%
# 9     17.97%
# Name: int_rate, dtype: object

# %%
#step by step convert int_rate to float

int_rate = ' 15.02%'
int_rate
# Out:
# ' 15.02%'

# %%
int_rate.strip()
# Out:
# '15.02%'

# %%
int_rate.strip().strip('%')
# Out:
# '15.02'

# %%
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
#float!

# %%
#function to remove % from our string

def int_rate_to_float(int_rate):
  return float(int_rate.strip().strip('%'))

int_rate_to_float(int_rate)
# Out:
# 15.02

# %%
#now apply it to the column int_rate

df['int_rate'].apply(int_rate_to_float)[:15]
# Out:
# 0     14.47
# 1     16.14
# 2     11.31
# 3     12.98
# 4     12.98
# 5      7.56
# 6     17.97
# 7     14.47
# 8     11.80
# 9     17.97
# 10    18.94
# 11    10.72
# 12    11.31
# 13    10.33
# 14    17.97
# Name: int_rate, dtype: float64

# %%
#now make it true for our actual df as its own column

df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      20000        20000  ...              NaN          14.47
# 1      25000        25000  ...              NaN          16.14
# 2      26500        26500  ...              NaN          11.31
# 3      10400        10400  ...              NaN          12.98
# 4      35000        35000  ...              NaN          12.98
#
# [5 rows x 141 columns]

# %%
# 2 different tyes of column referencing
#df.int_rate[:10]
#df['int_rate'][:10]

# %%
#clean up emp_title
#looking at top 20 titles
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
#count of unique job titles

len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
df['emp_title'].value_counts().reset_index().head()
# Out:
#               index  emp_title
# 0           Teacher       2090
# 1           Manager       1773
# 2  Registered Nurse        952
# 3            Driver        924
# 4                RN        726

# %%
df['emp_title'].value_counts().reset_index().shape
# Out:
# (43892, 2)

# %%
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
#clean up and handle missing values
#need numpy
import numpy as np

# %%
#with a function
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return 'Unknown'

[clean_title(item) for item in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
#apply to our df
df['emp_title'] = df['emp_title'].apply(clean_title)

df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      20000        20000  ...              NaN          14.47
# 1      25000        25000  ...              NaN          16.14
# 2      26500        26500  ...              NaN          11.31
# 3      10400        10400  ...              NaN          12.98
# 4      35000        35000  ...              NaN          12.98
#
# [5 rows x 141 columns]

# %%
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
#create emp_title_manager column

df['emp_title_manager'] = df['emp_title'].str.contains("Manager")
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  int_rate_float emp_title_manager
# 0      20000        20000  ...           14.47             False
# 1      25000        25000  ...           16.14              True
# 2      26500        26500  ...           11.31             False
# 3      10400        10400  ...           12.98             False
# 4      35000        35000  ...           12.98              True
#
# [5 rows x 142 columns]

# %%
#filter the data so that we have 2 subsets based on a condition

condition = (df['emp_title_manager'] == True)

managers = df[df['emp_title_manager'] == True]

print(managers.shape)
managers.head()
# Out:
# (17882, 142)
#     loan_amnt  funded_amnt  ...  int_rate_float emp_title_manager
# 1       25000        25000  ...           16.14              True
# 4       35000        35000  ...           12.98              True
# 8       12000        12000  ...           11.80              True
# 16      12000        12000  ...           16.14              True
# 18      20400        20400  ...           10.33              True
#
# [5 rows x 142 columns]

# %%
(df['emp_title_manager'] == False) & (df['home_ownership']=="OWN")
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24         True
# 25        False
# 26        False
# 27         True
# 28        False
# 29        False
#           ...
# 128382    False
# 128383    False
# 128384    False
# 128385    False
# 128386    False
# 128387    False
# 128388    False
# 128389    False
# 128390    False
# 128391    False
# 128392    False
# 128393    False
# 128394    False
# 128395    False
# 128396    False
# 128397    False
# 128398    False
# 128399    False
# 128400    False
# 128401     True
# 128402    False
# 128403     True
# 128404    False
# 128405    False
# ...

# %%
not_mang = df[(df['emp_title_manager'] == False) & (df['home_ownership']=="MORTGAGE")]
print(not_mang.shape)
not_mang.head()
# Out:
# (53930, 142)
#     loan_amnt  funded_amnt  ...  int_rate_float emp_title_manager
# 2       26500        26500  ...           11.31             False
# 3       10400        10400  ...           12.98             False
# 5       20000        20000  ...            7.56             False
# 6       13000        13000  ...           17.97             False
# 11       7000         7000  ...           10.72             False
#
# [5 rows x 142 columns]

# %%
managers['int_rate_float'].mean()
# Out:
# 12.760582149647117

# %%
not_mang['int_rate_float'].mean()
# Out:
# 12.576722603373335

# %%
#now we can viz the data
#with seaborn

import seaborn as sns
sns.kdeplot(not_mang['int_rate_float'])
sns.kdeplot(managers['int_rate_float']);

# %%
sns.distplot(not_mang['int_rate_float'])
sns.distplot(managers['int_rate_float']);

# %%
#list of all the colunms in our df

list(df.columns)

# %%
#looking at columns with dates
#the '_d' being dates 
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
#issue_d is an object right now
df.dtypes[:15]
# Out:
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate                object
# installment            float64
# grade                   object
# sub_grade               object
# emp_title               object
# emp_length              object
# home_ownership          object
# annual_inc             float64
# verification_status     object
# issue_d                 object
# loan_status             object
# dtype: object

# %%
#lets look at it

df['issue_d'][:15]
# Out:
# 0     Dec-2018
# 1     Dec-2018
# 2     Dec-2018
# 3     Dec-2018
# 4     Dec-2018
# 5     Dec-2018
# 6     Dec-2018
# 7     Dec-2018
# 8     Dec-2018
# 9     Dec-2018
# 10    Dec-2018
# 11    Dec-2018
# 12    Dec-2018
# 13    Dec-2018
# 14    Dec-2018
# Name: issue_d, dtype: object

# %%
#change the format of the date to datetime64 
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  int_rate_float emp_title_manager
# 0      20000        20000  ...           14.47             False
# 1      25000        25000  ...           16.14              True
# 2      26500        26500  ...           11.31             False
# 3      10400        10400  ...           12.98             False
# 4      35000        35000  ...           12.98              True
#
# [5 rows x 142 columns]

# %%
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
#check the years in df
#df['issue_d'].dt.year

# %%
#a column of loan issue year
df['issue_year'] = df["issue_d"].dt.year

# %%
#a column of loan issue month
df['issue_month'] = df["issue_d"].dt.month

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      20000        20000  ...        2018          12
# 1      25000        25000  ...        2018          12
# 2      26500        26500  ...        2018          12
# 3      10400        10400  ...        2018          12
# 4      35000        35000  ...        2018          12
#
# [5 rows x 144 columns]

# %%
df['earliest_cr_line'].head()
# Out:
# 0    Jun-1979
# 1    Sep-2003
# 2    Dec-2006
# 3    Jul-2013
# 4    Sep-1985
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], 
                                        infer_datetime_format=True)

# %%
df['days_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_month days_from_earliest_credit_to_issue
# 0      20000        20000  ...           12                              14428
# 1      25000        25000  ...           12                               5570
# 2      26500        26500  ...           12                               4383
# 3      10400        10400  ...           12                               1979
# 4      35000        35000  ...           12                              12144
#
# [5 rows x 145 columns]

# %%
df['days_from_earliest_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: days_from_earliest_credit_to_issue, dtype: float64

# %%
#max days is 25171
#that comes out to 68.96 years

# %% [markdown]
# ##make the column term into a float

# %%
#stripping 'months' off of the object
#and converting to float

def term_float(astring):
  return float(astring.strip().strip('months'))

term_float(term_s)
# Out:
# 36.0

# %%
#now to apply to the df

df['term'].apply(term_float)[:15]
# Out:
# 0     36.0
# 1     60.0
# 2     60.0
# 3     36.0
# 4     60.0
# 5     36.0
# 6     36.0
# 7     60.0
# 8     36.0
# 9     60.0
# 10    60.0
# 11    36.0
# 12    36.0
# 13    36.0
# 14    36.0
# Name: term, dtype: float64

# %%
df['term'] = df['term'].apply(term_float)


df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_month  days_from_earliest_credit_to_issue
# 0      20000        20000  ...           12                               14428
# 1      25000        25000  ...           12                                5570
# 2      26500        26500  ...           12                                4383
# 3      10400        10400  ...           12                                1979
# 4      35000        35000  ...           12                               12144
#
# [5 rows x 145 columns]

# %% [markdown]
# ##loan status is great column

# %%
df['loan_status'].value_counts()
# Out:
# Current               105925
# Fully Paid             15780
# Charged Off             2863
# Late (31-120 days)      2482
# In Grace Period          901
# Late (16-30 days)        459
# Default                    2
# Name: loan_status, dtype: int64

# %%
#leaving the column with True and False since that is still boolean

df['loan_status_is_great']  = df['loan_status'].str.contains('Current', 'Fully Paid')

df.head()
# Out:
#    loan_amnt  ...  loan_status_is_great
# 0      20000  ...                  True
# 1      25000  ...                 False
# 2      26500  ...                  True
# 3      10400  ...                  True
# 4      35000  ...                 False
#
# [5 rows x 146 columns]

# %% [markdown]
# ##Make last_pymnt_d_month and last_pymnt_d_year columns.

# %%
df['last_pymnt_d'][:10]
# Out:
# 0    Sep-2019
# 1    Apr-2019
# 2    Sep-2019
# 3    Sep-2019
# 4    Apr-2019
# 5    Feb-2019
# 6    Sep-2019
# 7    Sep-2019
# 8    Sep-2019
# 9    Sep-2019
# Name: last_pymnt_d, dtype: object

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)

# %%
df['last_pymnt_d'][:10]
# Out:
# 0   2019-09-01
# 1   2019-04-01
# 2   2019-09-01
# 3   2019-09-01
# 4   2019-04-01
# 5   2019-02-01
# 6   2019-09-01
# 7   2019-09-01
# 8   2019-09-01
# 9   2019-09-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
type(df['last_pymnt_d'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['last_pymnt_d'].dt.year[:15]
# Out:
# 0     2019.0
# 1     2019.0
# 2     2019.0
# 3     2019.0
# 4     2019.0
# 5     2019.0
# 6     2019.0
# 7     2019.0
# 8     2019.0
# 9     2019.0
# 10    2019.0
# 11    2019.0
# 12    2019.0
# 13    2019.0
# 14    2019.0
# Name: last_pymnt_d, dtype: float64

# %%
df['last_pymnt_d_month'] = df['last_pymnt_d'].dt.month

# %%
df['last_pymnt_d_year'] = df['last_pymnt_d'].dt.year

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  last_pymnt_d_month  last_pymnt_d_year
# 0      20000        20000  ...                 9.0             2019.0
# 1      25000        25000  ...                 4.0             2019.0
# 2      26500        26500  ...                 9.0             2019.0
# 3      10400        10400  ...                 9.0             2019.0
# 4      35000        35000  ...                 4.0             2019.0
#
# [5 rows x 148 columns]

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
