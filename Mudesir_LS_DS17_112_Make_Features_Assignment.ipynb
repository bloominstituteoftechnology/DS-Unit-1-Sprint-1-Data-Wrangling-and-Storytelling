# %% [markdown]
# <a href="https://colab.research.google.com/github/mudesir/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Mudesir_LS_DS17_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####
import pandas as pd
# Lets take a look at the Ames Iowa Housing Dataset:
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
pd.set_option('display.max_rows', 400)

# We can look at column datatypes 
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
# Look at the first ten rows of the `BedroomAbvGr` column.
### Looks like integers from the first 5 rows
df['BedroomAbvGr'].head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    4
# 5    1
# 6    3
# 7    3
# 8    2
# 9    2
# Name: BedroomAbvGr, dtype: int64

# %%
# Look at the first ten rows of the `BedroomAbvGr` column.
df['LotFrontage'].head(10)
# Out:
# 0    65.0
# 1    80.0
# 2    68.0
# 3    60.0
# 4    84.0
# 5    85.0
# 6    75.0
# 7     NaN
# 8    51.0
# 9    50.0
# Name: LotFrontage, dtype: float64

# %%
# It looks float data type but have '0' after period and have missed value
df['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 67.0      12
# 57.0      12
# 82.0      12
# 43.0      12
# 40.0      12
# 76.0      11
# 69.0      11
# 53.0      10
# 92.0      10
# 88.0      10
# 34.0      10
# 86.0      10
# 77.0       9
# 35.0       9
# 44.0       9
# 84.0       9
# 62.0       9
# 93.0       8
# 61.0       8
# 98.0       8
# 96.0       8
# 107.0      7
# 95.0       7
# 120.0      7
# 58.0       7
# 41.0       6
# 105.0      6
# 54.0       6
# 94.0       6
# 48.0       6
# 110.0      6
# 30.0       6
# 89.0       6
# 81.0       6
# 91.0       6
# 36.0       6
# 47.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# ...

# %%
# NaN is the most common value in this column. What is a NaN
df["LotFrontage"].value_counts(dropna=False).head()
# Out:
# NaN     259
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# Name: LotFrontage, dtype: int64

# %%
import numpy as np
# What is the datatype of NaN?
type(np.NaN)
# Out:
# float

# %%
# We can make a smaller dataframe with a few specific column headers
# by passing a list of column headers inside of the square brackets
small_df = df[['TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'SalePrice']].copy()

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice
# 0          856       856       854     208500
# 1         1262      1262         0     181500
# 2          920       920       866     223500
# 3          756       961       756     140000
# 4         1145      1145      1053     250000

# %%
# Lets add up all of the square footage to get a single square footage 
# column for the entire dataset
# Using bracket syntax to make a new 'TotalSquareFootage' column

small_df['TotalSquareFootage'] = small_df['TotalBsmtSF'] + small_df['1stFlrSF'] + small_df['2ndFlrSF']

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage
# 0          856       856       854     208500                2566
# 1         1262      1262         0     181500                2524
# 2          920       920       866     223500                2706
# 3          756       961       756     140000                2473
# 4         1145      1145      1053     250000                3343

# %%
## Lets make another new column that is 'PricePerSqFt' by
# dividing the price by the square footage

small_df['PricePerSqFt'] = (small_df['SalePrice'] / small_df['TotalSquareFootage'])

small_df.head()
# Out:
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  SalePrice  TotalSquareFootage  PricePerSqFt
# 0          856       856       854     208500                2566     81.254871
# 1         1262      1262         0     181500                2524     71.909667
# 2          920       920       866     223500                2706     82.594235
# 3          756       961       756     140000                2473     56.611403
# 4         1145      1145      1053     250000                3343     74.783129

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-06-03 19:46:07--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 44.228.179.66, 35.163.140.110, 52.89.160.109
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|44.228.179.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [           <=>      ]  22.10M  2.05MB/s    in 12s
#
# 2020-06-03 19:46:19 (1.90 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23170772]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# look at the raw file using the !head and !tail commands
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","2926.62","2926.62","3603.44","3603.44","2673.38","930.06","0.0","0.0","0.0","May-2020","190.21","Jun-2020","May-2020","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
# look at the raw file itself, do you see anything that might cause us 
# trouble as we read in the CSV file to a dataframe
df = pd.read_csv('LoanStats_2018Q4.csv')

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128415, 1)
# ...

# %%
# There is a problem in header We can fix
# the header problem by using the 'skiprows' parameter
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)

print(df.shape)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (128414, 144)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
# look at the NaN values of each column so that you can see the problem
# that the extra rows at the bottom of the file are creating for us
# Sum null values by column and sort from least to greatest
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# mo_sin_old_rev_tl_op                               2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# open_il_12m                                        2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
# Address the extra NaNs in each column by skipping the footer as well.
df = pd.read_csv('LoanStats_2018Q4.csv', 
                 skiprows=1, 
                 skipfooter=2, 
                 engine='python')
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# mo_sin_old_rev_tl_op                               0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# open_il_12m                                        0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
# We’ll also drop some columns that are made up completely of NaN values
df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
print(df.shape)
df.head()
# Out:
# (128412, 140)
#    loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0      20000        20000  ...                    NaN             NaN
# 1      16000        16000  ...                    NaN             NaN
# 2       8425         8425  ...                    NaN             NaN
# 3      10000        10000  ...                    NaN             NaN
# 4      30000        30000  ...                    NaN             NaN
#
# [5 rows x 140 columns]

# %%
#check NaN again
print(df.shape)
df.isnull().sum()
# Out:
# (128412, 140)
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
#                           ...
# settlement_status        127561
# settlement_date          127561
# settlement_amount        127561
# settlement_percentage    127561
# settlement_term          127561
# Length: 140, dtype: int64

# %%
# Clean up the int_rate column we don’t want to leave any string values in
# our dataset –because it’s hard to do math 
# Look at the first 10 values of the int_rate column
df['int_rate'][:10]
# Out:
# 0     16.14%
# 1     11.80%
# 2     11.31%
# 3     14.47%
# 4     27.27%
# 5     16.14%
# 6     12.98%
# 7     12.98%
# 8     10.33%
# 9     23.40%
# Name: int_rate, dtype: object

# %%
# Look at a specific value from the int_rate column
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
# Problems that we need to address with this column:
# String column that should be numeric
# Percent Sign % included with the number
# Leading space at the beginning of the string
# Lets start with just fixing a single string.
# If we can fix one, we can usually fix all of them
int_rate = ' 14.17%'

# %%
int_rate.strip()
# Out:
# '14.17%'

# %%
int_rate.strip('%')
# Out:
# ' 14.17'

# %%
int_rate.strip().strip('%')
# Out:
# '14.17'

# %%
# look at data type
type(int_rate.strip().strip('%'))
# Out:
# str

# %%
# "Cast" the string value to a float

float(int_rate.strip().strip('%'))
# Out:
# 14.17

# %%
# Now look at data type
type(float(int_rate.strip().strip('%')))
# Out:
# float

# %%
# Write a function that can do what we have written above to any 
# string that is passsed to it.

def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
# Test out our function by calling it on our example

int_rate_to_float(int_rate)
# Out:
# 14.17

# %%
# is the data type correct?

type(int_rate_to_float(int_rate))
# Out:
# float

# %%
# Apply our solution to every cell in a column
df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      20000        20000  ...              NaN          14.47
# 1      16000        16000  ...              NaN          14.47
# 2       8425         8425  ...              NaN          27.27
# 3      10000        10000  ...              NaN          12.98
# 4      30000        30000  ...              NaN          26.31
#
# [5 rows x 141 columns]

# %%
# What type of data is held in our new column?
# Look at the datatypes of the last 5 columns
df.dtypes[-5:]
# Out:
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# int_rate_float           float64
# dtype: object

# %%
# Look at the top 20 employment titles
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
len(df['emp_title'].value_counts())
# Out:
# 43892

# %%
# How often is the employment_title null?
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
# Create some examples that represent the cases that we want to clean up
import numpy as np

examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
# Write a function to clean up these use cases and increase uniformity.
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"
for example in examples:
  print(clean_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
# list comprehensions can combine function calls and for loops over lists
# into one succinct and fairly readable single line of code.
[clean_title(example) for example in examples]
# Out:
# ['Owner', 'Supervisor', 'Project Manager', 'Unknown']

# %%
# We have a function that works as expected. Lets apply it to our column.
# This time we'll overwrite the original column
df['emp_title'] = df['emp_title'].apply(clean_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  settlement_term int_rate_float
# 0      20000        20000  ...              NaN          14.47
# 1      16000        16000  ...              NaN          14.47
# 2       8425         8425  ...              NaN          27.27
# 3      10000        10000  ...              NaN          12.98
# 4      30000        30000  ...              NaN          26.31
#
# [5 rows x 141 columns]

# %%
# Look at the top 20 employment titles
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
# How many different unique employment titles are there currently?
len(df['emp_title'].value_counts())
# Out:
# 34902

# %%
# How often is the employment_title null (NaN)?
df['emp_title'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
df['loan_status_is_great'] = df.loan_status.apply(lambda x: 1 if x in ["Current", "Fully Paid"] else 0)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  revol_util_to_float loan_status_is_great
# 0      20000        20000  ...                 73.0                    0
# 1      16000        16000  ...                 59.2                    1
# 2       8425         8425  ...                 65.7                    1
# 3      10000        10000  ...                 54.2                    1
# 4      30000        30000  ...                 39.8                    0
#
# [5 rows x 146 columns]

# %%
df['loan_status_is_great'].value_counts()
# Out:
# 1    116544
# 0     11868
# Name: loan_status_is_great, dtype: int64

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
# Lets look at the string format of the issue_d column
df['issue_d'][:10]
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)
df.dtypes[:15]
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                datetime64[ns]
# loan_status                    object
# dtype: object

# %%
# Lets look at one of the cells specifically to see what a datetime object looks like:
df['issue_d'].iloc[0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
# Now grab specific parts of the datetime object
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
# Now, instead of printing them out, lets add these year and
# month values as new columns on our dataframe
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_year issue_month
# 0      20000        20000  ...        2018          12
# 1      16000        16000  ...        2018          12
# 2       8425         8425  ...        2018          12
# 3      10000        10000  ...        2018          12
# 4      30000        30000  ...        2018          12
#
# [5 rows x 143 columns]

# %%
# We’re going to create a new column called days_from_earliest_credit_to_issue
df['earliest_cr_line'].head()
# Out:
# 0    Mar-1991
# 1    Aug-2011
# 2    Dec-2003
# 3    Jan-1997
# 4    Dec-1997
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], 
                                        infer_datetime_format=True)

# %%
df['days_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line']).dt.days
df['days_from_earliest_credit_to_issue'].head()
# Out:
# 0    14428
# 1     6239
# 2     7731
# 3     4232
# 4     4079
# Name: days_from_earliest_credit_to_issue, dtype: int64

# %%
# What’s oldest credit history that was involved in Q4 2018?
df['days_from_earliest_credit_to_issue'].describe()
# Out:
# count    128412.000000
# mean       5859.891490
# std        2886.535578
# min        1126.000000
# 25%        4049.000000
# 50%        5266.000000
# 75%        7244.000000
# max       25171.000000
# Name: days_from_earliest_credit_to_issue, dtype: float64

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %%
df['revol_util'].value_counts()
# Out:
# 0%        1132
# 43%        225
# 49%        222
# 39.1%      220
# 32%        217
#           ...
# 107.6%       1
# 108.7%       1
# 113.2%       1
# 108.8%       1
# 103.7%       1
# Name: revol_util, Length: 1074, dtype: int64

# %%
df['revol_util'].isnull().sum()
# Out:
# 156

# %%
# Look at the top 20 revol_util values
df['revol_util'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# 0%       1132
# 43%       225
# 49%       222
# 39.1%     220
# 32%       217
# 32.9%     216
# 28%       214
# 37.5%     213
# 44%       212
# 33.8%     211
# 33%       211
# 51%       211
# 29%       210
# 34%       210
# 38%       210
# 47%       208
# 33.3%     208
# 39%       205
# 45%       203
# 37.3%     203
# Name: revol_util, dtype: int64

# %%
# Create some examples that represent the cases that we want to clean up

examples = ['25%', '37.3%', '39%', np.NaN]

# %%
# Write a function to clean up these use cases and increase uniformity.
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "0.001%"
for example in examples:
  print(clean_title(example))
# Out:
# 25%
# 37.3%
# 39%
# 0.001%

# %%
# list comprehensions can combine function calls and for loops over lists
# into one succinct and fairly readable single line of code.
[clean_title(example) for example in examples]
# Out:
# ['25%', '37.3%', '39%', '0.001%']

# %%
df['revol_util'].isnull().sum()
# Out:
# 156

# %%
# We have a function that works as expected. Lets apply it to our column.
# This time we'll overwrite the original column
df['revol_util'] = df['revol_util'].apply(clean_title)
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  issue_month days_from_earliest_credit_to_issue
# 0      20000        20000  ...           12                              14428
# 1      16000        16000  ...           12                               6239
# 2       8425         8425  ...           12                               7731
# 3      10000        10000  ...           12                               4232
# 4      30000        30000  ...           12                               4079
#
# [5 rows x 144 columns]

# %%
# Look at the top 20 employment titles
df['revol_util'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# 0%       1132
# 43%       225
# 49%       222
# 39.1%     220
# 32%       217
# 32.9%     216
# 28%       214
# 37.5%     213
# 44%       212
# 33.8%     211
# 51%       211
# 33%       211
# 29%       210
# 38%       210
# 34%       210
# 47%       208
# 33.3%     208
# 39%       205
# 37.3%     203
# 41%       203
# Name: revol_util, dtype: int64

# %%
# How many different unique revol_util are there currently?
len(df['revol_util'].value_counts())
# Out:
# 1075

# %%
# How often is the revol_util null (NaN)?
df['revol_util'].isnull().sum()
# Out:
# 0

# %%
# Clean up the revol_util column we don’t want to leave any string values in
# our dataset because it’s hard to do math 
# Look at the first 10 values of the revol_util	_rate column
df['revol_util'][:10]
# Out:
# 0       73%
# 1     59.2%
# 2     65.7%
# 3     54.2%
# 4     39.8%
# 5     49.6%
# 6     41.6%
# 7     12.6%
# 8    101.8%
# 9     53.3%
# Name: revol_util, dtype: object

# %%
# Look at a specific value from the revol_util column
df['revol_util'][0]
# Out:
# '73%'

# %%
# Problems that we need to address with this column:
# String column that should be numeric
# Percent Sign % included with the number
# Lets start with just fixing a single string.
# If we can fix one, we can usually fix all of them
revol_util = '58.5%'

# %%
revol_util.strip('%')
# Out:
# '58.5'

# %%
# Write a function that can do what we have written above to any 
# string that is passsed to it.

def revol_util_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
# Test out our function by calling it on our example

revol_util_to_float(revol_util)
# Out:
# 58.5

# %%
# is the data type correct?

type(revol_util_to_float(revol_util))
# Out:
# float

# %%
# Apply our solution to every cell in a column
df['revol_util_to_float'] = df['revol_util'].apply(revol_util_to_float)
df.head()
# Out:
#    loan_amnt  ...  revol_util_to_float
# 0      20000  ...                 73.0
# 1      16000  ...                 59.2
# 2       8425  ...                 65.7
# 3      10000  ...                 54.2
# 4      30000  ...                 39.8
#
# [5 rows x 145 columns]

# %%
print(df['revol_util_to_float'].mean())
# Out:
# 44.143589820265206

# %%
df['revol_util_to_float'] = df['revol_util_to_float'].replace(0.001, 44.14)

# %%
# What type of data is held in our new column?
# Look at the datatypes of the last 5 columns
df.dtypes[-5:]
# Out:
# int_rate_float                        float64
# issue_year                              int64
# issue_month                             int64
# days_from_earliest_credit_to_issue      int64
# revol_util_to_float                   float64
# dtype: object

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-06-03 20:13:49--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.131.173
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.131.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  87.3MB/s    in 2.2s
#
# 2020-06-03 20:13:51 (87.3 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
 # !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
 # %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01
