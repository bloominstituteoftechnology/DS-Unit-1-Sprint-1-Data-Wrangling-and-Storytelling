# %% [markdown]
# <a href="https://colab.research.google.com/github/evitts1989/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Corey_Evitts_LS_DS_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-02-13 14:58:04--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [ <=>                ]  21.74M  1.54MB/s    in 14s
#
# 2020-02-13 14:58:18 (1.52 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [22793561]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# !head LoanStats_2018Q4.csv
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# ...

# %%
import pandas as pd
df = pd.read_csv('LoanStats_2018Q4.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.shape
# Out:
# (128415, 1)

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1)

df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  ...  settlement_percentage  settlement_term
# 0  NaN        NaN  ...                    NaN              NaN
# 1  NaN        NaN  ...                    NaN              NaN
# 2  NaN        NaN  ...                    NaN              NaN
# 3  NaN        NaN  ...                    NaN              NaN
# 4  NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
#                                                ...
# orig_projected_additional_accrued_interest    128174
# id                                            128412
# url                                           128414
# member_id                                     128414
# desc                                          128414
# Length: 144, dtype: int64

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')
print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
#                                                ...
# orig_projected_additional_accrued_interest    128172
# url                                           128412
# member_id                                     128412
# desc                                          128412
# id                                            128412
# Length: 144, dtype: int64

# %%
df.drop(['url','member_id','desc','id'], axis=1)
# Out:
#         loan_amnt  funded_amnt  ...  settlement_percentage settlement_term
# 0           35000        35000  ...                    NaN             NaN
# 1            5000         5000  ...                    NaN             NaN
# 2           10000        10000  ...                    NaN             NaN
# 3           17100        17100  ...                    NaN             NaN
# 4            4000         4000  ...                    NaN             NaN
# ...           ...          ...  ...                    ...             ...
# 128407      23000        23000  ...                    NaN             NaN
# 128408      10000        10000  ...                    NaN             NaN
# 128409       5000         5000  ...                    NaN             NaN
# 128410      10000        10000  ...                    NaN             NaN
# 128411      10000        10000  ...                    NaN             NaN
#
# [128412 rows x 140 columns]

# %%
df['int_rate'][0:10]
# Out:
# 0     14.47%
# 1     22.35%
# 2     23.40%
# 3     18.94%
# 4     10.72%
# 5     11.31%
# 6     11.31%
# 7     11.80%
# 8     11.80%
# 9     18.94%
# Name: int_rate, dtype: object

# %%
df['int_rate'][0]
# Out:
# ' 14.47%'

# %%
int_rate = ' 14.17%'

# %%
int_rate.strip()
# Out:
# '14.17%'

# %%
int_rate.strip('%')
# Out:
# ' 14.17'

# %%
int_rate.strip().strip('%')
# Out:
# '14.17'

# %%
type(int_rate.strip().strip('%'))
# Out:
# str

# %%
float(int_rate.strip().strip('%'))
# Out:
# 14.17

# %%
#Writing a function that is reusable to perform the lines of code above to any string we apply it to

def int_rate_to_float(cell_contents):
  return float(int_rate.strip().strip('%'))

# %%
int_rate_to_float(int_rate)
# Out:
# 14.17

# %%
df['int_rate'] = df['int_rate'].apply(int_rate_to_float)

df['int_rate'].head()
# Out:
# 0    14.17
# 1    14.17
# 2    14.17
# 3    14.17
# 4    14.17
# Name: int_rate, dtype: float64

# %%
#Look at the data types of the last 5 columns

df.dtypes[-5:]
# Out:
# settlement_status         object
# settlement_date           object
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# dtype: object

# %%
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Truck Driver            387
# Operations Manager      387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
import numpy as np

# %%
examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
def clean_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

for example in examples:
  print(clean_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
df['emp_title'] = df['emp_title'].apply(clean_title)

df.head()
# Out:
#    id  member_id  ...  settlement_percentage  settlement_term
# 0 NaN        NaN  ...                    NaN              NaN
# 1 NaN        NaN  ...                    NaN              NaN
# 2 NaN        NaN  ...                    NaN              NaN
# 3 NaN        NaN  ...                    NaN              NaN
# 4 NaN        NaN  ...                    NaN              NaN
#
# [5 rows x 144 columns]

# %%
df['emp_title'].value_counts(dropna=False, ascending=False)[:20]
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
len(df['emp_title'].value_counts())
# Out:
# 34902

# %%
df['emp_title'].isnull().sum()
# Out:
# 0

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'][:10]
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# 5    Dec-2018
# 6    Dec-2018
# 7    Dec-2018
# 8    Dec-2018
# 9    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

df.dtypes['issue_d']
# Out:
# dtype('<M8[ns]')

# %%
df['issue_d'].iloc[0]
# Out:
# Timestamp('2018-12-01 00:00:00')

# %%
df['issue_d'].head().values
# Out:
# array(['2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2018-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year 
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    id  member_id  loan_amnt  ...  settlement_term  issue_year issue_month
# 0 NaN        NaN      35000  ...              NaN        2018          12
# 1 NaN        NaN       5000  ...              NaN        2018          12
# 2 NaN        NaN      10000  ...              NaN        2018          12
# 3 NaN        NaN      17100  ...              NaN        2018          12
# 4 NaN        NaN       4000  ...              NaN        2018          12
#
# [5 rows x 146 columns]

# %%
df['earliest_cr_line'].head()
# Out:
# 0    Apr-1995
# 1    Mar-2010
# 2    Apr-2007
# 3    Mar-1998
# 4    Sep-2006
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], infer_datetime_format=True)
df['earliest_cr_line'].head()
# Out:
# 0   1995-04-01
# 1   2010-03-01
# 2   2007-04-01
# 3   1998-03-01
# 4   2006-09-01
# Name: earliest_cr_line, dtype: datetime64[ns]

# %%
df['days_from_earliest_credit_to_issue'] = (df['issue_d'] - df['earliest_cr_line'])

df['days_from_earliest_credit_to_issue'].head()
# Out:
# 0   8645 days
# 1   3197 days
# 2   4262 days
# 3   7580 days
# 4   4474 days
# Name: days_from_earliest_credit_to_issue, dtype: timedelta64[ns]

# %%
df['days_from_earliest_credit_to_issue'].describe()
# Out:
# count                       128412
# mean     5859 days 21:23:44.726636
# std      2886 days 12:51:13.941888
# min             1126 days 00:00:00
# 25%             4049 days 00:00:00
# 50%             5266 days 00:00:00
# 75%             7244 days 00:00:00
# max            25171 days 00:00:00
# Name: days_from_earliest_credit_to_issue, dtype: object

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
term_0 = df.loc[0, 'term']
def term_0_to_int(mystring):
  return int(mystring.strip(' months'))
df['term_2_int'] = df['term'].apply(term_0_to_int)
df['term_2_int'].dtype
df[['term', 'term_2_int']].head()
# Out:
#          term  term_2_int
# 0   36 months          36
# 1   36 months          36
# 2   60 months          60
# 3   36 months          36
# 4   36 months          36

# %%
df['loan_status'].dtypes
# Out:
# dtype('O')

# %%
# Checking if 'Current' or 'Fully Paid' is in the loan_status column & how it is represented.
df['loan_status_is_great'] = df['loan_status'].isin(['Current','Fully Paid']).astype(int)

# %%
df[['loan_status_is_great', 'loan_status']].sample(6)
# Out:
#        loan_status_is_great        loan_status
# 76981                     1         Fully Paid
# 33517                     1            Current
# 9702                      1            Current
# 29511                     1            Current
# 85180                     0  Late (16-30 days)
# 47987                     1            Current

# %%
for col in df.columns:
  if (col.endswith('_d')) or (col.endswith('_date')):
    print(col)
# Out:
# issue_d
# last_pymnt_d
# next_pymnt_d
# last_credit_pull_d
# hardship_start_date
# hardship_end_date
# payment_plan_start_date
# debt_settlement_flag_date
# settlement_date

# %%
df['last_pymnt_d'].dtypes
df['last_pymnt_date'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format=True)
df['last_pymnt_d_month'] = df['last_pymnt_date'].dt.month
df['last_pymnt_d_year'] = df['last_pymnt_date'].dt.year
df[['last_pymnt_d', 'last_pymnt_date', 'last_pymnt_d_month', 'last_pymnt_d_year']].sample(10)
# Out:
#        last_pymnt_d last_pymnt_date  last_pymnt_d_month  last_pymnt_d_year
# 86396      Oct-2019      2019-10-01                10.0             2019.0
# 50963      Jan-2020      2020-01-01                 1.0             2020.0
# 107166     Jan-2020      2020-01-01                 1.0             2020.0
# 63603      May-2019      2019-05-01                 5.0             2019.0
# 39674      Jan-2020      2020-01-01                 1.0             2020.0
# 78806      Jan-2020      2020-01-01                 1.0             2020.0
# 85018      Jan-2020      2020-01-01                 1.0             2020.0
# 54459      Jan-2020      2020-01-01                 1.0             2020.0
# 60872      Jan-2020      2020-01-01                 1.0             2020.0
# 21917      Jun-2019      2019-06-01                 6.0             2019.0

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
