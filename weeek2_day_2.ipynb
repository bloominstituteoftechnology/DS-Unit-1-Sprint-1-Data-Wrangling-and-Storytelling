# %% [markdown]
# <a href="https://colab.research.google.com/github/nealonleo9/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/weeek2_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
import pandas as pd

# Pandas Display Options

pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 100)

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-06-02 21:30:05--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 52.89.160.109, 44.228.179.66, 35.163.140.110
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|52.89.160.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [               <=>  ]  22.10M  2.03MB/s    in 11s
#
# 2020-06-02 21:30:17 (2.00 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23170772]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      16000        16000          16000.0   36 months     14.47       550.51
# 2       8425         8425           8425.0   36 months     27.27       345.18
# 3      10000        10000          10000.0   60 months     12.98       227.43
# 4      30000        30000          30000.0   60 months     26.31       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       Bus Driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
# Read in the CSV

df = pd.read_csv('LoanStats_2018Q4.csv', header=1)

df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    20000.0      20000.0          20000.0   36 months
# 1  NaN        NaN    16000.0      16000.0          16000.0   36 months
# 2  NaN        NaN     8425.0       8425.0           8425.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 4  NaN        NaN    30000.0      30000.0          30000.0   60 months
#
#   int_rate  installment grade sub_grade                        emp_title  \
# 0   14.47%       688.13     C        C2                       bus driver
# 1   14.47%       550.51     C        C2                        Carpenter
# 2   27.27%       345.18     E        E5  Senior Director Risk Management
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             2
# mo_sin_old_rev_tl_op                               2
# delinq_amnt                                        2
# chargeoff_within_12_mths                           2
# acc_open_past_24mths                               2
# inq_last_12m                                       2
# total_cu_tl                                        2
# total_rev_hi_lim                                   2
# open_rv_24m                                        2
# open_rv_12m                                        2
# total_bal_il                                       2
# open_il_24m                                        2
# open_il_12m                                        2
# open_act_il                                        2
# open_acc_6m                                        2
# tot_cur_bal                                        2
# tot_coll_amt                                       2
# acc_now_delinq                                     2
# ...

# %%
df = pd.read_csv('LoanStats_2018Q4.csv', skiprows=1, skipfooter=2, engine='python')

print(df.shape)
df.head()
# Out:
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      16000        16000          16000.0   36 months
# 2 NaN        NaN       8425         8425           8425.0   36 months
# 3 NaN        NaN      10000        10000          10000.0   60 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#   int_rate  installment grade sub_grade                        emp_title  \
# 0   14.47%       688.13     C        C2                       bus driver
# 1   14.47%       550.51     C        C2                        Carpenter
# 2   27.27%       345.18     E        E5  Senior Director Risk Management
# 3   12.98%       227.43     B        B5                          Printer
# 4   26.31%       903.73     E        E4                      Casino Host
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df = df.drop(['desc', 'url', 'member_id', 'id'], axis=1)

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     14.47%
# 2     27.27%
# 3     12.98%
# 4     26.31%
# 5     17.97%
# 6     11.80%
# 7     10.72%
# 8     16.14%
# 9     12.98%
# Name: int_rate, dtype: object

# %%
df['int_rate'][3]
# Out:
# ' 12.98%'

# %%
# alterantive way to get a slice of a dataframe
df.iloc[0:10,0:2]
# Out:
#    loan_amnt  funded_amnt
# 0      20000        20000
# 1      16000        16000
# 2       8425         8425
# 3      10000        10000
# 4      30000        30000
# 5      13000        13000
# 6       6500         6500
# 7       7500         7500
# 8      14000        14000
# 9      25000        25000

# %%
df['int_rate'].head(10)
# Out:
# 0     14.47%
# 1     14.47%
# 2     27.27%
# 3     12.98%
# 4     26.31%
# 5     17.97%
# 6     11.80%
# 7     10.72%
# 8     16.14%
# 9     12.98%
# Name: int_rate, dtype: object

# %%
#int_rate.strip()
#int_rate.strip('%')
#int_rate.strip().strip('%')
#type(int_rate.strip().strip('%'))
#float(int_rate.strip().strip('%'))
#type(float(int_rate.strip().strip('%')))

# %%
cleaned = []

for int_rate in df['int_rate']:
  cleaned.append(int_rate_to_float(int_rate))

df['int_rate_cleaned'] = pd.Series(cleaned)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      16000        16000          16000.0   36 months   14.47%       550.51
# 2       8425         8425           8425.0   36 months   27.27%       345.18
# 3      10000        10000          10000.0   60 months   12.98%       227.43
# 4      30000        30000          30000.0   60 months   26.31%       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       bus driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
df['int_rate'].values
# Out:
# array([' 14.47%', ' 14.47%', ' 27.27%', ..., ' 13.56%', ' 11.06%',
#        ' 16.91%'], dtype=object)

# %%
df['int_rate'] = df['int_rate'].apply(int_rate_to_float)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      16000        16000          16000.0   36 months     14.47       550.51
# 2       8425         8425           8425.0   36 months     27.27       345.18
# 3      10000        10000          10000.0   60 months     12.98       227.43
# 4      30000        30000          30000.0   60 months     26.31       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       bus driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
# Look at the top 20 employment titles
df['emp_title'].value_counts(dropna=False).head(20)
# Out:
# NaN                   20947
# Teacher                2090
# Manager                1773
# Registered Nurse        952
# Driver                  924
# RN                      726
# Supervisor              697
# Sales                   580
# Project Manager         526
# General Manager         523
# Office Manager          521
# Owner                   420
# Director                402
# Operations Manager      387
# Truck Driver            387
# Nurse                   326
# Engineer                325
# Sales Manager           304
# manager                 301
# Supervisor              270
# Name: emp_title, dtype: int64

# %%
df['emp_title'].nunique()
# Out:
# 43892

# %%
# How often is the employment_title null?
df['emp_title'].isnull().sum()
# Out:
# 20947

# %%
import numpy as np

examples = ['owner', 'Supervisor', ' Project Manager', np.NaN]

# %%
# Write a function to clean up these use cases and increase uniformity.

def clean_emp_title(title):
  if isinstance(title, str):
    return title.strip().title()
  else:
    return "Unknown"

for example in examples:
  print(clean_emp_title(example))
# Out:
# Owner
# Supervisor
# Project Manager
# Unknown

# %%
df['emp_title'] = df['emp_title'].apply(clean_emp_title)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      16000        16000          16000.0   36 months     14.47       550.51
# 2       8425         8425           8425.0   36 months     27.27       345.18
# 3      10000        10000          10000.0   60 months     12.98       227.43
# 4      30000        30000          30000.0   60 months     26.31       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       Bus Driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
loan_statuses = ['Current', 'Late (31-120 days)', 'Default', "Fully Paid (16-30 days)", "In Grace Period"]

loan_status_int = []

def is_the_status_great(status_string):
  if status_string == 'Current' or status_string == 'Fully Paid (16-30 days)':
    return 1
  else:
    return 0

for status in loan_statuses:
  loan_status_int.append(is_the_status_great(status))

example_df = pd.DataFrame()
example_df['loan_status'] = pd.Series(loan_status_int)

example_df.head()
# Out:
#    loan_status
# 0            1
# 1            0
# 2            0
# 3            1
# 4            0

# %%
df['loan_status_is_great'] = df['loan_status'].apply(is_the_status_great)

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      16000        16000          16000.0   36 months     14.47       550.51
# 2       8425         8425           8425.0   36 months     27.27       345.18
# 3      10000        10000          10000.0   60 months     12.98       227.43
# 4      30000        30000          30000.0   60 months     26.31       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       Bus Driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
[col for col in df if col.endswith('_d')]
# Out:
# ['issue_d', 'last_pymnt_d', 'next_pymnt_d', 'last_credit_pull_d']

# %%
df['issue_d'].head()
# Out:
# 0    Dec-2018
# 1    Dec-2018
# 2    Dec-2018
# 3    Dec-2018
# 4    Dec-2018
# Name: issue_d, dtype: object

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'], infer_datetime_format=True)

# %%
df['issue_d'].dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 128407    2018
# 128408    2018
# 128409    2018
# 128410    2018
# 128411    2018
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_d'].dt.month
# Out:
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 128407    10
# 128408    10
# 128409    10
# 128410    10
# 128411    10
# Name: issue_d, Length: 128412, dtype: int64

# %%
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month

df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      20000        20000          20000.0   36 months     14.47       688.13
# 1      16000        16000          16000.0   36 months     14.47       550.51
# 2       8425         8425           8425.0   36 months     27.27       345.18
# 3      10000        10000          10000.0   60 months     12.98       227.43
# 4      30000        30000          30000.0   60 months     26.31       903.73
#
#   grade sub_grade                        emp_title emp_length home_ownership  \
# 0     C        C2                       Bus Driver    4 years            OWN
# 1     C        C2                        Carpenter  10+ years           RENT
# 2     E        E5  Senior Director Risk Management    3 years       MORTGAGE
# 3     B        B5                          Printer    9 years           RENT
# 4     E        E4                      Casino Host  10+ years            OWN
#
# ...

# %%
df['emp_title'].value_counts().sum()
# Out:
# 128412

# %%
df['emp_title'].value_counts().head(20)
# Out:
# Unknown               20947
# Teacher                2557
# Manager                2395
# Registered Nurse       1418
# Driver                 1258
# Supervisor             1160
# Truck Driver            920
# Rn                      834
# Office Manager          805
# Sales                   803
# General Manager         791
# Project Manager         720
# Owner                   625
# Director                523
# Operations Manager      518
# Sales Manager           500
# Police Officer          440
# Nurse                   425
# Technician              420
# Engineer                412
# Name: emp_title, dtype: int64

# %%
df['revol_util'].head()
# Out:
# 0      73%
# 1    59.2%
# 2    65.7%
# 3    54.2%
# 4    39.8%
# Name: revol_util, dtype: object

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# --2020-06-02 21:31:16--  https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.45.238
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.45.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205548478 (196M) [application/x-gzip]
# Saving to: ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’
#
# instacart_online_gr 100%[===================>] 196.03M  30.0MB/s    in 7.2s
#
# 2020-06-02 21:31:24 (27.1 MB/s) - ‘instacart_online_grocery_shopping_2017_05_01.tar.gz’ saved [205548478/205548478]

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# instacart_2017_05_01/
# instacart_2017_05_01/._aisles.csv
# instacart_2017_05_01/aisles.csv
# instacart_2017_05_01/._departments.csv
# instacart_2017_05_01/departments.csv
# instacart_2017_05_01/._order_products__prior.csv
# instacart_2017_05_01/order_products__prior.csv
# instacart_2017_05_01/._order_products__train.csv
# instacart_2017_05_01/order_products__train.csv
# instacart_2017_05_01/._orders.csv
# instacart_2017_05_01/orders.csv
# instacart_2017_05_01/._products.csv
# instacart_2017_05_01/products.csv

# %%
# %cd instacart_2017_05_01
# Out:
# /content/instacart_2017_05_01/instacart_2017_05_01

# %%
# !unzip /content/instacart_online_grocery_shopping_2017_05_01.tar.gz
# Out:
# Archive:  /content/instacart_online_grocery_shopping_2017_05_01.tar.gz
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/instacart_online_grocery_shopping_2017_05_01.tar.gz or
#         /content/instacart_online_grocery_shopping_2017_05_01.tar.gz.zip, and cannot find /content/instacart_online_grocery_shopping_2017_05_01.tar.gz.ZIP, period.

# %%
df1 = pd.read_csv('/content/instacart_2017_05_01/order_products__prior.csv')
df2 = pd.read_csv('/content/instacart_2017_05_01/order_products__train.csv')
df3 = pd.read_csv('/content/instacart_2017_05_01/orders.csv')
df4 = pd.read_csv('/content/instacart_2017_05_01/products.csv')
df5 = pd.read_csv('/content/instacart_2017_05_01/departments.csv')

df7 = pd.read_csv('/content/instacart_2017_05_01/aisles.csv')

# %%
df1.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df3.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
